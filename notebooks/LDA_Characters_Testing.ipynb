# %%
import operator
from collections import Counter
import math
import os
import json
import gensim
from gensim import corpora

# %%
'''
Read in parsed books 
'''
def read_parsed_book_data(dataPath):
    data = {}
    for fileName in os.listdir(dataPath):
        with open(os.path.join(dataPath, fileName), 'r') as file:
            data[fileName.split("_parsed_")[0]]=json.load(file)
    print("Read " + str(len(data)) + " books")
    return data

# %%
'''
For parsing BookNLP formatted outputs.
'''

# def read_book_nlp_metadata(filename):
#     metadata={}
#     with open(filename) as file:
#         for line in file:
#             cols=line.rstrip().split("\t")
#             idd=cols[0]
#             date=int(cols[1])
#             author=cols[2]
#             title=cols[3]
#             author_gender=cols[4]
#             metadata[idd]=(date, author, title, author_gender)
#     return metadata

# def read_book_nlp_data(data_folder):
#     data={}

#     for idd in metadata:
#         filename=os.path.join(data_folder, "%s.book" % idd)
#         if os.path.exists(filename):
#             with open(filename) as file:
#                 data[idd]=json.load(file)

#     print(f"Read {len(data)} books")
#     return data

# %%
def get_corpus_frequencies(alldata, bookNLP=False):
    
    agentFreqs = Counter()
    patientFreqs =  Counter()
    modFreqs =  Counter()
    
    for idd in alldata:
        data=alldata[idd]
        for character in data["characters"]:
            if bookNLP:
                for term in character["agent"]:
                    agentFreqs[term['w']] += 1
                for term in character["patient"]:
                    patientFreqs[term['w']] += 1
                for term in character["mod"]:
                    modFreqs[term['w']] += 1 
            else:
                for action in character["agent"]:
                    agentFreqs[list(action.values())[0]] += 1
                for action in character["patient"]:
                    patientFreqs[list(action.values())[0]] += 1
                    
    return agentFreqs, patientFreqs, modFreqs

# %%
def get_character_actions(alldata, agentFilter={}, patientFilter={}, modFilter={}, bookNLP=False):
    
    charactersAgentsDict = {}
    charactersAgentsList = []
    charNameList = []
    
    for idd in alldata:
        data=alldata[idd]
        if bookNLP:
            for character in data["characters"]:
                if len(character["names"]) > 0:
                    char_name = character["names"][0]['n']
                    charNameList.append(char_name)
                    charactersAgentsDict[char_name] = Counter()
                    charactersAgentsList.append([])
                    agent_terms=[term["w"] + "_agent" for term in character["agent"] \
                                 if term["w"] not in agentFilter]
                    agent_terms += [term["w"] + "_patient" for term in character["patient"]\
                                 if term["w"] not in patientFilter]
                    agent_terms += [term["w"] + "_mod" for term in character["mod"]\
                                 if term["w"] not in modFilter]

                    for verb in agent_terms:
                        charactersAgentsDict[char_name][verb]+=1

                    for verb, count in charactersAgentsDict[char_name].items():
                        charactersAgentsList[-1]+=[verb]*count
                        
        else:
            for character in data["characters"]:
                char_name = character["mainName"] + "\t(" + idd + ")" +\
                '\n aka ' + ", ".join(character['aliases'][:9])
                charNameList.append(char_name)
                charactersAgentsDict[char_name] = Counter()
                charactersAgentsList.append([])
                agent_terms = [list(action.values())[0] + "_agent" for action in character["agent"] \
                             if list(action.values())[0] not in agentFilter]
                agent_terms += [list(action.values())[0] + "_patient" for action in character["patient"] \
                             if list(action.values())[0] not in agentFilter]
                
                for verb in agent_terms:
                    charactersAgentsDict[char_name][verb]+=1

                for verb, count in charactersAgentsDict[char_name].items():
                    charactersAgentsList[-1]+=[verb]*count
                    
                    
    return charactersAgentsDict, charactersAgentsList, charNameList

# %%
# metadata=read_book_nlp_metadata("../../../../Code/comphumF20/data/pulitzer_metadata.txt")
# data=read_book_nlp_data("../../../../Code/comphumF20/data/pulitzer_booknlp")

# %%
newData = read_parsed_book_data('../results/book_parses_top_only')
# Out:
# Read 239 books

# %%
agentFreqs, patientFreqs, modFreqs = get_corpus_frequencies(newData)

# %%
agentFilter = set([freqPair[0] for freqPair in agentFreqs.most_common(50)])
patientFilter = set([freqPair[0] for freqPair in patientFreqs.most_common(50)])
modFilter = set([freqPair[0] for freqPair in modFreqs.most_common(50)])

# %%
charAgents, charTexts, charNames = get_character_actions(newData, 
                                                         agentFilter=agentFilter, 
                                                         patientFilter=patientFilter, 
                                                         modFilter=modFilter)

# %%
for charName in charNames:
    print(charName)
# Out:
# he	(Joseph Conrad___Amy Foster)
#  aka he, his
# his	(Joseph Conrad___Amy Foster)
#  aka his
# she	(Joseph Conrad___Amy Foster)
#  aka she, her
# smith	(Joseph Conrad___Amy Foster)
#  aka her, smith, she, he, the girl, his, mrs. smith, him
# him	(Joseph Conrad___Amy Foster)
#  aka him, his
# carthoris	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#  aka her, she, his, carthoris, he
# he	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#  aka he, his
# thuvia	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#  aka thuvia
# jav	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#  aka jav, he, his
# his	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#  aka he, his
# otto	(Robert Louis Stevenson___Prince Otto)
#  aka he, him, otto, his
# she	(Robert Louis Stevenson___Prince Otto)
#  aka she, her
# the prince	(Robert Louis Stevenson___Prince Otto)
#  aka me, the prince, myself
# seraphina	(Robert Louis Stevenson___Prince Otto)
#  aka he, seraphina, his
# he	(Robert Louis Stevenson___Prince Otto)
#  aka himself, he, him, his
# she	(Henry James___The Lesson of the Master)
#  aka she
# paul	(Henry James___The Lesson of the Master)
#  aka paul, his, himself, he, him
# he	(Henry James___The Lesson of the Master)
#  aka he, his
# paul overt	(Henry James___The Lesson of the Master)
#  aka he, him, paul overt, his
# st. george	(Henry James___The Lesson of the Master)
#  aka st. george, his
# lord lambeth	(Henry James___An International Episode)
#  aka she, herself, lord lambeth, her
# bessie alden	(Henry James___An International Episode)
#  aka she, bessie alden
# mrs. westgate	(Henry James___An International Episode)
#  aka her, mrs. westgate, she, he, him
# bessie	(Henry James___An International Episode)
#  aka the elder lady, dear bessie, her, bessie, she
# percy beaumont	(Henry James___An International Episode)
#  aka he, percy beaumont
# my aunt	(Charles Dickens___David Copperfield)
#  aka her, she, my aunt
# we	(Charles Dickens___David Copperfield)
#  aka our, we
# it	(Charles Dickens___David Copperfield)
#  aka it
# mr. micawber	(Charles Dickens___David Copperfield)
#  aka mr. micawber, him, his
# he	(Charles Dickens___David Copperfield)
#  aka himself, he
# billy	(Edgar Rice Burroughs___The Mucker)
#  aka he, him, billy, his
# billy byrne	(Edgar Rice Burroughs___The Mucker)
#  aka he, billy byrne, byrne, his
# barbara harding	(Edgar Rice Burroughs___The Mucker)
#  aka she, barbara harding, her
# byrne	(Edgar Rice Burroughs___The Mucker)
#  aka billy byrne, byrne, billy, his, him
# huck	(Mark Twain___The Adventures of Tom Sawyer, Complete)
#  aka you, he, huck
# it	(Mark Twain___The Adventures of Tom Sawyer, Complete)
#  aka it
# he	(Mark Twain___The Adventures of Tom Sawyer, Complete)
#  aka he, his
# they	(Mark Twain___The Adventures of Tom Sawyer, Complete)
#  aka they, their
# he	(Rudyard Kipling___Plain Tales from the Hills)
#  aka he, his
# strickland	(Rudyard Kipling___Plain Tales from the Hills)
#  aka he, strickland
# his	(Rudyard Kipling___Plain Tales from the Hills)
#  aka he, mcintosh, him, his
# we	(Rudyard Kipling___Plain Tales from the Hills)
#  aka we
# mrs. hauksbee	(Rudyard Kipling___Plain Tales from the Hills)
#  aka mrs. hauksbee, her
# the captain	(Charles Dickens___A Message from the Sea)
#  aka he, the captain, his
# kitty	(Charles Dickens___A Message from the Sea)
#  aka she, kitty
# the captain to the young man	(Charles Dickens___A Message from the Sea)
#  aka the young man, the captain to the young man, the captain, his, himself, he, him
# we	(Charles Dickens___A Message from the Sea)
#  aka we
# it	(Charles Dickens___A Message from the Sea)
#  aka it
# jerry	(Jack London___Jerry of the Islands)
#  aka jerry, he, his
# he	(Jack London___Jerry of the Islands)
#  aka his, himself, he, jerry, him
# van horn	(Jack London___Jerry of the Islands)
#  aka van horn
# skipper	(Jack London___Jerry of the Islands)
#  aka skipper
# his	(Jack London___Jerry of the Islands)
#  aka his
# eustacia	(Thomas Hardy___The Return of the Native)
#  aka eustacia
# he	(Thomas Hardy___The Return of the Native)
#  aka he, him, his
# her	(Thomas Hardy___The Return of the Native)
#  aka she, her
# wildeve	(Thomas Hardy___The Return of the Native)
#  aka wildeve, she, her
# she	(Thomas Hardy___The Return of the Native)
#  aka she, her
# he	(Oscar Wilde___The Picture of Dorian Gray)
#  aka he, him, his
# lord henry	(Oscar Wilde___The Picture of Dorian Gray)
#  aka lord henry, his
# dorian	(Oscar Wilde___The Picture of Dorian Gray)
#  aka she, dorian, her
# dorian gray	(Oscar Wilde___The Picture of Dorian Gray)
#  aka harry, he, his, dorian gray
# it	(Oscar Wilde___The Picture of Dorian Gray)
#  aka it
# mr. traveller	(Charles Dickens___Tom Tiddler's Ground)
#  aka mr. traveller, he, his
# miss pupford	(Charles Dickens___Tom Tiddler's Ground)
#  aka miss pupford
# little kitty kimmeens	(Charles Dickens___Tom Tiddler's Ground)
#  aka kimmeens, little miss kimmeens, her, miss kitty kimmeens, miss kimmeens, little kitty kimmeens, she, kitty kimmeens
# mr. mopes	(Charles Dickens___Tom Tiddler's Ground)
#  aka mr. mopes, his, himself, he, him
# his	(Charles Dickens___Tom Tiddler's Ground)
#  aka himself, he, his

# %%
charAgents
# Out:
# {'he\t(Joseph Conrad___Amy Foster)\n aka he, his': Counter(),
#  'his\t(Joseph Conrad___Amy Foster)\n aka his': Counter(),
#  'she\t(Joseph Conrad___Amy Foster)\n aka she, her': Counter({'call_agent': 1}),
#  'smith\t(Joseph Conrad___Amy Foster)\n aka her, smith, she, he, the girl, his, mrs. smith, him': Counter({'promise_agent': 1,
#           'twist_agent': 1,
#           'call_agent': 1,
#           'moan_agent': 1,
#           'wonder_agent': 1,
#           'promise_patient': 1,
#           'call_patient': 1,
#           'moan_patient': 1}),
#  'him\t(Joseph Conrad___Amy Foster)\n aka him, his': Counter(),
#  'carthoris\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)\n aka her, she, his, carthoris, he': Counter({'graze_agent': 1,
#           'distance_agent': 1,
#           'hasten_agent': 1,
#           'reach_agent': 1}),
#  'he\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)\n aka he, his': Counter(),
#  'thuvia\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)\n aka thuvia': Counter(),
#  'jav\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)\n aka jav, he, his': Counter({'choose_agent': 1}),
#  'his\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)\n aka he, his': Counter({'furnish_agent': 1}),
#  'otto\t(Robert Louis Stevenson___Prince Otto)\n aka he, him, otto, his': Counter({'watch_agent': 1,
#           'resume_agent': 1}),
#  'she\t(Robert Louis Stevenson___Prince Otto)\n aka she, her': Counter({'dream_agent': 1}),
#  'the prince\t(Robert Louis Stevenson___Prince Otto)\n aka me, the prince, myself': Counter(),
#  'seraphina\t(Robert Louis Stevenson___Prince Otto)\n aka he, seraphina, his': Counter({'hurry_agent': 1}),
#  'he\t(Robert Louis Stevenson___Prince Otto)\n aka himself, he, him, his': Counter({'lighten_agent': 1,
#           'lighten_patient': 1}),
#  'she\t(Henry James___The Lesson of the Master)\n aka she': Counter({'will_agent': 1}),
#  'paul\t(Henry James___The Lesson of the Master)\n aka paul, his, himself, he, him': Counter({'quit_agent': 1,
#           'recover_agent': 1,
#           'linger_agent': 1,
#           'publish_agent': 1,
#           'recover_patient': 1,
#           'linger_patient': 1}),
#  'he\t(Henry James___The Lesson of the Master)\n aka he, his': Counter({'wonder_agent': 1,
#           'suggest_agent': 1}),
#  'paul overt\t(Henry James___The Lesson of the Master)\n aka he, him, paul overt, his': Counter(),
#  'st. george\t(Henry James___The Lesson of the Master)\n aka st. george, his': Counter(),
#  'lord lambeth\t(Henry James___An International Episode)\n aka she, herself, lord lambeth, her': Counter(),
#  'bessie alden\t(Henry James___An International Episode)\n aka she, bessie alden': Counter(),
#  'mrs. westgate\t(Henry James___An International Episode)\n aka her, mrs. westgate, she, he, him': Counter({'display_agent': 1,
#           'wish_patient': 1}),
#  'bessie\t(Henry James___An International Episode)\n aka the elder lady, dear bessie, her, bessie, she': Counter({'bend_agent': 1,
#           'wish_agent': 1,
#           'reflect_agent': 1}),
#  'percy beaumont\t(Henry James___An International Episode)\n aka he, percy beaumont': Counter(),
#  'my aunt\t(Charles Dickens___David Copperfield)\n aka her, she, my aunt': Counter(),
#  'we\t(Charles Dickens___David Copperfield)\n aka our, we': Counter({'cheer_agent': 1}),
#  'it\t(Charles Dickens___David Copperfield)\n aka it': Counter(),
#  'mr. micawber\t(Charles Dickens___David Copperfield)\n aka mr. micawber, him, his': Counter(),
#  'he\t(Charles Dickens___David Copperfield)\n aka himself, he': Counter({'bow_agent': 1}),
#  'billy\t(Edgar Rice Burroughs___The Mucker)\n aka he, him, billy, his': Counter({'draw_agent': 1,
#           'assure_patient': 1}),
#  'billy byrne\t(Edgar Rice Burroughs___The Mucker)\n aka he, billy byrne, byrne, his': Counter({'happen_agent': 1,
#           'admonish_agent': 1,
#           'venture_agent': 1}),
#  'barbara harding\t(Edgar Rice Burroughs___The Mucker)\n aka she, barbara harding, her': Counter(),
#  'byrne\t(Edgar Rice Burroughs___The Mucker)\n aka billy byrne, byrne, billy, his, him': Counter({'step_agent': 1,
#           'call_patient': 1}),
#  'they\t(Edgar Rice Burroughs___The Mucker)\n aka them, they': Counter(),
#  'gale\t(Zane Grey___Desert Gold)\n aka her, he, him, gale': Counter({'realize_agent': 1}),
#  'dick\t(Zane Grey___Desert Gold)\n aka dick': Counter(),
#  'he\t(Zane Grey___Desert Gold)\n aka he, him, his': Counter({'mount_agent': 1}),
#  'nell\t(Zane Grey___Desert Gold)\n aka nell, her': Counter(),
#  'belding\t(Zane Grey___Desert Gold)\n aka belding': Counter(),
#  'mr. grewgious\t(Charles Dickens___The Mystery of Edwin Drood)\n aka it, his, mr. grewgious, he, no harbour in mr. crisparkle': Counter({'haunt_agent': 1,
#           'appear_patient': 1}),
#  'rosa\t(Charles Dickens___The Mystery of Edwin Drood)\n aka rosa': Counter({'travel_agent': 1}),
#  'mr. crisparkle\t(Charles Dickens___The Mystery of Edwin Drood)\n aka mr. crisparkle, his': Counter(),
#  'it\t(Charles Dickens___The Mystery of Edwin Drood)\n aka it': Counter({'avail_agent': 1,
#           'avail_patient': 1}),
#  'he\t(Charles Dickens___The Mystery of Edwin Drood)\n aka he, his': Counter({'accompany_agent': 1}),
#  'his\t(Herman Melville___Moby Dick)\n aka his': Counter(),
#  'ahab\t(Herman Melville___Moby Dick)\n aka he, ahab, him': Counter({'clear_agent': 1,
#           'clear_patient': 1}),
#  'he\t(Herman Melville___Moby Dick)\n aka himself, he': Counter({'parry_agent': 1,
#           'parry_patient': 1}),
#  'it\t(Herman Melville___Moby Dick)\n aka it': Counter({'roll_agent': 1}),
#  'him\t(Herman Melville___Moby Dick)\n aka him, his': Counter(),
#  'he\t(Charles Dickens___Reprinted Pieces)\n aka he, his': Counter(),
#  'we\t(Charles Dickens___Reprinted Pieces)\n aka our, we': Counter(),
#  'his\t(Charles Dickens___Reprinted Pieces)\n aka he, his': Counter(),
#  'our\t(Charles Dickens___Reprinted Pieces)\n aka our, we': Counter(),
#  'it\t(Charles Dickens___Reprinted Pieces)\n aka it': Counter({'build_patient': 1}),
#  'little britain\t(Washington Irving___Little Britain)\n aka little britain': Counter(),
#  'his\t(Washington Irving___Little Britain)\n aka himself, he, him, his': Counter({'pass_agent': 1,
#           'coachman_agent': 1,
#           'coachman_patient': 1}),
#  'the daughters\t(Washington Irving___Little Britain)\n aka the daughters, he, him, his': Counter({'address_agent': 1,
#           'address_patient': 1,
#           'doom_patient': 1}),
#  'bully wagstaff himself\t(Washington Irving___Little Britain)\n aka bully wagstaff himself, he, him, his': Counter({'affirm_agent': 1,
#           'call_patient': 1}),
#  'the lambs\t(Washington Irving___Little Britain)\n aka the lambs, the miss lambs, their': Counter({'die_agent': 1,
#           'mount_agent': 1,
#           '"_agent': 1}),
#  "mr. silverman\t(Charles Dickens___George Silverman's Explanation)\n aka he, mr. silverman": Counter(),
#  "brother hawkyard\t(Charles Dickens___George Silverman's Explanation)\n aka brother hawkyard, brother gimblet, me, his, he, him": Counter({'read_agent': 1,
#           'groan_agent': 1}),
#  "me\t(Charles Dickens___George Silverman's Explanation)\n aka me": Counter(),
#  "my lady\t(Charles Dickens___George Silverman's Explanation)\n aka her, she, herself, my lady": Counter({'happen_agent': 1,
#           'set_agent': 1,
#           'tear_agent': 1,
#           'stab_agent': 1,
#           'marry_patient': 1,
#           'stab_patient': 1}),
#  "his\t(Charles Dickens___George Silverman's Explanation)\n aka his": Counter(),
#  'barney\t(Edgar Rice Burroughs___The Mad King)\n aka barney, his': Counter(),
#  'the king\t(Edgar Rice Burroughs___The Mad King)\n aka the king': Counter(),
#  'he\t(Edgar Rice Burroughs___The Mad King)\n aka the old chancellor, his, he, him, the chancellor': Counter({'cross_agent': 1,
#           'break_agent': 1}),
#  'leopold\t(Edgar Rice Burroughs___The Mad King)\n aka he, leopold': Counter({'wish_agent': 1}),
#  'peter\t(Edgar Rice Burroughs___The Mad King)\n aka peter': Counter(),
#  "von horn\t(Edgar Rice Burroughs___The Monster Men)\n aka von horn's, his, von horn, he, misguided von horn": Counter({'indicate_agent': 1,
#           'die_agent': 1,
#           'exclaimed_patient': 1}),
#  'the girl\t(Edgar Rice Burroughs___The Monster Men)\n aka the girl, she, her': Counter({'Thank_patient': 1}),
#  'bulan\t(Edgar Rice Burroughs___The Monster Men)\n aka her, his, bulan, he, him': Counter({'respond_agent': 1,
#           'catch_patient': 1}),
#  'virginia\t(Edgar Rice Burroughs___The Monster Men)\n aka virginia': Counter(),
#  'professor maxon\t(Edgar Rice Burroughs___The Monster Men)\n aka he, professor maxon': Counter(),
#  'tarzan\t(Edgar Rice Burroughs___Jungle Tales of Tarzan)\n aka tarzan': Counter({'kill_agent': 1}),
#  'the ape-man\t(Edgar Rice Burroughs___Jungle Tales of Tarzan)\n aka he, the ape-man, his': Counter({'waste_agent': 1,
#           'sway_agent': 1,
#           'fit_agent': 1}),
#  'he\t(Edgar Rice Burroughs___Jungle Tales of Tarzan)\n aka he, him, his': Counter({'harm_agent': 1}),
#  'teeka\t(Edgar Rice Burroughs___Jungle Tales of Tarzan)\n aka she, it, teeka, her': Counter({'surprise_agent': 1,
#           'flee_agent': 1,
#           'hurl_agent': 1,
#           'surprise_patient': 1}),
#  'his\t(Edgar Rice Burroughs___Jungle Tales of Tarzan)\n aka he, him, his': Counter(),
#  'tom\t(Charles Dickens___The Lamplighter)\n aka he, him, tom, his': Counter(),
#  'the old gentleman\t(Charles Dickens___The Lamplighter)\n aka the old gentleman, he, him, his': Counter({'wet_agent': 1}),
#  'the vice\t(Charles Dickens___The Lamplighter)\n aka the vice': Counter(),
#  'mr. mooney\t(Charles Dickens___The Lamplighter)\n aka the gifted mooney, mooney, a scientific man, his, himself, he, him, mr. mooney': Counter({'revive_agent': 1,
#           'inform_patient': 1}),
#  'his\t(Charles Dickens___The Lamplighter)\n aka himself, he, the chairman, his': Counter({'swam_agent': 1,
#           'swam_patient': 1}),
#  "isabel\t(Wilkie Collins___My Lady's Money)\n aka isabel": Counter(),
#  "lady lydiard\t(Wilkie Collins___My Lady's Money)\n aka lady lydiard's, lady lydiard, her": Counter(),
#  "moody\t(Wilkie Collins___My Lady's Money)\n aka she, moody": Counter(),
#  "mr. troy\t(Wilkie Collins___My Lady's Money)\n aka he, mr. troy": Counter({'suggest_agent': 1,
#           'consult_patient': 1}),
#  "hardyman\t(Wilkie Collins___My Lady's Money)\n aka hardyman, mr. hardyman, his, he, him": Counter(),
#  "he\t(Joseph Conrad___'Twixt Land & Sea)\n aka he": Counter({'stammer_agent': 1}),
#  "freya\t(Joseph Conrad___'Twixt Land & Sea)\n aka freya": Counter(),
#  "his\t(Joseph Conrad___'Twixt Land & Sea)\n aka he, me, his": Counter({'show_agent': 1}),
#  "her\t(Joseph Conrad___'Twixt Land & Sea)\n aka her": Counter({'move_patient': 1,
#           'nothing_patient': 1}),
#  "she\t(Joseph Conrad___'Twixt Land & Sea)\n aka she": Counter({'mention_agent': 1}),
#  'mr. tod\t(Beatrix Potter___The Great Big Treasury of Beatrix Potter)\n aka he, mr. tod': Counter({'rush_agent': 1,
#           'happen_agent': 1,
#           'happen_patient': 1}),
#  'peter\t(Beatrix Potter___The Great Big Treasury of Beatrix Potter)\n aka peter, he': Counter({'hesitate_agent': 1,
#           'shut_agent': 1}),
#  'tom kitten\t(Beatrix Potter___The Great Big Treasury of Beatrix Potter)\n aka poor tom kitten, tom, his, himself, he, tom kitten, him': Counter({'burst_agent': 1,
#           'want_agent': 1,
#           'determine_agent': 1,
#           'climb_agent': 1,
#           'wade_agent': 1,
#           'scramble_agent': 1,
#           'squeeze_agent': 1,
#           'wriggle_agent': 2,
#           'face_agent': 1,
#           'squeeze_patient': 1,
#           'wriggle_patient': 1,
#           'offer_patient': 1,
#           'smear_patient': 1,
#           'oblige_patient': 1}),
#  'mr. mcgregor\t(Beatrix Potter___The Great Big Treasury of Beatrix Potter)\n aka mrs. mcgregor, her, she, herself, his, he, him, mr. mcgregor': Counter({'stare_agent': 1,
#           'climb_agent': 1,
#           'tie_agent': 1,
#           'carry_agent': 1,
#           'watch_agent': 1,
#           'throw_agent': 1,
#           'enquire_agent': 1,
#           'untie_agent': 1}),
#  'benjamin bunny\t(Beatrix Potter___The Great Big Treasury of Beatrix Potter)\n aka benjamin bunny, he, his': Counter({'pick_agent': 1,
#           'lift_agent': 1}),
#  'tom\t(Charles Dickens___Life And Adventures Of Martin Chuzzlewit)\n aka tom': Counter(),
#  'mr pecksniff\t(Charles Dickens___Life And Adventures Of Martin Chuzzlewit)\n aka the little man, his, he, mr pecksniff, him': Counter({'depart_agent': 1}),
#  'martin\t(Charles Dickens___Life And Adventures Of Martin Chuzzlewit)\n aka martin, he, his': Counter({'persist_agent': 1}),
#  'he\t(Charles Dickens___Life And Adventures Of Martin Chuzzlewit)\n aka he, his': Counter({'word_agent': 1}),
#  'it\t(Charles Dickens___Life And Adventures Of Martin Chuzzlewit)\n aka it': Counter({'speak_patient': 1,
#           'pick_patient': 1}),
#  'he\t(Bret Harte___Selected Stories)\n aka he, his': Counter(),
#  'his\t(Bret Harte___Selected Stories)\n aka him, his': Counter(),
#  'her\t(Bret Harte___Selected Stories)\n aka she, her': Counter(),
#  'she\t(Bret Harte___Selected Stories)\n aka she, herself, her': Counter(),
#  'it\t(Bret Harte___Selected Stories)\n aka it': Counter(),
#  'pemberton\t(Henry James___The Pupil)\n aka he, him, his, pemberton': Counter({'break_patient': 1,
#           'hurry_patient': 1}),
#  'morgan\t(Henry James___The Pupil)\n aka he, him, his, morgan': Counter(),
#  'mrs. moreen\t(Henry James___The Pupil)\n aka mrs. moreen, he, mr. moreen, his': Counter({'tremble_agent': 1,
#           'wail_patient': 1}),
#  'they\t(Henry James___The Pupil)\n aka themselves, them, they, their': Counter(),
#  'the young man\t(Henry James___The Pupil)\n aka he, the young man, him, his': Counter({'stammer_agent': 1}),
#  'we\t(Charles Dickens___The Perils of Certain English Prisoners)\n aka we': Counter(),
#  'it\t(Charles Dickens___The Perils of Certain English Prisoners)\n aka its, it': Counter(),
#  'captain carton\t(Charles Dickens___The Perils of Certain English Prisoners)\n aka captain carton, me, myself, he, him': Counter(),
#  'miss maryon\t(Charles Dickens___The Perils of Certain English Prisoners)\n aka she, miss maryon, her': Counter(),
#  'our\t(Charles Dickens___The Perils of Certain English Prisoners)\n aka our, yours': Counter(),
#  'the major\t(Charles Dickens___Mrs. Lirriper\'s Legacy)\n aka "ah major, the major': Counter({'sink_patient': 1}),
#  "jemmy\t(Charles Dickens___Mrs. Lirriper's Legacy)\n aka jemmy, his": Counter(),
#  "mr. buffle\t(Charles Dickens___Mrs. Lirriper's Legacy)\n aka mr. buffle, him, his": Counter({'use_agent': 1}),
#  "he\t(Charles Dickens___Mrs. Lirriper's Legacy)\n aka himself, he": Counter(),
#  "his\t(Charles Dickens___Mrs. Lirriper's Legacy)\n aka he, lo, him, his": Counter({'use_agent': 1,
#           'sink_agent': 1,
#           'overtake_agent': 1,
#           'use_patient': 1,
#           'overtake_patient': 1,
#           'bring_patient': 1}),
#  'he\t(Jack London___Burning Daylight)\n aka himself, he, him, his': Counter({'pause_agent': 1}),
#  'his\t(Jack London___Burning Daylight)\n aka he, his': Counter(),
#  'she\t(Jack London___Burning Daylight)\n aka she, herself': Counter(),
#  'her\t(Jack London___Burning Daylight)\n aka she, her': Counter(),
#  'him\t(Jack London___Burning Daylight)\n aka he, him, his': Counter({'drop_agent': 1,
#           'attack_agent': 2,
#           'examine_agent': 1,
#           'straighten_agent': 1,
#           'fling_agent': 1,
#           'grin_agent': 1,
#           'mutter_agent': 1}),
#  'joe\t(Zane Grey___The Spirit of the Border)\n aka joe': Counter(),
#  'wetzel\t(Zane Grey___The Spirit of the Border)\n aka he, him, wetzel, his': Counter({'meet_agent': 1,
#           'stride_agent': 1,
#           'stride_patient': 1}),
#  'jim\t(Zane Grey___The Spirit of the Border)\n aka jim, his': Counter(),
#  'nell\t(Zane Grey___The Spirit of the Border)\n aka nell, her': Counter({'bow_agent': 1,
#           'whisper_patient': 1}),
#  'he\t(Zane Grey___The Spirit of the Border)\n aka he, him, wetzel, his': Counter({'halt_agent': 1,
#           'sink_agent': 1,
#           'crawl_agent': 1,
#           'on_agent': 1,
#           'part_agent': 1,
#           'warn_patient': 1}),
#  'dorothea\t(George Eliot___Middlemarch)\n aka dorothea, she': Counter({'observe_agent': 1}),
#  'lydgate\t(George Eliot___Middlemarch)\n aka he, lydgate, his': Counter({'accept_agent': 1,
#           'choose_agent': 1}),
#  'rosamond\t(George Eliot___Middlemarch)\n aka whence rosamond, she, rosamond, her': Counter({'commit_agent': 1,
#           'continue_agent': 1,
#           'oppose_agent': 1,
#           'die_agent': 1,
#           'call_agent': 1,
#           'oppose_patient': 1,
#           'call_patient': 1,
#           'choose_patient': 1}),
#  'he\t(George Eliot___Middlemarch)\n aka he, him': Counter({'repent_agent': 1}),
#  'mr. casaubon\t(George Eliot___Middlemarch)\n aka he, mr. casaubon': Counter(),
#  'he\t(Joseph Conrad___The Secret Sharer)\n aka himself, he, his': Counter(),
#  'his\t(Joseph Conrad___The Secret Sharer)\n aka he, his': Counter(),
#  'we\t(Joseph Conrad___The Secret Sharer)\n aka our, we, us': Counter(),
#  'him\t(Joseph Conrad___The Secret Sharer)\n aka him, his': Counter(),
#  'it\t(Joseph Conrad___The Secret Sharer)\n aka it': Counter({'save_agent': 1,
#           'mean_patient': 1}),
#  'ichabod\t(Washington Irving___The Legend of Sleepy Hollow)\n aka ichabod, it': Counter({'maintain_agent': 1,
#           'maintain_patient': 1}),
#  'he\t(Washington Irving___The Legend of Sleepy Hollow)\n aka he, his': Counter({'summon_agent': 1}),
#  'his\t(Washington Irving___The Legend of Sleepy Hollow)\n aka he, his': Counter(),
#  'ichabod crane\t(Washington Irving___The Legend of Sleepy Hollow)\n aka he, his, ichabod crane': Counter({'conduct_agent': 1}),
#  'old baltus van tassel\t(Washington Irving___The Legend of Sleepy Hollow)\n aka old baltus van tassel, his, himself, the musician, he': Counter({'move_agent': 1,
#           'part_agent': 1}),
#  'we\t(Edgar Rice Burroughs___The Land That Time Forgot)\n aka our, we': Counter({'continue_agent': 1}),
#  'the girl\t(Edgar Rice Burroughs___The Land That Time Forgot)\n aka her, the girl, herself, hers, she': Counter({'scream_agent': 1,
#           'struggle_agent': 1,
#           'shatter_patient': 1,
#           'struggle_patient': 1}),
#  'lys\t(Edgar Rice Burroughs___The Land That Time Forgot)\n aka he, him, his, lys': Counter({'pursue_agent': 1}),
#  'our\t(Edgar Rice Burroughs___The Land That Time Forgot)\n aka our, we, us': Counter({'break_agent': 1,
#           'marry_agent': 1,
#           'marry_patient': 1}),
#  'us\t(Edgar Rice Burroughs___The Land That Time Forgot)\n aka we, us': Counter({'talk_agent': 1}),
#  'he\t(Henry James___The Beast in the Jungle)\n aka himself, he, him, his': Counter({'affect_agent': 1,
#           'carry_agent': 1,
#           'but_agent': 1,
#           'settle_agent': 1,
#           'wear_patient': 1,
#           'affect_patient': 1}),
#  'she\t(Henry James___The Beast in the Jungle)\n aka she': Counter({'serve_agent': 1,
#           'baffle_agent': 1}),
#  'him\t(Henry James___The Beast in the Jungle)\n aka himself, he, him, his': Counter({'present_agent': 1,
#           'grant_agent': 1,
#           'rest_agent': 1,
#           'stare_agent': 1,
#           'carry_patient': 1,
#           'fresh_patient': 1}),
#  'it\t(Henry James___The Beast in the Jungle)\n aka it': Counter({'keep_patient': 1}),
#  'her\t(Henry James___The Beast in the Jungle)\n aka she, her': Counter(),
#  'falk\t(Joseph Conrad___Falk)\n aka his, falk': Counter({'wonder_patient': 1}),
#  'he\t(Joseph Conrad___Falk)\n aka he, him': Counter(),
#  'hermann\t(Joseph Conrad___Falk)\n aka mrs. hermann, falk, hermann, his': Counter({'sew_agent': 1,
#           'glide_agent': 1}),
#  'her\t(Joseph Conrad___Falk)\n aka she, her': Counter({'hold_agent': 1}),
#  'his\t(Joseph Conrad___Falk)\n aka himself, he, him, his': Counter({'suffer_agent': 1,
#           'witness_agent': 1}),
#  'joe\t(Charles Dickens___Great Expectations)\n aka joe': Counter({'lay_patient': 1}),
#  'herbert\t(Charles Dickens___Great Expectations)\n aka he, him, herbert, his': Counter(),
#  'it\t(Charles Dickens___Great Expectations)\n aka its, it': Counter(),
#  'he\t(Charles Dickens___Great Expectations)\n aka he, his': Counter({'for_agent': 1}),
#  'we\t(Charles Dickens___Great Expectations)\n aka our, we': Counter(),
#  'anne\t(Jane Austen___Persuasion)\n aka she, anne, her': Counter({'satisfy_agent': 1,
#           'requite_agent': 1,
#           'requite_patient': 1}),
#  'mr elliot\t(Jane Austen___Persuasion)\n aka mr elliot, his, himself, he, him': Counter({'quit_agent': 1,
#           'quit_patient': 1}),
#  'lady russell\t(Jane Austen___Persuasion)\n aka lady russell, her': Counter({'value_agent': 1}),
#  'captain wentworth\t(Jane Austen___Persuasion)\n aka captain wentworth': Counter(),
#  'he\t(Jane Austen___Persuasion)\n aka he, me, myself': Counter({'end_agent': 1}),
#  'we\t(Edgar Rice Burroughs___The Lost Continent)\n aka our, we, us': Counter({'decide_agent': 1,
#           'approach_agent': 1,
#           'march_agent': 1,
#           'converse_agent': 1,
#           'approach_patient': 1,
#           'hold_patient': 1}),
#  'us\t(Edgar Rice Burroughs___The Lost Continent)\n aka ourselves, we, us': Counter({'set_patient': 1,
#           'receive_patient': 1}),
#  'her\t(Edgar Rice Burroughs___The Lost Continent)\n aka she, mine, her, hers': Counter({'stop_agent': 1,
#           'guess_agent': 1,
#           'stamp_agent': 1,
#           'seize_agent': 1,
#           'cease_agent': 1,
#           'raise_agent': 1,
#           'approach_patient': 1,
#           'seize_patient': 1,
#           'crush_patient': 1}),
#  'he\t(Edgar Rice Burroughs___The Lost Continent)\n aka he, his': Counter(),
#  'the girl\t(Edgar Rice Burroughs___The Lost Continent)\n aka the girl, she, her': Counter({'strike_agent': 1,
#           'strike_patient': 1}),
#  'mrs. presty\t(Wilkie Collins___The Evil Genius)\n aka mrs. presty, her': Counter({'judge_agent': 1,
#           'march_agent': 1}),
#  'he\t(Wilkie Collins___The Evil Genius)\n aka he': Counter(),
#  'george\t(William Makepeace Thackeray___Vanity Fair)\n aka george': Counter(),
#  'becky\t(William Makepeace Thackeray___Vanity Fair)\n aka becky, she': Counter({'visible_agent': 1}),
#  'her\t(William Makepeace Thackeray___Vanity Fair)\n aka she, herself, her, mrs. becky': Counter(),
#  'she\t(Wilkie Collins___No Name)\n aka she, herself, yourself, her': Counter({'suppose_agent': 1,
#           'venture_agent': 1}),
#  'magdalen\t(Wilkie Collins___No Name)\n aka magdalen': Counter({'encourage_agent': 1,
#           'steal_agent': 1}),
#  'her\t(Wilkie Collins___No Name)\n aka she, me, her': Counter({'keep_agent': 2,
#           'lay_agent': 2,
#           'conceal_agent': 1,
#           'falter_agent': 1,
#           'yet_agent': 1,
#           'offer_agent': 1,
#           'guess_agent': 1,
#           'bear_agent': 1,
#           'beat_patient': 1,
#           'keep_patient': 1,
#           'hesitate_patient': 1,
#           'bear_patient': 1,
#           'fold_patient': 1,
#           'stoop_patient': 1}),
#  'mrs. lecount\t(Wilkie Collins___No Name)\n aka mrs. lecount, herself, it, her': Counter({'establish_agent': 1}),
#  'he\t(Wilkie Collins___No Name)\n aka he, him, his': Counter({'interrupt_agent': 1}),
#  'tarzan\t(Edgar Rice Burroughs___The Beasts of Tarzan)\n aka tarzan': Counter(),
#  'jane clayton\t(Edgar Rice Burroughs___The Beasts of Tarzan)\n aka jane clayton, her': Counter({'seize_agent': 1}),
#  'the ape-man\t(Edgar Rice Burroughs___The Beasts of Tarzan)\n aka him, the ape-man, his': Counter({'throw_patient': 1}),
#  'jane\t(Edgar Rice Burroughs___The Beasts of Tarzan)\n aka she, jane': Counter({'retort_agent': 1}),
#  'he\t(Edgar Rice Burroughs___The Beasts of Tarzan)\n aka he, him, his': Counter({'accompany_agent': 1}),
#  'fanny\t(Jane Austen___Mansfield Park)\n aka fanny, her': Counter(),
#  'sir thomas\t(Jane Austen___Mansfield Park)\n aka sir thomas, he': Counter(),
#  'edmund\t(Jane Austen___Mansfield Park)\n aka edmund, his, himself, he, him': Counter({'contribute_agent': 1,
#           'talk_agent': 1}),
#  'her\t(Jane Austen___Mansfield Park)\n aka she, her, hers': Counter(),
#  'miss crawford\t(Jane Austen___Mansfield Park)\n aka miss crawford, crawford': Counter(),
#  'we\t(Jack London___Before Adam)\n aka ourselves, our, we': Counter({'gain_agent': 1,
#           'cross_agent': 1,
#           'penetrate_agent': 1,
#           'river_agent': 1,
#           'cross_patient': 1}),
#  'red-eye\t(Jack London___Before Adam)\n aka red-eye, his, himself, he, him': Counter({'crook_agent': 1,
#           'crook_patient': 1}),
#  'he\t(Jack London___Before Adam)\n aka he, him, his': Counter({'pull_agent': 1,
#           'bite_agent': 1,
#           'manage_agent': 1,
#           'speed_agent': 1}),
#  'lop-ear\t(Jack London___Before Adam)\n aka he, lop-ear': Counter({'escape_agent': 1,
#           'meet_patient': 1}),
#  'our\t(Jack London___Before Adam)\n aka our, we': Counter(),
#  'mr. tod\t(Beatrix Potter___A Collection of Beatrix Potter Stories)\n aka mr. tod': Counter(),
#  'peter\t(Beatrix Potter___A Collection of Beatrix Potter Stories)\n aka peter, he': Counter({'hesitate_agent': 1,
#           'shut_agent': 1}),
#  'mr. mcgregor\t(Beatrix Potter___A Collection of Beatrix Potter Stories)\n aka mrs. mcgregor, tabitha, cousin tabitha, her, she, mcgregor, mrs. tabitha, herself, his': Counter({'stare_agent': 1,
#           'climb_agent': 1,
#           'tie_agent': 1,
#           'carry_agent': 1,
#           'watch_agent': 1,
#           'throw_agent': 1,
#           'enquire_agent': 1,
#           'untie_agent': 1,
#           'use_agent': 1,
#           'determine_agent': 1,
#           'catch_agent': 1,
#           'wipe_agent': 1}),
#  'duchess\t(Beatrix Potter___A Collection of Beatrix Potter Stories)\n aka my dear duchess, she, her, duchess': Counter({'slip_agent': 1}),
#  'ribby\t(Beatrix Potter___A Collection of Beatrix Potter Stories)\n aka my dear ribby, ribby, she, her': Counter(),
#  'poirot\t(Agatha Christie___The Mysterious Affair at Styles)\n aka poirot, then poirot': Counter({'mean_agent': 1,
#           'finish_agent': 1}),
#  'mrs. inglethorp\t(Agatha Christie___The Mysterious Affair at Styles)\n aka mrs. inglethorp, her': Counter({'mean_agent': 1}),
#  'john\t(Agatha Christie___The Mysterious Affair at Styles)\n aka john, his': Counter({'reconcile_patient': 1}),
#  'it\t(Agatha Christie___The Mysterious Affair at Styles)\n aka it': Counter(),
#  'we\t(Agatha Christie___The Mysterious Affair at Styles)\n aka our, we, us': Counter(),
#  'we\t(Edgar Rice Burroughs___A Princess of Mars)\n aka our, we, us': Counter({'converse_agent': 1,
#           'arise_agent': 1}),
#  'dejah thoris\t(Edgar Rice Burroughs___A Princess of Mars)\n aka dejah thoris': Counter({'bound_patient': 1}),
#  'me\t(Edgar Rice Burroughs___A Princess of Mars)\n aka me': Counter(),
#  'her\t(Edgar Rice Burroughs___A Princess of Mars)\n aka she, her': Counter(),
#  'his\t(Edgar Rice Burroughs___A Princess of Mars)\n aka his': Counter(),
#  'joe\t(Jack London___The Game)\n aka he, joe, his': Counter({'examine_patient': 1}),
#  'genevieve\t(Jack London___The Game)\n aka she, genevieve, her': Counter(),
#  'she\t(Jack London___The Game)\n aka she, her': Counter({'jam_agent': 1,
#           'clatter_agent': 1}),
#  'he\t(Jack London___The Game)\n aka he': Counter({'rest_agent': 1}),
#  'his\t(Jack London___The Game)\n aka he, him, his': Counter({'play_agent': 1,
#           'play_patient': 1}),
#  'tara\t(Edgar Rice Burroughs___The Chessmen of Mars)\n aka tara, she, her': Counter({'reach_agent': 1}),
#  'he\t(Edgar Rice Burroughs___The Chessmen of Mars)\n aka he': Counter(),
#  'tara of helium\t(Edgar Rice Burroughs___The Chessmen of Mars)\n aka tara of helium': Counter(),
#  'she\t(Edgar Rice Burroughs___The Chessmen of Mars)\n aka she, her': Counter({'dine_agent': 1}),
#  'turan\t(Edgar Rice Burroughs___The Chessmen of Mars)\n aka he, turan': Counter(),
#  'tarzan\t(Edgar Rice Burroughs___Tarzan and the Jewels of Opar)\n aka his, tarzan': Counter({'stoop_agent': 1,
#           'untie_agent': 1}),
#  'werper\t(Edgar Rice Burroughs___Tarzan and the Jewels of Opar)\n aka werper': Counter(),
#  'the ape-man\t(Edgar Rice Burroughs___Tarzan and the Jewels of Opar)\n aka me, the man, the ape-man, his, himself, he, him': Counter({'pay_agent': 1,
#           'suggest_agent': 1,
#           'strain_patient': 1,
#           'pass_patient': 1}),
#  "jane clayton\t(Edgar Rice Burroughs___Tarzan and the Jewels of Opar)\n aka her, john clayton, jane clayton's, he, jane clayton, herself, his, himself, she": Counter({'undo_agent': 1,
#           'throw_agent': 1,
#           'strain_agent': 1,
#           'breathe_agent': 1,
#           'throw_patient': 1,
#           'seize_patient': 1}),
#  'he\t(Edgar Rice Burroughs___Tarzan and the Jewels of Opar)\n aka he, his': Counter({'fight_agent': 1}),
#  'she\t(Wilkie Collins___Little Novels)\n aka she, her': Counter({'inform_agent': 1,
#           'desert_agent': 1,
#           'keep_agent': 1,
#           'desert_patient': 1,
#           'keep_patient': 1}),
#  'he\t(Wilkie Collins___Little Novels)\n aka he, him, his': Counter(),
#  'her\t(Wilkie Collins___Little Novels)\n aka she, her': Counter(),
#  'we\t(Wilkie Collins___Little Novels)\n aka our, we, us': Counter({'occur_agent': 1}),
#  'his\t(Wilkie Collins___Little Novels)\n aka he, his': Counter({'partook_agent': 1}),
#  'grace\t(Thomas Hardy___The Woodlanders)\n aka her, no grace, grace, herself': Counter(),
#  'she\t(Thomas Hardy___The Woodlanders)\n aka she, her, hers': Counter({'unending_agent': 1}),
#  'fitzpiers\t(Thomas Hardy___The Woodlanders)\n aka she, it, her, fitzpiers': Counter({'assist_agent': 1,
#           'assist_patient': 1}),
#  'he\t(Thomas Hardy___The Woodlanders)\n aka he, his': Counter({'examine_agent': 1}),
#  'her\t(Thomas Hardy___The Woodlanders)\n aka her': Counter(),
#  'mr harding\t(Anthony Trollope___The Warden)\n aka mr harding, his, himself, he, him': Counter({'keep_agent': 1,
#           'compliment_agent': 1,
#           'dine_agent': 1,
#           'dine_patient': 1}),
#  'eleanor\t(Anthony Trollope___The Warden)\n aka her, eleanor': Counter({'consent_patient': 1}),
#  'he\t(Anthony Trollope___The Warden)\n aka he, his': Counter({'fear_agent': 1,
#           'fear_patient': 1}),
#  'the warden\t(Anthony Trollope___The Warden)\n aka the warden, his': Counter(),
#  'bold\t(Anthony Trollope___The Warden)\n aka bold, his': Counter({'compel_patient': 1}),
#  'her\t(Charles Dickens___Doctor Marigold)\n aka her': Counter(),
#  'it\t(Charles Dickens___Doctor Marigold)\n aka it': Counter({'mean_agent': 1,
#           'foreboded_agent': 1}),
#  'she\t(Charles Dickens___Doctor Marigold)\n aka she': Counter({'confess_agent': 1}),
#  'a man\t(Charles Dickens___Doctor Marigold)\n aka a man, his': Counter(),
#  'his\t(Charles Dickens___Doctor Marigold)\n aka he, him, his': Counter(),
#  'duane\t(Zane Grey___The Lone Star Ranger)\n aka duane, he, him, his': Counter({'face_patient': 1,
#           'hold_patient': 1}),
#  'he\t(Zane Grey___The Lone Star Ranger)\n aka he': Counter({'cross_agent': 1}),
#  'jennie\t(Zane Grey___The Lone Star Ranger)\n aka she, jennie, her': Counter({'shut_agent': 1,
#           'shut_patient': 1}),
#  'his\t(Zane Grey___The Lone Star Ranger)\n aka him, his': Counter(),
#  'longstreth\t(Zane Grey___The Lone Star Ranger)\n aka he, longstreth': Counter(),
#  "white fang\t(Jack London___White Fang)\n aka white fang, his, he, white fang's, him": Counter({'snarl_agent': 1,
#           'bristle_agent': 1,
#           'bristle_patient': 1}),
#  'he\t(Jack London___White Fang)\n aka he, him, his': Counter({'assert_agent': 1,
#           'betray_agent': 1,
#           'pass_agent': 1}),
#  'his\t(Jack London___White Fang)\n aka he, his': Counter({'life_agent': 1}),
#  'henry\t(Jack London___White Fang)\n aka he, henry, him, his': Counter({'jerk_agent': 1,
#           'ease_patient': 1}),
#  'it\t(Jack London___White Fang)\n aka it, itself': Counter({'transform_agent': 1,
#           'transform_patient': 1}),
#  'we\t(Mark Twain___Adventures of Huckleberry Finn, Complete)\n aka we, us': Counter(),
#  'jim\t(Mark Twain___Adventures of Huckleberry Finn, Complete)\n aka he, jim': Counter(),
#  'it\t(Mark Twain___Adventures of Huckleberry Finn, Complete)\n aka it': Counter({"'s_agent": 1,
#           "'s_patient": 1}),
#  'he\t(Mark Twain___Adventures of Huckleberry Finn, Complete)\n aka he, him, his': Counter({'fling_agent': 2,
#           'fling_patient': 1}),
#  'tom\t(Mark Twain___Adventures of Huckleberry Finn, Complete)\n aka my tom, tom, me, his, he, him': Counter({'hold_agent': 1,
#           'change_agent': 1,
#           "hain't_patient": 1,
#           'peep_patient': 1,
#           'raise_patient': 1}),
#  'catherine\t(Jane Austen___Northanger Abbey)\n aka catherine': Counter(),
#  'she\t(Jane Austen___Northanger Abbey)\n aka she, her': Counter(),
#  'her\t(Jane Austen___Northanger Abbey)\n aka she, herself, her': Counter({'Catherine_agent': 1,
#           'Catherine_patient': 1,
#           'court_patient': 1}),
#  'henry\t(Jane Austen___Northanger Abbey)\n aka he, henry, his': Counter(),
#  'it\t(Jane Austen___Northanger Abbey)\n aka it': Counter(),
#  'tarzan\t(Edgar Rice Burroughs___Tarzan the Untamed)\n aka the ape-man, his, he, him, tarzan': Counter({'read_agent': 1}),
#  'the ape-man\t(Edgar Rice Burroughs___Tarzan the Untamed)\n aka he, him, the ape-man': Counter(),
#  'the girl\t(Edgar Rice Burroughs___Tarzan the Untamed)\n aka the girl, she, her': Counter(),
#  'he\t(Edgar Rice Burroughs___Tarzan the Untamed)\n aka he': Counter({'point_agent': 1}),
#  'smith-oldwick\t(Edgar Rice Burroughs___Tarzan the Untamed)\n aka smith-oldwick, him': Counter(),
#  'silas\t(George Eliot___Silas Marner)\n aka silas, his': Counter(),
#  'godfrey\t(George Eliot___Silas Marner)\n aka he, godfrey, me': Counter(),
#  'nancy\t(George Eliot___Silas Marner)\n aka nancy, her': Counter(),
#  'dunstan\t(George Eliot___Silas Marner)\n aka he, him, dunstan, his': Counter(),
#  'he\t(George Eliot___Silas Marner)\n aka he, him': Counter(),
#  'we\t(Bram Stoker___Dracula)\n aka our, we, us': Counter({'talk_agent': 1,
#           'wish_agent': 1,
#           'want_agent': 1,
#           'strike_patient': 1}),
#  'he\t(Bram Stoker___Dracula)\n aka he, him': Counter(),
#  'lucy\t(Bram Stoker___Dracula)\n aka she, her, lucy': Counter({'stop_agent': 1}),
#  'van helsing\t(Bram Stoker___Dracula)\n aka he, van helsing': Counter({'hypnotize_agent': 1}),
#  'the professor\t(Bram Stoker___Dracula)\n aka the professor, he, his': Counter({'shout_agent': 1,
#           'shout_patient': 1}),
#  'mr. pickwick\t(Charles Dickens___The Pickwick Papers)\n aka mr. pickwick': Counter(),
#  'sam\t(Charles Dickens___The Pickwick Papers)\n aka sam, his': Counter({'pause_agent': 1}),
#  'mr. weller\t(Charles Dickens___The Pickwick Papers)\n aka he, him, his, mr. weller': Counter(),
#  'sir\t(Charles Dickens___The Pickwick Papers)\n aka sir': Counter(),
#  'mr. winkle\t(Charles Dickens___The Pickwick Papers)\n aka his, mr. winkle': Counter({'engage_agent': 1}),
#  'elinor\t(Jane Austen___Sense and Sensibility)\n aka she, elinor, her': Counter({'appear_agent': 1}),
#  'marianne\t(Jane Austen___Sense and Sensibility)\n aka marianne': Counter({'reach_patient': 1}),
#  'edward\t(Jane Austen___Sense and Sensibility)\n aka edward, he, himself, his': Counter({'puzzle_agent': 1,
#           'appear_agent': 1,
#           'appear_patient': 1}),
#  'mrs. jennings\t(Jane Austen___Sense and Sensibility)\n aka mrs. jennings, she, her': Counter(),
#  'it\t(Jane Austen___Sense and Sensibility)\n aka its, it': Counter({'appear_agent': 1}),
#  "tom\t(Mark Twain___The Tragedy of Pudd'nhead Wilson)\n aka him, tom": Counter({'grant_agent': 1,
#           'pardon_patient': 1}),
#  "wilson\t(Mark Twain___The Tragedy of Pudd'nhead Wilson)\n aka he, wilson, his": Counter({'resume_agent': 1,
#           'confess_agent': 1,
#           'resign_agent': 1}),
#  "she\t(Mark Twain___The Tragedy of Pudd'nhead Wilson)\n aka she, her": Counter(),
#  "it\t(Mark Twain___The Tragedy of Pudd'nhead Wilson)\n aka it": Counter({'grieve_agent': 1,
#           'grieve_patient': 1}),
#  "he\t(Mark Twain___The Tragedy of Pudd'nhead Wilson)\n aka he, him, his": Counter(),
#  'tommy\t(Agatha Christie___The Secret Adversary)\n aka her, his, tommy, he, him': Counter({'expect_agent': 1,
#           'afflict_patient': 1,
#           'galvanize_patient': 1,
#           'scoff_patient': 1,
#           'inquired_patient': 1,
#           'round_patient': 1}),
#  'tuppence\t(Agatha Christie___The Secret Adversary)\n aka her, last tuppence, his, she, tuppence': Counter({'steal_agent': 1,
#           'observe_agent': 1,
#           'raise_agent': 1,
#           'respond_agent': 1,
#           'point_patient': 1}),
#  'julius\t(Agatha Christie___The Secret Adversary)\n aka julius': Counter({'like_patient': 1}),
#  'he\t(Agatha Christie___The Secret Adversary)\n aka he, the other boy, his': Counter({'suspect_agent': 1,
#           'fear_patient': 1}),
#  'we\t(Agatha Christie___The Secret Adversary)\n aka we, us': Counter({'continue_agent': 1}),
#  'gluck\t(John Ruskin___The King of the Golden River)\n aka he, gluck, him, his': Counter({'cast_agent': 1,
#           'climb_agent': 1,
#           'obey_agent': 1,
#           'spring_agent': 1}),
#  'hans\t(John Ruskin___The King of the Golden River)\n aka he, him, his, hans': Counter({'stop_agent': 1}),
#  'schwartz\t(John Ruskin___The King of the Golden River)\n aka he, schwartz, him, his': Counter({'glare_agent': 1}),
#  'his\t(John Ruskin___The King of the Golden River)\n aka the old man, his, why son, he, him': Counter({'drink_agent': 1,
#           'bid_agent': 1}),
#  'it\t(John Ruskin___The King of the Golden River)\n aka its, it': Counter(),
#  'he\t(Joseph Conrad___Within the Tides)\n aka he, his': Counter(),
#  'davidson\t(Joseph Conrad___Within the Tides)\n aka tony, poor davidson, davidson, his, he, him': Counter({'expect_agent': 1,
#           '’_agent': 1,
#           'assure_patient': 1}),
#  'renouard\t(Joseph Conrad___Within the Tides)\n aka renouard': Counter(),
#  'cloete\t(Joseph Conrad___Within the Tides)\n aka cloete, his, himself, he, him': Counter({'skunk_agent': 1,
#           'weep_agent': 1,
#           'jump_agent': 1,
#           'revolver_agent': 1,
#           'beat_patient': 1,
#           'exhaust_patient': 1,
#           'throw_patient': 1}),
#  'byrne\t(Joseph Conrad___Within the Tides)\n aka she, he, byrne, her': Counter({'wish_agent': 1}),
#  'wolf larsen\t(Jack London___The Sea-Wolf)\n aka wolf larsen': Counter({'blow_patient': 1}),
#  'maud\t(Jack London___The Sea-Wolf)\n aka she, maud, me, her': Counter({'smote_agent': 1,
#           'whisper_agent': 1,
#           'meet_agent': 1,
#           'rescue_agent': 1}),
#  'we\t(Jack London___The Sea-Wolf)\n aka we, us': Counter({'save_patient': 1}),
#  'he\t(Jack London___The Sea-Wolf)\n aka he, him, his': Counter({'receive_agent': 1,
#           'lose_agent': 1,
#           'complain_agent': 1,
#           'desert_patient': 1,
#           'complain_patient': 1}),
#  'it\t(Jack London___The Sea-Wolf)\n aka it': Counter({'rescue_agent': 1,
#           'rescue_patient': 1}),
#  'the colonel\t(Charles Dickens___Holiday Romance)\n aka the colonel, his, himself, he, him': Counter({'round_agent': 1,
#           'round_patient': 1}),
#  'boldheart\t(Charles Dickens___Holiday Romance)\n aka she, it, his, himself, he, boldheart': Counter({'anchor_agent': 1,
#           'accord_agent': 1,
#           'release_patient': 1}),
#  'the princess alicia\t(Charles Dickens___Holiday Romance)\n aka the princess alicia, she, her': Counter({'tap_agent': 1,
#           'tap_patient': 1,
#           'change_patient': 1}),
#  'the queen\t(Charles Dickens___Holiday Romance)\n aka its, the queen': Counter({'wave_agent': 1}),
#  'a king\t(Charles Dickens___Holiday Romance)\n aka the king, king, sir, his, he, a king, him': Counter({'proceed_agent': 1,
#           'spoil_agent': 1,
#           'hang_agent': 2,
#           'frighten_agent': 1,
#           'vanish_agent': 1,
#           'write_agent': 1,
#           'invite_agent': 1,
#           'inquire_patient': 1,
#           'invite_patient': 1}),
#  'dick\t(Robert Louis Stevenson___The Black Arrow)\n aka he, dick': Counter(),
#  'ye\t(Robert Louis Stevenson___The Black Arrow)\n aka ye, sir, you, me, yourself': Counter(),
#  'sir daniel\t(Robert Louis Stevenson___The Black Arrow)\n aka richard, his, he, him, sir daniel': Counter({'wring_agent': 1,
#           'judge_patient': 1,
#           'wring_patient': 1}),
#  'he\t(Robert Louis Stevenson___The Black Arrow)\n aka he, him, his': Counter({'smile_agent': 1,
#           'care_agent': 1}),
#  'they\t(Robert Louis Stevenson___The Black Arrow)\n aka they': Counter({'unfold_agent': 1}),
#  'oliver\t(Charles Dickens___Oliver Twist)\n aka oliver, his': Counter(),
#  'mr. bumble\t(Charles Dickens___Oliver Twist)\n aka he, mr. bumble, his': Counter(),
#  'the jew\t(Charles Dickens___Oliver Twist)\n aka the jew, he, him, his': Counter(),
#  'he\t(Charles Dickens___Oliver Twist)\n aka he, his': Counter({'struggle_agent': 1}),
#  'fagin\t(Charles Dickens___Oliver Twist)\n aka fagin, he, his': Counter({'burden_agent': 1}),
#  'mr. franklin\t(Wilkie Collins___The Moonstone)\n aka mr. franklin, he, him': Counter({'stare_agent': 1}),
#  'he\t(Wilkie Collins___The Moonstone)\n aka he, his': Counter({'express_agent': 1}),
#  'rachel\t(Wilkie Collins___The Moonstone)\n aka rachel': Counter(),
#  'it\t(Wilkie Collins___The Moonstone)\n aka it': Counter(),
#  'miss rachel\t(Wilkie Collins___The Moonstone)\n aka rachel, miss rachel': Counter(),
#  'the syndicate\t(Frank Richard Stockton___The Great War Syndicate)\n aka syndicate, the syndicate': Counter(),
#  'her\t(Frank Richard Stockton___The Great War Syndicate)\n aka her': Counter(),
#  'the adamant\t(Frank Richard Stockton___The Great War Syndicate)\n aka the adamant, adamant': Counter({'ready_agent': 1,
#           'send_patient': 1}),
#  'she\t(Frank Richard Stockton___The Great War Syndicate)\n aka she, her': Counter({'shoreward_agent': 1}),
#  'the crab\t(Frank Richard Stockton___The Great War Syndicate)\n aka the crab': Counter(),
#  'we\t(Daniel Defoe___The Life and Adventures of Robinson Crusoe (1808))\n aka our, we, us': Counter({'sail_agent': 1}),
#  'he\t(Daniel Defoe___The Life and Adventures of Robinson Crusoe (1808))\n aka himself, he, him, his': Counter({'spake_agent': 1}),
#  'they\t(Daniel Defoe___The Life and Adventures of Robinson Crusoe (1808))\n aka they': Counter(),
#  'our\t(Daniel Defoe___The Life and Adventures of Robinson Crusoe (1808))\n aka our, we, us': Counter({'staid_agent': 1,
#           'fancy_agent': 1,
#           'bade_agent': 1,
#           'aim_agent': 1,
#           'sleep_agent': 1}),
#  'it\t(Daniel Defoe___The Life and Adventures of Robinson Crusoe (1808))\n aka it': Counter(),
#  'the maid\t(Andrew Lang___A Monk of Fife)\n aka she, the maid, her': Counter({'mind_agent': 1}),
#  'we\t(Andrew Lang___A Monk of Fife)\n aka we': Counter({'wed_agent': 1,
#           'wed_patient': 1}),
#  'elliot\t(Andrew Lang___A Monk of Fife)\n aka elliot, she, her': Counter({'speak_agent': 1}),
#  'he\t(Andrew Lang___A Monk of Fife)\n aka he, him': Counter({'write_agent': 1,
#           'write_patient': 1}),
#  'her\t(Andrew Lang___A Monk of Fife)\n aka she, her': Counter({'fill_agent': 1}),
#  'mr verloc\t(Joseph Conrad___The Secret Agent)\n aka mr verloc, she, mrs verloc, her': Counter(),
#  'mrs verloc\t(Joseph Conrad___The Secret Agent)\n aka mrs verloc, her': Counter(),
#  'he\t(Joseph Conrad___The Secret Agent)\n aka himself, he, his': Counter({'mutter_agent': 1,
#           'bow_agent': 1}),
#  'his\t(Joseph Conrad___The Secret Agent)\n aka the professor, he, him, his': Counter({'divide_agent': 1,
#           'elaborate_agent': 1,
#           'pause_agent': 1,
#           'continue_agent': 1}),
#  'she\t(Joseph Conrad___The Secret Agent)\n aka she': Counter({'pause_agent': 1,
#           'sob_agent': 1}),
#  'venters\t(Zane Grey___Riders of the Purple Sage)\n aka he, me, venters': Counter({'forget_agent': 1,
#           'strap_agent': 1}),
#  'jane\t(Zane Grey___Riders of the Purple Sage)\n aka she, jane, her': Counter({'climb_agent': 1}),
#  'he\t(Zane Grey___Riders of the Purple Sage)\n aka tull, she, herself, his, he, him': Counter({'arise_agent': 1,
#           'climb_agent': 1}),
#  'lassiter\t(Zane Grey___Riders of the Purple Sage)\n aka he, lassiter, his': Counter({'place_agent': 1}),
#  'jane withersteen\t(Zane Grey___Riders of the Purple Sage)\n aka she, jane withersteen': Counter(),
#  'sir patrick\t(Wilkie Collins___Man and Wife)\n aka he, him, sir patrick, his': Counter({'resume_agent': 1,
#           'mean_agent': 1,
#           'honor_patient': 1}),
#  'geoffrey\t(Wilkie Collins___Man and Wife)\n aka himself, geoffrey, he, his': Counter({'bear_agent': 1,
#           'hurry_agent': 1,
#           'steady_agent': 1,
#           'stoop_agent': 1,
#           'poise_agent': 1}),
#  'anne\t(Wilkie Collins___Man and Wife)\n aka she, anne, me, her': Counter({'start_agent': 1,
#           'draw_agent': 1,
#           'fly_agent': 1,
#           'flee_agent': 1,
#           'wake_patient': 1}),
#  'blanche\t(Wilkie Collins___Man and Wife)\n aka blanche': Counter({'assure_agent': 1}),
#  'he\t(Wilkie Collins___Man and Wife)\n aka he, his': Counter({'advance_agent': 1,
#           'offer_agent': 1}),
#  'alan\t(Robert Louis Stevenson___Kidnapped)\n aka he, him, alan, his': Counter({'talk_agent': 1}),
# ...
#  'he\t(Jack London___The Jacket (The Star-Rover))\n aka he, myself': Counter(),
#  'it\t(Jack London___The Jacket (The Star-Rover))\n aka it': Counter({'present_patient': 1}),
#  'they\t(Jack London___The Jacket (The Star-Rover))\n aka them, they': Counter(),
#  'he\t(Joseph Conrad___End of the Tether)\n aka he, his': Counter({'carry_agent': 1}),
#  'captain whalley\t(Joseph Conrad___End of the Tether)\n aka he, captain whalley': Counter({'refuse_agent': 1}),
#  'his\t(Joseph Conrad___End of the Tether)\n aka himself, he, him, his': Counter({'wonder_agent': 1}),
#  'mr. van wyk\t(Joseph Conrad___End of the Tether)\n aka mr. van wyk, his': Counter(),
#  'massy\t(Joseph Conrad___End of the Tether)\n aka massy, him, mr. massy': Counter(),
#  'lady susan\t(Jane Austen___Lady Susan)\n aka she, herself, lady susan, her': Counter({'confess_patient': 1}),
#  'frederica\t(Jane Austen___Lady Susan)\n aka her, mrs. vernon, herself, she, frederica': Counter({'fix_patient': 1}),
#  'reginald\t(Jane Austen___Lady Susan)\n aka reginald, he, him, his': Counter(),
#  'sir james\t(Jane Austen___Lady Susan)\n aka him, sir james, myself': Counter({'confess_patient': 1}),
#  'we\t(Jane Austen___Lady Susan)\n aka we': Counter(),
#  'mrs. grose\t(Henry James___The Turn of the Screw)\n aka mrs. grose, she': Counter({'grant_agent': 1}),
#  'he\t(Henry James___The Turn of the Screw)\n aka he, him, his': Counter({'suffer_agent': 1,
#           'suffer_patient': 1}),
#  'it\t(Henry James___The Turn of the Screw)\n aka it': Counter({'imagine_agent': 1,
#           'imagine_patient': 1}),
#  'her\t(Henry James___The Turn of the Screw)\n aka her, me, myself, she, miss': Counter({'engage_agent': 1,
#           'hold_agent': 1,
#           'sigh_agent': 1,
#           'drop_agent': 1,
#           'spring_agent': 1}),
#  'his\t(Henry James___The Turn of the Screw)\n aka he, him, his': Counter({'matter_agent': 1,
#           'jerk_agent': 1,
#           'utter_agent': 1,
#           'utter_patient': 1,
#           'catch_patient': 1,
#           'imagine_patient': 1}),
#  "almayer\t(Joseph Conrad___Almayer's Folly)\n aka almayer, his": Counter({'stop_agent': 1,
#           'visit_patient': 1}),
#  "he\t(Joseph Conrad___Almayer's Folly)\n aka he": Counter({'pause_agent': 1}),
#  "nina\t(Joseph Conrad___Almayer's Folly)\n aka nina": Counter(),
#  "dain\t(Joseph Conrad___Almayer's Folly)\n aka dain, his": Counter(),
#  "she\t(Joseph Conrad___Almayer's Folly)\n aka she, her": Counter({'die_agent': 1,
#           'send_patient': 1,
#           'want_patient': 1}),
#  'sheldon\t(Jack London___Adventure)\n aka he, sheldon': Counter({'remark_agent': 1}),
#  'he\t(Jack London___Adventure)\n aka he, him, his': Counter(),
#  'joan\t(Jack London___Adventure)\n aka she, joan, herself, his, he, him': Counter({'recoil_agent': 1,
#           'recoil_patient': 1}),
#  'she\t(Jack London___Adventure)\n aka she, her': Counter({'stammer_agent': 1}),
#  'her\t(Jack London___Adventure)\n aka she, her': Counter({'whisper_agent': 1,
#           'urge_agent': 1,
#           'droop_agent': 1,
#           'hold_patient': 1,
#           'draw_patient': 1}),
#  'we\t(Charles Dickens___The Wreck of the Golden Mary)\n aka we, us': Counter(),
#  'our\t(Charles Dickens___The Wreck of the Golden Mary)\n aka our, we': Counter(),
#  'it\t(Charles Dickens___The Wreck of the Golden Mary)\n aka it': Counter({'lay_agent': 1}),
#  'john\t(Charles Dickens___The Wreck of the Golden Mary)\n aka john, he, his': Counter({'happen_agent': 1}),
#  'the child\t(Charles Dickens___The Wreck of the Golden Mary)\n aka the child': Counter({'save_patient': 1}),
#  'bernard\t(Henry James___Confidence)\n aka bernard, he, him, his': Counter({'repair_agent': 1,
#           'buy_agent': 1,
#           'buy_patient': 1,
#           'reach_patient': 1}),
#  'gordon\t(Henry James___Confidence)\n aka he, gordon, his': Counter({'buy_agent': 1}),
#  'angela\t(Henry James___Confidence)\n aka angela': Counter(),
#  'mrs. vivian\t(Henry James___Confidence)\n aka mrs. vivian, her': Counter(),
#  'he\t(Henry James___Confidence)\n aka he, him, his': Counter(),
#  "hiram\t(Howard Pyle___Howard Pyle's Book of Pirates)\n aka he, hiram, him, his": Counter({'offer_agent': 1,
#           'marry_agent': 1}),
#  "jonathan\t(Howard Pyle___Howard Pyle's Book of Pirates)\n aka he, him, his, jonathan": Counter({'need_agent': 1,
#           'gaze_agent': 1}),
#  "he\t(Howard Pyle___Howard Pyle's Book of Pirates)\n aka he, his": Counter({'lead_patient': 1}),
#  "barnaby\t(Howard Pyle___Howard Pyle's Book of Pirates)\n aka he, barnaby, his": Counter({'wish_agent': 1}),
#  "levi\t(Howard Pyle___Howard Pyle's Book of Pirates)\n aka himself, him, levi, his": Counter({'raise_agent': 1,
#           'raise_patient': 1,
#           'push_patient': 1}),
#  'he\t(Jack London___Smoke Bellew)\n aka he, his': Counter({'first_agent': 1,
#           'rest_agent': 1,
#           'hungry_agent': 1,
#           'cook_agent': 1,
#           'sleep_agent': 1,
#           'note_agent': 1}),
#  'shorty\t(Jack London___Smoke Bellew)\n aka shorty, his': Counter({'gulp_agent': 1}),
#  'his\t(Jack London___Smoke Bellew)\n aka he, his': Counter(),
#  'they\t(Jack London___Smoke Bellew)\n aka them, they, their': Counter({'taste_agent': 1}),
#  'we\t(Jack London___Smoke Bellew)\n aka we': Counter({'an_agent': 1}),
#  'billy\t(Jack London___The Valley of the Moon)\n aka he, him, billy, his': Counter({'will_agent': 1}),
#  'saxon\t(Jack London___The Valley of the Moon)\n aka saxon': Counter(),
#  'she\t(Jack London___The Valley of the Moon)\n aka she, her': Counter({'receive_patient': 1}),
#  'her\t(Jack London___The Valley of the Moon)\n aka her': Counter(),
#  'he\t(Jack London___The Valley of the Moon)\n aka he, his': Counter(),
#  'mansoul\t(John Bunyan___The Holy War)\n aka mansoul, my mansoul': Counter(),
#  'they\t(John Bunyan___The Holy War)\n aka themselves, them, they': Counter(),
#  'diabolus\t(John Bunyan___The Holy War)\n aka diabolus, his': Counter(),
#  'he\t(John Bunyan___The Holy War)\n aka he, him, his': Counter(),
#  'emmanuel\t(John Bunyan___The Holy War)\n aka emmanuel, him, his': Counter(),
#  'alan\t(Robert Louis Stevenson___Catriona)\n aka "alan, that man, alan, me, his, himself, he, him, next alan': Counter({'entertain_agent': 1,
#           'smack_agent': 1,
#           'scarce_agent': 1,
#           'suppose_agent': 1,
#           '"_agent': 1,
#           'sell_agent': 1,
#           'wear_agent': 1,
#           'pick_agent': 1,
#           'flee_agent': 1,
#           'spring_agent': 1,
#           'carry_agent': 1,
#           'show_agent': 1,
#           'forget_agent': 1,
#           'entertain_patient': 1,
#           '"_patient': 1,
#           'bring_patient': 1,
#           'jink_patient': 1,
#           'pursue_patient': 1,
#           'roared_patient': 1,
#           'pay_patient': 1,
#           'spring_patient': 1,
#           'carry_patient': 1,
#           'lodge_patient': 1,
#           'upon_patient': 1,
#           'forget_patient': 1}),
#  'catriona\t(Robert Louis Stevenson___Catriona)\n aka ye, her, you, catriona, me, myself, the girl, herself, she': Counter({'clap_agent': 1,
#           'avoid_agent': 1,
#           'observe_agent': 1,
#           'arouse_agent': 1,
#           'keep_agent': 1,
#           'mean_agent': 1,
#           'draw_agent': 1,
#           'raise_agent': 2,
#           'step_agent': 1,
#           'weep_agent': 1,
#           'pluck_agent': 1,
#           'hold_agent': 1,
#           'press_agent': 1,
#           'pick_agent': 1,
#           'use_patient': 1,
#           'remind_patient': 1,
#           'change_patient': 1,
#           'decoy_patient': 1,
#           'call_patient': 1,
#           'lodge_patient': 1,
#           'upon_patient': 1}),
#  'we\t(Robert Louis Stevenson___Catriona)\n aka we': Counter(),
#  'it\t(Robert Louis Stevenson___Catriona)\n aka it': Counter(),
#  'ye\t(Robert Louis Stevenson___Catriona)\n aka ye, he': Counter({'bring_agent': 1}),
#  'her\t(Frank Richard Stockton___The Lady, or the Tiger?)\n aka that woman, she, her': Counter({'lose_agent': 1,
#           'start_agent': 1,
#           'gnash_agent': 1,
#           'kindle_agent': 1,
#           'decide_agent': 1,
#           'kindle_patient': 1,
#           'decide_patient': 1}),
#  'her lover\t(Frank Richard Stockton___The Lady, or the Tiger?)\n aka her, her lover, he, herself, his, she': Counter({'expect_agent': 1,
#           'understand_agent': 1,
#           'base_agent': 1,
#           'raise_agent': 1}),
#  'him\t(Frank Richard Stockton___The Lady, or the Tiger?)\n aka he, him, his': Counter({'gnash_agent': 1,
#           'kindle_agent': 1,
#           'lose_patient': 1}),
#  'the accused person\t(Frank Richard Stockton___The Lady, or the Tiger?)\n aka his, the accused person': Counter({'entertain_agent': 1}),
#  'this semi-barbaric king\t(Frank Richard Stockton___The Lady, or the Tiger?)\n aka the king, her, this semi-barbaric king, he, his, she, him': Counter({'move_agent': 1,
#           'hesitate_agent': 1,
#           'love_agent': 1,
#           'dispose_agent': 1}),
#  'mr. henry\t(Robert Louis Stevenson___The Master of Ballantrae)\n aka he, mr. henry, his': Counter(),
#  'he\t(Robert Louis Stevenson___The Master of Ballantrae)\n aka he, his': Counter({'learn_agent': 1,
#           'prevail_agent': 1,
#           'learn_patient': 1}),
#  'we\t(Robert Louis Stevenson___The Master of Ballantrae)\n aka our, we, us': Counter({'hold_patient': 1}),
#  'my lord\t(Robert Louis Stevenson___The Master of Ballantrae)\n aka him, my lord, his': Counter({'dare_agent': 1,
#           'dare_patient': 1}),
#  'the master\t(Robert Louis Stevenson___The Master of Ballantrae)\n aka the master, his master': Counter(),
#  'private richard doubledick\t(Charles Dickens___The Seven Poor Travellers)\n aka he, private richard doubledick, his': Counter({'sob_agent': 1,
#           'drop_agent': 1,
#           'breathe_agent': 1}),
#  'the captain\t(Charles Dickens___The Seven Poor Travellers)\n aka he, the captain, him, his': Counter(),
#  "the captain of richard doubledick's company\t(Charles Dickens___The Seven Poor Travellers)\n aka the young captain, the captain of richard doubledick's company, the captain, his, he, him": Counter({'could_agent': 1,
#           'reproach_agent': 1,
#           'wish_agent': 1,
#           'earn_agent': 1,
#           'reproach_patient': 1,
#           'wish_patient': 1}),
#  'it\t(Charles Dickens___The Seven Poor Travellers)\n aka he, it, his': Counter({'sob_agent': 1}),
#  'a generous, noble man\t(Charles Dickens___The Seven Poor Travellers)\n aka he, him, a generous, noble man, his': Counter({'love_agent': 1,
#           'honour_agent': 1,
#           'bear_agent': 1,
#           'marry_agent': 1,
#           'love_patient': 1,
#           'honour_patient': 1,
#           'wound_patient': 1,
#           'bring_patient': 1}),
#  "it\t(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)\n aka it": Counter({'require_patient': 1}),
#  "we\t(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)\n aka we all, our, we, us": Counter({'conquer_agent': 1,
#           'recognize_agent': 1,
#           'conquer_patient': 1}),
#  "the king\t(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)\n aka he, the king, him": Counter({'escape_agent': 1,
#           'gat_agent': 1,
#           '-PRON-_patient': 1,
#           'escape_patient': 1}),
#  "he\t(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)\n aka he, his": Counter({'finish_agent': 1}),
#  "they\t(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)\n aka they": Counter({'deep_agent': 1}),
#  'we\t(Winston Churchill___The Crossing)\n aka our, we, us': Counter({'cross_agent': 1,
#           'climb_agent': 1,
#           'gather_agent': 1,
#           'pass_agent': 1}),
#  'he\t(Winston Churchill___The Crossing)\n aka he, his': Counter({'set_agent': 1,
#           'save_agent': 1,
#           'measure_agent': 1}),
#  'nick\t(Winston Churchill___The Crossing)\n aka he, nick': Counter(),
#  'she\t(Winston Churchill___The Crossing)\n aka she, her': Counter({'pass_agent': 1}),
#  'tom\t(Winston Churchill___The Crossing)\n aka tom himself, he, little tom, tom': Counter({'forget_agent': 1,
#           'leap_agent': 1}),
#  'his face\t(Herman Melville___Bartleby, The Scrivener)\n aka the bright silks and sparkling faces i had seen that day, his hat, his face, his back, the hat, me, it, the boy, his': Counter({'insist_agent': 1,
#           'lead_agent': 1,
#           'mollify_agent': 1,
#           'endeavor_agent': 1,
#           'call_agent': 1,
#           'consider_agent': 1,
#           'overhear_agent': 1,
#           'mean_agent': 1,
#           'want_agent': 1,
#           'bring_patient': 1,
#           'handle_patient': 1,
#           'lead_patient': 1,
#           'believe_patient': 1,
#           'send_patient': 1,
#           'engage_patient': 1,
#           'scorn_patient': 1,
#           'prove_patient': 1,
#           'goad_patient': 1,
#           'consider_patient': 1,
#           'prefer_patient': 1,
#           'perceive_patient': 1,
#           'permit_patient': 1}),
#  'bartleby\t(Herman Melville___Bartleby, The Scrivener)\n aka bartleby here, me, myself, bartleby, it, his, himself, he, him': Counter({'occur_agent': 1,
#           'conclude_agent': 1,
#           'surmise_agent': 1,
#           'move_agent': 1,
#           'but_agent': 1,
#           'notice_agent': 1,
#           'vouchsafe_agent': 1,
#           'inform_agent': 1,
#           'remain_agent': 1,
#           'restore_agent': 1,
#           'assume_agent': 1,
#           'enter_agent': 1,
#           'emerge_agent': 1,
#           'undertake_agent': 1,
#           'request_agent': 1,
#           'decline_agent': 1,
#           'apprise_agent': 1,
#           'persist_agent': 1,
#           'resolve_patient': 1,
#           'procure_patient': 1,
#           'prove_patient': 1,
#           'summon_patient': 1,
#           'vouchsafe_patient': 1,
#           'warn_patient': 1,
#           'offer_patient': 1,
#           'enter_patient': 1,
#           'slide_patient': 1,
#           'request_patient': 1}),
#  "the law-copyists or scriveners\t(Herman Melville___Bartleby, The Scrivener)\n aka their, the law-copyists or scriveners, nippers, nippers', they, the, me, my two scriveners, them": Counter({'bring_agent': 1,
#           'declare_agent': 1,
#           'write_agent': 2,
#           'dress_agent': 1,
#           'wear_agent': 1,
#           'spread_agent': 1,
#           'send_agent': 1,
#           'eat_agent': 1,
#           'prefer_agent': 1,
#           'appear_agent': 1,
#           'disappear_agent': 1,
#           'exceed_agent': 1,
#           'complain_agent': 1,
#           'catch_agent': 1,
#           'in_agent': 1,
#           'vouchsafe_agent': 1,
#           'remain_agent': 1,
#           'stay_agent': 1,
#           'speak_agent': 1,
#           'retire_agent': 1,
#           'mean_patient': 1,
#           'spread_patient': 1,
#           'vanish_patient': 1}),
#  'him\t(Herman Melville___Bartleby, The Scrivener)\n aka the silent man, me, myself, it, his fatal act--an act which certainly no man could possibly deplore more than the actor himself, his, himself, he, him': Counter({'hint_agent': 1,
#           'decline_agent': 1,
#           'occur_agent': 1,
#           'depart_agent': 1,
#           'support_agent': 1,
#           'quit_agent': 1,
#           'wish_agent': 1,
#           'narrate_agent': 1,
#           'tis_agent': 1,
#           'ripple_patient': 1,
#           'hint_patient': 1,
#           'depart_patient': 1,
#           'support_patient': 1,
#           'quit_patient': 1,
#           'move_patient': 1,
#           'address_patient': 1,
#           'withdraw_patient': 1,
#           'lead_patient': 1,
#           'receive_patient': 1,
#           'obtain_patient': 1}),
#  'me\t(Herman Melville___Bartleby, The Scrivener)\n aka some light, myself, they, he would but have named a single relative or friend, this old adam of resentment, it, the light, their, four lengthy documents': Counter({'write_agent': 2,
#           'grapple_agent': 1,
#           'accost_agent': 1,
#           'want_agent': 1,
#           'place_patient': 1,
#           'conclude_patient': 1,
#           'grapple_patient': 1,
#           'drop_patient': 1}),
#  ...}

# %%
charTexts
# Out:
# [[],
#  [],
#  ['call_agent'],
#  ['promise_agent',
#   'twist_agent',
#   'call_agent',
#   'moan_agent',
#   'wonder_agent',
#   'promise_patient',
#   'call_patient',
#   'moan_patient'],
#  [],
#  ['graze_agent', 'distance_agent', 'hasten_agent', 'reach_agent'],
#  [],
#  [],
#  ['choose_agent'],
#  ['furnish_agent'],
#  ['watch_agent', 'resume_agent'],
#  ['dream_agent'],
#  [],
#  ['hurry_agent'],
#  ['lighten_agent', 'lighten_patient'],
#  ['will_agent'],
#  ['quit_agent',
#   'recover_agent',
#   'linger_agent',
#   'publish_agent',
#   'recover_patient',
#   'linger_patient'],
#  ['wonder_agent', 'suggest_agent'],
#  [],
#  [],
#  [],
#  [],
#  ['display_agent', 'wish_patient'],
#  ['bend_agent', 'wish_agent', 'reflect_agent'],
#  [],
#  [],
#  ['cheer_agent'],
#  [],
#  [],
#  ['bow_agent'],
#  ['draw_agent', 'assure_patient'],
#  ['happen_agent', 'admonish_agent', 'venture_agent'],
#  [],
#  ['step_agent', 'call_patient'],
#  [],
#  ['realize_agent'],
#  [],
#  ['mount_agent'],
#  [],
#  [],
#  ['haunt_agent', 'appear_patient'],
#  ['travel_agent'],
#  [],
#  ['avail_agent', 'avail_patient'],
#  ['accompany_agent'],
#  [],
#  ['clear_agent', 'clear_patient'],
#  ['parry_agent', 'parry_patient'],
#  ['roll_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['build_patient'],
#  [],
#  ['pass_agent', 'coachman_agent', 'coachman_patient'],
#  ['address_agent', 'address_patient', 'doom_patient'],
#  ['affirm_agent', 'call_patient'],
#  ['die_agent', 'mount_agent', '"_agent'],
#  [],
#  ['read_agent', 'groan_agent'],
#  [],
#  ['happen_agent',
#   'set_agent',
#   'tear_agent',
#   'stab_agent',
#   'marry_patient',
#   'stab_patient'],
#  [],
#  [],
#  [],
#  ['cross_agent', 'break_agent'],
#  ['wish_agent'],
#  [],
#  ['indicate_agent', 'die_agent', 'exclaimed_patient'],
#  ['Thank_patient'],
#  ['respond_agent', 'catch_patient'],
#  [],
#  [],
#  ['kill_agent'],
#  ['waste_agent', 'sway_agent', 'fit_agent'],
#  ['harm_agent'],
#  ['surprise_agent', 'flee_agent', 'hurl_agent', 'surprise_patient'],
#  [],
#  [],
#  ['wet_agent'],
#  [],
#  ['revive_agent', 'inform_patient'],
#  ['swam_agent', 'swam_patient'],
#  [],
#  [],
#  [],
#  ['suggest_agent', 'consult_patient'],
#  [],
#  ['stammer_agent'],
#  [],
#  ['show_agent'],
#  ['move_patient', 'nothing_patient'],
#  ['mention_agent'],
#  ['rush_agent', 'happen_agent', 'happen_patient'],
#  ['hesitate_agent', 'shut_agent'],
#  ['burst_agent',
#   'want_agent',
#   'determine_agent',
#   'climb_agent',
#   'wade_agent',
#   'scramble_agent',
#   'squeeze_agent',
#   'wriggle_agent',
#   'wriggle_agent',
#   'face_agent',
#   'squeeze_patient',
#   'wriggle_patient',
#   'offer_patient',
#   'smear_patient',
#   'oblige_patient'],
#  ['stare_agent',
#   'climb_agent',
#   'tie_agent',
#   'carry_agent',
#   'watch_agent',
#   'throw_agent',
#   'enquire_agent',
#   'untie_agent'],
#  ['pick_agent', 'lift_agent'],
#  [],
#  ['depart_agent'],
#  ['persist_agent'],
#  ['word_agent'],
#  ['speak_patient', 'pick_patient'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['break_patient', 'hurry_patient'],
#  [],
#  ['tremble_agent', 'wail_patient'],
#  [],
#  ['stammer_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sink_patient'],
#  [],
#  ['use_agent'],
#  [],
#  ['use_agent',
#   'sink_agent',
#   'overtake_agent',
#   'use_patient',
#   'overtake_patient',
#   'bring_patient'],
#  ['pause_agent'],
#  [],
#  [],
#  [],
#  ['drop_agent',
#   'attack_agent',
#   'attack_agent',
#   'examine_agent',
#   'straighten_agent',
#   'fling_agent',
#   'grin_agent',
#   'mutter_agent'],
#  [],
#  ['meet_agent', 'stride_agent', 'stride_patient'],
#  [],
#  ['bow_agent', 'whisper_patient'],
#  ['halt_agent',
#   'sink_agent',
#   'crawl_agent',
#   'on_agent',
#   'part_agent',
#   'warn_patient'],
#  ['observe_agent'],
#  ['accept_agent', 'choose_agent'],
#  ['commit_agent',
#   'continue_agent',
#   'oppose_agent',
#   'die_agent',
#   'call_agent',
#   'oppose_patient',
#   'call_patient',
#   'choose_patient'],
#  ['repent_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['save_agent', 'mean_patient'],
#  ['maintain_agent', 'maintain_patient'],
#  ['summon_agent'],
#  [],
#  ['conduct_agent'],
#  ['move_agent', 'part_agent'],
#  ['continue_agent'],
#  ['scream_agent', 'struggle_agent', 'shatter_patient', 'struggle_patient'],
#  ['pursue_agent'],
#  ['break_agent', 'marry_agent', 'marry_patient'],
#  ['talk_agent'],
#  ['affect_agent',
#   'carry_agent',
#   'but_agent',
#   'settle_agent',
#   'wear_patient',
#   'affect_patient'],
#  ['serve_agent', 'baffle_agent'],
#  ['present_agent',
#   'grant_agent',
#   'rest_agent',
#   'stare_agent',
#   'carry_patient',
#   'fresh_patient'],
#  ['keep_patient'],
#  [],
#  ['wonder_patient'],
#  [],
#  ['sew_agent', 'glide_agent'],
#  ['hold_agent'],
#  ['suffer_agent', 'witness_agent'],
#  ['lay_patient'],
#  [],
#  [],
#  ['for_agent'],
#  [],
#  ['satisfy_agent', 'requite_agent', 'requite_patient'],
#  ['quit_agent', 'quit_patient'],
#  ['value_agent'],
#  [],
#  ['end_agent'],
#  ['decide_agent',
#   'approach_agent',
#   'march_agent',
#   'converse_agent',
#   'approach_patient',
#   'hold_patient'],
#  ['set_patient', 'receive_patient'],
#  ['stop_agent',
#   'guess_agent',
#   'stamp_agent',
#   'seize_agent',
#   'cease_agent',
#   'raise_agent',
#   'approach_patient',
#   'seize_patient',
#   'crush_patient'],
#  [],
#  ['strike_agent', 'strike_patient'],
#  ['judge_agent', 'march_agent'],
#  [],
#  ['want_agent'],
#  ['finish_agent', 'snatch_agent'],
#  ['bear_agent'],
#  [],
#  ['request_agent', 'request_patient'],
#  [],
#  ['shine_agent', 'show_agent', 'show_patient'],
#  [],
#  ['smile_agent', 'draw_agent', 'discover_agent'],
#  [],
#  ['shoot_agent', 'lift_agent'],
#  [],
#  [],
#  ['show_agent'],
#  [],
#  ['kneel_agent', 'whisper_agent'],
#  [],
#  [],
#  ['succeed_agent'],
#  [],
#  ['crave_agent'],
#  ['read_agent', 'read_agent', 'perceive_agent'],
#  [],
#  ['bend_agent', 'bend_patient'],
#  ['betray_agent'],
#  ['discover_agent'],
#  ['stammer_agent'],
#  [],
#  [],
#  ['decline_agent'],
#  [],
#  ['visible_agent'],
#  [],
#  ['suppose_agent', 'venture_agent'],
#  ['encourage_agent', 'steal_agent'],
#  ['keep_agent',
#   'keep_agent',
#   'lay_agent',
#   'lay_agent',
#   'conceal_agent',
#   'falter_agent',
#   'yet_agent',
#   'offer_agent',
#   'guess_agent',
#   'bear_agent',
#   'beat_patient',
#   'keep_patient',
#   'hesitate_patient',
#   'bear_patient',
#   'fold_patient',
#   'stoop_patient'],
#  ['establish_agent'],
#  ['interrupt_agent'],
#  [],
#  ['seize_agent'],
#  ['throw_patient'],
#  ['retort_agent'],
#  ['accompany_agent'],
#  [],
#  [],
#  ['contribute_agent', 'talk_agent'],
#  [],
#  [],
#  ['gain_agent',
#   'cross_agent',
#   'penetrate_agent',
#   'river_agent',
#   'cross_patient'],
#  ['crook_agent', 'crook_patient'],
#  ['pull_agent', 'bite_agent', 'manage_agent', 'speed_agent'],
#  ['escape_agent', 'meet_patient'],
#  [],
#  [],
#  ['hesitate_agent', 'shut_agent'],
#  ['stare_agent',
#   'climb_agent',
#   'tie_agent',
#   'carry_agent',
#   'watch_agent',
#   'throw_agent',
#   'enquire_agent',
#   'untie_agent',
#   'use_agent',
#   'determine_agent',
#   'catch_agent',
#   'wipe_agent'],
#  ['slip_agent'],
#  [],
#  ['mean_agent', 'finish_agent'],
#  ['mean_agent'],
#  ['reconcile_patient'],
#  [],
#  [],
#  ['converse_agent', 'arise_agent'],
#  ['bound_patient'],
#  [],
#  [],
#  [],
#  ['examine_patient'],
#  [],
#  ['jam_agent', 'clatter_agent'],
#  ['rest_agent'],
#  ['play_agent', 'play_patient'],
#  ['reach_agent'],
#  [],
#  [],
#  ['dine_agent'],
#  [],
#  ['stoop_agent', 'untie_agent'],
#  [],
#  ['pay_agent', 'suggest_agent', 'strain_patient', 'pass_patient'],
#  ['undo_agent',
#   'throw_agent',
#   'strain_agent',
#   'breathe_agent',
#   'throw_patient',
#   'seize_patient'],
#  ['fight_agent'],
#  ['inform_agent',
#   'desert_agent',
#   'keep_agent',
#   'desert_patient',
#   'keep_patient'],
#  [],
#  [],
#  ['occur_agent'],
#  ['partook_agent'],
#  [],
#  ['unending_agent'],
#  ['assist_agent', 'assist_patient'],
#  ['examine_agent'],
#  [],
#  ['keep_agent', 'compliment_agent', 'dine_agent', 'dine_patient'],
#  ['consent_patient'],
#  ['fear_agent', 'fear_patient'],
#  [],
#  ['compel_patient'],
#  [],
#  ['mean_agent', 'foreboded_agent'],
#  ['confess_agent'],
#  [],
#  [],
#  ['face_patient', 'hold_patient'],
#  ['cross_agent'],
#  ['shut_agent', 'shut_patient'],
#  [],
#  [],
#  ['snarl_agent', 'bristle_agent', 'bristle_patient'],
#  ['assert_agent', 'betray_agent', 'pass_agent'],
#  ['life_agent'],
#  ['jerk_agent', 'ease_patient'],
#  ['transform_agent', 'transform_patient'],
#  [],
#  [],
#  ["'s_agent", "'s_patient"],
#  ['fling_agent', 'fling_agent', 'fling_patient'],
#  ['hold_agent',
#   'change_agent',
#   "hain't_patient",
#   'peep_patient',
#   'raise_patient'],
#  [],
#  [],
#  ['Catherine_agent', 'Catherine_patient', 'court_patient'],
#  [],
#  [],
#  ['read_agent'],
#  [],
#  [],
#  ['point_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['talk_agent', 'wish_agent', 'want_agent', 'strike_patient'],
#  [],
#  ['stop_agent'],
#  ['hypnotize_agent'],
#  ['shout_agent', 'shout_patient'],
#  [],
#  ['pause_agent'],
#  [],
#  [],
#  ['engage_agent'],
#  ['appear_agent'],
#  ['reach_patient'],
#  ['puzzle_agent', 'appear_agent', 'appear_patient'],
#  [],
#  ['appear_agent'],
#  ['grant_agent', 'pardon_patient'],
#  ['resume_agent', 'confess_agent', 'resign_agent'],
#  [],
#  ['grieve_agent', 'grieve_patient'],
#  [],
#  ['expect_agent',
#   'afflict_patient',
#   'galvanize_patient',
#   'scoff_patient',
#   'inquired_patient',
#   'round_patient'],
#  ['steal_agent',
#   'observe_agent',
#   'raise_agent',
#   'respond_agent',
#   'point_patient'],
#  ['like_patient'],
#  ['suspect_agent', 'fear_patient'],
#  ['continue_agent'],
#  ['cast_agent', 'climb_agent', 'obey_agent', 'spring_agent'],
#  ['stop_agent'],
#  ['glare_agent'],
#  ['drink_agent', 'bid_agent'],
#  [],
#  [],
#  ['expect_agent', '’_agent', 'assure_patient'],
#  [],
#  ['skunk_agent',
#   'weep_agent',
#   'jump_agent',
#   'revolver_agent',
#   'beat_patient',
#   'exhaust_patient',
#   'throw_patient'],
#  ['wish_agent'],
#  ['blow_patient'],
#  ['smote_agent', 'whisper_agent', 'meet_agent', 'rescue_agent'],
#  ['save_patient'],
#  ['receive_agent',
#   'lose_agent',
#   'complain_agent',
#   'desert_patient',
#   'complain_patient'],
#  ['rescue_agent', 'rescue_patient'],
#  ['round_agent', 'round_patient'],
#  ['anchor_agent', 'accord_agent', 'release_patient'],
#  ['tap_agent', 'tap_patient', 'change_patient'],
#  ['wave_agent'],
#  ['proceed_agent',
#   'spoil_agent',
#   'hang_agent',
#   'hang_agent',
#   'frighten_agent',
#   'vanish_agent',
#   'write_agent',
#   'invite_agent',
#   'inquire_patient',
#   'invite_patient'],
#  [],
#  [],
#  ['wring_agent', 'judge_patient', 'wring_patient'],
#  ['smile_agent', 'care_agent'],
#  ['unfold_agent'],
#  [],
#  [],
#  [],
#  ['struggle_agent'],
#  ['burden_agent'],
#  ['stare_agent'],
#  ['express_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['ready_agent', 'send_patient'],
#  ['shoreward_agent'],
#  [],
#  ['sail_agent'],
#  ['spake_agent'],
#  [],
#  ['staid_agent', 'fancy_agent', 'bade_agent', 'aim_agent', 'sleep_agent'],
#  [],
#  ['mind_agent'],
#  ['wed_agent', 'wed_patient'],
#  ['speak_agent'],
#  ['write_agent', 'write_patient'],
#  ['fill_agent'],
#  [],
#  [],
#  ['mutter_agent', 'bow_agent'],
#  ['divide_agent', 'elaborate_agent', 'pause_agent', 'continue_agent'],
#  ['pause_agent', 'sob_agent'],
#  ['forget_agent', 'strap_agent'],
#  ['climb_agent'],
#  ['arise_agent', 'climb_agent'],
#  ['place_agent'],
#  [],
#  ['resume_agent', 'mean_agent', 'honor_patient'],
#  ['bear_agent', 'hurry_agent', 'steady_agent', 'stoop_agent', 'poise_agent'],
#  ['start_agent', 'draw_agent', 'fly_agent', 'flee_agent', 'wake_patient'],
#  ['assure_agent'],
#  ['advance_agent', 'offer_agent'],
#  ['talk_agent'],
#  ['desert_agent'],
#  [],
#  [],
#  ['bind_agent', 'bind_patient'],
#  ['bite_agent'],
#  ['keep_agent'],
#  ['weigh_agent'],
#  ['peer_agent', 'bed_agent'],
#  ['desert_agent', 'reach_agent'],
#  ['tear_agent'],
#  ['carry_agent'],
#  [],
#  [],
#  ['bless_patient', 'continue_patient', 'kiss_patient', 'kiss_patient'],
#  [],
#  [],
#  [],
#  ['matter_agent'],
#  [],
#  ['connive_patient'],
#  ['bring_agent', 'bring_patient'],
#  [],
#  ['tis_agent'],
#  [],
#  [],
#  [],
#  ['clear_agent', 'reach_patient'],
#  ['offer_agent',
#   'blaze_agent',
#   'sound_agent',
#   'untie_agent',
#   'pet_agent',
#   'brush_agent',
#   'ease_agent',
#   'change_agent',
#   'score_agent',
#   'proceed_agent',
#   'talk_agent',
#   'befriend_patient',
#   'blaze_patient',
#   'untie_patient',
#   'grab_patient',
#   'spoil_patient',
#   'punish_patient'],
#  [],
#  ['stare_agent', 'assure_agent'],
#  [],
#  [],
#  [],
#  [],
#  ['post_agent',
#   'watch_agent',
#   'recognize_agent',
#   'conclude_agent',
#   'suspect_agent',
#   'ride_agent'],
#  [],
#  ['allow_agent'],
#  [],
#  [],
#  ['salute_agent', 'sing_agent'],
#  [],
#  ['recount_agent',
#   'dismiss_agent',
#   'echo_patient',
#   'recount_patient',
#   'dismiss_patient'],
#  ['thank_agent', 'start_agent', 'move_patient', 'thank_patient'],
#  ['recognise_agent'],
#  [],
#  [],
#  ['obey_agent', 'spur_agent', 'drop_agent', 'obey_patient', 'spur_patient'],
#  ['2_agent'],
#  ['leap_agent', 'shouted,--_agent', 'leap_patient', 'carry_patient'],
#  [],
#  ['disappear_agent'],
#  [],
#  [],
#  [],
#  ['move_agent', 'write_agent', '"_patient', 'write_patient'],
#  ['sound_agent',
#   'slip_agent',
#   'bless_agent',
#   'keep_agent',
#   'strike_agent',
#   'arch_agent',
#   'fly_agent',
#   'sound_patient',
#   'keep_patient'],
#  ['miss_agent',
#   'lay_agent',
#   'lay_agent',
#   'use_agent',
#   'meet_agent',
#   'nod_agent'],
#  ['Bobbo_agent'],
#  [],
#  ['shout_agent'],
#  ['escape_agent'],
#  ['divide_agent'],
#  [],
#  ['grumble_agent'],
#  ['refuse_agent'],
#  ['pursue_agent'],
#  [],
#  [],
#  [],
#  ['cross_agent', 'start_agent'],
#  [],
#  ['help_agent', 'declare_agent', 'scowl_agent', 'help_patient'],
#  [],
#  ['sound_agent',
#   "isn't_agent",
#   'bring_patient',
#   'like_patient',
#   'accept_patient',
#   'disown_patient',
#   'please_patient',
#   'pity_patient',
#   'grant_patient'],
#  ['doze_agent'],
#  ['pull_agent', 'notice_agent', 'bend_agent', 'pull_patient'],
#  ['keep_agent', 'keep_patient'],
#  ['shrug_agent', 'drink_agent', 'shout_agent', 'drink_patient'],
#  ['wander_agent',
#   'disappear_agent',
#   'imagine_agent',
#   'jump_agent',
#   'long_agent',
#   'bring_agent',
#   'keep_patient',
#   'disappear_patient',
#   'job_patient',
#   'fear_patient',
#   'jump_patient'],
#  ['sigh_agent', 'wrench_agent', 'toof_agent', 'sell_agent', 'eat_patient'],
#  [],
#  [],
#  ['bring_patient'],
#  [],
#  ['capacitie_agent'],
#  ['advance_agent',
#   'perceive_agent',
#   'vanish_agent',
#   'perceive_patient',
#   'convey_patient'],
#  [],
#  [],
#  ['marry_agent', 'marry_patient'],
#  [],
#  ['pursue_agent', 'deny_patient'],
#  [],
#  ['retort_agent'],
#  ['expect_agent'],
#  [],
#  [],
#  ['twitch_agent', 'appeal_agent', 'twitch_patient'],
#  [],
#  [],
#  [],
#  ['interpose_agent', 'force_agent'],
#  [],
#  [],
#  [],
#  ['smile_agent', 'slip_agent'],
#  ['then_agent'],
#  ['meaneth_agent'],
#  ['center_agent', 'strike_agent'],
#  [],
#  ['offer_agent'],
#  ['chatter_agent', 'stop_agent', 'hurry_patient'],
#  [],
#  [],
#  ['send_agent', 'appreciate_agent', 'affect_patient'],
#  [],
#  ['sing_agent', 'sing_agent', 'occur_agent'],
#  [],
#  [],
#  ['form_patient'],
#  [],
#  ['so_agent'],
#  ['reckon_agent'],
#  [],
#  ['perform_agent', 'stop_agent', 'without_agent'],
#  ['respect_agent'],
#  [],
#  ['zeed_agent', 'eat_agent', 'pin_agent'],
#  ['hitch_agent', 'knock_agent'],
#  [],
#  ['marry_agent'],
#  [],
#  ['with_agent'],
#  [],
#  ['marry_patient'],
#  ['pant_agent',
#   'wish_agent',
#   'whisper_agent',
#   'oblige_agent',
#   'carry_agent',
#   'watch_agent',
#   'write_agent',
#   'hurry_patient'],
#  ['spread_agent',
#   'voice_agent',
#   'notice_agent',
#   'suppose_agent',
#   'swallow_agent',
#   'dodge_agent',
#   'stretch_agent',
#   'stretch_agent',
#   'fold_agent',
#   'set_agent',
#   'press_agent',
#   'move_agent',
#   'fly_agent',
#   '-PRON-_agent',
#   'crouch_agent',
#   'call_agent',
#   'foolish_patient',
#   'dodge_patient',
#   'stretch_patient',
#   'fly_patient',
#   'frighten_patient'],
#  ['like_agent',
#   'like_agent',
#   'like_agent',
#   'beat_agent',
#   'catch_agent',
#   'snort_agent',
#   'carry_agent',
#   'grunt_agent',
#   'sob_agent',
#   'set_agent',
#   'grin_agent',
#   'want_agent',
#   'appear_agent',
#   'remark_agent',
#   'remark_agent',
#   'learn_agent',
#   'consider_agent',
#   'understand_agent',
#   'sigh_agent',
#   'venture_agent',
#   'help_agent',
#   'move_agent',
#   'confuse_agent',
#   'catch_patient',
#   'suppose_patient',
#   'puzzle_patient',
#   'exclaimed_patient',
#   'plead_patient',
#   'help_patient',
#   'confuse_patient'],
#  [],
#  ['shriek_agent',
#   'mean_agent',
#   'send_agent',
#   'shout_agent',
#   'suppress_patient',
#   'pinch_patient',
#   'persist_patient'],
#  ['promise_agent', 'admit_agent', 'declare_agent'],
#  ['pause_agent'],
#  ['ought_agent', 'write_agent'],
#  ['wonder_agent', 'wind_patient', 'wonder_patient'],
#  ['volunteer_agent'],
#  ['watch_agent'],
#  ['lead_agent'],
#  ['depart_agent'],
#  [],
#  ['remain_patient'],
#  ['meet_agent'],
#  [],
#  ['cease_agent',
#   'rouse_agent',
#   'teeter_agent',
#   'kick_agent',
#   'scream_agent',
#   'retreat_agent',
#   'show_agent',
#   'kick_patient'],
#  ['throw_agent', 'enter_agent', 'drive_agent', 'end_agent', 'kick_agent'],
#  ['thrust_agent',
#   'rub_agent',
#   'snarl_agent',
#   'upreare_agent',
#   'retreat_agent',
#   'understand_agent',
#   'show_agent'],
#  ['clasp_agent',
#   'kindle_agent',
#   'catch_agent',
#   'bethink_agent',
#   'stifle_agent'],
#  ['quicken_agent', 'cling_agent'],
#  [],
#  ['whisper_agent', 'breathe_agent', 'befriend_patient'],
#  ['stare_agent',
#   'call_agent',
#   'kill_agent',
#   'respect_patient',
#   'kill_patient'],
#  ['time_agent',
#   'recover_agent',
#   'visit_agent',
#   'mention_agent',
#   'practise_agent',
#   'visit_patient',
#   'mention_patient',
#   'practise_patient'],
#  [],
#  ['recover_agent', 'recover_patient'],
#  [],
#  ['increase_agent', 'establish_patient'],
#  [],
#  [],
#  ['forget_agent'],
#  ['arrive_agent'],
#  ['deceive_agent', 'deceive_patient'],
#  [],
#  ['respond_agent', 'resume_agent'],
#  ['possess_agent', 'dress_agent', 'possess_patient', 'haunt_patient'],
#  [],
#  ['change_agent'],
#  ['succeed_agent'],
#  [],
#  ['and_agent'],
#  ['succeed_agent', 'perform_agent', 'succeed_patient'],
#  ['lead_agent', 'lead_patient'],
#  ['dream_agent', 'exchange_patient'],
#  [],
#  [],
#  ['happily_agent', 'happily_patient'],
#  [],
#  [],
#  ['enter_agent'],
#  ['warn_agent', 'lug_agent', 'save_agent', 'order_agent', 'warn_patient'],
#  [],
#  [],
#  ['startle_agent',
#   'relieve_agent',
#   'correct_agent',
#   'correct_agent',
#   'bring_agent',
#   'expect_agent',
#   'reach_agent',
#   'plead_agent',
#   'deny_agent',
#   'interrupt_agent',
#   'consider_agent',
#   'would_agent',
#   'help_agent',
#   'explain_agent',
#   'wish_agent',
#   'remark_agent',
#   'venture_agent',
#   'sigh_agent',
#   'knock_agent',
#   'stamp_agent',
#   'glance_agent',
#   'set_agent',
#   'conquer_agent',
#   'speak_agent',
#   'speak_agent',
#   'support_agent',
#   'push_agent',
#   'happen_agent',
#   'catch_agent',
#   'startle_patient',
#   'correct_patient',
#   'correct_patient',
#   'bring_patient',
#   'bring_patient',
#   'throw_patient',
#   'draw_patient',
#   'puzzle_patient',
#   'welcome_patient',
#   'welcome_patient',
#   'push_patient'],
#  ['help_patient'],
#  ['interrupt_agent',
#   'interrupt_agent',
#   'interrupt_agent',
#   'break_agent',
#   'break_agent',
#   'moan_agent',
#   'moan_agent',
#   'remark_agent',
#   'smile_agent',
#   'gasp_agent',
#   'blow_agent',
#   'draw_agent',
#   'want_agent',
#   'pat_agent',
#   'catch_agent',
#   'support_agent',
#   'thank_agent',
#   'like_patient',
#   'blow_patient',
#   'so_patient',
#   'pat_patient',
#   'scream_patient'],
#  ['catch_agent',
#   'catch_agent',
#   'call_agent',
#   'remark_agent',
#   'punish_agent',
#   'shout_agent',
#   'groan_agent',
#   'spread_agent',
#   'catch_patient',
#   'groan_patient',
#   'shout_patient'],
#  ['gather_agent'],
#  ['pause_agent',
#   'send_agent',
#   'pause_patient',
#   'send_patient',
#   'write_patient'],
#  ['string_agent',
#   'smile_agent',
#   'doubt_agent',
#   'string_patient',
#   'doubt_patient'],
#  [],
#  ['write_agent'],
#  ['send_agent', 'hope_agent', 'hope_patient'],
#  ['show_agent', 'man_agent', 'meet_agent', 'ring_patient', 'meet_patient'],
#  ['stoop_agent', 'set_agent', 'befall_agent'],
#  ['smote_agent'],
#  ['pipe_agent'],
#  [],
#  ['thing_agent'],
#  [],
#  ['agree_agent', 'hold_patient'],
#  ['lose_patient'],
#  [],
#  [],
#  ['speak_agent', 'steal_agent', 'account_agent'],
#  ['bless_patient'],
#  ['force_patient'],
#  [],
#  ['sail_agent'],
#  [],
#  ['confess_agent'],
#  ['steal_agent',
#   'start_agent',
#   'start_agent',
#   'manage_agent',
#   'light_agent',
#   'strike_agent',
#   'manage_patient',
#   'puzzle_patient',
#   'strike_patient'],
#  [],
#  ['lay_patient'],
#  [],
#  ['call_agent', 'overpower_patient'],
#  ['close_agent', 'close_patient'],
#  ['kiss_agent', 'fancy_agent', 'Turlington_patient'],
#  ['hasten_agent'],
#  ['lead_agent', '"_agent', 'lead_patient'],
#  ['reach_agent'],
#  ['"_agent'],
#  ['toss_agent'],
#  [],
#  [],
#  ['retire_agent', 'prevail_agent'],
#  ['state_patient'],
#  [],
#  [],
#  [],
#  ['talk_agent'],
#  ['fail_agent', 'admit_patient'],
#  ['vary_agent'],
#  [],
#  ['forget_agent',
#   'tear_agent',
#   'insist_patient',
#   'would_patient',
#   'tear_patient'],
#  [],
#  ['draw_patient'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['rush_agent', 'join_agent', 'decline_agent', 'join_patient'],
#  ['whisper_agent', 'nod_agent', 'fumble_agent', 'hand_agent'],
#  ['decline_agent', 'explain_agent', 'suppose_agent'],
#  ['arouse_agent'],
#  ['sail_agent'],
#  [],
#  ['manage_agent',
#   'keep_agent',
#   'quiver_agent',
#   'range_agent',
#   'dangle_agent',
#   'dangle_agent'],
#  ['bring_agent'],
#  ['embrace_agent',
#   'mean_agent',
#   '"_agent',
#   'hesitate_agent',
#   'nail_agent',
#   'nail_agent',
#   'marry_patient',
#   'pull_patient'],
#  [],
#  ['suspect_agent'],
#  [],
#  ['confess_agent'],
#  ['understand_patient'],
#  [],
#  [],
#  ['understand_agent', 'understand_patient'],
#  [],
#  ['whisper_agent'],
#  ['consider_agent'],
#  [],
#  [],
#  [],
#  ['strike_agent'],
#  ['stick_agent', '"_agent'],
#  ['spring_agent'],
#  ['roam_agent', 'oblige_patient'],
#  ['pass_agent',
#   'bear_agent',
#   'pass_patient',
#   'regard_patient',
#   'bear_patient'],
#  ['hurry_agent', 'remain_agent'],
#  ['resume_patient'],
#  ['start_agent', 'consent_agent'],
#  ['lay_agent'],
#  [],
#  [],
#  ['inform_patient'],
#  [],
#  ['mention_agent'],
#  ['second_agent', 'dash_agent', 'dash_patient'],
#  ['regret_agent',
#   'dream_agent',
#   'execute_agent',
#   'board_patient',
#   'execute_patient'],
#  ['wash_agent'],
#  ['talk_patient'],
#  [],
#  [],
#  [],
#  [],
#  ['shine_agent',
#   'close_agent',
#   'relieve_agent',
#   'fatigued_patient',
#   'urge_patient'],
#  ['swing_agent'],
#  ['dive_agent', 'roar_agent', 'touch_patient'],
#  ['part_agent', 'watch_agent', 'expand_agent', 'tear_patient', 'beat_patient'],
#  ['recover_agent', 'travel_agent', 'forwards_agent'],
#  ['swam_agent', 'falter_agent', 'falter_patient'],
#  ['sleep_agent',
#   'soak_agent',
#   'move_agent',
#   'ache_agent',
#   'force_agent',
#   'hold_agent',
#   'soak_patient',
#   'force_patient',
#   'hold_patient'],
#  ['fool_agent', 'cease_agent', 'bring_patient', 'surround_patient'],
#  ['question_agent'],
#  ['bring_patient'],
#  ['realize_agent', 'because_agent', 'bring_patient', 'vary_patient'],
#  ['march_agent', 'replenish_agent'],
#  [],
#  [],
#  [],
#  ['bow_agent', 'hold_agent', 'hold_patient'],
#  ['speak_agent', 'drop_agent', 'wail_agent'],
#  [],
#  ['speak_agent', 'drop_agent', 'remain_agent', 'speak_patient'],
#  ['challenge_agent', 'accept_agent'],
#  ['object_patient'],
#  ['pass_patient'],
#  ['infer_patient'],
#  ['spring_agent', 'struggle_agent', 'stop_patient'],
#  ['stop_agent'],
#  [],
#  [],
#  [],
#  ['resume_agent',
#   'smile_agent',
#   'clasp_agent',
#   'release_agent',
#   'pass_agent',
#   'seek_agent',
#   'raise_agent',
#   'lay_agent',
#   'dearest_patient',
#   'smile_patient',
#   'seek_patient',
#   'raise_patient',
#   'irradiate_patient'],
#  ['observe_agent'],
#  ['lay_agent'],
#  ['close_agent', 'lay_agent', 'catch_agent', 'close_patient', 'catch_patient'],
#  ['hold_agent'],
#  ['believe_agent'],
#  ['woman_patient'],
#  ['undergo_agent'],
#  [],
#  [],
#  [],
#  [],
#  ['visit_agent'],
#  [],
#  ['remain_agent'],
#  ['help_agent'],
#  [],
#  ['succumb_agent',
#   'fathom_agent',
#   'outstretche_agent',
#   'kneel_agent',
#   'exclaimed_patient',
#   'forgive_patient'],
#  [],
#  ['save_agent',
#   'enter_agent',
#   'interrupt_agent',
#   'bespoke_agent',
#   'relieve_agent',
#   'wave_agent',
#   'hasten_agent',
#   'reach_agent',
#   'sink_agent',
#   'argue_agent',
#   'drag_agent',
#   'oh_patient',
#   'drag_patient'],
#  [],
#  [],
#  ['push_agent'],
#  ['quote_patient'],
#  ['shut_agent'],
#  ['work_agent', 'wonder_agent', 'interrupt_patient'],
#  ['breathe_agent'],
#  [],
#  [],
#  [],
#  [],
#  ['pass_agent'],
#  [],
#  ['crazed_agent'],
#  [],
#  ['about_patient'],
#  [],
#  ['care_agent', 'offer_agent', 'forgive_agent'],
#  [],
#  [],
#  ['surge_agent',
#   'soon_agent',
#   'regard_patient',
#   'surge_patient',
#   'soon_patient'],
#  ['close_agent',
#   'receive_agent',
#   'gasp_agent',
#   'change_agent',
#   'reach_patient'],
#  [],
#  ['echo_agent'],
#  ['pretend_patient'],
#  ['echo_agent', 'pretend_agent', 'pretend_agent', 'sigh_agent'],
#  ['ring_agent', 'mean_agent'],
#  ['propose_agent'],
#  [],
#  [],
#  [],
#  [],
#  ['rush_agent', 'hurt_agent'],
#  ['lean_agent', 'tremble_agent'],
#  ['swing_agent', 'speak_patient'],
#  ['face_patient'],
#  ['totter_agent'],
#  [],
#  ['devote_agent'],
#  ['spirit_agent'],
#  [],
#  [],
#  [],
#  ['await_patient'],
#  ['kill_agent', 'raise_agent', 'pause_agent'],
#  ['ejaculate_patient'],
#  ['possess_agent', 'pass_agent'],
#  ['durn_patient'],
#  ['raise_agent',
#   'fit_agent',
#   'smile_agent',
#   'drawl_agent',
#   'fit_patient',
#   'smile_patient'],
#  ['scream_agent', 'admit_agent', 'tole_agent'],
#  ['Gail_agent'],
#  ['raise_agent', 'smile_agent', 'smile_agent'],
#  ['change_agent'],
#  ['escape_patient'],
#  ['understand_agent'],
#  [],
#  [],
#  [],
#  ['break_agent',
#   'journey_agent',
#   'journey_agent',
#   'float_agent',
#   'float_agent',
#   'whisper_agent',
#   'fly_agent',
#   'journey_patient',
#   'whisper_patient'],
#  [],
#  [],
#  ['feast_agent', 'dwell_agent', 'light_patient'],
#  [],
#  [],
#  ['prevent_agent',
#   'explain_agent',
#   'slide_agent',
#   'demand_agent',
#   'prevent_patient'],
#  [],
#  ['finish_agent'],
#  ['frighten_patient'],
#  ['work_agent', 'rebel_agent', 'work_patient'],
#  ['set_agent',
#   'stagger_agent',
#   'dart_agent',
#   'shout_agent',
#   'call_agent',
#   'burst_agent',
#   'sob_agent',
#   'stagger_patient'],
#  ['fidget_agent'],
#  ['resist_agent', 'nod_agent', 'whisper_agent'],
#  [],
#  [],
#  [],
#  ['visit_agent', 'Henry_agent', 'marry_agent', 'adorn_patient'],
#  ['maintain_agent',
#   'receive_agent',
#   'receive_agent',
#   'die_agent',
#   'establish_agent',
#   'settle_agent',
#   'lose_agent',
#   'pay_patient'],
#  [],
#  [],
#  [],
#  ['pledge_agent'],
#  ['show_agent', 'warn_agent'],
#  ['fulfil_agent',
#   'trouble_patient',
#   'suggest_patient',
#   'fulfil_patient',
#   'regard_patient'],
#  [],
#  [],
#  ['fulfil_patient'],
#  ['understand_agent', 'resume_agent'],
#  [],
#  ['remain_agent',
#   'remain_agent',
#   'hover_agent',
#   'visit_agent',
#   'hover_patient'],
#  [],
#  [],
#  ['command_agent', 'furnish_agent', 'discuss_agent', 'command_patient'],
#  ['gasp_patient'],
#  ['post_agent', 'sweep_patient'],
#  ['speak_agent', 'warn_agent'],
#  ['appear_agent', 'plough_agent'],
#  [],
#  ['decide_agent', 'flare_agent'],
#  ['lead_agent'],
#  [],
#  ['occur_agent'],
#  ['pity_agent', 'rejoice_agent', 'awake_agent'],
#  ['gaze_agent'],
#  [],
#  ['hope_agent', 'assail_agent', 'assail_patient'],
#  ['gaze_agent'],
#  ['why_agent'],
#  ['cross_agent', 'stamp_agent'],
#  [],
#  ['discover_agent'],
#  ['consider_agent', 'consider_patient'],
#  ['trust_patient'],
#  ['love_patient'],
#  [],
#  [],
#  ['bear_agent'],
#  [],
#  ['attend_agent'],
#  [],
#  ['appear_agent', 'bear_agent', 'bear_patient'],
#  [],
#  ['recollect_agent'],
#  [],
#  ['expression_agent'],
#  ['conduct_agent'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['agree_patient'],
#  [],
#  [],
#  [],
#  ['bear_agent', 'bear_patient', 'use_patient', 'use_patient'],
#  ['listen_agent', 'light_patient'],
#  ['recognise_agent', 'move_agent', 'pull_patient', 'move_patient'],
#  [],
#  [],
#  ['start_agent', 'dress_agent', 'dress_patient'],
#  [],
#  [],
#  ['remain_agent', 'send_patient'],
#  ['inform_agent', 'inform_patient', 'celebrate_patient'],
#  ['call_patient'],
#  [],
#  ['send_agent'],
#  ['watch_agent', 'watch_patient'],
#  ['suspect_agent', 'shatter_agent', 'speak_agent', 'shatter_patient'],
#  ['browse_agent'],
#  ['hang_agent', 'send_patient'],
#  ['lift_agent'],
#  [],
#  ['show_agent', 'agree_agent'],
#  ['build_agent'],
#  ['locate_agent'],
#  [],
#  ['dream_agent'],
#  ['write_agent'],
#  [],
#  ['present_patient'],
#  [],
#  ['carry_agent'],
#  ['refuse_agent'],
#  ['wonder_agent'],
#  [],
#  [],
#  ['confess_patient'],
#  ['fix_patient'],
#  [],
#  ['confess_patient'],
#  [],
#  ['grant_agent'],
#  ['suffer_agent', 'suffer_patient'],
#  ['imagine_agent', 'imagine_patient'],
#  ['engage_agent', 'hold_agent', 'sigh_agent', 'drop_agent', 'spring_agent'],
#  ['matter_agent',
#   'jerk_agent',
#   'utter_agent',
#   'utter_patient',
#   'catch_patient',
#   'imagine_patient'],
#  ['stop_agent', 'visit_patient'],
#  ['pause_agent'],
#  [],
#  [],
#  ['die_agent', 'send_patient', 'want_patient'],
#  ['remark_agent'],
#  [],
#  ['recoil_agent', 'recoil_patient'],
#  ['stammer_agent'],
#  ['whisper_agent',
#   'urge_agent',
#   'droop_agent',
#   'hold_patient',
#   'draw_patient'],
#  [],
#  [],
#  ['lay_agent'],
#  ['happen_agent'],
#  ['save_patient'],
#  ['repair_agent', 'buy_agent', 'buy_patient', 'reach_patient'],
#  ['buy_agent'],
#  [],
#  [],
#  [],
#  ['offer_agent', 'marry_agent'],
#  ['need_agent', 'gaze_agent'],
#  ['lead_patient'],
#  ['wish_agent'],
#  ['raise_agent', 'raise_patient', 'push_patient'],
#  ['first_agent',
#   'rest_agent',
#   'hungry_agent',
#   'cook_agent',
#   'sleep_agent',
#   'note_agent'],
#  ['gulp_agent'],
#  [],
#  ['taste_agent'],
#  ['an_agent'],
#  ['will_agent'],
#  [],
#  ['receive_patient'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['entertain_agent',
#   'smack_agent',
#   'scarce_agent',
#   'suppose_agent',
#   '"_agent',
#   'sell_agent',
#   'wear_agent',
#   'pick_agent',
#   'flee_agent',
#   'spring_agent',
#   'carry_agent',
#   'show_agent',
#   'forget_agent',
#   'entertain_patient',
#   '"_patient',
#   'bring_patient',
#   'jink_patient',
#   'pursue_patient',
#   'roared_patient',
#   'pay_patient',
#   'spring_patient',
#   'carry_patient',
#   'lodge_patient',
#   'upon_patient',
#   'forget_patient'],
#  ['clap_agent',
#   'avoid_agent',
#   'observe_agent',
#   'arouse_agent',
#   'keep_agent',
#   'mean_agent',
#   'draw_agent',
#   'raise_agent',
#   'raise_agent',
#   'step_agent',
#   'weep_agent',
#   'pluck_agent',
#   'hold_agent',
#   'press_agent',
#   'pick_agent',
#   'use_patient',
#   'remind_patient',
#   'change_patient',
#   'decoy_patient',
#   'call_patient',
#   'lodge_patient',
#   'upon_patient'],
#  [],
#  [],
#  ['bring_agent'],
#  ['lose_agent',
#   'start_agent',
#   'gnash_agent',
#   'kindle_agent',
#   'decide_agent',
#   'kindle_patient',
#   'decide_patient'],
#  ['expect_agent', 'understand_agent', 'base_agent', 'raise_agent'],
#  ['gnash_agent', 'kindle_agent', 'lose_patient'],
#  ['entertain_agent'],
#  ['move_agent', 'hesitate_agent', 'love_agent', 'dispose_agent'],
#  [],
#  ['learn_agent', 'prevail_agent', 'learn_patient'],
#  ['hold_patient'],
#  ['dare_agent', 'dare_patient'],
#  [],
#  ['sob_agent', 'drop_agent', 'breathe_agent'],
#  [],
#  ['could_agent',
#   'reproach_agent',
#   'wish_agent',
#   'earn_agent',
#   'reproach_patient',
#   'wish_patient'],
#  ['sob_agent'],
#  ['love_agent',
#   'honour_agent',
#   'bear_agent',
#   'marry_agent',
#   'love_patient',
#   'honour_patient',
#   'wound_patient',
#   'bring_patient'],
#  ['require_patient'],
#  ['conquer_agent', 'recognize_agent', 'conquer_patient'],
#  ['escape_agent', 'gat_agent', '-PRON-_patient', 'escape_patient'],
#  ['finish_agent'],
#  ['deep_agent'],
#  ['cross_agent', 'climb_agent', 'gather_agent', 'pass_agent'],
#  ['set_agent', 'save_agent', 'measure_agent'],
#  [],
#  ['pass_agent'],
#  ['forget_agent', 'leap_agent'],
#  ['insist_agent',
#   'lead_agent',
#   'mollify_agent',
#   'endeavor_agent',
#   'call_agent',
#   'consider_agent',
#   'overhear_agent',
#   'mean_agent',
#   'want_agent',
#   'bring_patient',
#   'handle_patient',
#   'lead_patient',
#   'believe_patient',
#   'send_patient',
#   'engage_patient',
#   'scorn_patient',
#   'prove_patient',
#   'goad_patient',
#   'consider_patient',
#   'prefer_patient',
#   'perceive_patient',
#   'permit_patient'],
#  ['occur_agent',
#   'conclude_agent',
#   'surmise_agent',
#   'move_agent',
#   'but_agent',
#   'notice_agent',
#   'vouchsafe_agent',
#   'inform_agent',
#   'remain_agent',
#   'restore_agent',
#   'assume_agent',
#   'enter_agent',
#   'emerge_agent',
#   'undertake_agent',
#   'request_agent',
#   'decline_agent',
#   'apprise_agent',
#   'persist_agent',
#   'resolve_patient',
#   'procure_patient',
#   'prove_patient',
#   'summon_patient',
#   'vouchsafe_patient',
#   'warn_patient',
#   'offer_patient',
#   'enter_patient',
#   'slide_patient',
#   'request_patient'],
#  ['bring_agent',
#   'declare_agent',
#   'write_agent',
#   'write_agent',
#   'dress_agent',
#   'wear_agent',
#   'spread_agent',
#   'send_agent',
#   'eat_agent',
#   'prefer_agent',
#   'appear_agent',
#   'disappear_agent',
#   'exceed_agent',
#   'complain_agent',
#   'catch_agent',
#   'in_agent',
#   'vouchsafe_agent',
#   'remain_agent',
#   'stay_agent',
#   'speak_agent',
#   'retire_agent',
#   'mean_patient',
#   'spread_patient',
#   'vanish_patient'],
#  ['hint_agent',
#   'decline_agent',
#   'occur_agent',
#   'depart_agent',
#   'support_agent',
#   'quit_agent',
#   'wish_agent',
#   'narrate_agent',
#   'tis_agent',
#   'ripple_patient',
#   'hint_patient',
#   'depart_patient',
#   'support_patient',
#   'quit_patient',
#   'move_patient',
#   'address_patient',
#   'withdraw_patient',
#   'lead_patient',
#   'receive_patient',
#   'obtain_patient'],
#  ['write_agent',
#   'write_agent',
#   'grapple_agent',
#   'accost_agent',
#   'want_agent',
#   'place_patient',
#   'conclude_patient',
#   'grapple_patient',
#   'drop_patient'],
#  ...]

# %%
dictionary = corpora.Dictionary(charTexts)
corpus = [dictionary.doc2bow(text) for text in charTexts]
num_topics = 5
lda_model = gensim.models.LdaModel(corpus, id2word=dictionary, 
                                   num_topics=num_topics, passes=3, alpha='auto')

# %%
for i in range(num_topics):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	pause_agent speak_agent smile_agent drop_agent sob_agent shut_agent marry_agent hurry_agent assure_patient keep_agent
# topic 1:	remain_agent bring_patient enter_agent occur_agent confess_agent die_agent happen_agent fling_agent forget_agent move_patient
# topic 2:	raise_agent keep_agent interrupt_agent bring_agent catch_agent offer_agent reach_agent hold_agent carry_agent mean_agent
# topic 3:	write_agent whisper_agent pass_agent bear_agent hold_patient lay_agent want_agent marry_patient use_agent send_agent
# topic 4:	show_agent call_agent call_patient cross_agent catch_agent write_agent catch_patient meet_agent stop_agent suppose_agent

# %%
topic_model=lda_model 

topic_docs=[]
for i in range(num_topics):
    topic_docs.append({})
for doc_id in range(len(corpus)):
    doc_topics=topic_model.get_document_topics(corpus[doc_id])
    for topic_num, topic_prob in doc_topics:
        topic_docs[topic_num][doc_id]=topic_prob

for i in range(num_topics):
    print("%s\n" % ' '.join([term for term, freq in topic_model.show_topic(i, topn=10)]))
    sorted_x = sorted(topic_docs[i].items(), key=operator.itemgetter(1), reverse=True)
    for k, v in sorted_x[:5]:
        print("%s\t%.3f\t%s" % (i,v, charNames[k]))
    print()
# Out:
# pause_agent speak_agent smile_agent drop_agent sob_agent shut_agent marry_agent hurry_agent assure_patient keep_agent
#
# 0	0.918	she	(Joseph Conrad___To-morrow)
#  aka her, she, herself
# 0	0.908	cloete	(Joseph Conrad___Within the Tides)
#  aka cloete, his, himself, he, him
# 0	0.895	he	(Jack London___Smoke Bellew)
#  aka he, his
# 0	0.895	her	(Henry James___In the Cage)
#  aka she, herself, her
# 0	0.895	the doctor	(Wilkie Collins___A Rogue's Life)
#  aka the doctor, his, himself, he, him
#
# remain_agent bring_patient enter_agent occur_agent confess_agent die_agent happen_agent fling_agent forget_agent move_patient
#
# 1	0.975	bartleby	(Herman Melville___Bartleby, The Scrivener)
#  aka bartleby here, me, myself, bartleby, it, his, himself, he, him
# 1	0.965	him	(Herman Melville___Bartleby, The Scrivener)
#  aka the silent man, me, myself, it, his fatal act--an act which certainly no man could possibly deplore more than the actor himself, his, himself, he, him
# 1	0.927	spencer brydon	(Henry James___The Jolly Corner)
#  aka brydon, spencer brydon, his, he, him
# 1	0.918	him	(Jack London___Burning Daylight)
#  aka he, him, his
# 1	0.918	col. zane	(Zane Grey___Betty Zane)
#  aka jonathan zane, isaac zane, his, himself, he, him, col. zane
#
# raise_agent keep_agent interrupt_agent bring_agent catch_agent offer_agent reach_agent hold_agent carry_agent mean_agent
#
# 2	0.982	alice	(Lewis Carroll___Through the Looking-Glass)
#  aka queen alice's, her, poor alice, mean--' alice, queen alice ', me, he, herself, queen alice
# 2	0.976	this alice	(Lewis Carroll___Alice's Adventures in Wonderland)
#  aka her, you, poor alice, myself, herself, this alice, she, only alice, alice
# 2	0.968	the red queen	(Lewis Carroll___Through the Looking-Glass)
#  aka queen, your majesty, the red queen, her, me--' the white queen, her white majesty, her red majesty, ' the white queen, your white majesty
# 2	0.968	catriona	(Robert Louis Stevenson___Catriona)
#  aka ye, her, you, catriona, me, myself, the girl, herself, she
# 2	0.959	a raven but that child	(Mark Twain___A Horse's Tale)
#  aka her, the raven, me, miss cathy, it, herself, cathy, she, a raven but that child
#
# write_agent whisper_agent pass_agent bear_agent hold_patient lay_agent want_agent marry_patient use_agent send_agent
#
# 3	0.970	the law-copyists or scriveners	(Herman Melville___Bartleby, The Scrivener)
#  aka their, the law-copyists or scriveners, nippers, nippers', they, the, me, my two scriveners, them
# 3	0.968	his face	(Herman Melville___Bartleby, The Scrivener)
#  aka the bright silks and sparkling faces i had seen that day, his hat, his face, his back, the hat, me, it, the boy, his
# 3	0.954	tom kitten	(Beatrix Potter___The Great Big Treasury of Beatrix Potter)
#  aka poor tom kitten, tom, his, himself, he, tom kitten, him
# 3	0.947	richard	(Charles Dickens___Bleak House)
#  aka richard, dear rick, rick, you, me, his, himself, he, him
# 3	0.933	a king	(Charles Dickens___Holiday Romance)
#  aka the king, king, sir, his, he, a king, him
#
# show_agent call_agent call_patient cross_agent catch_agent write_agent catch_patient meet_agent stop_agent suppose_agent
#
# 4	0.972	alan	(Robert Louis Stevenson___Catriona)
#  aka "alan, that man, alan, me, his, himself, he, him, next alan
# 4	0.967	poor alice	(Lewis Carroll___Alice's Adventures in Wonderland)
#  aka alice hastily, her, poor alice, herself, she, alice
# 4	0.938	the white queen	(Lewis Carroll___Through the Looking-Glass)
#  aka queen, her, myself, ' the queen, the queen, herself, she, the white queen, the poor queen
# 4	0.918	rosamond	(George Eliot___Middlemarch)
#  aka whence rosamond, she, rosamond, her
# 4	0.918	smith	(Joseph Conrad___Amy Foster)
#  aka her, smith, she, he, the girl, his, mrs. smith, him

# %%
# {"agent":[{"w":"wore","i":104276},
#           {"w":"had","i":104283},
#           {"w":"carried","i":104297},
#           {"w":"seemed","i":104306},
#           {"w":"said","i":104318},
#           {"w":"said","i":104358},
#           {"w":"said","i":107106},
#           {"w":"realized","i":107110},
#           {"w":"gave","i":107125}],
#  "NNPcount":3,
#  "names":[{"c":3,"n":"Dr. Whittaker"}],
#  "mod":[],
#  "speaking":[{"w":"`` Oh , good morning , '' ","i":104321},
#              {"w":"`` Of course , '' ","i":104353}],
#  "patient":[],
#  "g":2,
#  "id":0,
#  "poss":[{"w":"words","i":107127}]}
