# %%
import operator
from collections import Counter
import math
import os
import json
import gensim
from gensim import corpora

# %%
'''
Read in parsed books 
'''
def read_parsed_book_data(dataPath):
    data = {}
    for fileName in os.listdir(dataPath):
        with open(os.path.join(dataPath, fileName), 'r') as file:
            data[fileName.split("_parsed_")[0]]=json.load(file)
    return data

# %%
# def read_book_nlp_metadata(filename):
#     metadata={}
#     with open(filename) as file:
#         for line in file:
#             cols=line.rstrip().split("\t")
#             idd=cols[0]
#             date=int(cols[1])
#             author=cols[2]
#             title=cols[3]
#             author_gender=cols[4]
#             metadata[idd]=(date, author, title, author_gender)
#     return metadata

# def read_book_nlp_data(data_folder):
#     data={}

#     for idd in metadata:
#         filename=os.path.join(data_folder, "%s.book" % idd)
#         if os.path.exists(filename):
#             with open(filename) as file:
#                 data[idd]=json.load(file)

#     print(f"Read {len(data)} books")
#     return data

# %%
def get_corpus_frequencies(alldata, bookNLP=False):
    
    agentFreqs = Counter()
    patientFreqs =  Counter()
    modFreqs =  Counter()
    
    for idd in alldata:
        data=alldata[idd]
        for character in data["characters"]:
            if bookNLP:
                for term in character["agent"]:
                    agentFreqs[term['w']] += 1
                for term in character["patient"]:
                    patientFreqs[term['w']] += 1
                for term in character["mod"]:
                    modFreqs[term['w']] += 1 
            else:
                for action in character["agent"]:
                    agentFreqs[list(action.values())[0]] += 1
                for action in character["patient"]:
                    patientFreqs[list(action.values())[0]] += 1
                    
    return agentFreqs, patientFreqs, modFreqs

# %%
def get_character_actions(alldata, agentFilter={}, patientFilter={}, modFilter={}, bookNLP=False):
    
    charactersAgentsDict = {}
    charactersAgentsList = []
    charNameList = []
    
    for idd in alldata:
        data=alldata[idd]
        if bookNLP:
            for character in data["characters"]:
                if len(character["names"]) > 0:
                    char_name = character["names"][0]['n']
                    charNameList.append(char_name)
                    charactersAgentsDict[char_name] = Counter()
                    charactersAgentsList.append([])
                    agent_terms=[term["w"] + "_agent" for term in character["agent"] \
                                 if term["w"] not in agentFilter]
                    agent_terms += [term["w"] + "_patient" for term in character["patient"]\
                                 if term["w"] not in patientFilter]
                    agent_terms += [term["w"] + "_mod" for term in character["mod"]\
                                 if term["w"] not in modFilter]

                    for verb in agent_terms:
                        charactersAgentsDict[char_name][verb]+=1

                    for verb, count in charactersAgentsDict[char_name].items():
                        charactersAgentsList[-1]+=[verb]*count
                        
        else:
            for character in data["characters"]:
                char_name = character["mainName"] + "\t(" + idd + ")"
                #+ '\taka ' + \
                #", ".join(character['aliases'][:2]) + "\t(" + idd + ")"
                charNameList.append(char_name)
                charactersAgentsDict[char_name] = Counter()
                charactersAgentsList.append([])
                agent_terms = [list(action.values())[0] + "_agent" for action in character["agent"] \
                             if list(action.values())[0] not in agentFilter]
                agent_terms += [list(action.values())[0] + "_patient" for action in character["patient"] \
                             if list(action.values())[0] not in agentFilter]
                
                for verb in agent_terms:
                    charactersAgentsDict[char_name][verb]+=1

                for verb, count in charactersAgentsDict[char_name].items():
                    charactersAgentsList[-1]+=[verb]*count
                    
                    
    return charactersAgentsDict, charactersAgentsList, charNameList

# %%
metadata=read_book_nlp_metadata("../../../../Code/comphumF20/data/pulitzer_metadata.txt")
data=read_book_nlp_data("../../../../Code/comphumF20/data/pulitzer_booknlp")
# Out:
# Read 94 books

# %%
newData = read_parsed_book_data('../results/book_parses_top_only')

# %%
agentFreqs, patientFreqs, modFreqs = get_corpus_frequencies(newData)

# %%
agentFilter = set([freqPair[0] for freqPair in agentFreqs.most_common(50)])
patientFilter = set([freqPair[0] for freqPair in patientFreqs.most_common(50)])
modFilter = set([freqPair[0] for freqPair in modFreqs.most_common(50)])

# %%
charAgents, charTexts, charNames = get_character_actions(newData, 
                                                         agentFilter=agentFilter, 
                                                         patientFilter=patientFilter, 
                                                         modFilter=modFilter)

# %%
for charName in charNames:
    print(charName)
# Out:
# carthoris	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
# the girl	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
# the man	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
# astok of dusar	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
# ptarth	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
# his	(Herman Melville___Moby Dick)
# it	(Herman Melville___Moby Dick)
# ahab	(Herman Melville___Moby Dick)
# the mouth	(Herman Melville___Moby Dick)
# me	(Herman Melville___Moby Dick)
# they	(Washington Irving___The Legend of Sleepy Hollow)
# ichabod crane	(Washington Irving___The Legend of Sleepy Hollow)
# this sequestered glen	(Washington Irving___The Legend of Sleepy Hollow)
# her	(Washington Irving___The Legend of Sleepy Hollow)
# old baltus van tassel	(Washington Irving___The Legend of Sleepy Hollow)
# tarzan	(Edgar Rice Burroughs___The Beasts of Tarzan)
# the ape-man	(Edgar Rice Burroughs___The Beasts of Tarzan)
# his	(Edgar Rice Burroughs___The Beasts of Tarzan)
# it	(Edgar Rice Burroughs___The Beasts of Tarzan)
# jane clayton's face	(Edgar Rice Burroughs___The Beasts of Tarzan)
# the war	(Edgar Rice Burroughs___A Princess of Mars)
# her	(Edgar Rice Burroughs___A Princess of Mars)
# we all	(Edgar Rice Burroughs___A Princess of Mars)
# mars	(Edgar Rice Burroughs___A Princess of Mars)
# his little study	(Edgar Rice Burroughs___A Princess of Mars)
# it	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# we	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# miss watson's big nigger, named jim	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# the truth	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# they all	(Mark Twain___Adventures of Huckleberry Finn, Complete)
#  alice	(Lewis Carroll___Alice's Adventures in Wonderland)
# it	(Lewis Carroll___Alice's Adventures in Wonderland)
# the well	(Lewis Carroll___Alice's Adventures in Wonderland)
# bats	(Lewis Carroll___Alice's Adventures in Wonderland)
# the duchess	(Lewis Carroll___Alice's Adventures in Wonderland)
# alice	(Lewis Carroll___Through the Looking-Glass)
# the white kitten	(Lewis Carroll___Through the Looking-Glass)
# the queen	(Lewis Carroll___Through the Looking-Glass)
# we	(Lewis Carroll___Through the Looking-Glass)
# one knight	(Lewis Carroll___Through the Looking-Glass)
# he	(Edgar Rice Burroughs___The Gods of Mars)
# his powerful tail	(Edgar Rice Burroughs___The Gods of Mars)
# a ferocious fellow who was endeavouring to reach my throat from in front	(Edgar Rice Burroughs___The Gods of Mars)
# me	(Edgar Rice Burroughs___The Gods of Mars)
# it	(Edgar Rice Burroughs___The Gods of Mars)
#  tom	(Mark Twain___Tom Sawyer Abroad)
# we	(Mark Twain___Tom Sawyer Abroad)
# it	(Mark Twain___Tom Sawyer Abroad)
# jim	(Mark Twain___Tom Sawyer Abroad)
# the river	(Mark Twain___Tom Sawyer Abroad)
# tarzan	(Edgar Rice Burroughs___The Return of Tarzan)
# her	(Edgar Rice Burroughs___The Return of Tarzan)
# his	(Edgar Rice Burroughs___The Return of Tarzan)
# the game	(Edgar Rice Burroughs___The Return of Tarzan)
# clayton	(Edgar Rice Burroughs___The Return of Tarzan)
# it	(Nathaniel Hawthorne___The House of the Seven Gables)
# phoebe	(Nathaniel Hawthorne___The House of the Seven Gables)
# clifford	(Nathaniel Hawthorne___The House of the Seven Gables)
# miss hepzibah	(Nathaniel Hawthorne___The House of the Seven Gables)
# this woman	(Nathaniel Hawthorne___The House of the Seven Gables)
# it	(Edgar Rice Burroughs___Warlord of Mars)
# the river	(Edgar Rice Burroughs___Warlord of Mars)
# we	(Edgar Rice Burroughs___Warlord of Mars)
# our victorious fleet and land forces	(Edgar Rice Burroughs___Warlord of Mars)
# the black men	(Edgar Rice Burroughs___Warlord of Mars)
# scrooge	(Charles Dickens___A Christmas Carol)
# the spirit	(Charles Dickens___A Christmas Carol)
# the interpretations in this volume	(Charles Dickens___A Christmas Carol)
# the ghost	(Charles Dickens___A Christmas Carol)
# us	(Charles Dickens___A Christmas Carol)
# it	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# the ungentle laws and customs	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# we	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# a squirrel on the king's head	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# her	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
#  the long boat of the marjorie w.	(Edgar Rice Burroughs___The Son of Tarzan)
# korak	(Edgar Rice Burroughs___The Son of Tarzan)
# meriem	(Edgar Rice Burroughs___The Son of Tarzan)
# it	(Edgar Rice Burroughs___The Son of Tarzan)
# she	(Edgar Rice Burroughs___The Son of Tarzan)
# she	(Thomas Hardy___Far from the Madding Crowd)
# gabriel oak	(Thomas Hardy___Far from the Madding Crowd)
# troy	(Thomas Hardy___Far from the Madding Crowd)
# his friends and critics	(Thomas Hardy___Far from the Madding Crowd)
# the letter	(Thomas Hardy___Far from the Madding Crowd)
# hester	(Nathaniel Hawthorne___The Scarlet Letter)
# her	(Nathaniel Hawthorne___The Scarlet Letter)
# pearl	(Nathaniel Hawthorne___The Scarlet Letter)
# his	(Nathaniel Hawthorne___The Scarlet Letter)
# salem	(Nathaniel Hawthorne___The Scarlet Letter)
# tarzan	(Edgar Rice Burroughs___Tarzan of the Apes)
# john clayton	(Edgar Rice Burroughs___Tarzan of the Apes)
# jane and esmeralda	(Edgar Rice Burroughs___Tarzan of the Apes)
# the british colonial office	(Edgar Rice Burroughs___Tarzan of the Apes)
# d'arnot	(Edgar Rice Burroughs___Tarzan of the Apes)
# tom	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# they	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# it	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# huck finn	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# becky	(Mark Twain___The Adventures of Tom Sawyer, Complete)

# %%
charAgents
# Out:
# {'carthoris\taka a real man, a real warrior--carthoris of helium!", themselves\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)': Counter({'hesitate_agent': 2,
#           'breathe_agent': 1,
#           'raise_agent': 2,
#           'back_agent': 1,
#           'explain_agent': 2,
#           'smile_agent': 7,
#           'urge_agent': 2,
#           'detect_agent': 1,
#           'observe_agent': 1,
#           'drop_agent': 1,
#           'spring_agent': 3,
#           'examine_agent': 1,
#           'believe_agent': 4,
#           'unlock_agent': 1,
#           'hazard_agent': 1,
#           'succeed_agent': 1,
#           'wait_agent': 2,
#           'send_agent': 1,
#           'hurry_agent': 1,
#           'touch_agent': 3,
#           'damage_agent': 1,
#           'float_agent': 1,
#           'hope_agent': 2,
#           'watch_agent': 2,
#           'leap_agent': 2,
#           'trail_agent': 1,
#           'follow_agent': 5,
#           'creep_agent': 1,
#           'time_agent': 2,
#           'surround_agent': 1,
#           'guess_agent': 1,
#           'tear_agent': 1,
#           'search_agent': 1,
#           'show_agent': 2,
#           'drag_agent': 1,
#           'cover_agent': 1,
#           'issue_agent': 1,
#           'seek_agent': 1,
#           'lay_agent': 2,
#           'swift_agent': 1,
#           'wipe_agent': 1,
#           'choke_agent': 1,
#           'revert_agent': 1,
#           'point_agent': 2,
#           'whisper_agent': 2,
#           'lead_agent': 2,
#           'scarce_agent': 1,
#           'consent_agent': 1,
#           'notice_agent': 1,
#           'nod_agent': 3,
#           'note_agent': 1,
#           'understand_agent': 1,
#           'laugh_agent': 2,
#           'shake_agent': 1,
#           'eye_agent': 2,
#           'lift_agent': 1,
#           'exclaim_agent': 1,
#           'insist_agent': 1,
#           'remind_agent': 1,
#           'catch_agent': 1,
#           'trust_agent': 1,
#           'hold_agent': 1,
#           'harm_agent': 1,
#           'murmur_agent': 1,
#           'meet_agent': 1,
#           'brace_agent': 1,
#           'clasp_agent': 1,
#           'whimper_agent': 1,
#           'step_agent': 2,
#           'place_agent': 2,
#           'seat_agent': 1,
#           'cause_agent': 1,
#           'horrify_agent': 1,
#           'curse_agent': 1,
#           'realize_agent': 2,
#           'flood_agent': 1,
#           'halt_agent': 2,
#           'like_agent': 1,
#           'charge_agent': 1,
#           'pay_agent': 1,
#           'remain_agent': 1,
#           'sleep_agent': 2,
#           'squat_agent': 1,
#           'disappear_agent': 1,
#           'strain_agent': 1,
#           'shout_agent': 1,
#           'read_agent': 1,
#           'relate_agent': 1,
#           'shrug_agent': 1,
#           'enter_agent': 2,
#           'strike_agent': 1,
#           'learn_agent': 1,
#           'centre_agent': 1,
#           'appear_agent': 1,
#           'indication_agent': 1,
#           'discard_agent': 1,
#           'greet_agent': 1,
#           'invite_agent': 1,
#           'light_agent': 1,
#           'suffice_agent': 1,
#           'walk_agent': 1,
#           'bless_agent': 1,
#           'fumble_agent': 1,
#           'grasp_agent': 2,
#           'bring_agent': 1,
#           'bang_agent': 1,
#           'sight_agent': 1,
#           'race_agent': 1,
#           'hasten_agent': 2,
#           'recourse_agent': 1,
#           'graze_agent': 1,
#           'distance_agent': 1,
#           'group_patient': 1,
#           'assist_patient': 1,
#           'betray_patient': 1,
#           'succeed_patient': 1,
#           'carry_patient': 1,
#           'tear_patient': 1,
#           'show_patient': 1,
#           'explain_patient': 1,
#           'swift_patient': 1,
#           'touch_patient': 1,
#           'choke_patient': 1,
#           'hurt_patient': 1,
#           'leap_patient': 1,
#           'whisper_patient': 1,
#           'lead_patient': 1,
#           'watch_patient': 1,
#           'exclaim_patient': 2,
#           'brace_patient': 1,
#           'place_patient': 1,
#           'seat_patient': 1,
#           'strike_patient': 1,
#           'dumbfound_patient': 1,
#           'cause_patient': 1,
#           'curse_patient': 1,
#           'realize_patient': 1,
#           'overpower_patient': 1,
#           'drag_patient': 1,
#           'squat_patient': 1,
#           'recognize_patient': 1,
#           'shout_patient': 1,
#           'relate_patient': 1,
#           'discard_patient': 1,
#           'admit_patient': 1,
#           'repeat_patient': 1,
#           'follow_patient': 1,
#           'race_patient': 1}),
#  'the girl\taka the mad beast, the air-patrol boat\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)': Counter({'repeat_agent': 1,
#           'strike_agent': 1,
#           'exclaim_agent': 1,
#           'steal_agent': 2,
#           'shake_agent': 2,
#           'sheer_agent': 1,
#           'land_agent': 2,
#           'raise_agent': 1,
#           'seek_agent': 2,
#           'offer_agent': 1,
#           'cease_agent': 1,
#           'lead_agent': 3,
#           'command_agent': 2,
#           'ride_agent': 1,
#           'reveal_agent': 1,
#           'miss_agent': 1,
#           'tear_agent': 1,
#           'shut_agent': 1,
#           'catch_agent': 2,
#           'continue_agent': 2,
#           'drag_agent': 2,
#           'issue_agent': 1,
#           'detect_agent': 1,
#           'note_agent': 1,
#           'mean_agent': 1,
#           'disperse_agent': 1,
#           'carry_agent': 1,
#           'murmur_agent': 1,
#           'descend_agent': 1,
#           'step_agent': 1,
#           'leap_agent': 1,
#           'advance_agent': 1,
#           'commence_agent': 1,
#           'growl_agent': 1,
#           'guess_agent': 2,
#           'with_agent': 1,
#           'glance_agent': 1,
#           'spring_agent': 1,
#           'die_agent': 1,
#           'await_agent': 1,
#           'fear_agent': 1,
#           'loose_agent': 1,
#           'pause_agent': 1,
#           '"_agent': 1,
#           'ah_agent': 1,
#           'appear_agent': 1,
#           'muse_agent': 1,
#           'recognize_agent': 2,
#           'centre_agent': 1,
#           'exist_agent': 1,
#           'taunt_agent': 1,
#           'attempt_agent': 1,
#           'push_agent': 1,
#           'bend_agent': 1,
#           'whisper_agent': 3,
#           'flash_agent': 1,
#           'chide_agent': 1,
#           'overpower_agent': 1,
#           'hate_agent': 1,
#           'halt_agent': 1,
#           'occupy_agent': 1,
#           'compel_agent': 1,
#           'realize_agent': 2,
#           'trapping_agent': 1,
#           'believe_agent': 1,
#           'admit_agent': 1,
#           'conclude_agent': 1,
#           'helpless_agent': 1,
#           'despatch_agent': 1,
#           'smile_agent': 1,
#           'slay_agent': 1,
#           'choose_agent': 1,
#           'learn_agent': 1,
#           'blanch_agent': 1,
#           'nod_agent': 1,
#           'bear_agent': 1,
#           'join_agent': 1,
#           'hasten_agent': 1,
#           'distance_agent': 1,
#           'bring_agent': 1,
#           'mutter_patient': 1,
#           'repeat_patient': 1,
#           'exclaim_patient': 1,
#           'mistaken_patient': 1,
#           'tear_patient': 1,
#           'seek_patient': 1,
#           'detect_patient': 1,
#           'carry_patient': 2,
#           'leap_patient': 1,
#           'advance_patient': 1,
#           'lead_patient': 1,
#           'growl_patient': 1,
#           'picture_patient': 1,
#           'appear_patient': 1,
#           'command_patient': 1,
#           'recognize_patient': 1,
#           'chide_patient': 1,
#           'overpower_patient': 1,
#           'hate_patient': 1,
#           'compel_patient': 1,
#           'realize_patient': 1,
#           'centre_patient': 1,
#           'believe_patient': 1,
#           'despatch_patient': 1,
#           'choose_patient': 1}),
#  'the man\taka the act, the floor\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)': Counter({'mutter_agent': 1,
#           'throw_agent': 1,
#           'waste_agent': 1,
#           'snap_agent': 1,
#           'bow_agent': 1,
#           'narrow_agent': 1,
#           'approach_agent': 1,
#           'sweep_agent': 1,
#           'whisper_agent': 1,
#           'bent_agent': 1,
#           'measure_agent': 1,
#           'smile_agent': 2,
#           'remark_agent': 1,
#           'close_agent': 1,
#           'switch_agent': 1,
#           'instant_agent': 1,
#           'raise_agent': 1,
#           'mount_agent': 1,
#           'drag_agent': 2,
#           'remove_agent': 2,
#           'study_agent': 1,
#           'this_agent': 1,
#           'replace_agent': 1,
#           'touch_agent': 1,
#           'lose_agent': 1,
#           'search_agent': 1,
#           'leap_agent': 2,
#           'spring_agent': 1,
#           'loom_agent': 1,
#           'yawn_agent': 1,
#           'hesitate_agent': 1,
#           'steal_agent': 1,
#           'lead_agent': 1,
#           'hold_agent': 1,
#           'place_agent': 1,
#           'perfect_agent': 1,
#           'conclude_agent': 1,
#           'shake_agent': 2,
#           'commence_agent': 1,
#           'eye_agent': 2,
#           'scream_agent': 1,
#           'exclaim_agent': 1,
#           'restrain_agent': 1,
#           'meet_agent': 1,
#           'swear_agent': 1,
#           'plan_agent': 1,
#           'watch_agent': 1,
#           'charge_agent': 1,
#           'swing_agent': 1,
#           'permit_agent': 1,
#           'growl_agent': 1,
#           'need_agent': 1,
#           'form_agent': 1,
#           'drop_agent': 1,
#           'battle_agent': 1,
#           'arise_agent': 1,
#           'withstand_agent': 1,
#           'consist_agent': 1,
#           'strike_patient': 1,
#           'snap_patient': 1,
#           'bring_patient': 1,
#           'snatch_patient': 2,
#           'switch_patient': 1,
#           'head_patient': 1,
#           'touch_patient': 1,
#           'discover_patient': 1,
#           'penetrate_patient': 1,
#           'place_patient': 1,
#           'miss_patient': 1,
#           'catch_patient': 1,
#           'perfect_patient': 1,
#           'conclude_patient': 1,
#           'growl_patient': 1,
#           'repeat_patient': 1,
#           'throw_patient': 1,
#           'eye_patient': 1,
#           'exclaim_patient': 1,
#           'bespoke_patient': 1,
#           'meet_patient': 1,
#           'watch_patient': 1,
#           'emerge_patient': 1,
#           'discard_patient': 1,
#           'permit_patient': 1,
#           'deny_patient': 1,
#           'pursue_patient': 1,
#           'equip_patient': 1}),
#  'astok of dusar\taka us, astok or dusar\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)': Counter({'spring_agent': 2,
#           'clutch_agent': 1,
#           'youth_agent': 1,
#           'leap_agent': 3,
#           'shrug_agent': 1,
#           'direct_agent': 1,
#           'trust_agent': 1,
#           'defend_agent': 1,
#           'die_agent': 1,
#           'throw_agent': 1,
#           'kill_agent': 1,
#           'deny_agent': 1,
#           'glower_agent': 1,
#           'dare_agent': 1,
#           'occur_agent': 1,
#           'exclaim_agent': 1,
#           'withdraw_agent': 1,
#           'chance_agent': 1,
#           'crush_agent': 1,
#           'heart_agent': 1,
#           'recall_agent': 1,
#           'cool_agent': 1,
#           'enter_agent': 1,
#           'hate_agent': 1,
#           'wheel_agent': 1,
#           'summon_agent': 1,
#           'nod_agent': 1,
#           'conclude_agent': 1,
#           'hesitate_agent': 1,
#           'snatch_agent': 1,
#           'doubt_agent': 1,
#           'seek_agent': 1,
#           'elude_agent': 1,
#           'mean_agent': 1,
#           'race_agent': 1,
#           'scarce_agent': 1,
#           'round_agent': 1,
#           'pen_agent': 1,
#           'whisper_agent': 1,
#           'fight_agent': 1,
#           'show_agent': 1,
#           'clutch_patient': 1,
#           'narrow_patient': 1,
#           'shrug_patient': 1,
#           'defend_patient': 1,
#           'perish_patient': 1,
#           'rush_patient': 1,
#           'hand_patient': 1,
#           'fill_patient': 1,
#           'need_patient': 1,
#           'choose_patient': 1,
#           'help_patient': 1,
#           'enter_patient': 1,
#           'hold_patient': 1,
#           'discover_patient': 1}),
#  'ptarth\taka themselves, they\t(Edgar Rice Burroughs___Thuvia, Maid of Mars)': Counter({'notice_agent': 1,
#           'stride_agent': 1,
#           'work_agent': 1,
#           'seek_agent': 1,
#           'bow_agent': 1,
#           'reappear_agent': 1,
#           'closet_agent': 1,
#           'hurry_agent': 1,
#           'stroll_agent': 1,
#           'watch_agent': 2,
#           'encounter_agent': 1,
#           'tremble_agent': 2,
#           'believe_agent': 1,
#           'hope_agent': 2,
#           'scream_agent': 1,
#           'fasten_agent': 1,
#           'live_agent': 1,
#           'conquer_agent': 1,
#           'constitute_agent': 1,
#           'eat_agent': 1,
#           'seat_agent': 1,
#           'scarce_agent': 1,
#           'wing_agent': 1,
#           'stoop_agent': 1,
#           'glance_agent': 1,
#           'learn_agent': 1,
#           'deny_agent': 1,
#           'battle_agent': 1,
#           'graze_agent': 1,
#           'catch_agent': 1,
#           'warn_patient': 1,
#           'notice_patient': 1,
#           'offer_patient': 1,
#           'bring_patient': 1,
#           'arouse_patient': 1,
#           'land_patient': 1,
#           'cease_patient': 1,
#           'lead_patient': 1,
#           'believe_patient': 1,
#           'chance_patient': 1,
#           'halt_patient': 1,
#           'lose_patient': 1,
#           'seek_patient': 1,
#           'follow_patient': 1,
#           'conquer_patient': 1,
#           'discover_patient': 1,
#           'intercept_patient': 1,
#           'save_patient': 1}),
#  'his\taka his ship, his courageousness\t(Herman Melville___Moby Dick)': Counter({'touch_agent': 2,
#           'plug_agent': 1,
#           'complain_agent': 1,
#           'observe_agent': 3,
#           'interest_agent': 1,
#           'announce_agent': 1,
#           'slip_agent': 1,
#           'demand_agent': 1,
#           'chance_agent': 2,
#           'conclude_agent': 1,
#           'notice_agent': 1,
#           'commence_agent': 1,
#           'puff_agent': 1,
#           'satisfy_agent': 1,
#           'sabbee_agent': 1,
#           'suppose_agent': 2,
#           'hug_agent': 1,
#           'succeed_agent': 2,
#           'tarry_agent': 1,
#           'justify_agent': 1,
#           'withdraw_agent': 1,
#           'TABLET_agent': 2,
#           'terrify_agent': 1,
#           'symbolize_agent': 1,
#           'read_agent': 2,
#           'Woe_agent': 1,
#           'strike_agent': 1,
#           'redeem_agent': 1,
#           'express_agent': 1,
#           'own_agent': 1,
#           'use_agent': 1,
#           'carry_agent': 2,
#           'button_agent': 1,
#           'last_agent': 1,
#           'flourish_agent': 1,
#           'revolve_agent': 1,
#           'breathe_agent': 1,
#           'present_agent': 1,
#           'blame_agent': 1,
#           'expect_agent': 1,
#           'word_agent': 1,
#           'state_agent': 1,
#           'yield_agent': 1,
#           'gather_agent': 1,
#           'mount_agent': 1,
#           'spoil_agent': 1,
#           'proceed_agent': 1,
#           'rank_agent': 1,
#           'depend_agent': 1,
#           'live_agent': 2,
#           'form_agent': 1,
#           'fed_agent': 1,
#           'range_agent': 1,
#           'shake_agent': 1,
#           'for_agent': 2,
#           'plant_agent': 1,
#           'reveal_agent': 1,
#           'gain_agent': 1,
#           'left_agent': 1,
#           'storm_agent': 1,
#           'troop_agent': 1,
#           'question_agent': 1,
#           'deny_agent': 2,
#           'stove_agent': 1,
#           'apply_agent': 1,
#           'substantiate_agent': 1,
#           'stretch_agent': 1,
#           'prepare_agent': 1,
#           'strange_agent': 1,
#           'swell_agent': 2,
#           'denote_agent': 1,
#           'grow_agent': 3,
#           'descry_agent': 1,
#           'serve_agent': 1,
#           'need_agent': 1,
#           'admit_agent': 1,
#           'conceive_agent': 1,
#           'love_agent': 1,
#           'affect_agent': 1,
#           'church_agent': 1,
#           'mix_agent': 1,
#           'rush_agent': 1,
#           'open_agent': 1,
#           'pause_agent': 1,
#           'doze_agent': 1,
#           'employ_agent': 1,
#           'lift_agent': 1,
#           'carve_agent': 1,
#           'dash_agent': 1,
#           'swam_agent': 2,
#           'elevate_agent': 1,
#           'tug_agent': 1,
#           'advance_agent': 1,
#           'freeze_agent': 1,
#           'blow_agent': 1,
#           'clothe_agent': 1,
#           'hint_agent': 1,
#           'guess_agent': 1,
#           'act_agent': 1,
#           'drag_agent': 1,
#           'furnish_agent': 1,
#           'illustrate_agent': 1,
#           'occur_agent': 1,
#           'insult_agent': 1,
#           'declare_agent': 1,
#           'hide_agent': 1,
#           'secrete_agent': 1,
#           'assume_agent': 1,
#           'stick_agent': 1,
#           'point_agent': 1,
#           'shoot_agent': 2,
#           'sink_agent': 1,
#           'die_agent': 1,
#           'disclose_agent': 1,
#           'accommodate_agent': 1,
#           'evince_agent': 3,
#           'level_agent': 1,
#           'mind_agent': 1,
#           'spout_agent': 1,
#           'dodge_agent': 1,
#           'oh_agent': 1,
#           'knit_agent': 1,
#           'curve_agent': 1,
#           'more_agent': 1,
#           'bend_agent': 1,
#           'resolve_agent': 1,
#           'abandon_agent': 1,
#           'says--"hand_agent': 1,
#           'seize_agent': 2,
#           'thrust_agent': 2,
#           'breast_agent': 1,
#           'consist_agent': 1,
#           'belong_agent': 1,
#           'consume_agent': 1,
#           'burn_agent': 1,
#           'replace_agent': 1,
#           'show_agent': 1,
#           'think.--is_agent': 1,
#           'bestir_agent': 1,
#           'behove_agent': 1,
#           'alter_agent': 1,
#           'inquire_agent': 1,
#           'despise_agent': 1,
#           'fail_agent': 1,
#           'receive_agent': 2,
#           'lash_agent': 1,
#           'account_agent': 1,
#           'pinch_agent': 1,
#           'forthwith_agent': 1,
#           'marshal_agent': 1,
#           'shoulder_agent': 1,
#           'entreat_agent': 1,
#           'murmur_agent': 1,
#           'roll_agent': 1,
#           'toil_agent': 1,
#           'regard_agent': 1,
#           'remain_agent': 1,
#           'ponder_agent': 1,
#           'smack_agent': 1,
#           'swing_agent': 1,
#           'avoid_agent': 1,
#           'laugh_agent': 1,
#           'stay_agent': 1,
#           'slouch_agent': 1,
#           'dart_agent': 2,
#           'desolation_agent': 1,
#           'blind_agent': 1,
#           'surpass_agent': 1,
#           'spill_agent': 1,
#           'prick_agent': 1,
#           'retain_agent': 1,
#           'remind_agent': 1,
#           'punish_agent': 1,
#           'soever_agent': 1,
#           'lord_patient': 1,
#           'assure_patient': 1,
#           'warm_patient': 1,
#           'raise_patient': 1,
#           'chance_patient': 1,
#           'commence_patient': 3,
#           'puff_patient': 1,
#           'succeed_patient': 2,
#           'wash_patient': 1,
#           'don_patient': 1,
#           'justify_patient': 1,
#           'terrify_patient': 1,
#           'accompany_patient': 2,
#           'read_patient': 1,
#           'grow_patient': 2,
#           'redeem_patient': 1,
#           'thaw_patient': 1,
#           'propose_patient': 1,
#           'lend_patient': 1,
#           'catch_patient': 1,
#           'discover_patient': 1,
#           'push_patient': 2,
#           'furl_patient': 1,
#           'sally_patient': 1,
#           'seat_patient': 1,
#           'rub_patient': 1,
#           'aye_patient': 1,
#           'nothing_patient': 1,
#           'dare_patient': 1,
#           'visit_patient': 1,
#           'attend_patient': 1,
#           'remove_patient': 1,
#           'present_patient': 1,
#           'ascribe_patient': 1,
#           'toss_patient': 1,
#           'hiss_patient': 1,
#           'stick_patient': 2,
#           'define_patient': 1,
#           'suppose_patient': 2,
#           'distil_patient': 1,
#           'mount_patient': 1,
#           'retain_patient': 1,
#           'receive_patient': 1,
#           'SAILOR_patient': 1,
#           'for_patient': 2,
#           'plant_patient': 1,
#           'reveal_patient': 1,
#           'smote_patient': 1,
#           'pile_patient': 1,
#           'awake_patient': 1,
#           'aught_patient': 1,
#           'invest_patient': 1,
#           'efface_patient': 1,
#           'permit_patient': 1,
#           'deny_patient': 1,
#           'question_patient': 1,
#           'observe_patient': 1,
#           'consist_patient': 1,
#           'withdraw_patient': 1,
#           'load_patient': 1,
#           'pull_patient': 1,
#           'swell_patient': 1,
#           'descry_patient': 1,
#           'serve_patient': 1,
#           'hailed--"Ahoy_patient': 1,
#           'carry_patient': 1,
#           'occur_patient': 2,
#           'cruise_patient': 1,
#           'bear_patient': 1,
#           'affect_patient': 1,
#           'command_patient': 2,
#           'purge_patient': 1,
#           'mix_patient': 1,
#           'open_patient': 1,
#           'collar_patient': 1,
#           'murder_patient': 1,
#           'calculate_patient': 1,
#           'lift_patient': 1,
#           'bring_patient': 1,
#           'cut_patient': 1,
#           'anchor_patient': 1,
#           'swear_patient': 1,
#           'rest_patient': 1,
#           'enable_patient': 1,
#           'swam_patient': 1,
#           'grant_patient': 1,
#           'encourage_patient': 1,
#           'overcome_patient': 1,
#           'limp_patient': 1,
#           'box_patient': 1,
#           'guess_patient': 1,
#           'sell_patient': 1,
#           'insert_patient': 1,
#           'dispirit_patient': 1,
#           'unhinge_patient': 1,
#           'drag_patient': 2,
#           'thrust_patient': 2,
#           'deify_patient': 1,
#           'hide_patient': 1,
#           'assume_patient': 1,
#           'lose_patient': 2,
#           'level_patient': 1,
#           'breathe_patient': 1,
#           'dodge_patient': 1,
#           'deplore_patient': 1,
#           'dissect_patient': 1,
#           'more_patient': 1,
#           'purchase_patient': 1,
#           'resolve_patient': 1,
#           'insinuate_patient': 1,
#           'abandon_patient': 1,
#           'says--"hand_patient': 1,
#           'seize_patient': 2,
#           'evince_patient': 1,
#           'consume_patient': 1,
#           'hold_patient': 1,
#           'drop_patient': 2,
#           'continue_patient': 1,
#           'roar_patient': 1,
#           'behove_patient': 2,
#           'compress_patient': 1,
#           'treat_patient': 1,
#           'inquire_patient': 1,
#           'publish_patient': 1,
#           'prepare_patient': 1,
#           'forthwith_patient': 1,
#           'lay_patient': 1,
#           'use_patient': 1,
#           'exclaim_patient': 1,
#           'add_patient': 1,
#           'hand_patient': 1,
#           'hope_patient': 1,
#           'beget_patient': 1,
#           'nail_patient': 1,
#           'caulk_patient': 1,
#           'pay_patient': 1,
#           'like_patient': 1,
#           'unwind_patient': 1,
#           'patch_patient': 1,
#           'save_patient': 1,
#           'allude_patient': 1,
#           'declare_patient': 1,
#           'blind_patient': 1,
#           'cozening_patient': 1,
#           'flow_patient': 1,
#           'spill_patient': 1,
#           'dash_patient': 1,
#           'snap_patient': 1,
#           'so_patient': 1,
#           'remind_patient': 1,
#           'rear_patient': 1}),
#  'it\taka this delicacy, this thus far successful fugitive\t(Herman Melville___Moby Dick)': Counter({'hang_agent': 1,
#           'conclude_agent': 1,
#           'increase_agent': 1,
#           'blend_agent': 1,
#           'lead_agent': 1,
#           'write_agent': 1,
#           'oscillate_agent': 1,
#           'raise_agent': 1,
#           'sally_agent': 1,
#           'pay_agent': 1,
#           'groan_agent': 1,
#           'whale_agent': 2,
#           'assert_agent': 1,
#           'resemble_agent': 1,
#           'contradict_agent': 1,
#           'flash_agent': 1,
#           'consider_agent': 1,
#           'split_agent': 1,
#           'fail_agent': 1,
#           'assume_agent': 2,
#           'diffuse_agent': 1,
#           'fetch_agent': 1,
#           'will_agent': 1,
#           'confound_agent': 1,
#           'sting_agent': 1,
#           'drill_agent': 1,
#           'haunt_agent': 1,
#           'lower_agent': 1,
#           'swam_agent': 1,
#           'arch_agent': 1,
#           'question_agent': 1,
#           'deny_agent': 1,
#           'solve_agent': 1,
#           '"_agent': 1,
#           'care_agent': 1,
#           'distant_agent': 1,
#           'fly_agent': 1,
#           'argue_agent': 1,
#           'reign_agent': 1,
#           'end_agent': 1,
#           'diminish_agent': 1,
#           'believe_agent': 1,
#           'constrain_agent': 1,
#           'mince_agent': 1,
#           'display_agent': 1,
#           'hit_agent': 1,
#           'subside_agent': 1,
#           'gaze_agent': 1,
#           'continue_agent': 2,
#           'dart_agent': 3,
#           'happen_agent': 1,
#           'box_agent': 1,
#           'lose_agent': 1,
#           'float_agent': 1,
#           'straightway_agent': 1,
#           'push_agent': 1,
#           'coil_agent': 1,
#           'prove_agent': 1,
#           'yield_agent': 1,
#           'occur_agent': 2,
#           'remain_agent': 2,
#           'thrust_agent': 1,
#           'aver_agent': 1,
#           'extract_agent': 1,
#           'gather_agent': 1,
#           'breathe_agent': 2,
#           'overhang_agent': 1,
#           'hail_agent': 1,
#           'tend_agent': 1,
#           'rush_agent': 1,
#           'beheld_agent': 1,
#           'mention_agent': 1,
#           'contain_agent': 2,
#           'reserve_agent': 1,
#           'evince_agent': 1,
#           'rescue_agent': 1,
#           'feed_agent': 1,
#           'preserve_agent': 1,
#           'talk_agent': 2,
#           'chance_agent': 1,
#           'ECUADOR_agent': 1,
#           'was--_agent': 1,
#           'resolve_agent': 1,
#           'desire_agent': 1,
#           'declare_agent': 1,
#           'shade_agent': 1,
#           'yet_agent': 1,
#           'abide_agent': 1,
#           'forge_agent': 1,
#           'supply_agent': 1,
#           'murmur_agent': 1,
#           'conduct_agent': 1,
#           'work_agent': 2,
#           'eye_agent': 1,
#           'point_agent': 1,
#           'bring_agent': 1,
#           'needs_agent': 1,
#           'swallow_agent': 1,
#           'arrange_agent': 1,
#           'snatch_agent': 1,
#           'domineer_agent': 1,
#           'flow_agent': 1,
#           'reveal_agent': 1,
#           'boom_agent': 1,
#           'bravadoe_agent': 1,
#           'cross_agent': 1,
#           'drag_agent': 1,
#           'dash_agent': 1,
#           'peck_agent': 1,
#           'glide_agent': 1,
#           'last_agent': 1,
#           'cast_agent': 1,
#           'roll_agent': 1,
#           'collapse_agent': 1,
#           'lead_patient': 1,
#           'hang_patient': 1,
#           'help_patient': 1,
#           'use_patient': 2,
#           'blend_patient': 1,
#           'approach_patient': 1,
#           'write_patient': 1,
#           'appal_patient': 1,
#           'invite_patient': 1,
#           'march_patient': 1,
#           'fetch_patient': 1,
#           'groan_patient': 1,
#           'appear_patient': 1,
#           'depend_patient': 1,
#           'confess_patient': 1,
#           'grant_patient': 1,
#           'bear_patient': 1,
#           'contradict_patient': 1,
#           'split_patient': 1,
#           'restrict_patient': 1,
#           'fail_patient': 1,
#           'forget_patient': 1,
#           'raise_patient': 3,
#           'chase_patient': 1,
#           'thy_patient': 1,
#           'reckon_patient': 1,
#           'twig_patient': 2,
#           'jig_patient': 1,
#           'Bang_patient': 1,
#           'rig_patient': 1,
#           'well_patient': 1,
#           'swam_patient': 1,
#           'pit_patient': 1,
#           'storm_patient': 1,
#           'crew_patient': 1,
#           'shake_patient': 1,
#           'question_patient': 1,
#           'that_patient': 1,
#           'solve_patient': 2,
#           '"_patient': 1,
#           'swim_patient': 1,
#           'live_patient': 2,
#           'care_patient': 1,
#           'refine_patient': 1,
#           'free_patient': 1,
#           'steady_patient': 1,
#           'present_patient': 1,
#           'argue_patient': 1,
#           'believe_patient': 3,
#           'constrain_patient': 1,
#           'arrive_patient': 1,
#           'evince_patient': 2,
#           'mercy_patient': 1,
#           'manner_patient': 1,
#           'assign_patient': 1,
#           'include_patient': 1,
#           'consist_patient': 1,
#           'straighten_patient': 1,
#           'say"--holde_patient': 1,
#           'hold_patient': 1,
#           'box_patient': 1,
#           'consider_patient': 1,
#           'pause_patient': 1,
#           'Shakers_patient': 1,
#           'sigh_patient': 1,
#           'clutch_patient': 1,
#           'coil_patient': 1,
#           'suppose_patient': 2,
#           'lodge_patient': 1,
#           'declare_patient': 2,
#           'strike_patient': 1,
#           'place_patient': 1,
#           'assert_patient': 1,
#           'extract_patient': 1,
#           'assume_patient': 1,
#           'hide_patient': 1,
#           'tend_patient': 1,
#           'attach_patient': 1,
#           'meet_patient': 1,
#           'regard_patient': 1,
#           'break_patient': 1,
#           'reserve_patient': 1,
#           'cut_patient': 1,
#           'stagger_patient': 1,
#           'proceed_patient': 1,
#           'lengthwise_patient': 1,
#           'revere_patient': 1,
#           'talk_patient': 1,
#           'all_patient': 1,
#           'resolve_patient': 1,
#           'measure_patient': 1,
#           'bless_patient': 1,
#           'weave_patient': 1,
#           'gain_patient': 1,
#           'desire_patient': 1,
#           'drive_patient': 1,
#           'die_patient': 1,
#           'bring_patient': 1,
#           'catch_patient': 1,
#           'mark_patient': 1,
#           'combine_patient': 1,
#           'swallow_patient': 1,
#           'arrange_patient': 1,
#           'work_patient': 1,
#           'stay_patient': 1,
#           'head_patient': 1,
#           'surpass_patient': 1,
#           'thrill_patient': 1,
#           'lay_patient': 1,
#           'dawn_patient': 1,
#           'blow_patient': 1,
#           'conquer_patient': 1,
#           'muttered--"whether_patient': 1}),
#  'ahab\taka slouched ahab, mr. starbuck\t(Herman Melville___Moby Dick)': Counter({'name_agent': 1,
#           'whim_agent': 1,
#           'bye_agent': 1,
#           'ye_agent': 1,
#           'beget_agent': 1,
#           'visit_agent': 1,
#           'attend_agent': 1,
#           'indeed_agent': 1,
#           'affect_agent': 1,
#           'for_agent': 2,
#           'advance_agent': 1,
#           'soothe_agent': 1,
#           'pace_agent': 3,
#           'swing_agent': 1,
#           'preside_agent': 1,
#           'receive_agent': 2,
#           'forbid_agent': 1,
#           'form_agent': 1,
#           'assemble_agent': 1,
#           'continue_agent': 1,
#           'summon_agent': 1,
#           'cried:--_agent': 1,
#           'rub_agent': 1,
#           'resume_agent': 1,
#           'laugh_agent': 1,
#           'snort_agent': 1,
#           'order_agent': 2,
#           'range_agent': 2,
#           'rush_agent': 1,
#           'disperse_agent': 1,
#           'cabin_agent': 1,
#           'embattle_agent': 1,
#           'pit_agent': 1,
#           'pile_agent': 1,
#           'storm_agent': 1,
#           'succeed_agent': 1,
#           'sail_agent': 2,
#           'suspend_agent': 1,
#           'thread_agent': 1,
#           'hope_agent': 2,
#           'permit_agent': 1,
#           'mutter_agent': 1,
#           'seek_agent': 1,
#           'sleep_agent': 1,
#           'use_agent': 1,
#           'observe_agent': 1,
#           'throw_agent': 1,
#           'settle_agent': 1,
#           'leap_agent': 1,
#           'allusion_agent': 1,
#           'solicit_agent': 1,
#           'command_agent': 1,
#           'walk_agent': 1,
#           'swore_agent': 1,
#           'manifest_agent': 1,
#           'hailed--"Ahoy_agent': 1,
#           'perceive_agent': 2,
#           'swam_agent': 1,
#           'issue_agent': 1,
#           'evince_agent': 1,
#           'betray_agent': 1,
#           'elapse_agent': 1,
#           'pause_agent': 1,
#           'demand_agent': 1,
#           'wager)--aye_agent': 1,
#           'chance_agent': 1,
#           'purpose_agent': 1,
#           'sweep_agent': 1,
#           'touch_agent': 2,
#           'revolve_agent': 1,
#           'and_agent': 1,
#           'mould_agent': 1,
#           'retire_agent': 1,
#           'relate_agent': 1,
#           'shoot_agent': 1,
#           'nail_agent': 1,
#           'forget_agent': 1,
#           'light_agent': 1,
#           'unattende_agent': 1,
#           'bid_agent': 1,
#           'pump_agent': 1,
#           'seize_agent': 2,
#           'snuff_agent': 1,
#           'hammer_agent': 1,
#           'slide_agent': 2,
#           'fit_agent': 1,
#           'exclaim_agent': 1,
#           'remain_agent': 1,
#           'vassal_agent': 1,
#           'lurch_agent': 1,
#           'escape_agent': 1,
#           'close_agent': 1,
#           'wave_agent': 1,
#           'hurry_agent': 1,
#           'allude_agent': 1,
#           'beseech_agent': 1,
#           'slouch_agent': 1,
#           'clothe_agent': 1,
#           'gaze_agent': 2,
#           'reveal_agent': 1,
#           'rig_agent': 1,
#           'hold_agent': 2,
#           'lean_agent': 1,
#           'drop_agent': 1,
#           'avert_agent': 1,
#           'cross_agent': 1,
#           'cast_agent': 2,
#           'gain_agent': 1,
#           'discover_agent': 1,
#           'yawn_agent': 1,
#           'slip_agent': 1,
#           'descry_agent': 2,
#           'pay_agent': 1,
#           'fasten_agent': 1,
#           'ring_agent': 1,
#           'lower_agent': 1,
#           'snap_agent': 1,
#           'hail_agent': 1,
#           'catch_agent': 1,
#           'drive_agent': 1,
#           'rally_agent': 1,
#           'shout_agent': 1,
#           'glide_agent': 1,
#           'curl_agent': 1,
#           'dart_agent': 1,
#           'smite_agent': 1,
#           'clear_agent': 1,
#           'use_patient': 1,
#           'name_patient': 1,
#           'reveal_patient': 1,
#           'cherish_patient': 1,
#           'enshrine_patient': 1,
#           'indeed_patient': 1,
#           'deputation_patient': 1,
#           'Enter_patient': 1,
#           'gritted_patient': 2,
#           'swing_patient': 1,
#           'die_patient': 1,
#           'pace_patient': 2,
#           'mark_patient': 1,
#           'repeat_patient': 1,
#           'assemble_patient': 1,
#           'shout_patient': 1,
#           'rush_patient': 1,
#           'embattle_patient': 1,
#           'pit_patient': 1,
#           'succeed_patient': 1,
#           'crew_patient': 1,
#           'follow_patient': 1,
#           'hope_patient': 1,
#           'permit_patient': 1,
#           'mutter_patient': 3,
#           'strip_patient': 1,
#           'scorn_patient': 1,
#           'observe_patient': 1,
#           'range_patient': 1,
#           'throw_patient': 1,
#           'tear_patient': 2,
#           'perceive_patient': 1,
#           'evince_patient': 1,
#           'chance_patient': 1,
#           'sweep_patient': 1,
#           'and_patient': 1,
#           'hint_patient': 1,
#           'bring_patient': 1,
#           'roar_patient': 1,
#           'belie_patient': 1,
#           'bid_patient': 1,
#           'murmur_patient': 1,
#           'howl_patient': 1,
#           'grasp_patient': 1,
#           'approach_patient': 1,
#           'seize_patient': 2,
#           'allude_patient': 1,
#           'discern_patient': 1,
#           'cast_patient': 1,
#           'fasten_patient': 1,
#           'untouched_patient': 1,
#           'girdle_patient': 1,
#           'wilt_patient': 1,
#           'away!"-crie_patient': 1,
#           'hail_patient': 1,
#           'glide_patient': 1,
#           'roll_patient': 1,
#           'clear_patient': 1}),
#  'the mouth\taka the other captain, themselves\t(Herman Melville___Moby Dick)': Counter({'account_agent': 1,
#           'deep_agent': 1,
#           'sea_agent': 1,
#           'raise_agent': 2,
#           'arrive_agent': 1,
#           'chance_agent': 1,
#           'continue_agent': 1,
#           'checker_agent': 1,
#           'kindle_agent': 1,
#           'add_agent': 2,
#           'commence_agent': 1,
#           'trouble_agent': 1,
#           'emerge_agent': 1,
#           'seek_agent': 1,
#           'pause_agent': 2,
#           'end_agent': 1,
#           'show_agent': 2,
#           'comply_agent': 1,
#           'jump_agent': 1,
#           'nothing_agent': 2,
#           'rejoin_agent': 1,
#           'word_agent': 1,
#           'mutter_agent': 1,
#           'flash_agent': 1,
#           'kick_agent': 1,
#           'deny_agent': 1,
#           'resemble_agent': 1,
#           'baleen_agent': 1,
#           'comprise_agent': 1,
#           'fail_agent': 1,
#           'receive_agent': 1,
#           'forbid_agent': 1,
#           'rub_agent': 1,
#           'resume_agent': 1,
#           'whisper_agent': 2,
#           'hang_agent': 1,
#           'inhale_agent': 1,
#           'kiss_agent': 1,
#           'wrap_agent': 1,
#           'rest_agent': 1,
#           'sailor_agent': 1,
#           'that_agent': 1,
#           'circumnavigate_agent': 1,
#           'write_agent': 1,
#           'strip_agent': 1,
#           'swell_agent': 1,
#           'cut_agent': 1,
#           'disable_agent': 1,
#           'sway_agent': 1,
#           'board_agent': 1,
#           'for_agent': 1,
#           'hold_agent': 1,
#           'exchange_agent': 1,
#           'meet_agent': 1,
#           'grin_agent': 1,
#           'govern_agent': 1,
#           'suppose_agent': 2,
#           'command_agent': 2,
#           'declare_agent': 1,
#           'bolt_agent': 1,
#           'save_agent': 1,
#           'revenge_agent': 1,
#           'swam_agent': 1,
#           'embark_agent': 1,
#           'can_agent': 1,
#           'publish_agent': 2,
#           'churn_agent': 1,
#           'smoke_agent': 1,
#           'besides_agent': 1,
#           'Bear_agent': 1,
#           'demand_agent': 1,
#           'announce_agent': 1,
#           'earnestness_agent': 1,
#           'open_agent': 1,
#           'work_agent': 1,
#           'jerk_agent': 1,
#           'fringe_agent': 1,
#           'elevate_agent': 1,
#           'search_agent': 1,
#           'proceed_agent': 2,
#           'accost_agent': 1,
#           'stir_agent': 1,
#           'furthermore_agent': 1,
#           'hide_agent': 1,
#           'derive_agent': 1,
#           'bend_agent': 1,
#           'line_agent': 1,
#           'float_agent': 1,
#           'contain_agent': 1,
#           'love_agent': 1,
#           'assail_agent': 1,
#           'drop_agent': 1,
#           'happen_agent': 1,
#           'rescue_agent': 1,
#           'stagger_agent': 1,
#           'lengthwise_agent': 1,
#           'sun_agent': 1,
#           'cross_agent': 1,
#           'thrust_agent': 1,
#           'weigh_agent': 1,
#           'lose_agent': 1,
#           'perish_agent': 1,
#           'inquire_agent': 1,
#           'desire_agent': 1,
#           'comfort_agent': 1,
#           'beat_agent': 1,
#           'steer_agent': 1,
#           'but_agent': 1,
#           'baulk_agent': 1,
#           'endure_agent': 1,
#           'eat_agent': 1,
#           'rush_agent': 1,
#           'pull_agent': 1,
#           'remain_agent': 1,
#           'equal_agent': 1,
#           'travel_agent': 1,
#           'foretell_agent': 1,
#           'about_agent': 1,
#           'sail_agent': 1,
#           'tear_agent': 1,
#           'soar_agent': 1,
#           'visit_agent': 1,
#           'rear_agent': 1,
#           'parry_agent': 1,
#           'arrive_patient': 1,
#           'trouble_patient': 1,
#           'emerge_patient': 1,
#           'fear_patient': 1,
#           'fellow_patient': 1,
#           'deny_patient': 1,
#           'capture_patient': 1,
#           'distinguish_patient': 1,
#           'incorporate_patient': 1,
#           'fail_patient': 1,
#           'forbid_patient': 1,
#           'carry_patient': 1,
#           'obstruct_patient': 1,
#           'consider_patient': 1,
#           'strip_patient': 1,
#           'hail_patient': 1,
#           'disable_patient': 1,
#           'bolt_patient': 1,
#           'moor_patient': 1,
#           'wallow_patient': 1,
#           'remind_patient': 1,
#           'omit_patient': 1,
#           'roll_patient': 1,
#           'suppose_patient': 1,
#           'engage_patient': 1,
#           'announce_patient': 2,
#           'publish_patient': 1,
#           'open_patient': 1,
#           'sink_patient': 1,
#           'accost_patient': 1,
#           'furthermore_patient': 1,
#           'line_patient': 1,
#           'evince_patient': 1,
#           'him!--hit_patient': 1,
#           'quit_patient': 2,
#           'love_patient': 1,
#           'assail_patient': 1,
#           'drop_patient': 1,
#           'rescue_patient': 1,
#           'protect_patient': 1,
#           'comfort_patient': 1,
#           'beat_patient': 1,
#           'cure_patient': 1,
#           'spoil_patient': 1,
#           'hold_patient': 1,
#           'abide_patient': 1,
#           '"_patient': 1,
#           'rush_patient': 1,
#           'command_patient': 1,
#           'meet_patient': 1,
#           'crowd_patient': 1,
#           'lower_patient': 1,
#           'parry_patient': 1}),
#  'me\taka domestic people in the temperate zone, these silent islands of men and women\t(Herman Melville___Moby Dick)': Counter({'blend_agent': 1,
#           'possess_agent': 1,
#           'bloom_agent': 1,
#           'arrive_agent': 1,
#           'notice_agent': 1,
#           'offer_agent': 1,
#           'touch_agent': 1,
#           'part_agent': 1,
#           'fly_agent': 1,
#           'rush_agent': 2,
#           'shut_agent': 1,
#           'suppose_agent': 1,
#           'state_agent': 1,
#           'remain_agent': 1,
#           'rub_agent': 1,
#           'true_agent': 1,
#           'dry_agent': 1,
#           'retain_agent': 1,
#           'say--_agent': 1,
#           'submit_agent': 1,
#           'hint_agent': 1,
#           'pretend_agent': 1,
#           'agree_agent': 1,
#           'hunt_agent': 1,
#           'occur_agent': 2,
#           'raise_agent': 1,
#           'muster_agent': 1,
#           'methink_agent': 1,
#           'cross_agent': 1,
#           'plant_agent': 1,
#           'swam_agent': 1,
#           'aught_agent': 1,
#           'consist_agent': 1,
#           'live_agent': 2,
#           'scorn_agent': 1,
#           'drop_agent': 1,
#           'pull_agent': 1,
#           'argue_agent': 1,
#           'hail_agent': 1,
#           'toss_agent': 1,
#           'drown_agent': 1,
#           'repeat_agent': 1,
#           'collar_agent': 1,
#           'furnish_agent': 1,
#           'toil_agent': 1,
#           'for_agent': 1,
#           'afford_agent': 1,
#           'break_agent': 1,
#           'hit_agent': 1,
#           'swallow_agent': 1,
#           'exclude_agent': 1,
#           'dispirit_agent': 1,
#           'suspend_agent': 2,
#           'hold_agent': 1,
#           'anoint_agent': 1,
#           'spring_agent': 1,
#           'insinuate_agent': 1,
#           'provide_agent': 1,
#           'squeeze_agent': 1,
#           'watch_agent': 1,
#           'wear_agent': 1,
#           'enter_agent': 1,
#           'wheel_agent': 1,
#           'continue_agent': 1,
#           'admeasurement_agent': 1,
#           'conclude_agent': 1,
#           'deem_agent': 1,
#           'command_agent': 1,
#           'roll_agent': 1,
#           'impersonate_agent': 1,
#           'fight_agent': 1,
#           'strove_agent': 1,
#           'launch_agent': 1,
#           'something_agent': 1,
#           'Truth_agent': 1,
#           'visit_agent': 1,
#           'remember_patient': 1,
#           'puzzle_patient': 1,
#           'proceed_patient': 1,
#           'rush_patient': 1,
#           'drop_patient': 1,
#           'join_patient': 1,
#           'resolve_patient': 1,
#           'furnish_patient': 1,
#           'recognise_patient': 1,
#           'hunt_patient': 1,
#           'assume_patient': 1,
#           'rub_patient': 1,
#           'muster_patient': 1,
#           'hand_patient': 1,
#           'cross_patient': 1,
#           'swam_patient': 1,
#           'read_patient': 1,
#           'share_patient': 1,
#           'strip_patient': 1,
#           'pull_patient': 1,
#           'remain_patient': 1,
#           'arrive_patient': 1,
#           'bear_patient': 1,
#           'carve_patient': 1,
#           'fetch_patient': 2,
#           'succeed_patient': 1,
#           'exclude_patient': 1,
#           'stir_patient': 1,
#           'receive_patient': 1,
#           'repressed_patient': 1,
#           'strike_patient': 1,
#           'regard_patient': 1,
#           'bid_patient': 1,
#           'watch_patient': 1,
#           'carry_patient': 1,
#           'use_patient': 1,
#           'drive_patient': 1,
#           'deem_patient': 1,
#           'strove_patient': 1,
#           'girdle_patient': 1,
#           'something_patient': 1,
#           'shout_patient': 1,
#           'suspend_patient': 1,
#           'visit_patient': 1,
#           'catch_patient': 1}),
#  "they\taka a contagion in the very air that blew from that haunted region, the pedagogue's mouth\t(Washington Irving___The Legend of Sleepy Hollow)": Counter({'recollect_agent': 1,
#           'wander_agent': 1,
#           'continue_agent': 1,
#           'abode_agent': 1,
#           'mistake_agent': 1,
#           'secure_agent': 1,
#           'administer_agent': 1,
#           'live_agent': 1,
#           'assist_agent': 1,
#           'lay_agent': 1,
#           'carry_agent': 1,
#           'flutter_agent': 2,
#           'delight_agent': 1,
#           'with_agent': 1,
#           'shrink_agent': 1,
#           'skim_agent': 1,
#           'water_agent': 1,
#           'swim_agent': 1,
#           'harry_agent': 1,
#           'interrupt_agent': 1,
#           'spend_agent': 1,
#           'borrow_agent': 1,
#           'wheel_agent': 1,
#           'queue_agent': 1,
#           'attract_agent': 1,
#           'breathe_agent': 1,
#           'throw_agent': 1,
#           'affirm_agent': 1,
#           'repay_agent': 1,
#           'gather_agent': 1,
#           'mount_agent': 1,
#           'spread_agent': 1,
#           'crowd_agent': 1,
#           'summon_agent': 1,
#           'bestow_agent': 1,
#           'behold_agent': 1,
#           'demand_agent': 1,
#           'receive_agent': 1,
#           'repeat_agent': 1,
#           'cudgel_agent': 1,
#           'appear_agent': 1,
#           'dash_agent': 1,
#           'lead_agent': 1,
#           'seize_agent': 1,
#           'rider_agent': 1,
#           'cheer_agent': 1,
#           'consist_agent': 1,
#           'belong_agent': 1,
#           'lean_agent': 1,
#           'knit_agent': 1,
#           'observe_agent': 1,
#           'recollect_patient': 1,
#           'mistake_patient': 1,
#           'administer_patient': 1,
#           'behoove_patient': 1,
#           'stream_patient': 1,
#           'appal_patient': 1,
#           'throw_patient': 1,
#           'delight_patient': 1,
#           'hang_patient': 1,
#           'borrow_patient': 1,
#           'affirm_patient': 1,
#           'repay_patient': 1,
#           'pause_patient': 1,
#           'seize_patient': 1,
#           'knit_patient': 1}),
#  'ichabod crane\taka no ichabod, ichabod\t(Washington Irving___The Legend of Sleepy Hollow)': Counter({'carry_agent': 3,
#           'sway_agent': 1,
#           'help_agent': 1,
#           'round_agent': 1,
#           'snap_agent': 1,
#           'pride_agent': 1,
#           'linger_agent': 1,
#           'fear_agent': 1,
#           'steal_agent': 1,
#           'pause_agent': 1,
#           'pull_agent': 1,
#           'endeavor_agent': 2,
#           'rain_agent': 1,
#           'flutter_agent': 1,
#           'gain_agent': 1,
#           'encounter_agent': 1,
#           'conduct_agent': 1,
#           'maintain_agent': 1,
#           'carry_patient': 1,
#           'sway_patient': 1,
#           'round_patient': 1,
#           'snap_patient': 1,
#           'pride_patient': 1,
#           'maintain_patient': 1}),
#  'this sequestered glen\taka his, himself\t(Washington Irving___The Legend of Sleepy Hollow)': Counter({'ride_agent': 1,
#           'strut_agent': 1,
#           'water_agent': 1,
#           'swim_agent': 1,
#           'carve_agent': 1,
#           'beheld_agent': 2,
#           'fancy_agent': 1,
#           'lose_agent': 1,
#           'heap_agent': 1,
#           'journey_agent': 1,
#           'elapse_agent': 1,
#           'ride_patient': 1}),
#  'her\taka this rantipole hero, her\t(Washington Irving___The Legend of Sleepy Hollow)': Counter({'distinguish_agent': 1,
#           'despair_agent': 1,
#           'bless_agent': 1,
#           'connect_patient': 1,
#           'regard_patient': 1}),
#  'old baltus van tassel\taka balt van tassel, old baltus van tassel\t(Washington Irving___The Legend of Sleepy Hollow)': Counter({'love_agent': 1,
#           'part_agent': 1}),
#  'tarzan\taka bara, they\t(Edgar Rice Burroughs___The Beasts of Tarzan)': Counter({'tear_agent': 1,
#           'meet_agent': 2,
#           'repeat_agent': 1,
#           'beg_agent': 1,
# ...
#           'play_agent': 3,
#           'pear_agent': 1,
#           'hurt_agent': 1,
#           'flatter_agent': 1,
#           'forget_agent': 2,
#           'remember_agent': 3,
#           'struggle_agent': 1,
#           'respond_agent': 2,
#           'hold_agent': 2,
#           'hove_agent': 1,
#           'eat_agent': 2,
#           'slacken_agent': 1,
#           'resign_agent': 1,
#           'skip_agent': 1,
#           'pretend_agent': 1,
#           'pick_agent': 1,
#           'button_agent': 2,
#           'stride_agent': 1,
#           'wander_agent': 3,
#           'invite_agent': 1,
#           'bring_agent': 3,
#           'pause_agent': 2,
#           'lay_agent': 1,
#           'face_agent': 1,
#           'shall_agent': 1,
#           'tackle_agent': 1,
#           'cut_agent': 1,
#           'coat_agent': 1,
#           'waylay_agent': 1,
#           'show_agent': 5,
#           'despise_agent': 1,
#           'deliver_agent': 1,
#           'distribute_agent': 1,
#           'titter_agent': 1,
#           'plead_agent': 1,
#           'believe_agent': 2,
#           'detect_agent': 1,
#           'light_agent': 1,
#           'lapse_agent': 1,
#           'bethink_agent': 1,
#           'survey_agent': 1,
#           'eye_agent': 2,
#           'grow_agent': 4,
#           'fling_agent': 2,
#           'resume_agent': 1,
#           'sink_agent': 1,
#           'seize_agent': 3,
#           'hate_agent': 1,
#           'work_agent': 2,
#           'erect_agent': 1,
#           'step_agent': 4,
#           'glow_agent': 1,
#           'escape_agent': 2,
#           'in_agent': 1,
#           'chew_agent': 1,
#           'mean_agent': 2,
#           'die_agent': 2,
#           'toss_agent': 1,
#           'watch_agent': 2,
#           'dress_agent': 1,
#           'wade_agent': 1,
#           'talk_agent': 3,
#           'wait_agent': 1,
#           'notice_agent': 4,
#           'bent_agent': 1,
#           'strike_agent': 2,
#           'pry_agent': 1,
#           'reel_agent': 1,
#           'murmur_agent': 1,
#           'rob_agent': 1,
#           'raise_agent': 3,
#           'fly_agent': 2,
#           'glance_agent': 1,
#           'burst_agent': 3,
#           'swear_agent': 2,
#           'tiptoe_agent': 1,
#           'separate_agent': 2,
#           'mope_agent': 1,
#           'betake_agent': 1,
#           'change_agent': 1,
#           'unroll_agent': 1,
#           'hang_agent': 2,
#           'shake_agent': 2,
#           'sob_agent': 1,
#           'order_agent': 2,
#           'taste_agent': 1,
#           'drop_agent': 1,
#           'gaze_agent': 2,
#           'should_agent': 1,
#           'lead_agent': 1,
#           'hunt_agent': 2,
#           'point_agent': 1,
#           'discover_agent': 2,
#           "o'clock_agent": 1,
#           'stretch_agent': 2,
#           "'s_agent": 1,
#           'resolve_agent': 1,
#           'carry_agent': 2,
#           'spring_agent': 3,
#           'part_agent': 1,
#           'reckon_agent': 3,
#           'agree_agent': 1,
#           'listen_agent': 1,
#           'climb_agent': 1,
#           'press_agent': 1,
#           'giveth_agent': 1,
#           'thread_agent': 1,
#           'untie_agent': 1,
#           'hit_agent': 1,
#           'rest_agent': 1,
#           'desert_agent': 1,
#           'stoop_agent': 1,
#           'venture_agent': 1,
#           'hide_agent': 1,
#           'learn_agent': 2,
#           'bet_agent': 2,
#           'huddle_agent': 1,
#           'clung_agent': 1,
#           'pour_agent': 1,
#           'drench_agent': 1,
#           'care_agent': 1,
#           'assemble_agent': 1,
#           'practise_agent': 1,
#           'disturb_agent': 2,
#           'relate_agent': 1,
#           'blow_agent': 1,
#           'Alfred_agent': 1,
#           'prepare_agent': 1,
#           'endure_agent': 1,
#           'lose_agent': 1,
#           'hand_agent': 1,
#           'ketch_agent': 1,
#           'would_agent': 1,
#           'avoid_agent': 1,
#           'decline_agent': 1,
#           'jump_agent': 2,
#           'drift_agent': 1,
#           'sally_agent': 1,
#           'stumble_agent': 1,
#           'arrive_agent': 1,
#           'toil_agent': 2,
#           'choose_agent': 1,
#           'drag_agent': 1,
#           'peg_agent': 1,
#           'like_agent': 1,
#           'mark_agent': 1,
#           'deepen_agent': 1,
#           'fight_agent': 1,
#           'fail_agent': 1,
#           'creep_agent': 1,
#           'alert_agent': 1,
#           'droop_agent': 1,
#           'subtract_agent': 1,
#           'nudge_agent': 1,
#           'examine_agent': 2,
#           'slip_agent': 1,
#           'suppose_agent': 2,
#           'follow_agent': 1,
#           'may_agent': 1,
#           'close_agent': 2,
#           'lock_agent': 1,
#           'astonish_agent': 1,
#           'bury_agent': 1,
#           'plunge_agent': 1,
#           'happen_agent': 1,
#           'depart_agent': 1,
#           'kill_agent': 1,
#           'promise_agent': 1,
#           'sneak_agent': 1,
#           'suggest_agent': 1,
#           'add_agent': 1,
#           'admit_agent': 1,
#           'excite_agent': 1,
#           'thought_agent': 1,
#           'blurt_agent': 1,
#           'flutter_agent': 1,
#           'curious_agent': 1,
#           'wind_agent': 1,
#           'walk_agent': 1,
#           'confess_agent': 1,
#           'miss_agent': 3,
#           'will_agent': 2,
#           'divide_agent': 1,
#           'stay_agent': 1,
#           'sleep_agent': 1,
#           'search_agent': 2,
#           'contrive_agent': 1,
#           'scoop_agent': 1,
#           'borrow_agent': 1,
#           'land_agent': 1,
#           'hive_agent': 1,
#           'open_agent': 1,
#           'weigh_agent': 1,
#           'receive_agent': 1,
#           'suffer_agent': 1,
#           'cuff_agent': 1,
#           'collect_agent': 1,
#           'bear_agent': 1,
#           'for_agent': 1,
#           'pray_agent': 1,
#           'smoke_agent': 1,
#           'learn_patient': 2,
#           'flatter_patient': 1,
#           'struggle_patient': 1,
#           'respond_patient': 1,
#           'sweep_patient': 1,
#           'pretend_patient': 1,
#           'button_patient': 1,
#           'invite_patient': 1,
#           'lay_patient': 1,
#           'contrive_patient': 1,
#           'remove_patient': 1,
#           'refill_patient': 1,
#           'coat_patient': 1,
#           'waylay_patient': 1,
#           'eat_patient': 1,
#           'despise_patient': 1,
#           'deliver_patient': 1,
#           'distribute_patient': 1,
#           'bring_patient': 3,
#           'regard_patient': 1,
#           'endure_patient': 1,
#           'detect_patient': 1,
#           'bethink_patient': 1,
#           'lift_patient': 3,
#           'grow_patient': 2,
#           'resume_patient': 1,
#           'restore_patient': 1,
#           'seize_patient': 3,
#           'traverse_patient': 1,
#           'enter_patient': 2,
#           'dress_patient': 1,
#           'stagger_patient': 1,
#           'believe_patient': 2,
#           'notice_patient': 2,
#           'die_patient': 1,
#           'cast_patient': 1,
#           'threaten_patient': 1,
#           'reel_patient': 1,
#           'and_patient': 1,
#           'rob_patient': 1,
#           'glance_patient': 1,
#           'exclaim_patient': 1,
#           'betake_patient': 1,
#           'shake_patient': 2,
#           'help_patient': 2,
#           'divine_patient': 1,
#           'accost_patient': 1,
#           'submit_patient': 1,
#           'discover_patient': 1,
#           'stretch_patient': 2,
#           'kill_patient': 3,
#           'carry_patient': 2,
#           'fly_patient': 1,
#           'fling_patient': 1,
#           'untie_patient': 1,
#           'spend_patient': 2,
#           'erase_patient': 1,
#           'reckon_patient': 2,
#           'huddle_patient': 1,
#           'pour_patient': 1,
#           'talk_patient': 1,
#           'culminate_patient': 1,
#           'scorch_patient': 1,
#           'remind_patient': 1,
#           'attract_patient': 1,
#           'thrust_patient': 1,
#           'snatch_patient': 1,
#           'love_patient': 1,
#           'occupy_patient': 1,
#           'sponge_patient': 1,
#           'wander_patient': 1,
#           'decline_patient': 1,
#           'raise_patient': 1,
#           'swear_patient': 1,
#           'bury_patient': 2,
#           'arrive_patient': 1,
#           'subdue_patient': 1,
#           'spot_patient': 1,
#           'unearthed_patient': 1,
#           'forsake_patient': 1,
#           'track_patient': 1,
#           'follow_patient': 1,
#           'bet_patient': 1,
#           'by_patient': 1,
#           'hop_patient': 1,
#           'grab_patient': 1,
#           'how_patient': 1,
#           'occur_patient': 1,
#           'astonish_patient': 1,
#           'spring_patient': 1,
#           'describe_patient': 1,
#           'promise_patient': 1,
#           'suggest_patient': 1,
#           'disturb_patient': 1,
#           'waste_patient': 1,
#           'mass_patient': 1,
#           'hold_patient': 1,
#           'hive_patient': 1,
#           'receive_patient': 1,
#           'cover_patient': 1,
#           'about_patient': 1,
#           'cuff_patient': 1,
#           'collect_patient': 1,
#           'board_patient': 1,
#           "'s_patient": 1}),
#  'it\taka one little forgiving word, his visitors\t(Mark Twain___The Adventures of Tom Sawyer, Complete)': Counter({'resume_agent': 1,
#           'suit_agent': 1,
#           'picture_agent': 1,
#           'eat_agent': 1,
#           'hang_agent': 2,
#           'believe_agent': 1,
#           'eye_agent': 1,
#           'hurt_agent': 1,
#           'chew_agent': 1,
#           'occur_agent': 1,
#           'clung_agent': 1,
#           'rouse_agent': 1,
#           'resolve_agent': 1,
#           'dream_agent': 1,
#           'consist_agent': 1,
#           'build_agent': 1,
#           'hug_agent': 1,
#           'exclaimed_agent': 1,
#           'discourage_agent': 1,
#           'shall_agent': 1,
#           'dawn_agent': 1,
#           'fetch_agent': 1,
#           '"_agent': 2,
#           'happen_agent': 2,
#           'gratify_agent': 1,
#           'madden_agent': 1,
#           'reckon_agent': 1,
#           'venture_agent': 1,
#           'expect_agent': 1,
#           'sigh_agent': 1,
#           'fail_agent': 1,
#           'contemplate_agent': 1,
#           'sponge_agent': 1,
#           'increase_agent': 1,
#           'may_agent': 1,
#           'help_agent': 1,
#           'prove_agent': 1,
#           'swear_agent': 1,
#           'depose_agent': 1,
#           'hide_agent': 1,
#           'belong_agent': 1,
#           'in_agent': 1,
#           'carry_agent': 1,
#           'leap_agent': 1,
#           'track_agent': 1,
#           'present_agent': 1,
#           'grow_agent': 1,
#           'would_agent': 2,
#           'hunt_agent': 1,
#           'fit_agent': 1,
#           'spring_agent': 1,
#           'collect_agent': 1,
#           'work_agent': 1,
#           'used_agent': 1,
#           'confound_patient': 1,
#           'sew_patient': 1,
#           'remember_patient': 1,
#           'like_patient': 2,
#           'step_patient': 1,
#           'mean_patient': 1,
#           'reckon_patient': 4,
#           'bear_patient': 1,
#           'picture_patient': 1,
#           'manage_patient': 1,
#           'tackle_patient': 2,
#           'smooth_patient': 1,
#           'eat_patient': 1,
#           'will_patient': 1,
#           'eye_patient': 2,
#           'pull_patient': 1,
#           'view_patient': 1,
#           'whisper_patient': 2,
#           'strike_patient': 1,
#           'determined_patient': 1,
#           'occur_patient': 1,
#           'bet_patient': 1,
#           'depart_patient': 1,
#           'sob_patient': 1,
#           'moan_patient': 1,
#           'repeat_patient': 1,
#           'dream_patient': 1,
#           'deem_patient': 1,
#           'taste_patient': 1,
#           'signify_patient': 1,
#           'finish_patient': 2,
#           'dawn_patient': 1,
#           'help_patient': 1,
#           'expect_patient': 1,
#           'consider_patient': 1,
#           'allow_patient': 1,
#           'save_patient': 2,
#           'understand_patient': 1,
#           'leg_patient': 1,
#           'use_patient': 1,
#           'decide_patient': 1,
#           'tie_patient': 1,
#           'kill_patient': 1,
#           '"_patient': 1,
#           'walk_patient': 1,
#           'track_patient': 1,
#           'present_patient': 1,
#           'scoop_patient': 1,
#           'float_patient': 1,
#           'haul_patient': 1,
#           'mind_patient': 1,
#           'collect_patient': 1,
#           'work_patient': 1,
#           'pray_patient': 1}),
#  'huck finn\taka they, myself\t(Mark Twain___The Adventures of Tom Sawyer, Complete)': Counter({'by_agent': 1,
#           'inquire_agent': 1,
#           'scan_agent': 1,
#           'flash_agent': 1,
#           'join_agent': 1,
#           'pick_agent': 1,
#           'kneel_agent': 1,
#           'tiptoe_agent': 1,
#           'discomforte_agent': 1,
#           'bear_agent': 2,
#           'hope_agent': 1,
#           'recollect_agent': 2,
#           'throw_agent': 1,
#           'waver_agent': 1,
#           'suffer_agent': 1,
#           '--sometime_agent': 1,
#           'lean_agent': 1,
#           'drop_agent': 2,
#           'urge_agent': 1,
#           'wrung_agent': 1,
#           'conclude_agent': 1,
#           'prove_agent': 1,
#           'remain_agent': 1,
#           'burst_agent': 1,
#           'shudder_agent': 1,
#           'occur_agent': 1,
#           'outweigh_agent': 1,
#           'wait_agent': 2,
#           'close_agent': 1,
#           'slacken_agent': 1,
#           'shoot_agent': 1,
#           'remember_agent': 1,
#           'accompany_agent': 1,
#           'hide_agent': 1,
#           'spring_agent': 2,
#           'kill_agent': 1,
#           'sink_agent': 1,
#           'suggest_agent': 2,
#           'jump_agent': 1,
#           'lead_agent': 1,
#           'learn_agent': 2,
#           'search_agent': 2,
#           'stare_agent': 1,
#           'follow_agent': 1,
#           'bind_agent': 1,
#           'about_agent': 1,
#           "'s_agent": 1,
#           'introduce_agent': 1,
#           'breakfast_agent': 1,
#           'route_agent': 1,
#           'pick_patient': 1,
#           'inform_patient': 1,
#           'waver_patient': 1,
#           'snatch_patient': 1,
#           'bury_patient': 1,
#           'close_patient': 1,
#           'spring_patient': 1,
#           'stagger_patient': 1,
#           'eye_patient': 1,
#           'work_patient': 1,
#           'learn_patient': 1,
#           'admit_patient': 1,
#           'drown_patient': 1,
#           'believe_patient': 1,
#           'introduce_patient': 1,
#           'shut_patient': 1,
#           'route_patient': 1}),
#  "becky\taka rebecca thatcher, becky's candle\t(Mark Twain___The Adventures of Tom Sawyer, Complete)": Counter({'resist_agent': 1,
#           'bend_agent': 1,
#           'spring_agent': 1,
#           'strike_agent': 1,
#           'listen_agent': 1,
#           'what_agent': 1,
#           'carry_agent': 1,
#           'soliloquize_agent': 1,
#           'choke_agent': 1,
#           'break_agent': 2,
#           'arrive_agent': 1,
#           'observe_agent': 2,
#           'gratify_agent': 1,
#           'tremble_agent': 1,
#           'rouse_agent': 2,
#           'madden_agent': 1,
#           'resume_agent': 1,
#           'follow_agent': 1,
#           'grow_agent': 2,
#           'lose_agent': 1,
#           'drop_agent': 1,
#           'change_agent': 1,
#           'resolve_agent': 1,
#           'notice_agent': 1,
#           'glance_agent': 1,
#           'snatch_agent': 1,
#           'thrust_agent': 1,
#           'stamp_agent': 1,
#           'expect_agent': 1,
#           'suppose_agent': 1,
#           'sink_agent': 2,
#           'tease_agent': 1,
#           'reflect_agent': 1,
#           'respond_agent': 1,
#           'seize_agent': 1,
#           'watch_agent': 1,
#           'understand_agent': 2,
#           'economize_agent': 1,
#           'bear_agent': 1,
#           'wake_agent': 1,
#           'smile_agent': 1,
#           'divide_agent': 1,
#           'pale_agent': 1,
#           'suggest_agent': 1,
#           'show_agent': 1,
#           'describe_agent': 1,
#           'clasp_patient': 1,
#           'struggle_patient': 1,
#           'carry_patient': 1,
#           'break_patient': 1,
#           'pretend_patient': 1,
#           'tremble_patient': 1,
#           'spy_patient': 1,
#           'Alfred_patient': 1,
#           'drop_patient': 1,
#           'glance_patient': 1,
#           'seize_patient': 1,
#           'refuse_patient': 1,
#           'describe_patient': 1})}

# %%
charTexts
# Out:
# [['hesitate_agent',
#   'hesitate_agent',
#   'breathe_agent',
#   'raise_agent',
#   'raise_agent',
#   'back_agent',
#   'explain_agent',
#   'explain_agent',
#   'smile_agent',
#   'smile_agent',
#   'smile_agent',
#   'smile_agent',
#   'smile_agent',
#   'smile_agent',
#   'smile_agent',
#   'urge_agent',
#   'urge_agent',
#   'detect_agent',
#   'observe_agent',
#   'drop_agent',
#   'spring_agent',
#   'spring_agent',
#   'spring_agent',
#   'examine_agent',
#   'believe_agent',
#   'believe_agent',
#   'believe_agent',
#   'believe_agent',
#   'unlock_agent',
#   'hazard_agent',
#   'succeed_agent',
#   'wait_agent',
#   'wait_agent',
#   'send_agent',
#   'hurry_agent',
#   'touch_agent',
#   'touch_agent',
#   'touch_agent',
#   'damage_agent',
#   'float_agent',
#   'hope_agent',
#   'hope_agent',
#   'watch_agent',
#   'watch_agent',
#   'leap_agent',
#   'leap_agent',
#   'trail_agent',
#   'follow_agent',
#   'follow_agent',
#   'follow_agent',
#   'follow_agent',
#   'follow_agent',
#   'creep_agent',
#   'time_agent',
#   'time_agent',
#   'surround_agent',
#   'guess_agent',
#   'tear_agent',
#   'search_agent',
#   'show_agent',
#   'show_agent',
#   'drag_agent',
#   'cover_agent',
#   'issue_agent',
#   'seek_agent',
#   'lay_agent',
#   'lay_agent',
#   'swift_agent',
#   'wipe_agent',
#   'choke_agent',
#   'revert_agent',
#   'point_agent',
#   'point_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'lead_agent',
#   'lead_agent',
#   'scarce_agent',
#   'consent_agent',
#   'notice_agent',
#   'nod_agent',
#   'nod_agent',
#   'nod_agent',
#   'note_agent',
#   'understand_agent',
#   'laugh_agent',
#   'laugh_agent',
#   'shake_agent',
#   'eye_agent',
#   'eye_agent',
#   'lift_agent',
#   'exclaim_agent',
#   'insist_agent',
#   'remind_agent',
#   'catch_agent',
#   'trust_agent',
#   'hold_agent',
#   'harm_agent',
#   'murmur_agent',
#   'meet_agent',
#   'brace_agent',
#   'clasp_agent',
#   'whimper_agent',
#   'step_agent',
#   'step_agent',
#   'place_agent',
#   'place_agent',
#   'seat_agent',
#   'cause_agent',
#   'horrify_agent',
#   'curse_agent',
#   'realize_agent',
#   'realize_agent',
#   'flood_agent',
#   'halt_agent',
#   'halt_agent',
#   'like_agent',
#   'charge_agent',
#   'pay_agent',
#   'remain_agent',
#   'sleep_agent',
#   'sleep_agent',
#   'squat_agent',
#   'disappear_agent',
#   'strain_agent',
#   'shout_agent',
#   'read_agent',
#   'relate_agent',
#   'shrug_agent',
#   'enter_agent',
#   'enter_agent',
#   'strike_agent',
#   'learn_agent',
#   'centre_agent',
#   'appear_agent',
#   'indication_agent',
#   'discard_agent',
#   'greet_agent',
#   'invite_agent',
#   'light_agent',
#   'suffice_agent',
#   'walk_agent',
#   'bless_agent',
#   'fumble_agent',
#   'grasp_agent',
#   'grasp_agent',
#   'bring_agent',
#   'bang_agent',
#   'sight_agent',
#   'race_agent',
#   'hasten_agent',
#   'hasten_agent',
#   'recourse_agent',
#   'graze_agent',
#   'distance_agent',
#   'group_patient',
#   'assist_patient',
#   'betray_patient',
#   'succeed_patient',
#   'carry_patient',
#   'tear_patient',
#   'show_patient',
#   'explain_patient',
#   'swift_patient',
#   'touch_patient',
#   'choke_patient',
#   'hurt_patient',
#   'leap_patient',
#   'whisper_patient',
#   'lead_patient',
#   'watch_patient',
#   'exclaim_patient',
#   'exclaim_patient',
#   'brace_patient',
#   'place_patient',
#   'seat_patient',
#   'strike_patient',
#   'dumbfound_patient',
#   'cause_patient',
#   'curse_patient',
#   'realize_patient',
#   'overpower_patient',
#   'drag_patient',
#   'squat_patient',
#   'recognize_patient',
#   'shout_patient',
#   'relate_patient',
#   'discard_patient',
#   'admit_patient',
#   'repeat_patient',
#   'follow_patient',
#   'race_patient'],
#  ['repeat_agent',
#   'strike_agent',
#   'exclaim_agent',
#   'steal_agent',
#   'steal_agent',
#   'shake_agent',
#   'shake_agent',
#   'sheer_agent',
#   'land_agent',
#   'land_agent',
#   'raise_agent',
#   'seek_agent',
#   'seek_agent',
#   'offer_agent',
#   'cease_agent',
#   'lead_agent',
#   'lead_agent',
#   'lead_agent',
#   'command_agent',
#   'command_agent',
#   'ride_agent',
#   'reveal_agent',
#   'miss_agent',
#   'tear_agent',
#   'shut_agent',
#   'catch_agent',
#   'catch_agent',
#   'continue_agent',
#   'continue_agent',
#   'drag_agent',
#   'drag_agent',
#   'issue_agent',
#   'detect_agent',
#   'note_agent',
#   'mean_agent',
#   'disperse_agent',
#   'carry_agent',
#   'murmur_agent',
#   'descend_agent',
#   'step_agent',
#   'leap_agent',
#   'advance_agent',
#   'commence_agent',
#   'growl_agent',
#   'guess_agent',
#   'guess_agent',
#   'with_agent',
#   'glance_agent',
#   'spring_agent',
#   'die_agent',
#   'await_agent',
#   'fear_agent',
#   'loose_agent',
#   'pause_agent',
#   '"_agent',
#   'ah_agent',
#   'appear_agent',
#   'muse_agent',
#   'recognize_agent',
#   'recognize_agent',
#   'centre_agent',
#   'exist_agent',
#   'taunt_agent',
#   'attempt_agent',
#   'push_agent',
#   'bend_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'flash_agent',
#   'chide_agent',
#   'overpower_agent',
#   'hate_agent',
#   'halt_agent',
#   'occupy_agent',
#   'compel_agent',
#   'realize_agent',
#   'realize_agent',
#   'trapping_agent',
#   'believe_agent',
#   'admit_agent',
#   'conclude_agent',
#   'helpless_agent',
#   'despatch_agent',
#   'smile_agent',
#   'slay_agent',
#   'choose_agent',
#   'learn_agent',
#   'blanch_agent',
#   'nod_agent',
#   'bear_agent',
#   'join_agent',
#   'hasten_agent',
#   'distance_agent',
#   'bring_agent',
#   'mutter_patient',
#   'repeat_patient',
#   'exclaim_patient',
#   'mistaken_patient',
#   'tear_patient',
#   'seek_patient',
#   'detect_patient',
#   'carry_patient',
#   'carry_patient',
#   'leap_patient',
#   'advance_patient',
#   'lead_patient',
#   'growl_patient',
#   'picture_patient',
#   'appear_patient',
#   'command_patient',
#   'recognize_patient',
#   'chide_patient',
#   'overpower_patient',
#   'hate_patient',
#   'compel_patient',
#   'realize_patient',
#   'centre_patient',
#   'believe_patient',
#   'despatch_patient',
#   'choose_patient'],
#  ['mutter_agent',
#   'throw_agent',
#   'waste_agent',
#   'snap_agent',
#   'bow_agent',
#   'narrow_agent',
#   'approach_agent',
#   'sweep_agent',
#   'whisper_agent',
#   'bent_agent',
#   'measure_agent',
#   'smile_agent',
#   'smile_agent',
#   'remark_agent',
#   'close_agent',
#   'switch_agent',
#   'instant_agent',
#   'raise_agent',
#   'mount_agent',
#   'drag_agent',
#   'drag_agent',
#   'remove_agent',
#   'remove_agent',
#   'study_agent',
#   'this_agent',
#   'replace_agent',
#   'touch_agent',
#   'lose_agent',
#   'search_agent',
#   'leap_agent',
#   'leap_agent',
#   'spring_agent',
#   'loom_agent',
#   'yawn_agent',
#   'hesitate_agent',
#   'steal_agent',
#   'lead_agent',
#   'hold_agent',
#   'place_agent',
#   'perfect_agent',
#   'conclude_agent',
#   'shake_agent',
#   'shake_agent',
#   'commence_agent',
#   'eye_agent',
#   'eye_agent',
#   'scream_agent',
#   'exclaim_agent',
#   'restrain_agent',
#   'meet_agent',
#   'swear_agent',
#   'plan_agent',
#   'watch_agent',
#   'charge_agent',
#   'swing_agent',
#   'permit_agent',
#   'growl_agent',
#   'need_agent',
#   'form_agent',
#   'drop_agent',
#   'battle_agent',
#   'arise_agent',
#   'withstand_agent',
#   'consist_agent',
#   'strike_patient',
#   'snap_patient',
#   'bring_patient',
#   'snatch_patient',
#   'snatch_patient',
#   'switch_patient',
#   'head_patient',
#   'touch_patient',
#   'discover_patient',
#   'penetrate_patient',
#   'place_patient',
#   'miss_patient',
#   'catch_patient',
#   'perfect_patient',
#   'conclude_patient',
#   'growl_patient',
#   'repeat_patient',
#   'throw_patient',
#   'eye_patient',
#   'exclaim_patient',
#   'bespoke_patient',
#   'meet_patient',
#   'watch_patient',
#   'emerge_patient',
#   'discard_patient',
#   'permit_patient',
#   'deny_patient',
#   'pursue_patient',
#   'equip_patient'],
#  ['spring_agent',
#   'spring_agent',
#   'clutch_agent',
#   'youth_agent',
#   'leap_agent',
#   'leap_agent',
#   'leap_agent',
#   'shrug_agent',
#   'direct_agent',
#   'trust_agent',
#   'defend_agent',
#   'die_agent',
#   'throw_agent',
#   'kill_agent',
#   'deny_agent',
#   'glower_agent',
#   'dare_agent',
#   'occur_agent',
#   'exclaim_agent',
#   'withdraw_agent',
#   'chance_agent',
#   'crush_agent',
#   'heart_agent',
#   'recall_agent',
#   'cool_agent',
#   'enter_agent',
#   'hate_agent',
#   'wheel_agent',
#   'summon_agent',
#   'nod_agent',
#   'conclude_agent',
#   'hesitate_agent',
#   'snatch_agent',
#   'doubt_agent',
#   'seek_agent',
#   'elude_agent',
#   'mean_agent',
#   'race_agent',
#   'scarce_agent',
#   'round_agent',
#   'pen_agent',
#   'whisper_agent',
#   'fight_agent',
#   'show_agent',
#   'clutch_patient',
#   'narrow_patient',
#   'shrug_patient',
#   'defend_patient',
#   'perish_patient',
#   'rush_patient',
#   'hand_patient',
#   'fill_patient',
#   'need_patient',
#   'choose_patient',
#   'help_patient',
#   'enter_patient',
#   'hold_patient',
#   'discover_patient'],
#  ['notice_agent',
#   'stride_agent',
#   'work_agent',
#   'seek_agent',
#   'bow_agent',
#   'reappear_agent',
#   'closet_agent',
#   'hurry_agent',
#   'stroll_agent',
#   'watch_agent',
#   'watch_agent',
#   'encounter_agent',
#   'tremble_agent',
#   'tremble_agent',
#   'believe_agent',
#   'hope_agent',
#   'hope_agent',
#   'scream_agent',
#   'fasten_agent',
#   'live_agent',
#   'conquer_agent',
#   'constitute_agent',
#   'eat_agent',
#   'seat_agent',
#   'scarce_agent',
#   'wing_agent',
#   'stoop_agent',
#   'glance_agent',
#   'learn_agent',
#   'deny_agent',
#   'battle_agent',
#   'graze_agent',
#   'catch_agent',
#   'warn_patient',
#   'notice_patient',
#   'offer_patient',
#   'bring_patient',
#   'arouse_patient',
#   'land_patient',
#   'cease_patient',
#   'lead_patient',
#   'believe_patient',
#   'chance_patient',
#   'halt_patient',
#   'lose_patient',
#   'seek_patient',
#   'follow_patient',
#   'conquer_patient',
#   'discover_patient',
#   'intercept_patient',
#   'save_patient'],
#  ['touch_agent',
#   'touch_agent',
#   'plug_agent',
#   'complain_agent',
#   'observe_agent',
#   'observe_agent',
#   'observe_agent',
#   'interest_agent',
#   'announce_agent',
#   'slip_agent',
#   'demand_agent',
#   'chance_agent',
#   'chance_agent',
#   'conclude_agent',
#   'notice_agent',
#   'commence_agent',
#   'puff_agent',
#   'satisfy_agent',
#   'sabbee_agent',
#   'suppose_agent',
#   'suppose_agent',
#   'hug_agent',
#   'succeed_agent',
#   'succeed_agent',
#   'tarry_agent',
#   'justify_agent',
#   'withdraw_agent',
#   'TABLET_agent',
#   'TABLET_agent',
#   'terrify_agent',
#   'symbolize_agent',
#   'read_agent',
#   'read_agent',
#   'Woe_agent',
#   'strike_agent',
#   'redeem_agent',
#   'express_agent',
#   'own_agent',
#   'use_agent',
#   'carry_agent',
#   'carry_agent',
#   'button_agent',
#   'last_agent',
#   'flourish_agent',
#   'revolve_agent',
#   'breathe_agent',
#   'present_agent',
#   'blame_agent',
#   'expect_agent',
#   'word_agent',
#   'state_agent',
#   'yield_agent',
#   'gather_agent',
#   'mount_agent',
#   'spoil_agent',
#   'proceed_agent',
#   'rank_agent',
#   'depend_agent',
#   'live_agent',
#   'live_agent',
#   'form_agent',
#   'fed_agent',
#   'range_agent',
#   'shake_agent',
#   'for_agent',
#   'for_agent',
#   'plant_agent',
#   'reveal_agent',
#   'gain_agent',
#   'left_agent',
#   'storm_agent',
#   'troop_agent',
#   'question_agent',
#   'deny_agent',
#   'deny_agent',
#   'stove_agent',
#   'apply_agent',
#   'substantiate_agent',
#   'stretch_agent',
#   'prepare_agent',
#   'strange_agent',
#   'swell_agent',
#   'swell_agent',
#   'denote_agent',
#   'grow_agent',
#   'grow_agent',
#   'grow_agent',
#   'descry_agent',
#   'serve_agent',
#   'need_agent',
#   'admit_agent',
#   'conceive_agent',
#   'love_agent',
#   'affect_agent',
#   'church_agent',
#   'mix_agent',
#   'rush_agent',
#   'open_agent',
#   'pause_agent',
#   'doze_agent',
#   'employ_agent',
#   'lift_agent',
#   'carve_agent',
#   'dash_agent',
#   'swam_agent',
#   'swam_agent',
#   'elevate_agent',
#   'tug_agent',
#   'advance_agent',
#   'freeze_agent',
#   'blow_agent',
#   'clothe_agent',
#   'hint_agent',
#   'guess_agent',
#   'act_agent',
#   'drag_agent',
#   'furnish_agent',
#   'illustrate_agent',
#   'occur_agent',
#   'insult_agent',
#   'declare_agent',
#   'hide_agent',
#   'secrete_agent',
#   'assume_agent',
#   'stick_agent',
#   'point_agent',
#   'shoot_agent',
#   'shoot_agent',
#   'sink_agent',
#   'die_agent',
#   'disclose_agent',
#   'accommodate_agent',
#   'evince_agent',
#   'evince_agent',
#   'evince_agent',
#   'level_agent',
#   'mind_agent',
#   'spout_agent',
#   'dodge_agent',
#   'oh_agent',
#   'knit_agent',
#   'curve_agent',
#   'more_agent',
#   'bend_agent',
#   'resolve_agent',
#   'abandon_agent',
#   'says--"hand_agent',
#   'seize_agent',
#   'seize_agent',
#   'thrust_agent',
#   'thrust_agent',
#   'breast_agent',
#   'consist_agent',
#   'belong_agent',
#   'consume_agent',
#   'burn_agent',
#   'replace_agent',
#   'show_agent',
#   'think.--is_agent',
#   'bestir_agent',
#   'behove_agent',
#   'alter_agent',
#   'inquire_agent',
#   'despise_agent',
#   'fail_agent',
#   'receive_agent',
#   'receive_agent',
#   'lash_agent',
#   'account_agent',
#   'pinch_agent',
#   'forthwith_agent',
#   'marshal_agent',
#   'shoulder_agent',
#   'entreat_agent',
#   'murmur_agent',
#   'roll_agent',
#   'toil_agent',
#   'regard_agent',
#   'remain_agent',
#   'ponder_agent',
#   'smack_agent',
#   'swing_agent',
#   'avoid_agent',
#   'laugh_agent',
#   'stay_agent',
#   'slouch_agent',
#   'dart_agent',
#   'dart_agent',
#   'desolation_agent',
#   'blind_agent',
#   'surpass_agent',
#   'spill_agent',
#   'prick_agent',
#   'retain_agent',
#   'remind_agent',
#   'punish_agent',
#   'soever_agent',
#   'lord_patient',
#   'assure_patient',
#   'warm_patient',
#   'raise_patient',
#   'chance_patient',
#   'commence_patient',
#   'commence_patient',
#   'commence_patient',
#   'puff_patient',
#   'succeed_patient',
#   'succeed_patient',
#   'wash_patient',
#   'don_patient',
#   'justify_patient',
#   'terrify_patient',
#   'accompany_patient',
#   'accompany_patient',
#   'read_patient',
#   'grow_patient',
#   'grow_patient',
#   'redeem_patient',
#   'thaw_patient',
#   'propose_patient',
#   'lend_patient',
#   'catch_patient',
#   'discover_patient',
#   'push_patient',
#   'push_patient',
#   'furl_patient',
#   'sally_patient',
#   'seat_patient',
#   'rub_patient',
#   'aye_patient',
#   'nothing_patient',
#   'dare_patient',
#   'visit_patient',
#   'attend_patient',
#   'remove_patient',
#   'present_patient',
#   'ascribe_patient',
#   'toss_patient',
#   'hiss_patient',
#   'stick_patient',
#   'stick_patient',
#   'define_patient',
#   'suppose_patient',
#   'suppose_patient',
#   'distil_patient',
#   'mount_patient',
#   'retain_patient',
#   'receive_patient',
#   'SAILOR_patient',
#   'for_patient',
#   'for_patient',
#   'plant_patient',
#   'reveal_patient',
#   'smote_patient',
#   'pile_patient',
#   'awake_patient',
#   'aught_patient',
#   'invest_patient',
#   'efface_patient',
#   'permit_patient',
#   'deny_patient',
#   'question_patient',
#   'observe_patient',
#   'consist_patient',
#   'withdraw_patient',
#   'load_patient',
#   'pull_patient',
#   'swell_patient',
#   'descry_patient',
#   'serve_patient',
#   'hailed--"Ahoy_patient',
#   'carry_patient',
#   'occur_patient',
#   'occur_patient',
#   'cruise_patient',
#   'bear_patient',
#   'affect_patient',
#   'command_patient',
#   'command_patient',
#   'purge_patient',
#   'mix_patient',
#   'open_patient',
#   'collar_patient',
#   'murder_patient',
#   'calculate_patient',
#   'lift_patient',
#   'bring_patient',
#   'cut_patient',
#   'anchor_patient',
#   'swear_patient',
#   'rest_patient',
#   'enable_patient',
#   'swam_patient',
#   'grant_patient',
#   'encourage_patient',
#   'overcome_patient',
#   'limp_patient',
#   'box_patient',
#   'guess_patient',
#   'sell_patient',
#   'insert_patient',
#   'dispirit_patient',
#   'unhinge_patient',
#   'drag_patient',
#   'drag_patient',
#   'thrust_patient',
#   'thrust_patient',
#   'deify_patient',
#   'hide_patient',
#   'assume_patient',
#   'lose_patient',
#   'lose_patient',
#   'level_patient',
#   'breathe_patient',
#   'dodge_patient',
#   'deplore_patient',
#   'dissect_patient',
#   'more_patient',
#   'purchase_patient',
#   'resolve_patient',
#   'insinuate_patient',
#   'abandon_patient',
#   'says--"hand_patient',
#   'seize_patient',
#   'seize_patient',
#   'evince_patient',
#   'consume_patient',
#   'hold_patient',
#   'drop_patient',
#   'drop_patient',
#   'continue_patient',
#   'roar_patient',
#   'behove_patient',
#   'behove_patient',
#   'compress_patient',
#   'treat_patient',
#   'inquire_patient',
#   'publish_patient',
#   'prepare_patient',
#   'forthwith_patient',
#   'lay_patient',
#   'use_patient',
#   'exclaim_patient',
#   'add_patient',
#   'hand_patient',
#   'hope_patient',
#   'beget_patient',
#   'nail_patient',
#   'caulk_patient',
#   'pay_patient',
#   'like_patient',
#   'unwind_patient',
#   'patch_patient',
#   'save_patient',
#   'allude_patient',
#   'declare_patient',
#   'blind_patient',
#   'cozening_patient',
#   'flow_patient',
#   'spill_patient',
#   'dash_patient',
#   'snap_patient',
#   'so_patient',
#   'remind_patient',
#   'rear_patient'],
#  ['hang_agent',
#   'conclude_agent',
#   'increase_agent',
#   'blend_agent',
#   'lead_agent',
#   'write_agent',
#   'oscillate_agent',
#   'raise_agent',
#   'sally_agent',
#   'pay_agent',
#   'groan_agent',
#   'whale_agent',
#   'whale_agent',
#   'assert_agent',
#   'resemble_agent',
#   'contradict_agent',
#   'flash_agent',
#   'consider_agent',
#   'split_agent',
#   'fail_agent',
#   'assume_agent',
#   'assume_agent',
#   'diffuse_agent',
#   'fetch_agent',
#   'will_agent',
#   'confound_agent',
#   'sting_agent',
#   'drill_agent',
#   'haunt_agent',
#   'lower_agent',
#   'swam_agent',
#   'arch_agent',
#   'question_agent',
#   'deny_agent',
#   'solve_agent',
#   '"_agent',
#   'care_agent',
#   'distant_agent',
#   'fly_agent',
#   'argue_agent',
#   'reign_agent',
#   'end_agent',
#   'diminish_agent',
#   'believe_agent',
#   'constrain_agent',
#   'mince_agent',
#   'display_agent',
#   'hit_agent',
#   'subside_agent',
#   'gaze_agent',
#   'continue_agent',
#   'continue_agent',
#   'dart_agent',
#   'dart_agent',
#   'dart_agent',
#   'happen_agent',
#   'box_agent',
#   'lose_agent',
#   'float_agent',
#   'straightway_agent',
#   'push_agent',
#   'coil_agent',
#   'prove_agent',
#   'yield_agent',
#   'occur_agent',
#   'occur_agent',
#   'remain_agent',
#   'remain_agent',
#   'thrust_agent',
#   'aver_agent',
#   'extract_agent',
#   'gather_agent',
#   'breathe_agent',
#   'breathe_agent',
#   'overhang_agent',
#   'hail_agent',
#   'tend_agent',
#   'rush_agent',
#   'beheld_agent',
#   'mention_agent',
#   'contain_agent',
#   'contain_agent',
#   'reserve_agent',
#   'evince_agent',
#   'rescue_agent',
#   'feed_agent',
#   'preserve_agent',
#   'talk_agent',
#   'talk_agent',
#   'chance_agent',
#   'ECUADOR_agent',
#   'was--_agent',
#   'resolve_agent',
#   'desire_agent',
#   'declare_agent',
#   'shade_agent',
#   'yet_agent',
#   'abide_agent',
#   'forge_agent',
#   'supply_agent',
#   'murmur_agent',
#   'conduct_agent',
#   'work_agent',
#   'work_agent',
#   'eye_agent',
#   'point_agent',
#   'bring_agent',
#   'needs_agent',
#   'swallow_agent',
#   'arrange_agent',
#   'snatch_agent',
#   'domineer_agent',
#   'flow_agent',
#   'reveal_agent',
#   'boom_agent',
#   'bravadoe_agent',
#   'cross_agent',
#   'drag_agent',
#   'dash_agent',
#   'peck_agent',
#   'glide_agent',
#   'last_agent',
#   'cast_agent',
#   'roll_agent',
#   'collapse_agent',
#   'lead_patient',
#   'hang_patient',
#   'help_patient',
#   'use_patient',
#   'use_patient',
#   'blend_patient',
#   'approach_patient',
#   'write_patient',
#   'appal_patient',
#   'invite_patient',
#   'march_patient',
#   'fetch_patient',
#   'groan_patient',
#   'appear_patient',
#   'depend_patient',
#   'confess_patient',
#   'grant_patient',
#   'bear_patient',
#   'contradict_patient',
#   'split_patient',
#   'restrict_patient',
#   'fail_patient',
#   'forget_patient',
#   'raise_patient',
#   'raise_patient',
#   'raise_patient',
#   'chase_patient',
#   'thy_patient',
#   'reckon_patient',
#   'twig_patient',
#   'twig_patient',
#   'jig_patient',
#   'Bang_patient',
#   'rig_patient',
#   'well_patient',
#   'swam_patient',
#   'pit_patient',
#   'storm_patient',
#   'crew_patient',
#   'shake_patient',
#   'question_patient',
#   'that_patient',
#   'solve_patient',
#   'solve_patient',
#   '"_patient',
#   'swim_patient',
#   'live_patient',
#   'live_patient',
#   'care_patient',
#   'refine_patient',
#   'free_patient',
#   'steady_patient',
#   'present_patient',
#   'argue_patient',
#   'believe_patient',
#   'believe_patient',
#   'believe_patient',
#   'constrain_patient',
#   'arrive_patient',
#   'evince_patient',
#   'evince_patient',
#   'mercy_patient',
#   'manner_patient',
#   'assign_patient',
#   'include_patient',
#   'consist_patient',
#   'straighten_patient',
#   'say"--holde_patient',
#   'hold_patient',
#   'box_patient',
#   'consider_patient',
#   'pause_patient',
#   'Shakers_patient',
#   'sigh_patient',
#   'clutch_patient',
#   'coil_patient',
#   'suppose_patient',
#   'suppose_patient',
#   'lodge_patient',
#   'declare_patient',
#   'declare_patient',
#   'strike_patient',
#   'place_patient',
#   'assert_patient',
#   'extract_patient',
#   'assume_patient',
#   'hide_patient',
#   'tend_patient',
#   'attach_patient',
#   'meet_patient',
#   'regard_patient',
#   'break_patient',
#   'reserve_patient',
#   'cut_patient',
#   'stagger_patient',
#   'proceed_patient',
#   'lengthwise_patient',
#   'revere_patient',
#   'talk_patient',
#   'all_patient',
#   'resolve_patient',
#   'measure_patient',
#   'bless_patient',
#   'weave_patient',
#   'gain_patient',
#   'desire_patient',
#   'drive_patient',
#   'die_patient',
#   'bring_patient',
#   'catch_patient',
#   'mark_patient',
#   'combine_patient',
#   'swallow_patient',
#   'arrange_patient',
#   'work_patient',
#   'stay_patient',
#   'head_patient',
#   'surpass_patient',
#   'thrill_patient',
#   'lay_patient',
#   'dawn_patient',
#   'blow_patient',
#   'conquer_patient',
#   'muttered--"whether_patient'],
#  ['name_agent',
#   'whim_agent',
#   'bye_agent',
#   'ye_agent',
#   'beget_agent',
#   'visit_agent',
#   'attend_agent',
#   'indeed_agent',
#   'affect_agent',
#   'for_agent',
#   'for_agent',
#   'advance_agent',
#   'soothe_agent',
#   'pace_agent',
#   'pace_agent',
#   'pace_agent',
#   'swing_agent',
#   'preside_agent',
#   'receive_agent',
#   'receive_agent',
#   'forbid_agent',
#   'form_agent',
#   'assemble_agent',
#   'continue_agent',
#   'summon_agent',
#   'cried:--_agent',
#   'rub_agent',
#   'resume_agent',
#   'laugh_agent',
#   'snort_agent',
#   'order_agent',
#   'order_agent',
#   'range_agent',
#   'range_agent',
#   'rush_agent',
#   'disperse_agent',
#   'cabin_agent',
#   'embattle_agent',
#   'pit_agent',
#   'pile_agent',
#   'storm_agent',
#   'succeed_agent',
#   'sail_agent',
#   'sail_agent',
#   'suspend_agent',
#   'thread_agent',
#   'hope_agent',
#   'hope_agent',
#   'permit_agent',
#   'mutter_agent',
#   'seek_agent',
#   'sleep_agent',
#   'use_agent',
#   'observe_agent',
#   'throw_agent',
#   'settle_agent',
#   'leap_agent',
#   'allusion_agent',
#   'solicit_agent',
#   'command_agent',
#   'walk_agent',
#   'swore_agent',
#   'manifest_agent',
#   'hailed--"Ahoy_agent',
#   'perceive_agent',
#   'perceive_agent',
#   'swam_agent',
#   'issue_agent',
#   'evince_agent',
#   'betray_agent',
#   'elapse_agent',
#   'pause_agent',
#   'demand_agent',
#   'wager)--aye_agent',
#   'chance_agent',
#   'purpose_agent',
#   'sweep_agent',
#   'touch_agent',
#   'touch_agent',
#   'revolve_agent',
#   'and_agent',
#   'mould_agent',
#   'retire_agent',
#   'relate_agent',
#   'shoot_agent',
#   'nail_agent',
#   'forget_agent',
#   'light_agent',
#   'unattende_agent',
#   'bid_agent',
#   'pump_agent',
#   'seize_agent',
#   'seize_agent',
#   'snuff_agent',
#   'hammer_agent',
#   'slide_agent',
#   'slide_agent',
#   'fit_agent',
#   'exclaim_agent',
#   'remain_agent',
#   'vassal_agent',
#   'lurch_agent',
#   'escape_agent',
#   'close_agent',
#   'wave_agent',
#   'hurry_agent',
#   'allude_agent',
#   'beseech_agent',
#   'slouch_agent',
#   'clothe_agent',
#   'gaze_agent',
#   'gaze_agent',
#   'reveal_agent',
#   'rig_agent',
#   'hold_agent',
#   'hold_agent',
#   'lean_agent',
#   'drop_agent',
#   'avert_agent',
#   'cross_agent',
#   'cast_agent',
#   'cast_agent',
#   'gain_agent',
#   'discover_agent',
#   'yawn_agent',
#   'slip_agent',
#   'descry_agent',
#   'descry_agent',
#   'pay_agent',
#   'fasten_agent',
#   'ring_agent',
#   'lower_agent',
#   'snap_agent',
#   'hail_agent',
#   'catch_agent',
#   'drive_agent',
#   'rally_agent',
#   'shout_agent',
#   'glide_agent',
#   'curl_agent',
#   'dart_agent',
#   'smite_agent',
#   'clear_agent',
#   'use_patient',
#   'name_patient',
#   'reveal_patient',
#   'cherish_patient',
#   'enshrine_patient',
#   'indeed_patient',
#   'deputation_patient',
#   'Enter_patient',
#   'gritted_patient',
#   'gritted_patient',
#   'swing_patient',
#   'die_patient',
#   'pace_patient',
#   'pace_patient',
#   'mark_patient',
#   'repeat_patient',
#   'assemble_patient',
#   'shout_patient',
#   'rush_patient',
#   'embattle_patient',
#   'pit_patient',
#   'succeed_patient',
#   'crew_patient',
#   'follow_patient',
#   'hope_patient',
#   'permit_patient',
#   'mutter_patient',
#   'mutter_patient',
#   'mutter_patient',
#   'strip_patient',
#   'scorn_patient',
#   'observe_patient',
#   'range_patient',
#   'throw_patient',
#   'tear_patient',
#   'tear_patient',
#   'perceive_patient',
#   'evince_patient',
#   'chance_patient',
#   'sweep_patient',
#   'and_patient',
#   'hint_patient',
#   'bring_patient',
#   'roar_patient',
#   'belie_patient',
#   'bid_patient',
#   'murmur_patient',
#   'howl_patient',
#   'grasp_patient',
#   'approach_patient',
#   'seize_patient',
#   'seize_patient',
#   'allude_patient',
#   'discern_patient',
#   'cast_patient',
#   'fasten_patient',
#   'untouched_patient',
#   'girdle_patient',
#   'wilt_patient',
#   'away!"-crie_patient',
#   'hail_patient',
#   'glide_patient',
#   'roll_patient',
#   'clear_patient'],
#  ['account_agent',
#   'deep_agent',
#   'sea_agent',
#   'raise_agent',
#   'raise_agent',
#   'arrive_agent',
#   'chance_agent',
#   'continue_agent',
#   'checker_agent',
#   'kindle_agent',
#   'add_agent',
#   'add_agent',
#   'commence_agent',
#   'trouble_agent',
#   'emerge_agent',
#   'seek_agent',
#   'pause_agent',
#   'pause_agent',
#   'end_agent',
#   'show_agent',
#   'show_agent',
#   'comply_agent',
#   'jump_agent',
#   'nothing_agent',
#   'nothing_agent',
#   'rejoin_agent',
#   'word_agent',
#   'mutter_agent',
#   'flash_agent',
#   'kick_agent',
#   'deny_agent',
#   'resemble_agent',
#   'baleen_agent',
#   'comprise_agent',
#   'fail_agent',
#   'receive_agent',
#   'forbid_agent',
#   'rub_agent',
#   'resume_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'hang_agent',
#   'inhale_agent',
#   'kiss_agent',
#   'wrap_agent',
#   'rest_agent',
#   'sailor_agent',
#   'that_agent',
#   'circumnavigate_agent',
#   'write_agent',
#   'strip_agent',
#   'swell_agent',
#   'cut_agent',
#   'disable_agent',
#   'sway_agent',
#   'board_agent',
#   'for_agent',
#   'hold_agent',
#   'exchange_agent',
#   'meet_agent',
#   'grin_agent',
#   'govern_agent',
#   'suppose_agent',
#   'suppose_agent',
#   'command_agent',
#   'command_agent',
#   'declare_agent',
#   'bolt_agent',
#   'save_agent',
#   'revenge_agent',
#   'swam_agent',
#   'embark_agent',
#   'can_agent',
#   'publish_agent',
#   'publish_agent',
#   'churn_agent',
#   'smoke_agent',
#   'besides_agent',
#   'Bear_agent',
#   'demand_agent',
#   'announce_agent',
#   'earnestness_agent',
#   'open_agent',
#   'work_agent',
#   'jerk_agent',
#   'fringe_agent',
#   'elevate_agent',
#   'search_agent',
#   'proceed_agent',
#   'proceed_agent',
#   'accost_agent',
#   'stir_agent',
#   'furthermore_agent',
#   'hide_agent',
#   'derive_agent',
#   'bend_agent',
#   'line_agent',
#   'float_agent',
#   'contain_agent',
#   'love_agent',
#   'assail_agent',
#   'drop_agent',
#   'happen_agent',
#   'rescue_agent',
#   'stagger_agent',
#   'lengthwise_agent',
#   'sun_agent',
#   'cross_agent',
#   'thrust_agent',
#   'weigh_agent',
#   'lose_agent',
#   'perish_agent',
#   'inquire_agent',
#   'desire_agent',
#   'comfort_agent',
#   'beat_agent',
#   'steer_agent',
#   'but_agent',
#   'baulk_agent',
#   'endure_agent',
#   'eat_agent',
#   'rush_agent',
#   'pull_agent',
#   'remain_agent',
#   'equal_agent',
#   'travel_agent',
#   'foretell_agent',
#   'about_agent',
#   'sail_agent',
#   'tear_agent',
#   'soar_agent',
#   'visit_agent',
#   'rear_agent',
#   'parry_agent',
#   'arrive_patient',
#   'trouble_patient',
#   'emerge_patient',
#   'fear_patient',
#   'fellow_patient',
#   'deny_patient',
#   'capture_patient',
#   'distinguish_patient',
#   'incorporate_patient',
#   'fail_patient',
#   'forbid_patient',
#   'carry_patient',
#   'obstruct_patient',
#   'consider_patient',
#   'strip_patient',
#   'hail_patient',
#   'disable_patient',
#   'bolt_patient',
#   'moor_patient',
#   'wallow_patient',
#   'remind_patient',
#   'omit_patient',
#   'roll_patient',
#   'suppose_patient',
#   'engage_patient',
#   'announce_patient',
#   'announce_patient',
#   'publish_patient',
#   'open_patient',
#   'sink_patient',
#   'accost_patient',
#   'furthermore_patient',
#   'line_patient',
#   'evince_patient',
#   'him!--hit_patient',
#   'quit_patient',
#   'quit_patient',
#   'love_patient',
#   'assail_patient',
#   'drop_patient',
#   'rescue_patient',
#   'protect_patient',
#   'comfort_patient',
#   'beat_patient',
#   'cure_patient',
#   'spoil_patient',
#   'hold_patient',
#   'abide_patient',
#   '"_patient',
#   'rush_patient',
#   'command_patient',
#   'meet_patient',
#   'crowd_patient',
#   'lower_patient',
#   'parry_patient'],
#  ['blend_agent',
#   'possess_agent',
#   'bloom_agent',
#   'arrive_agent',
#   'notice_agent',
#   'offer_agent',
#   'touch_agent',
#   'part_agent',
#   'fly_agent',
#   'rush_agent',
#   'rush_agent',
#   'shut_agent',
#   'suppose_agent',
#   'state_agent',
#   'remain_agent',
#   'rub_agent',
#   'true_agent',
#   'dry_agent',
#   'retain_agent',
#   'say--_agent',
#   'submit_agent',
#   'hint_agent',
#   'pretend_agent',
#   'agree_agent',
#   'hunt_agent',
#   'occur_agent',
#   'occur_agent',
#   'raise_agent',
#   'muster_agent',
#   'methink_agent',
#   'cross_agent',
#   'plant_agent',
#   'swam_agent',
#   'aught_agent',
#   'consist_agent',
#   'live_agent',
#   'live_agent',
#   'scorn_agent',
#   'drop_agent',
#   'pull_agent',
#   'argue_agent',
#   'hail_agent',
#   'toss_agent',
#   'drown_agent',
#   'repeat_agent',
#   'collar_agent',
#   'furnish_agent',
#   'toil_agent',
#   'for_agent',
#   'afford_agent',
#   'break_agent',
#   'hit_agent',
#   'swallow_agent',
#   'exclude_agent',
#   'dispirit_agent',
#   'suspend_agent',
#   'suspend_agent',
#   'hold_agent',
#   'anoint_agent',
#   'spring_agent',
#   'insinuate_agent',
#   'provide_agent',
#   'squeeze_agent',
#   'watch_agent',
#   'wear_agent',
#   'enter_agent',
#   'wheel_agent',
#   'continue_agent',
#   'admeasurement_agent',
#   'conclude_agent',
#   'deem_agent',
#   'command_agent',
#   'roll_agent',
#   'impersonate_agent',
#   'fight_agent',
#   'strove_agent',
#   'launch_agent',
#   'something_agent',
#   'Truth_agent',
#   'visit_agent',
#   'remember_patient',
#   'puzzle_patient',
#   'proceed_patient',
#   'rush_patient',
#   'drop_patient',
#   'join_patient',
#   'resolve_patient',
#   'furnish_patient',
#   'recognise_patient',
#   'hunt_patient',
#   'assume_patient',
#   'rub_patient',
#   'muster_patient',
#   'hand_patient',
#   'cross_patient',
#   'swam_patient',
#   'read_patient',
#   'share_patient',
#   'strip_patient',
#   'pull_patient',
#   'remain_patient',
#   'arrive_patient',
#   'bear_patient',
#   'carve_patient',
#   'fetch_patient',
#   'fetch_patient',
#   'succeed_patient',
#   'exclude_patient',
#   'stir_patient',
#   'receive_patient',
#   'repressed_patient',
#   'strike_patient',
#   'regard_patient',
#   'bid_patient',
#   'watch_patient',
#   'carry_patient',
#   'use_patient',
#   'drive_patient',
#   'deem_patient',
#   'strove_patient',
#   'girdle_patient',
#   'something_patient',
#   'shout_patient',
#   'suspend_patient',
#   'visit_patient',
#   'catch_patient'],
#  ['recollect_agent',
#   'wander_agent',
#   'continue_agent',
#   'abode_agent',
#   'mistake_agent',
#   'secure_agent',
#   'administer_agent',
#   'live_agent',
#   'assist_agent',
#   'lay_agent',
#   'carry_agent',
#   'flutter_agent',
#   'flutter_agent',
#   'delight_agent',
#   'with_agent',
#   'shrink_agent',
#   'skim_agent',
#   'water_agent',
#   'swim_agent',
#   'harry_agent',
#   'interrupt_agent',
#   'spend_agent',
#   'borrow_agent',
#   'wheel_agent',
#   'queue_agent',
#   'attract_agent',
#   'breathe_agent',
#   'throw_agent',
#   'affirm_agent',
#   'repay_agent',
#   'gather_agent',
#   'mount_agent',
#   'spread_agent',
#   'crowd_agent',
#   'summon_agent',
#   'bestow_agent',
#   'behold_agent',
#   'demand_agent',
#   'receive_agent',
#   'repeat_agent',
#   'cudgel_agent',
#   'appear_agent',
#   'dash_agent',
#   'lead_agent',
#   'seize_agent',
#   'rider_agent',
#   'cheer_agent',
#   'consist_agent',
#   'belong_agent',
#   'lean_agent',
#   'knit_agent',
#   'observe_agent',
#   'recollect_patient',
#   'mistake_patient',
#   'administer_patient',
#   'behoove_patient',
#   'stream_patient',
#   'appal_patient',
#   'throw_patient',
#   'delight_patient',
#   'hang_patient',
#   'borrow_patient',
#   'affirm_patient',
#   'repay_patient',
#   'pause_patient',
#   'seize_patient',
#   'knit_patient'],
#  ['carry_agent',
#   'carry_agent',
#   'carry_agent',
#   'sway_agent',
#   'help_agent',
#   'round_agent',
#   'snap_agent',
#   'pride_agent',
#   'linger_agent',
#   'fear_agent',
#   'steal_agent',
#   'pause_agent',
#   'pull_agent',
#   'endeavor_agent',
#   'endeavor_agent',
#   'rain_agent',
#   'flutter_agent',
#   'gain_agent',
#   'encounter_agent',
#   'conduct_agent',
#   'maintain_agent',
#   'carry_patient',
#   'sway_patient',
#   'round_patient',
#   'snap_patient',
#   'pride_patient',
#   'maintain_patient'],
#  ['ride_agent',
#   'strut_agent',
#   'water_agent',
#   'swim_agent',
#   'carve_agent',
#   'beheld_agent',
#   'beheld_agent',
#   'fancy_agent',
#   'lose_agent',
#   'heap_agent',
#   'journey_agent',
#   'elapse_agent',
#   'ride_patient'],
#  ['distinguish_agent',
#   'despair_agent',
#   'bless_agent',
#   'connect_patient',
#   'regard_patient'],
#  ['love_agent', 'part_agent'],
#  ['tear_agent',
#   'meet_agent',
#   'meet_agent',
#   'repeat_agent',
#   'beg_agent',
#   'guess_agent',
#   'realize_agent',
#   'realize_agent',
#   'realize_agent',
#   'realize_agent',
#   'nod_agent',
#   'nod_agent',
#   'occupy_agent',
#   'bring_agent',
#   'occur_agent',
#   'occur_agent',
#   'occur_agent',
#   'occur_agent',
#   'scarce_agent',
#   'hesitate_agent',
#   'hesitate_agent',
#   'demur_agent',
#   'unfold_agent',
#   'watch_agent',
#   'watch_agent',
#   'circle_agent',
#   'differ_agent',
#   'witness_agent',
#   'claim_agent',
#   'overcome_agent',
#   'help_agent',
#   'help_agent',
#   'relax_agent',
#   'grow_agent',
#   'note_agent',
#   'string_agent',
#   'braid_agent',
#   'sheath_agent',
#   'cover_agent',
#   'gain_agent',
#   'continue_agent',
#   'notice_agent',
#   'bare_agent',
#   'shudder_agent',
#   'shudder_agent',
#   'groan_agent',
#   'extend_agent',
#   'brush_agent',
#   'bound_agent',
#   'welcome_agent',
#   'possess_agent',
#   'eat_agent',
#   'devote_agent',
#   'place_agent',
#   'show_agent',
#   'spring_agent',
#   'feast_agent',
#   'awake_agent',
#   'right_agent',
#   'burst_agent',
#   'expect_agent',
#   'pause_agent',
#   'repress_agent',
#   'travel_agent',
#   'decide_agent',
#   'explain_agent',
#   'explain_agent',
#   'village_agent',
#   'prepare_agent',
#   'follow_agent',
#   'follow_agent',
#   'prove_agent',
#   'offer_agent',
#   'like_agent',
#   'smile_agent',
#   'thank_agent',
#   'writhe_agent',
#   'pursue_agent',
#   'walk_agent',
#   'proceed_agent',
#   'proceed_agent',
#   'tie_agent',
#   'augur_agent',
#   'result_agent',
#   'wager_agent',
#   'cause_agent',
#   'from_agent',
#   'arrive_agent',
#   'drag_agent',
#   'understand_agent',
#   'doubt_agent',
#   'believe_agent',
#   'ache_agent',
#   'rush_agent',
#   'pick_agent',
#   'pick_agent',
#   'knelt_agent',
#   'settle_agent',
#   'lose_agent',
#   'drive_agent',
#   'determine_agent',
#   'demand_agent',
#   'convince_agent',
#   'learn_agent',
#   'question_agent',
#   'hang_agent',
#   'interpret_agent',
#   'facilitate_agent',
#   'accept_agent',
#   'hover_agent',
#   'sleep_agent',
#   'sleep_agent',
#   'happen_agent',
#   'happen_agent',
#   'scurry_agent',
#   'argue_agent',
#   'fill_agent',
#   'handicap_agent',
#   'trail_agent',
#   'serve_agent',
#   'grope_agent',
#   'accustom_agent',
#   'crawl_agent',
#   'wound_agent',
#   'rest_agent',
#   'gather_agent',
#   'lower_agent',
#   'guide_agent',
#   'seize_agent',
#   'push_agent',
#   'stay_agent',
#   'clench_agent',
#   'pounce_agent',
#   'glance_agent',
#   'retreat_agent',
#   'force_agent',
#   'glare_agent',
#   'seek_agent',
#   'sniff_agent',
#   'fear_agent',
#   'drop_agent',
#   'loose_agent',
#   'propose_agent',
#   'beg_patient',
#   'continue_patient',
#   'lead_patient',
#   'believe_patient',
#   'occur_patient',
#   'experience_patient',
#   'claim_patient',
#   'help_patient',
#   'whisper_patient',
#   'string_patient',
#   'in_patient',
#   'puzzle_patient',
#   'designate_patient',
#   'follow_patient',
#   'like_patient',
#   'leap_patient',
#   'from_patient',
#   'cause_patient',
#   'rush_patient',
#   'compel_patient',
#   'lose_patient',
#   'drive_patient',
#   'recognize_patient',
#   'desert_patient',
#   'deny_patient',
#   'grin_patient',
#   'bring_patient',
#   'strike_patient',
#   'realize_patient',
#   'realize_patient',
#   'realize_patient',
#   'fill_patient',
#   'trail_patient',
#   'accustom_patient',
#   'add_patient',
#   'guide_patient',
#   'seize_patient',
#   'stay_patient',
#   'force_patient',
#   'seek_patient',
#   'laugh_patient',
#   'spell_patient'],
#  ['need_agent',
#   '"_agent',
#   'beg_agent',
#   'walk_agent',
#   'strike_agent',
#   'realize_agent',
#   'realize_agent',
#   'tear_agent',
#   'tear_agent',
#   'wheel_agent',
#   'lead_agent',
#   'lead_agent',
#   'lead_agent',
#   'halt_agent',
#   'swing_agent',
#   'release_agent',
#   'roam_agent',
#   'learn_agent',
#   'learn_agent',
#   'learn_agent',
#   'examine_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'hope_agent',
#   'hasten_agent',
#   'jump_agent',
#   'demand_agent',
#   'convince_agent',
#   'convince_agent',
#   'assist_agent',
#   'clap_agent',
#   'relax_agent',
#   'occur_agent',
#   'write_agent',
#   'rivet_agent',
#   'claim_agent',
#   'hurl_agent',
#   'hurl_agent',
#   'hurl_agent',
#   'hurl_agent',
#   'circle_agent',
#   'appraise_agent',
#   'bring_agent',
#   'bring_agent',
#   'awake_agent',
#   'whirl_agent',
#   'waddle_agent',
#   'stalk_agent',
#   'stalk_agent',
#   'manage_agent',
#   'cut_agent',
#   'cut_agent',
#   'scoop_agent',
#   'crumble_agent',
#   'thrust_agent',
#   'commence_agent',
#   'commence_agent',
#   'attempt_agent',
#   'these_agent',
#   'through_agent',
#   'crouch_agent',
#   'long_agent',
#   'long_agent',
#   'long_agent',
#   'settle_agent',
#   'but_agent',
#   'touch_agent',
#   'roar_agent',
#   'grasp_agent',
#   'grasp_agent',
#   'glide_agent',
#   'raise_agent',
#   'continue_agent',
#   'continue_agent',
#   'continue_agent',
#   'notice_agent',
#   'Oftentimes_agent',
#   'bare_agent',
#   'skip_agent',
#   'decide_agent',
#   'sail_agent',
#   'act_agent',
#   'step_agent',
#   'brush_agent',
#   'in_agent',
#   'drop_agent',
#   'separate_agent',
#   'leap_agent',
#   'form_agent',
#   'pursue_agent',
#   'control_agent',
#   'at_agent',
#   'break_agent',
#   'fellow_agent',
#   'place_agent',
#   'creep_agent',
#   'hunt_agent',
#   'proceed_agent',
#   'melt_agent',
#   'burst_agent',
#   'time_agent',
#   'augur_agent',
#   'growl_agent',
#   'ring_agent',
#   'believe_agent',
#   'carry_agent',
#   'understand_agent',
#   'low_agent',
#   'catch_agent',
#   'tak_agent',
#   'march_agent',
#   'wipe_agent',
#   'doze_agent',
#   'watch_agent',
#   'show_agent',
#   'forge_agent',
#   'slip_agent',
#   'speed_agent',
#   'waste_agent',
#   'scream_agent',
#   'warn_agent',
#   'forget_agent',
#   'jerk_agent',
#   'escape_agent',
#   'ejaculate_agent',
#   'scowl_agent',
#   'retort_agent',
#   'insist_agent',
#   'cease_agent',
#   'direction_agent',
#   'approach_agent',
#   'clamber_agent',
#   'accompany_agent',
#   'bring_patient',
#   'bring_patient',
#   'strike_patient',
#   'beg_patient',
#   'carry_patient',
#   'whisper_patient',
#   'whisper_patient',
#   'relax_patient',
#   'row_patient',
#   'hurl_patient',
#   'whirl_patient',
#   'stalk_patient',
#   'stalk_patient',
#   'settle_patient',
#   'but_patient',
#   'grasp_patient',
#   'cease_patient',
#   'separate_patient',
#   'teach_patient',
#   'devote_patient',
#   'melt_patient',
#   'time_patient',
#   'trap_patient',
#   'snuff_patient',
#   'tie_patient',
#   'admit_patient',
#   'worry_patient',
#   'attempt_patient',
#   'befall_patient',
#   'commence_patient',
#   'hide_patient',
#   'use_patient',
#   'scurry_patient',
#   'seize_patient',
#   'jerk_patient',
#   'escape_patient',
#   'learn_patient',
#   'scowl_patient',
#   'member_patient',
#   'clamber_patient',
#   'arise_patient',
#   'becalm_patient',
#   'throw_patient'],
#  ['tear_agent',
#   'attempt_agent',
#   'beg_agent',
#   'guess_agent',
#   'lead_agent',
#   'explore_agent',
#   'hope_agent',
#   'remove_agent',
#   'swing_agent',
#   'wheel_agent',
#   'crouch_agent',
#   'drive_agent',
#   'bury_agent',
#   'possess_agent',
#   'teach_agent',
#   'growls_agent',
#   'rivet_agent',
#   'carry_agent',
#   'proceed_agent',
#   'follow_agent',
#   'follow_agent',
#   'battle_agent',
#   'battle_agent',
#   '"_agent',
#   'land_agent',
#   'flee_agent',
#   'like_agent',
#   'prepare_agent',
#   'explain_agent',
#   'touch_agent',
#   'throw_agent',
#   'grow_agent',
#   'cock_agent',
#   'ban_agent',
#   'urge_agent',
#   'understand_agent',
#   'glare_agent',
#   'legge_agent',
#   'shove_agent',
#   'watch_agent',
#   'seek_agent',
#   'drop_agent',
#   'trail_agent',
#   'convince_agent',
#   'realize_agent',
#   'miss_agent',
#   'distract_agent',
#   'tremble_agent',
#   'hide_agent',
#   'insinuate_agent',
#   'retain_agent',
#   'shout_agent',
#   'requisition_agent',
#   'protrude_agent',
#   'learn_agent',
#   'arrange_agent',
#   'propose_agent',
#   'revolve_patient',
#   'bring_patient',
#   'beg_patient',
#   'remember_patient',
#   'swing_patient',
#   'relax_patient',
#   'drive_patient',
#   'string_patient',
#   'drop_patient',
#   'possess_patient',
#   'hesitate_patient',
#   'teach_patient',
#   'growls_patient',
#   'proceed_patient',
#   'follow_patient',
#   'battle_patient',
#   'shudder_patient',
#   'shudder_patient',
#   'venture_patient',
#   'travel_patient',
#   'circle_patient',
#   'explain_patient',
#   'time_patient',
#   'commence_patient',
#   'carry_patient',
#   'snatch_patient',
#   'shake_patient',
#   'lift_patient',
#   'legge_patient',
#   'devote_patient',
#   'watch_patient',
#   'hide_patient',
#   'halt_patient',
#   'fill_patient',
#   'trail_patient',
#   'convince_patient',
#   'miss_patient',
#   'dip_patient',
#   'quit_patient',
#   'insinuate_patient',
#   'drift_patient',
#   'work_patient',
#   'raise_patient',
#   'strain_patient',
#   'prevail_patient',
#   'seize_patient',
#   'learn_patient',
#   'accompany_patient'],
#  ['proclaim_agent',
#   'soliloquize_agent',
#   'add_agent',
#   'add_agent',
#   'remember_agent',
#   'cease_agent',
#   'grow_agent',
#   'rob_agent',
#   'place_agent',
#   'roll_agent',
#   'wrest_agent',
#   'whisper_agent',
#   'work_agent',
#   'cluster_agent',
#   'starve_agent',
#   'doubt_agent',
#   'doubt_agent',
#   'recover_agent',
#   'approach_agent',
#   'state_agent',
#   'determine_agent',
#   'poise_agent',
#   'this_agent',
#   'choose_agent',
#   'notice_agent',
#   'die_agent',
#   'flee_agent',
#   'abandon_agent',
#   'withdraw_agent',
#   'dip_agent',
#   'show_agent',
#   'realize_agent',
#   'realize_agent',
#   'berate_agent',
#   'scurry_agent',
#   'recall_agent',
#   'slink_agent',
#   'worm_agent',
#   'depend_agent',
#   'hide_agent',
#   'drive_agent',
#   'creep_agent',
#   'chance_agent',
#   'lean_agent',
#   'scowl_agent',
#   'hope_agent',
#   'divide_agent',
#   'conceal_agent',
#   'long_agent',
#   'circle_agent',
#   'hasten_agent',
#   'chase_agent',
#   'explore_patient',
#   'thrust_patient',
#   'roll_patient',
#   'prepare_patient',
#   'starve_patient',
#   'obliterate_patient',
#   'recover_patient',
#   'convince_patient',
#   'die_patient',
#   'die_patient',
#   'this_patient',
#   'choose_patient',
#   'notice_patient',
#   'need_patient',
#   'realize_patient',
#   'recall_patient',
#   'forget_patient',
#   'startle_patient',
#   'send_patient',
#   'direct_patient',
#   'grumble_patient',
#   'surround_patient',
#   'lead_patient',
#   'desire_patient',
#   'hide_patient',
#   'ride_patient',
#   'chance_patient',
#   'conceal_patient',
#   'miscarry_patient'],
#  ['bring_agent',
#   'sink_agent',
#   'sink_agent',
#   'hold_agent',
#   'insist_agent',
#   'could_agent',
#   'could_agent',
#   'like_agent',
#   'like_agent',
#   'stumble_agent',
#   'ply_agent',
#   'decide_agent',
#   'watch_agent',
#   'wipe_agent',
#   'realize_agent',
#   'realize_agent',
#   'realize_agent',
#   'care_agent',
#   'breathe_agent',
#   'breathe_agent',
#   'urge_agent',
#   'recall_agent',
#   'deceive_agent',
#   'struggle_agent',
#   'commence_agent',
#   'rivet_agent',
#   'halt_agent',
#   'happen_agent',
#   'happen_agent',
#   'believe_agent',
#   'permit_agent',
#   'promise_agent',
#   'collapse_agent',
#   'crouch_agent',
#   'close_agent',
#   'drop_agent',
#   'lose_agent',
#   'beat_agent',
#   'sweep_agent',
#   'sweep_agent',
#   'bear_agent',
#   'wield_agent',
#   'cling_agent',
#   'succeed_agent',
#   'clamber_agent',
#   'clamber_agent',
#   'seek_agent',
#   'appear_agent',
#   'proceed_agent',
#   'alarm_agent',
#   'perceive_agent',
#   'open_agent',
#   'release_agent',
#   'hope_agent',
#   'order_agent',
#   'drift_agent',
#   'break_agent',
#   'stay_agent',
#   'whisper_agent',
#   'glare_agent',
#   'creep_agent',
#   'leap_agent',
#   'fail_agent',
#   'with_agent',
#   'spring_agent',
#   'inquire_agent',
#   'kneel_agent',
#   'seize_agent',
#   'surround_patient',
#   'ply_patient',
#   'puzzle_patient',
#   'realize_patient',
#   'escort_patient',
#   'deceive_patient',
#   'grasp_patient',
#   'struggle_patient',
#   'strike_patient',
#   'could_patient',
#   'permit_patient',
#   'close_patient',
#   'sweep_patient',
#   'sweep_patient',
#   'bear_patient',
#   'capture_patient',
#   'order_patient',
#   'push_patient',
#   'startle_patient',
#   'leap_patient',
#   'hurl_patient'],
#  ['relate_agent',
#   'stretch_agent',
#   'stretch_agent',
#   'open_agent',
#   'direct_agent',
#   'forge_agent',
#   'capture_agent',
#   'manifest_agent',
#   'cover_agent',
#   'throw_agent',
#   'throw_agent',
#   'unclasp_agent',
#   'mean_agent',
#   'explain_agent',
#   'explain_agent',
#   'sink_agent',
#   'repeat_agent',
#   'witness_agent',
#   'last_agent',
#   'bring_agent',
#   'approach_agent',
#   'approach_agent',
#   'follow_agent',
#   'follow_agent',
#   'follow_agent',
#   'worship_agent',
#   'advance_agent',
#   'pay_agent',
#   'range_agent',
#   'consist_agent',
#   'step_agent',
#   'teach_agent',
#   'teach_agent',
#   'prove_agent',
#   'rear_agent',
#   'ride_agent',
#   'locate_agent',
#   'arrange_agent',
#   'arrange_agent',
#   'melt_agent',
#   'discover_agent',
#   'swing_agent',
#   'near_agent',
#   'observe_agent',
#   'mete_agent',
#   'plead_agent',
#   'chance_agent',
#   'address_agent',
#   'calculate_agent',
#   'place_agent',
#   'undisputed_agent',
#   'surplus_agent',
#   'control_agent',
#   'use_agent',
#   'hate_agent',
#   'exclaim_agent',
#   'meet_agent',
#   'meet_agent',
#   'talk_agent',
#   'lose_agent',
#   'occupy_agent',
#   'bear_agent',
#   'bear_agent',
#   'allow_agent',
#   'believe_agent',
#   'believe_agent',
#   'spring_agent',
#   'plunge_agent',
#   'slip_agent',
#   'struggle_agent',
#   'in_agent',
#   'race_agent',
#   'render_agent',
#   'eye_agent',
#   'tear_agent',
#   'crouch_agent',
#   'retreat_agent',
#   'drag_agent',
#   'assure_agent',
#   'injure_agent',
#   'suspect_agent',
#   'add_agent',
#   'close_agent',
#   'kill_agent',
#   'lower_agent',
#   'continue_agent',
#   'spend_agent',
#   'learn_agent',
#   'occur_agent',
#   'store_agent',
#   'waste_agent',
#   'dismount_agent',
#   'bend_agent',
#   'access_agent',
#   'project_agent',
#   'dispatch_agent',
#   'menace_agent',
#   'loot_agent',
#   'fight_agent',
#   'muscle_agent',
#   'need_agent',
#   'commence_agent',
#   'arise_agent',
#   'stoop_agent',
#   'arrive_patient',
#   'stretch_patient',
#   'direct_patient',
#   'follow_patient',
#   'follow_patient',
#   'repeat_patient',
#   'manifest_patient',
#   'advance_patient',
#   'advance_patient',
#   'near_patient',
#   'ignore_patient',
#   'exchange_patient',
#   'grasp_patient',
#   'grasp_patient',
#   'illumined_patient',
#   'consist_patient',
#   'bring_patient',
#   'wear_patient',
#   'teach_patient',
#   'teach_patient',
#   'prove_patient',
#   'swing_patient',
#   'catch_patient',
#   'throw_patient',
#   'throw_patient',
#   'rub_patient',
#   'approach_patient',
#   'chance_patient',
#   'receive_patient',
#   'accompany_patient',
#   'bewitch_patient',
#   'warn_patient',
#   'however_patient',
#   'use_patient',
#   'lose_patient',
#   'learn_patient',
#   'arrange_patient',
#   'bear_patient',
#   'plunge_patient',
#   'engrave_patient',
#   'pick_patient',
#   'grant_patient',
#   'order_patient',
#   'eye_patient',
#   'await_patient',
#   'injure_patient',
#   'kill_patient',
#   'kill_patient',
#   'store_patient',
#   'hang_patient',
#   'work_patient',
#   'realize_patient',
#   'build_patient',
#   'dispatch_patient',
#   'join_patient',
#   'surge_patient',
#   'arise_patient',
#   'believe_patient'],
#  ['smile_agent',
#   'smile_agent',
#   'enter_agent',
#   'learn_agent',
#   'learn_agent',
#   'pick_agent',
#   'swing_agent',
#   'rush_agent',
#   'drift_agent',
#   'drift_agent',
#   'near_agent',
#   'swarm_agent',
#   'open_agent',
#   'remodel_agent',
#   'observe_agent',
#   'sink_agent',
#   'jerk_agent',
#   'receive_agent',
#   'continue_agent',
#   'continue_agent',
#   'clasp_agent',
#   'strike_agent',
#   'care_agent',
#   'whisper_agent',
#   'gaze_agent',
#   'question_agent',
#   'explain_agent',
#   'show_agent',
#   'upturne_agent',
#   'visit_agent',
#   'visit_agent',
#   'share_agent',
#   'dismount_agent',
#   'exclaim_agent',
#   'meet_agent',
#   'trust_agent',
#   'fear_agent',
#   'gain_agent',
#   'diminish_agent',
#   'lose_agent',
#   'hope_agent',
#   'teach_agent',
#   'exercise_agent',
#   'thing_agent',
#   'hasten_agent',
#   'retreat_agent',
#   'shrink_agent',
#   'form_agent',
#   'mix_agent',
#   'imprison_agent',
#   'disbelieve_agent',
#   'read_agent',
#   'worship_agent',
#   'escape_agent',
#   'search_agent',
#   'push_agent',
#   'pause_agent',
#   'accompany_agent',
#   'as_agent',
#   'roll_agent',
#   'tear_agent',
#   'arise_agent',
#   'attempt_agent',
#   'flash_agent',
#   'owe_agent',
#   'extend_agent',
#   'appreciate_agent',
#   'smile_patient',
#   'rush_patient',
#   'board_patient',
#   'watch_patient',
#   'fade_patient',
#   'note_patient',
#   'observe_patient',
#   'sink_patient',
#   'jerk_patient',
#   'question_patient',
#   'confess_patient',
#   'plead_patient',
#   'explain_patient',
#   'force_patient',
#   'one_patient',
# ...
#   'fear_agent',
#   'force_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'whisper_agent',
#   'seize_agent',
#   'seize_agent',
#   'slow_agent',
#   'pick_agent',
#   'unwound_agent',
#   'gasp_agent',
#   'mean_agent',
#   'mean_agent',
#   'mean_agent',
#   'mean_agent',
#   'choke_agent',
#   'prick_agent',
#   'quail_agent',
#   'spend_agent',
#   'undress_agent',
#   'vanish_agent',
#   'worm_agent',
#   'blanch_agent',
#   'notice_agent',
#   'notice_agent',
#   'watch_agent',
#   'watch_agent',
#   'watch_agent',
#   'struggle_agent',
#   'struggle_agent',
#   'pry_agent',
#   'divine_agent',
#   'wince_agent',
#   'because_agent',
#   'thout_agent',
#   'accost_agent',
#   'lead_agent',
#   'submit_agent',
#   'meet_agent',
#   'arrive_agent',
#   'arrive_agent',
#   'listen_agent',
#   'furnish_agent',
#   'tumble_agent',
#   'climb_agent',
#   'stir_agent',
#   'reward_agent',
#   'tramp_agent',
#   'reckon_agent',
#   'reckon_agent',
#   'reckon_agent',
#   'agree_agent',
#   'wither_agent',
#   'quartering_agent',
#   'creep_agent',
#   'press_agent',
#   'press_agent',
#   'hurry_agent',
#   'but_agent',
#   'snuffle_agent',
#   'touch_agent',
#   'kneel_agent',
#   'provide_agent',
#   'hide_agent',
#   'hide_agent',
#   'venture_agent',
#   'scratch_agent',
#   'help_agent',
#   'erase_agent',
#   'remind_agent',
#   'waver_agent',
#   'swell_agent',
#   'boy_agent',
#   'pretend_agent',
#   'pretend_agent',
#   'decide_agent',
#   'live_agent',
#   'observe_agent',
#   'observe_agent',
#   'gratify_agent',
#   'continue_agent',
#   'spy_agent',
#   'chat_agent',
#   'fleeting_agent',
#   'attend_agent',
#   'hasten_agent',
#   'flee_agent',
#   'follow_agent',
#   'follow_agent',
#   'mope_agent',
#   'encounter_agent',
#   'steal_agent',
#   'expect_agent',
#   'deny_agent',
#   'forget_agent',
#   'tremble_agent',
#   'promise_agent',
#   'hand_agent',
#   'resolve_agent',
#   'drink_agent',
#   'fact_agent',
#   'attempt_agent',
#   'seek_agent',
#   'hunt_agent',
#   'cover_agent',
#   'believe_agent',
#   'believe_agent',
#   'believe_agent',
#   'relapse_agent',
#   'drift_agent',
#   'close_agent',
#   'fasten_agent',
#   'glance_agent',
#   'hesitate_agent',
#   'fix_agent',
#   'consider_agent',
#   'urge_agent',
#   'conclude_agent',
#   'care_agent',
#   'enable_agent',
#   'squeeze_agent',
#   'smoke_agent',
#   'trip_agent',
#   'shout_agent',
#   'shout_agent',
#   'sink_agent',
#   'bury_agent',
#   'beg_agent',
#   'economize_agent',
#   'rest_agent',
#   'wake_agent',
#   'divide_agent',
#   'whoop_agent',
#   'propose_agent',
#   'propose_agent',
#   'happen_agent',
#   'describe_agent',
#   'learn_agent',
#   'learn_agent',
#   'drown_agent',
#   '"_agent',
#   'descend_agent',
#   'skim_agent',
#   'pour_agent',
#   'hope_agent',
#   'route_agent',
#   'appear_patient',
#   'appear_patient',
#   'survey_patient',
#   'help_patient',
#   'help_patient',
#   'present_patient',
#   'picture_patient',
#   'contrive_patient',
#   'button_patient',
#   'lose_patient',
#   'elevated_patient',
#   'deliver_patient',
#   'quake_patient',
#   'quake_patient',
#   'like_patient',
#   'like_patient',
#   'like_patient',
#   'aggravate_patient',
#   'shake_patient',
#   'shake_patient',
#   'gather_patient',
#   'gather_patient',
#   'hang_patient',
#   'hang_patient',
#   'hang_patient',
#   'rouse_patient',
#   'learn_patient',
#   'learn_patient',
#   'bear_patient',
#   'release_patient',
#   'glow_patient',
#   'smote_patient',
#   'idea_patient',
#   'search_patient',
#   'lay_patient',
#   'lay_patient',
#   'drag_patient',
#   'send_patient',
#   'disturb_patient',
#   'bring_patient',
#   'bring_patient',
#   'whisper_patient',
#   'whisper_patient',
#   'whisper_patient',
#   'undress_patient',
#   'vanish_patient',
#   'raise_patient',
#   'burn_patient',
#   'lead_patient',
#   'submit_patient',
#   'sweep_patient',
#   'sweep_patient',
#   '"_patient',
#   'touch_patient',
#   'hide_patient',
#   'erase_patient',
#   'downhearte_patient',
#   'follow_patient',
#   'shut_patient',
#   'gratify_patient',
#   'arrive_patient',
#   'thank_patient',
#   'steal_patient',
#   'grow_patient',
#   'pronounce_patient',
#   'add_patient',
#   'glance_patient',
#   'enable_patient',
#   'understand_patient',
#   'show_patient',
#   'divide_patient'],
#  ['hope_agent',
#   'hope_agent',
#   'hope_agent',
#   'hope_agent',
#   'finish_agent',
#   'finish_agent',
#   'bend_agent',
#   'bend_agent',
#   'resurrect_agent',
#   'lift_agent',
#   'lift_agent',
#   'whirl_agent',
#   'flee_agent',
#   'play_agent',
#   'play_agent',
#   'play_agent',
#   'pear_agent',
#   'hurt_agent',
#   'flatter_agent',
#   'forget_agent',
#   'forget_agent',
#   'remember_agent',
#   'remember_agent',
#   'remember_agent',
#   'struggle_agent',
#   'respond_agent',
#   'respond_agent',
#   'hold_agent',
#   'hold_agent',
#   'hove_agent',
#   'eat_agent',
#   'eat_agent',
#   'slacken_agent',
#   'resign_agent',
#   'skip_agent',
#   'pretend_agent',
#   'pick_agent',
#   'button_agent',
#   'button_agent',
#   'stride_agent',
#   'wander_agent',
#   'wander_agent',
#   'wander_agent',
#   'invite_agent',
#   'bring_agent',
#   'bring_agent',
#   'bring_agent',
#   'pause_agent',
#   'pause_agent',
#   'lay_agent',
#   'face_agent',
#   'shall_agent',
#   'tackle_agent',
#   'cut_agent',
#   'coat_agent',
#   'waylay_agent',
#   'show_agent',
#   'show_agent',
#   'show_agent',
#   'show_agent',
#   'show_agent',
#   'despise_agent',
#   'deliver_agent',
#   'distribute_agent',
#   'titter_agent',
#   'plead_agent',
#   'believe_agent',
#   'believe_agent',
#   'detect_agent',
#   'light_agent',
#   'lapse_agent',
#   'bethink_agent',
#   'survey_agent',
#   'eye_agent',
#   'eye_agent',
#   'grow_agent',
#   'grow_agent',
#   'grow_agent',
#   'grow_agent',
#   'fling_agent',
#   'fling_agent',
#   'resume_agent',
#   'sink_agent',
#   'seize_agent',
#   'seize_agent',
#   'seize_agent',
#   'hate_agent',
#   'work_agent',
#   'work_agent',
#   'erect_agent',
#   'step_agent',
#   'step_agent',
#   'step_agent',
#   'step_agent',
#   'glow_agent',
#   'escape_agent',
#   'escape_agent',
#   'in_agent',
#   'chew_agent',
#   'mean_agent',
#   'mean_agent',
#   'die_agent',
#   'die_agent',
#   'toss_agent',
#   'watch_agent',
#   'watch_agent',
#   'dress_agent',
#   'wade_agent',
#   'talk_agent',
#   'talk_agent',
#   'talk_agent',
#   'wait_agent',
#   'notice_agent',
#   'notice_agent',
#   'notice_agent',
#   'notice_agent',
#   'bent_agent',
#   'strike_agent',
#   'strike_agent',
#   'pry_agent',
#   'reel_agent',
#   'murmur_agent',
#   'rob_agent',
#   'raise_agent',
#   'raise_agent',
#   'raise_agent',
#   'fly_agent',
#   'fly_agent',
#   'glance_agent',
#   'burst_agent',
#   'burst_agent',
#   'burst_agent',
#   'swear_agent',
#   'swear_agent',
#   'tiptoe_agent',
#   'separate_agent',
#   'separate_agent',
#   'mope_agent',
#   'betake_agent',
#   'change_agent',
#   'unroll_agent',
#   'hang_agent',
#   'hang_agent',
#   'shake_agent',
#   'shake_agent',
#   'sob_agent',
#   'order_agent',
#   'order_agent',
#   'taste_agent',
#   'drop_agent',
#   'gaze_agent',
#   'gaze_agent',
#   'should_agent',
#   'lead_agent',
#   'hunt_agent',
#   'hunt_agent',
#   'point_agent',
#   'discover_agent',
#   'discover_agent',
#   "o'clock_agent",
#   'stretch_agent',
#   'stretch_agent',
#   "'s_agent",
#   'resolve_agent',
#   'carry_agent',
#   'carry_agent',
#   'spring_agent',
#   'spring_agent',
#   'spring_agent',
#   'part_agent',
#   'reckon_agent',
#   'reckon_agent',
#   'reckon_agent',
#   'agree_agent',
#   'listen_agent',
#   'climb_agent',
#   'press_agent',
#   'giveth_agent',
#   'thread_agent',
#   'untie_agent',
#   'hit_agent',
#   'rest_agent',
#   'desert_agent',
#   'stoop_agent',
#   'venture_agent',
#   'hide_agent',
#   'learn_agent',
#   'learn_agent',
#   'bet_agent',
#   'bet_agent',
#   'huddle_agent',
#   'clung_agent',
#   'pour_agent',
#   'drench_agent',
#   'care_agent',
#   'assemble_agent',
#   'practise_agent',
#   'disturb_agent',
#   'disturb_agent',
#   'relate_agent',
#   'blow_agent',
#   'Alfred_agent',
#   'prepare_agent',
#   'endure_agent',
#   'lose_agent',
#   'hand_agent',
#   'ketch_agent',
#   'would_agent',
#   'avoid_agent',
#   'decline_agent',
#   'jump_agent',
#   'jump_agent',
#   'drift_agent',
#   'sally_agent',
#   'stumble_agent',
#   'arrive_agent',
#   'toil_agent',
#   'toil_agent',
#   'choose_agent',
#   'drag_agent',
#   'peg_agent',
#   'like_agent',
#   'mark_agent',
#   'deepen_agent',
#   'fight_agent',
#   'fail_agent',
#   'creep_agent',
#   'alert_agent',
#   'droop_agent',
#   'subtract_agent',
#   'nudge_agent',
#   'examine_agent',
#   'examine_agent',
#   'slip_agent',
#   'suppose_agent',
#   'suppose_agent',
#   'follow_agent',
#   'may_agent',
#   'close_agent',
#   'close_agent',
#   'lock_agent',
#   'astonish_agent',
#   'bury_agent',
#   'plunge_agent',
#   'happen_agent',
#   'depart_agent',
#   'kill_agent',
#   'promise_agent',
#   'sneak_agent',
#   'suggest_agent',
#   'add_agent',
#   'admit_agent',
#   'excite_agent',
#   'thought_agent',
#   'blurt_agent',
#   'flutter_agent',
#   'curious_agent',
#   'wind_agent',
#   'walk_agent',
#   'confess_agent',
#   'miss_agent',
#   'miss_agent',
#   'miss_agent',
#   'will_agent',
#   'will_agent',
#   'divide_agent',
#   'stay_agent',
#   'sleep_agent',
#   'search_agent',
#   'search_agent',
#   'contrive_agent',
#   'scoop_agent',
#   'borrow_agent',
#   'land_agent',
#   'hive_agent',
#   'open_agent',
#   'weigh_agent',
#   'receive_agent',
#   'suffer_agent',
#   'cuff_agent',
#   'collect_agent',
#   'bear_agent',
#   'for_agent',
#   'pray_agent',
#   'smoke_agent',
#   'learn_patient',
#   'learn_patient',
#   'flatter_patient',
#   'struggle_patient',
#   'respond_patient',
#   'sweep_patient',
#   'pretend_patient',
#   'button_patient',
#   'invite_patient',
#   'lay_patient',
#   'contrive_patient',
#   'remove_patient',
#   'refill_patient',
#   'coat_patient',
#   'waylay_patient',
#   'eat_patient',
#   'despise_patient',
#   'deliver_patient',
#   'distribute_patient',
#   'bring_patient',
#   'bring_patient',
#   'bring_patient',
#   'regard_patient',
#   'endure_patient',
#   'detect_patient',
#   'bethink_patient',
#   'lift_patient',
#   'lift_patient',
#   'lift_patient',
#   'grow_patient',
#   'grow_patient',
#   'resume_patient',
#   'restore_patient',
#   'seize_patient',
#   'seize_patient',
#   'seize_patient',
#   'traverse_patient',
#   'enter_patient',
#   'enter_patient',
#   'dress_patient',
#   'stagger_patient',
#   'believe_patient',
#   'believe_patient',
#   'notice_patient',
#   'notice_patient',
#   'die_patient',
#   'cast_patient',
#   'threaten_patient',
#   'reel_patient',
#   'and_patient',
#   'rob_patient',
#   'glance_patient',
#   'exclaim_patient',
#   'betake_patient',
#   'shake_patient',
#   'shake_patient',
#   'help_patient',
#   'help_patient',
#   'divine_patient',
#   'accost_patient',
#   'submit_patient',
#   'discover_patient',
#   'stretch_patient',
#   'stretch_patient',
#   'kill_patient',
#   'kill_patient',
#   'kill_patient',
#   'carry_patient',
#   'carry_patient',
#   'fly_patient',
#   'fling_patient',
#   'untie_patient',
#   'spend_patient',
#   'spend_patient',
#   'erase_patient',
#   'reckon_patient',
#   'reckon_patient',
#   'huddle_patient',
#   'pour_patient',
#   'talk_patient',
#   'culminate_patient',
#   'scorch_patient',
#   'remind_patient',
#   'attract_patient',
#   'thrust_patient',
#   'snatch_patient',
#   'love_patient',
#   'occupy_patient',
#   'sponge_patient',
#   'wander_patient',
#   'decline_patient',
#   'raise_patient',
#   'swear_patient',
#   'bury_patient',
#   'bury_patient',
#   'arrive_patient',
#   'subdue_patient',
#   'spot_patient',
#   'unearthed_patient',
#   'forsake_patient',
#   'track_patient',
#   'follow_patient',
#   'bet_patient',
#   'by_patient',
#   'hop_patient',
#   'grab_patient',
#   'how_patient',
#   'occur_patient',
#   'astonish_patient',
#   'spring_patient',
#   'describe_patient',
#   'promise_patient',
#   'suggest_patient',
#   'disturb_patient',
#   'waste_patient',
#   'mass_patient',
#   'hold_patient',
#   'hive_patient',
#   'receive_patient',
#   'cover_patient',
#   'about_patient',
#   'cuff_patient',
#   'collect_patient',
#   'board_patient',
#   "'s_patient"],
#  ['resume_agent',
#   'suit_agent',
#   'picture_agent',
#   'eat_agent',
#   'hang_agent',
#   'hang_agent',
#   'believe_agent',
#   'eye_agent',
#   'hurt_agent',
#   'chew_agent',
#   'occur_agent',
#   'clung_agent',
#   'rouse_agent',
#   'resolve_agent',
#   'dream_agent',
#   'consist_agent',
#   'build_agent',
#   'hug_agent',
#   'exclaimed_agent',
#   'discourage_agent',
#   'shall_agent',
#   'dawn_agent',
#   'fetch_agent',
#   '"_agent',
#   '"_agent',
#   'happen_agent',
#   'happen_agent',
#   'gratify_agent',
#   'madden_agent',
#   'reckon_agent',
#   'venture_agent',
#   'expect_agent',
#   'sigh_agent',
#   'fail_agent',
#   'contemplate_agent',
#   'sponge_agent',
#   'increase_agent',
#   'may_agent',
#   'help_agent',
#   'prove_agent',
#   'swear_agent',
#   'depose_agent',
#   'hide_agent',
#   'belong_agent',
#   'in_agent',
#   'carry_agent',
#   'leap_agent',
#   'track_agent',
#   'present_agent',
#   'grow_agent',
#   'would_agent',
#   'would_agent',
#   'hunt_agent',
#   'fit_agent',
#   'spring_agent',
#   'collect_agent',
#   'work_agent',
#   'used_agent',
#   'confound_patient',
#   'sew_patient',
#   'remember_patient',
#   'like_patient',
#   'like_patient',
#   'step_patient',
#   'mean_patient',
#   'reckon_patient',
#   'reckon_patient',
#   'reckon_patient',
#   'reckon_patient',
#   'bear_patient',
#   'picture_patient',
#   'manage_patient',
#   'tackle_patient',
#   'tackle_patient',
#   'smooth_patient',
#   'eat_patient',
#   'will_patient',
#   'eye_patient',
#   'eye_patient',
#   'pull_patient',
#   'view_patient',
#   'whisper_patient',
#   'whisper_patient',
#   'strike_patient',
#   'determined_patient',
#   'occur_patient',
#   'bet_patient',
#   'depart_patient',
#   'sob_patient',
#   'moan_patient',
#   'repeat_patient',
#   'dream_patient',
#   'deem_patient',
#   'taste_patient',
#   'signify_patient',
#   'finish_patient',
#   'finish_patient',
#   'dawn_patient',
#   'help_patient',
#   'expect_patient',
#   'consider_patient',
#   'allow_patient',
#   'save_patient',
#   'save_patient',
#   'understand_patient',
#   'leg_patient',
#   'use_patient',
#   'decide_patient',
#   'tie_patient',
#   'kill_patient',
#   '"_patient',
#   'walk_patient',
#   'track_patient',
#   'present_patient',
#   'scoop_patient',
#   'float_patient',
#   'haul_patient',
#   'mind_patient',
#   'collect_patient',
#   'work_patient',
#   'pray_patient'],
#  ['by_agent',
#   'inquire_agent',
#   'scan_agent',
#   'flash_agent',
#   'join_agent',
#   'pick_agent',
#   'kneel_agent',
#   'tiptoe_agent',
#   'discomforte_agent',
#   'bear_agent',
#   'bear_agent',
#   'hope_agent',
#   'recollect_agent',
#   'recollect_agent',
#   'throw_agent',
#   'waver_agent',
#   'suffer_agent',
#   '--sometime_agent',
#   'lean_agent',
#   'drop_agent',
#   'drop_agent',
#   'urge_agent',
#   'wrung_agent',
#   'conclude_agent',
#   'prove_agent',
#   'remain_agent',
#   'burst_agent',
#   'shudder_agent',
#   'occur_agent',
#   'outweigh_agent',
#   'wait_agent',
#   'wait_agent',
#   'close_agent',
#   'slacken_agent',
#   'shoot_agent',
#   'remember_agent',
#   'accompany_agent',
#   'hide_agent',
#   'spring_agent',
#   'spring_agent',
#   'kill_agent',
#   'sink_agent',
#   'suggest_agent',
#   'suggest_agent',
#   'jump_agent',
#   'lead_agent',
#   'learn_agent',
#   'learn_agent',
#   'search_agent',
#   'search_agent',
#   'stare_agent',
#   'follow_agent',
#   'bind_agent',
#   'about_agent',
#   "'s_agent",
#   'introduce_agent',
#   'breakfast_agent',
#   'route_agent',
#   'pick_patient',
#   'inform_patient',
#   'waver_patient',
#   'snatch_patient',
#   'bury_patient',
#   'close_patient',
#   'spring_patient',
#   'stagger_patient',
#   'eye_patient',
#   'work_patient',
#   'learn_patient',
#   'admit_patient',
#   'drown_patient',
#   'believe_patient',
#   'introduce_patient',
#   'shut_patient',
#   'route_patient'],
#  ['resist_agent',
#   'bend_agent',
#   'spring_agent',
#   'strike_agent',
#   'listen_agent',
#   'what_agent',
#   'carry_agent',
#   'soliloquize_agent',
#   'choke_agent',
#   'break_agent',
#   'break_agent',
#   'arrive_agent',
#   'observe_agent',
#   'observe_agent',
#   'gratify_agent',
#   'tremble_agent',
#   'rouse_agent',
#   'rouse_agent',
#   'madden_agent',
#   'resume_agent',
#   'follow_agent',
#   'grow_agent',
#   'grow_agent',
#   'lose_agent',
#   'drop_agent',
#   'change_agent',
#   'resolve_agent',
#   'notice_agent',
#   'glance_agent',
#   'snatch_agent',
#   'thrust_agent',
#   'stamp_agent',
#   'expect_agent',
#   'suppose_agent',
#   'sink_agent',
#   'sink_agent',
#   'tease_agent',
#   'reflect_agent',
#   'respond_agent',
#   'seize_agent',
#   'watch_agent',
#   'understand_agent',
#   'understand_agent',
#   'economize_agent',
#   'bear_agent',
#   'wake_agent',
#   'smile_agent',
#   'divide_agent',
#   'pale_agent',
#   'suggest_agent',
#   'show_agent',
#   'describe_agent',
#   'clasp_patient',
#   'struggle_patient',
#   'carry_patient',
#   'break_patient',
#   'pretend_patient',
#   'tremble_patient',
#   'spy_patient',
#   'Alfred_patient',
#   'drop_patient',
#   'glance_patient',
#   'seize_patient',
#   'refuse_patient',
#   'describe_patient']]

# %%
dictionary = corpora.Dictionary(charTexts)
corpus = [dictionary.doc2bow(text) for text in charTexts]
num_topics = 5
lda_model = gensim.models.LdaModel(corpus, id2word=dictionary, 
                                   num_topics=num_topics, passes=3, alpha='auto')

# %%
for i in range(num_topics):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	enter_agent smile_agent raise_agent spring_agent drop_agent walk_agent realize_agent continue_agent laugh_agent whisper_agent
# topic 1:	lay_agent follow_agent work_agent drop_agent reckon_agent talk_agent hold_agent add_agent lead_agent show_agent
# topic 2:	add_agent like_agent wait_agent walk_agent watch_agent open_agent repeat_agent live_agent occur_agent lay_agent
# topic 3:	bring_agent show_agent drop_agent learn_agent watch_agent carry_agent strike_agent continue_agent lead_agent raise_agent
# topic 4:	reckon_agent exclaim_agent show_agent murmur_agent use_agent continue_agent like_agent lay_agent shake_agent lay_patient

# %%
topic_model=lda_model 

topic_docs=[]
for i in range(num_topics):
    topic_docs.append({})
for doc_id in range(len(corpus)):
    doc_topics=topic_model.get_document_topics(corpus[doc_id])
    for topic_num, topic_prob in doc_topics:
        topic_docs[topic_num][doc_id]=topic_prob

for i in range(num_topics):
    print("%s\n" % ' '.join([term for term, freq in topic_model.show_topic(i, topn=10)]))
    sorted_x = sorted(topic_docs[i].items(), key=operator.itemgetter(1), reverse=True)
    for k, v in sorted_x[:5]:
        print("%s\t%.3f\t%s" % (i,v, charNames[k]))
    print()
# Out:
# enter_agent smile_agent raise_agent spring_agent drop_agent walk_agent realize_agent continue_agent laugh_agent whisper_agent
#
# 0	0.999	he	aka her face, the inner guards	(Edgar Rice Burroughs___The Gods of Mars)
# 0	0.999	his	aka his ship, his courageousness	(Herman Melville___Moby Dick)
# 0	0.999	korak	aka "korak!  , chapter 27  korak	(Edgar Rice Burroughs___The Son of Tarzan)
# 0	0.998	meriem	aka all meriem,  meriem	(Edgar Rice Burroughs___The Son of Tarzan)
# 0	0.998	carthoris	aka a real man, a real warrior--carthoris of helium!", themselves	(Edgar Rice Burroughs___Thuvia, Maid of Mars)
#
# lay_agent follow_agent work_agent drop_agent reckon_agent talk_agent hold_agent add_agent lead_agent show_agent
#
# 1	0.998	 the long boat of the marjorie w.	aka the long rope, swede	(Edgar Rice Burroughs___The Son of Tarzan)
# 1	0.998	it	aka these traditions, itself	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# 1	0.998	we	aka himself, every man that went	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# 1	0.998	it	aka he was an example and representative of that great class of people whom an inexplicable providence is continually putting at cross-purposes with the world, no other man in the city	(Nathaniel Hawthorne___The House of the Seven Gables)
# 1	0.996	phoebe	aka the fair young girl, miss phoebe	(Nathaniel Hawthorne___The House of the Seven Gables)
#
# add_agent like_agent wait_agent walk_agent watch_agent open_agent repeat_agent live_agent occur_agent lay_agent
#
# 2	0.997	alice	aka alice hastily, her face	(Lewis Carroll___Through the Looking-Glass)
# 2	0.997	the ungentle laws and customs	aka the gentleman, themselves	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# 2	0.997	his	aka her mother's face, this gentleman	(Edgar Rice Burroughs___The Return of Tarzan)
# 2	0.997	 alice	aka alice hastily, poor alice	(Lewis Carroll___Alice's Adventures in Wonderland)
# 2	0.997	troy	aka himself, mr. troy	(Thomas Hardy___Far from the Madding Crowd)
#
# bring_agent show_agent drop_agent learn_agent watch_agent carry_agent strike_agent continue_agent lead_agent raise_agent
#
# 3	0.999	they	aka the great world, the air	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# 3	0.999	tom	aka huckleberry and tom, colicky symptoms	(Mark Twain___The Adventures of Tom Sawyer, Complete)
# 3	0.998	it	aka this delicacy, this thus far successful fugitive	(Herman Melville___Moby Dick)
# 3	0.998	we	aka your tower, the tower episode	(Mark Twain___A Connecticut Yankee in King Arthur's Court, Complete)
# 3	0.998	the ape-man	aka the man before him, the agile ape-man	(Edgar Rice Burroughs___The Beasts of Tarzan)
#
# reckon_agent exclaim_agent show_agent murmur_agent use_agent continue_agent like_agent lay_agent shake_agent lay_patient
#
# 4	0.999	she	aka the shearers', rick	(Thomas Hardy___Far from the Madding Crowd)
# 4	0.997	it	aka a little cubby, witches	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# 4	0.996	his friends and critics	aka her face, they	(Thomas Hardy___Far from the Madding Crowd)
# 4	0.996	miss watson's big nigger, named jim	aka ole jim, only jim	(Mark Twain___Adventures of Huckleberry Finn, Complete)
# 4	0.995	his	aka this former self, this rule	(Nathaniel Hawthorne___The Scarlet Letter)

# %%
# {"agent":[{"w":"wore","i":104276},
#           {"w":"had","i":104283},
#           {"w":"carried","i":104297},
#           {"w":"seemed","i":104306},
#           {"w":"said","i":104318},
#           {"w":"said","i":104358},
#           {"w":"said","i":107106},
#           {"w":"realized","i":107110},
#           {"w":"gave","i":107125}],
#  "NNPcount":3,
#  "names":[{"c":3,"n":"Dr. Whittaker"}],
#  "mod":[],
#  "speaking":[{"w":"`` Oh , good morning , '' ","i":104321},
#              {"w":"`` Of course , '' ","i":104353}],
#  "patient":[],
#  "g":2,
#  "id":0,
#  "poss":[{"w":"words","i":107127}]}
