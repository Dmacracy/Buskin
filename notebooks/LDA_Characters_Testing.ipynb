# %%
import operator
from collections import Counter
import math
from os import path
import json
import gensim
from gensim import corpora

# %%
def read_book_nlp_metadata(filename):
    metadata={}
    with open(filename) as file:
        for line in file:
            cols=line.rstrip().split("\t")
            idd=cols[0]
            date=int(cols[1])
            author=cols[2]
            title=cols[3]
            author_gender=cols[4]
            metadata[idd]=(date, author, title, author_gender)
    return metadata

def read_book_nlp_data(data_folder):
    data={}

    for idd in metadata:
        filename=path.join(data_folder, "%s.book" % idd)
        if path.exists(filename):
            with open(filename) as file:
                data[idd]=json.load(file)

    print(f"Read {len(data)} books")
    return data

# %%
def get_corpus_frequencies(alldata):
    
    agentFreqs = Counter()
    patientFreqs =  Counter()
    modFreqs =  Counter()
    
    for idd in alldata:
        data=alldata[idd]
        for character in data["characters"]:
            for term in character["agent"]:
                agentFreqs[term['w']] += 1
            for term in character["patient"]:
                patientFreqs[term['w']] += 1
            for term in character["mod"]:
                modFreqs[term['w']] += 1 
                    
    return agentFreqs, patientFreqs, modFreqs

# %%
agentFreqs, patientFreqs, modFreqs = get_corpus_frequencies(data)

# %%
agentFilter = set([freqPair[0] for freqPair in agentFreqs.most_common(100)])
patientFilter = set([freqPair[0] for freqPair in patientFreqs.most_common(100)])
modFilter = set([freqPair[0] for freqPair in modFreqs.most_common(100)])

# %%
def get_character_actions(alldata, agentFilter={}, patientFilter={}, modFilter={}):
    
    charactersAgentsDict = {}
    charactersAgentsList = []
    charNameList = []
    
    for idd in alldata:
        data=alldata[idd]
        for character in data["characters"]:
            if len(character["names"]) > 0:
                char_name = character["names"][0]['n']
                charNameList.append(char_name)
                charactersAgentsDict[char_name] = Counter()
                charactersAgentsList.append([])
                agent_terms=[term["w"] + "_agent" for term in character["agent"] \
                             if term["w"] not in agentFilter]
                agent_terms += [term["w"] + "_patient" for term in character["patient"]\
                             if term["w"] not in patientFilter]
                agent_terms += [term["w"] + "_mod" for term in character["mod"]\
                             if term["w"] not in modFilter]

                for verb in agent_terms:
                    charactersAgentsDict[char_name][verb]+=1
                    
                for verb, count in charactersAgentsDict[char_name].items():
                    charactersAgentsList[-1]+=[verb]*count
                    
                    
    return charactersAgentsDict, charactersAgentsList, charNameList

# %%
metadata=read_book_nlp_metadata("../../../../Code/comphumF20/data/pulitzer_metadata.txt")
data=read_book_nlp_data("../../../../Code/comphumF20/data/pulitzer_booknlp")
# Out:
# Read 94 books

# %%
charAgents, charTexts, charNames = get_character_actions(data, 
                                                         agentFilter=agentFilter, 
                                                         patientFilter=patientFilter, 
                                                         modFilter=modFilter)

# %%
charAgents
# Out:
# {'Dr. Whittaker': Counter({'carried_agent': 1}),
#  'Mrs. Gunn': Counter(),
#  'Sadie': Counter({'plowing_agent': 1,
#           'meant_agent': 1,
#           'answer_agent': 2,
#           'breathing_agent': 1,
#           'managed_agent': 1,
#           'draw_agent': 1,
#           'snapped_agent': 2,
#           'cut_agent': 2,
#           'slapped_agent': 1,
#           'landed_agent': 1,
#           'saying_agent': 2,
#           'elaborated_agent': 1,
#           'popping_agent': 1,
#           'cleared_agent': 1,
#           'learned_agent': 2,
#           'inspected_agent': 1,
#           'demanded_agent': 6,
#           'admitted_agent': 1,
#           'spewed_agent': 1,
#           'spotted_agent': 1,
#           'knocked_agent': 1,
#           'led_agent': 2,
#           'flashed_agent': 1,
#           'sent_agent': 1,
#           'fudge_agent': 1,
#           'cook_agent': 1,
#           'blazed_agent': 1,
#           'paused_agent': 1,
#           'waited_agent': 2,
#           'twisted_agent': 1,
#           'exclaimed_agent': 1,
#           'swung_agent': 2,
#           'announced_agent': 2,
#           'notice_agent': 1,
#           'leaned_agent': 1,
#           'turn_agent': 1,
#           'defining_agent': 1,
#           'expelled_agent': 1,
#           'played_agent': 1,
#           'mean_agent': 1,
#           'beat_agent': 1,
#           'looking_agent': 2,
#           'settled_agent': 1,
#           'commanded_agent': 1,
#           'hung_agent': 1,
#           'smack_agent': 1,
#           'God-damn_agent': 1,
#           'sprang_agent': 1,
#           'strangle_agent': 1,
#           'popped_agent': 1,
#           'stuck_agent': 1,
#           'running_agent': 1,
#           'snatched_agent': 1,
#           'caught_agent': 1,
#           'iterated_agent': 1,
#           'repeated_agent': 2,
#           'lifted_agent': 2,
#           'face_agent': 1,
#           'showing_agent': 1,
#           'asserted_agent': 1,
#           'fumes_agent': 1,
#           'exploded_agent': 1,
#           'condoning_agent': 1,
#           'jabbed_agent': 2,
#           'ask_agent': 1,
#           'grown_agent': 1,
#           'keep_agent': 1,
#           'hack_agent': 1,
#           'treat_agent': 1,
#           'stand_agent': 1,
#           'suffered_agent': 1,
#           'bit_agent': 1,
#           'crying_agent': 1,
#           'eyed_agent': 1,
#           'commented_agent': 1,
#           'fished_agent': 1,
#           'whipped_agent': 1,
#           'swept_agent': 1,
#           'affirmed_agent': 1,
#           'ordered_agent': 1,
#           'understood_agent': 1,
#           'hanging_agent': 1,
#           'respond_agent': 1,
#           'continued_agent': 1,
#           'help_agent': 1,
#           'lying_agent': 1,
#           'studied_agent': 1,
#           'reckon_agent': 1,
#           'interrupted_agent': 1,
#           'sank_agent': 1,
#           'seem_agent': 1,
#           'watching_agent': 1,
#           'throwing_agent': 1,
#           'practicing_agent': 1,
#           'killed_agent': 1,
#           'putting_agent': 1,
#           'rose_agent': 1,
#           'plunged_agent': 1,
#           'shrugged_agent': 1,
#           'care_agent': 1,
#           'given_agent': 1,
#           'live_agent': 1,
#           'beating_patient': 1,
#           'working_patient': 1,
#           'worked_patient': 1,
#           'came_patient': 1,
#           'built_patient': 1,
#           'attached_patient': 1,
#           'ordered_patient': 1,
#           'jump_patient': 2,
#           'nudged_patient': 1,
#           'answer_patient': 1,
#           'approached_patient': 1,
#           'said_patient': 1,
#           'studied_patient': 1,
#           'fix_patient': 1,
#           'thanked_patient': 1,
#           "'s_patient": 1,
#           'friends_mod': 1,
#           'lot_mod': 1,
#           'heel_mod': 1,
#           'Burke_mod': 1,
#           'dependable_mod': 1,
#           'difficult_mod': 1}),
#  'Jackson': Counter(),
#  'Lynch': Counter(),
#  'Mother': Counter({'died_agent': 1, 'call_agent': 1, 'protected_patient': 1}),
#  'Jessie': Counter({'explained_agent': 1,
#           'led_agent': 1,
#           'sighed_agent': 2,
#           'clicked_agent': 1,
#           'confessed_agent': 1,
#           'advanced_agent': 2,
#           'demanded_agent': 1,
#           'defended_agent': 1,
#           'raged_agent': 1,
#           'ordered_agent': 1,
#           'ai_agent': 1,
#           'shut_patient': 1,
#           'lady_mod': 1}),
#  'Ettie Lou': Counter(),
#  'Mrs. Dekalb': Counter({'bear_agent': 1,
#           'hurried_agent': 3,
#           'crying_agent': 1}),
#  'Mama': Counter({'accusing_agent': 1,
#           'coming_agent': 1,
#           'trailed_agent': 1,
#           'promised_agent': 2}),
#  'Rufus': Counter({'grabbed_agent': 1,
#           'dropped_agent': 1,
#           'Served_patient': 1}),
#  'Joel': Counter({'comes_agent': 1,
#           'clobbers_agent': 1,
#           'applied_patient': 1,
#           'driven_patient': 1,
#           'everything_mod': 1,
#           'onstage_mod': 1}),
#  'Amelia': Counter({'warned_agent': 1,
#           'prefer_agent': 1,
#           'helped_agent': 1,
#           'spread_agent': 1}),
#  'Victoria': Counter(),
#  'Abraham Lincoln': Counter(),
#  'George Bailey': Counter({'leaning_agent': 1, 'roused_patient': 1}),
#  'Jay': Counter({'lumbered_agent': 1}),
#  'Thomas': Counter(),
#  'Google': Counter(),
#  'Bell': Counter({'dressed_agent': 1,
#           'bring_agent': 1,
#           'wound_agent': 1,
#           'headed_agent': 1,
#           'crept_agent': 1,
#           'hid_agent': 1,
#           'caressed_agent': 1,
#           'soothe_agent': 1,
#           'involved_patient': 1,
#           'bathed_patient': 1,
#           'soothed_patient': 1}),
#  'Miss Amy Field': Counter(),
#  'Ted': Counter({'experienced_agent': 2,
#           'speak_agent': 1,
#           'glimpsed_agent': 2,
#           'folded_agent': 1,
#           'slip_agent': 1,
#           'supposed_agent': 1,
#           'braced_agent': 1,
#           'refused_agent': 1,
#           'sensed_agent': 6,
#           'appeared_agent': 1,
#           'drank_agent': 1,
#           'thinking_agent': 1,
#           'taught_agent': 1,
#           'needed_agent': 1,
#           'installed_agent': 1,
#           'point_agent': 1,
#           'sit_agent': 1,
#           'strolled_agent': 1,
#           'shrank_agent': 1,
#           'witnessed_agent': 1,
#           'steered_agent': 1,
#           'rose_agent': 2,
#           'drifted_agent': 1,
#           'faced_agent': 1,
#           'stepped_agent': 1,
#           'spent_agent': 2,
#           'visited_agent': 1,
#           'passed_agent': 1,
#           'imagined_agent': 2,
#           'recognized_agent': 2,
#           'dreading_agent': 1,
#           'slowed_agent': 1,
#           'followed_agent': 4,
#           'sliding_agent': 1,
#           'rejoined_agent': 1,
#           'hugged_agent': 1,
#           'doing_agent': 1,
#           'pushed_agent': 2,
#           'given_agent': 1,
#           'hiding_agent': 1,
#           'allow_agent': 1,
#           'carried_agent': 1,
#           'turn_agent': 1,
#           'hurting_agent': 1,
#           'longed_agent': 1,
#           'trusted_agent': 1,
#           'loaded_agent': 1,
#           'exhausted_agent': 1,
#           'parked_agent': 1,
#           'hoped_agent': 1,
#           'paid_agent': 1,
#           'pictured_agent': 1,
#           'assured_agent': 1,
#           'write_agent': 1,
#           'corrected_agent': 1,
#           'waved_agent': 1,
#           'shoved_agent': 1,
#           'escape_agent': 1,
#           'wrested_agent': 1,
#           'noticed_agent': 3,
#           'hovered_agent': 1,
#           'lingered_agent': 1,
#           'circled_agent': 1,
#           'ordered_agent': 1,
#           'realize_agent': 1,
#           'met_agent': 1,
#           'thrown_agent': 1,
#           'showered_agent': 1,
#           'deliberated_agent': 1,
#           'caught_agent': 1,
#           'tripped_agent': 1,
#           'lecturing_agent': 1,
#           'notice_agent': 1,
#           'smelled_agent': 1,
#           'need_agent': 1,
#           'bring_agent': 1,
#           'rubbed_agent': 1,
#           'sleep_agent': 1,
#           'forgotten_agent': 1,
#           'begun_agent': 1,
#           'hauled_agent': 1,
#           'divorced_agent': 1,
#           'filling_patient': 1,
#           'preoccupy_patient': 1,
#           'wrestled_patient': 1,
#           'presumed_patient': 1,
#           'robbing_patient': 1,
#           'tenured_patient': 1,
#           'affect_patient': 1,
#           'awaited_patient': 1,
#           'buzzing_patient': 1,
#           'greeting_patient': 1,
#           'gird_patient': 1,
#           'driven_patient': 1,
#           'embarrassed_patient': 1,
#           'encircled_patient': 1,
#           'robbed_patient': 1,
#           'forcing_patient': 1,
#           'forgotten_patient': 1,
#           'cost_patient': 1,
#           'mentioned_patient': 1,
#           'foot_mod': 1,
#           'fake_mod': 1,
#           'suspicious_mod': 1,
#           'skeptical_mod': 1,
#           'element_mod': 1}),
#  'Andrew': Counter({'knows_patient': 1, 'ones_mod': 1}),
#  'Hannah': Counter({'stay_agent': 1,
#           'dressed_agent': 1,
#           'lamented_agent': 1,
#           'sang_agent': 1,
#           'handed_agent': 1,
#           'confirmed_agent': 1,
#           'prepared_agent': 1,
#           'needed_agent': 1,
#           'wiping_agent': 1,
#           'inclined_agent': 1,
#           'interrupted_agent': 1,
#           'getting_agent': 1,
#           'beamed_agent': 1,
#           "'d_agent": 1}),
#  'Gordon Dekalb': Counter({'wearing_agent': 1, 'carried_agent': 1}),
#  'Roberts': Counter(),
#  'Uncle Ralph': Counter({'phoned_agent': 1, 'loves_agent': 1}),
#  'Grampa': Counter({'killed_agent': 1,
#           'throwed_agent': 1,
#           'yells_agent': 1,
#           'raced_agent': 1,
#           'demanded_agent': 1,
#           'choked_agent': 1,
#           'focused_agent': 1,
#           'bowed_agent': 1,
#           'emerging_agent': 1,
#           'waved_agent': 1,
#           'carried_agent': 1,
#           'struggling_agent': 1,
#           'slept_agent': 1,
#           'grunted_agent': 1,
#           'sticking_agent': 1,
#           'buried_agent': 1,
#           'died_agent': 3,
#           'lies_agent': 1,
#           'Injun_patient': 1,
#           'come_patient': 2,
#           'succeeded_patient': 1,
#           'ai_patient': 1,
#           'facing_patient': 1,
#           'Feeling_patient': 1,
#           'sore_mod': 1,
#           'friends_mod': 1,
#           'bastard_mod': 1,
#           'head_mod': 1,
#           'scairt_mod': 1,
#           'havin_mod': 1}),
#  'LaFollette': Counter(),
#  'Jesus': Counter({'carry_agent': 1,
#           'stayed_agent': 1,
#           'planned_agent': 1,
#           'intended_agent': 1,
#           'hold_agent': 1,
#           'overwhelmed_patient': 1,
#           'stage_mod': 1}),
#  'Powell': Counter({'inaugurating_agent': 1,
#           'hiring_agent': 1,
#           'understood_agent': 1,
#           'kill_agent': 1}),
#  'Miss Nettie Field': Counter(),
#  'Granmaw': Counter(),
#  'Dr. Dekalb': Counter(),
#  'Arthur': Counter(),
#  'Rhoda': Counter(),
#  'Walter': Counter({'blew_agent': 1,
#           'handed_agent': 1,
#           'stretched_agent': 1,
#           'leaving_agent': 1,
#           'smiling_agent': 1,
#           'raised_agent': 1,
#           'divorced_patient': 1,
#           'alcoholic_mod': 1}),
#  'John Henry': Counter({'indicated_agent': 1}),
#  'Mr. Starr': Counter({'carried_agent': 1,
#           'tease_agent': 1,
#           'trust_agent': 1,
#           'understood_agent': 1,
#           'teasing_agent': 1,
#           'quieted_agent': 1,
#           'noticed_agent': 1,
#           'bring_agent': 1,
#           'drove_agent': 1,
#           'shut_agent': 1,
#           'twisted_agent': 1,
#           'move_agent': 1,
#           'trust_patient': 1}),
#  'Carrie': Counter({'start_agent': 1,
#           'wearing_agent': 1,
#           'say_patient': 1,
#           'dropped_patient': 1}),
#  'Mr. Ralph': Counter({'restrained_agent': 1,
#           'swing_agent': 1,
#           'bear_agent': 1}),
#  'Jim-Wilson': Counter(),
#  'Tom': Counter({'flipped_agent': 1,
#           'walking_agent': 1,
#           'vent_agent': 1,
#           'claimed_agent': 1,
#           'wept_agent': 1,
#           'tormented_patient': 1,
#           'calm_mod': 1}),
#  'Catherine': Counter({'accompanied_agent': 1}),
#  'Granma': Counter({'ai_agent': 1,
#           'coughed_agent': 1,
#           'raised_agent': 1,
#           'spoken_agent': 1,
#           'bowed_agent': 1,
#           'give_agent': 1,
#           'slept_agent': 4,
#           'drew_agent': 2,
#           'yawned_agent': 1,
#           'grinned_agent': 1,
#           'settled_agent': 1,
#           'answered_agent': 1,
#           'sulkin_agent': 1,
#           'gon_agent': 2,
#           'pray_agent': 1,
#           'hopped_agent': 1,
#           'shouted_agent': 1,
#           'whimpered_agent': 1,
#           'feels_agent': 1,
#           'speeded_agent': 2,
#           'retarded_agent': 1,
#           'needs_agent': 1,
#           'forget_agent': 1,
#           'dozed_agent': 1,
#           'bleated_agent': 1,
#           'swung_agent': 1,
#           'kicked_agent': 1,
#           'whined_agent': 1,
#           'sighed_agent': 1,
#           'thinkin_agent': 1,
#           'gets_agent': 1,
#           'sniffed_agent': 1,
#           'died_agent': 1,
#           'hobbled_patient': 1,
#           'helping_patient': 2,
#           'ai_patient': 1,
#           'tol_patient': 1,
#           'stripped_patient': 1,
#           'catch_patient': 1,
#           'Take_patient': 1,
#           'goin_mod': 1,
#           'awright_mod': 1,
#           'devil_mod': 1,
#           'tricky_mod': 1,
#           'jus_mod': 1,
#           'naked_mod': 1,
#           'a-sleepin_mod': 1}),
#  'Jackie': Counter({'knowing_agent': 1,
#           'grown_agent': 1,
#           'discovered_agent': 1,
#           'woke_agent': 1,
#           'disappointed_agent': 1,
#           'killed_agent': 1,
#           'live_agent': 1,
#           'passed_agent': 1,
#           'failed_agent': 1,
#           'leaked_agent': 1,
#           'adopted_patient': 1,
#           'accepted_patient': 1,
#           'excited_mod': 1,
#           'cheerful_mod': 1,
#           'number_mod': 1,
#           'captain_mod': 1,
#           'newborn_mod': 1,
#           'dark_mod': 1,
#           'psychic_mod': 1}),
#  'Morris': Counter({'cleared_agent': 1,
#           'raised_agent': 1,
#           'clicked_agent': 1,
#           'remind_patient': 1}),
#  'Ann': Counter({'hoping_agent': 1,
#           'gotten_agent': 1,
#           'saying_agent': 1,
#           'banged_agent': 1,
#           'holding_agent': 2,
#           'dropped_agent': 1,
#           'patted_agent': 1,
#           'scratching_agent': 1,
#           'shrugged_agent': 1,
#           'hoisted_agent': 1,
#           'respond_agent': 1,
#           'appeared_agent': 3,
#           'washed_agent': 1,
#           'stepped_agent': 1,
#           'noticed_agent': 1,
#           'answered_agent': 1,
#           'stand_agent': 1,
#           'swatted_agent': 1,
#           'tired_agent': 1,
#           'retired_agent': 1,
#           'trying_agent': 1,
#           'rubbed_agent': 1,
#           'feeding_agent': 1,
#           'speaking_agent': 1,
#           'swallowed_agent': 1,
#           'carried_agent': 1,
#           'ordered_agent': 1,
#           'pushed_agent': 1,
#           'flicked_agent': 1,
#           'slept_agent': 1,
#           'sit_agent': 1,
#           'mopping_agent': 1,
#           'call_agent': 1,
#           'discovered_patient': 1,
#           'Put_patient': 1,
#           'needed_patient': 1,
#           'split_patient': 1,
#           'understand_patient': 1,
#           'corrected_patient': 1,
#           'watch_patient': 1,
#           'touched_patient': 1,
#           'alcoholic_mod': 1,
#           'mess_mod': 1,
#           'lady_mod': 1}),
#  'Brannick': Counter(),
#  'Celia Gunn': Counter({'leave_agent': 1, 'available_mod': 1}),
#  'Mary': Counter({'feuded_agent': 1,
#           'suffered_agent': 1,
#           'woke_agent': 1,
#           'dragged_agent': 1,
#           'worked_agent': 1,
#           'ministered_agent': 1,
#           'stayed_agent': 1,
#           'endured_agent': 1,
#           'appeared_agent': 1,
#           'maintained_agent': 1,
#           'descended_agent': 1,
#           'judged_agent': 1,
#           'figure_agent': 1,
#           'puzzled_patient': 1,
#           'oldest_mod': 1,
#           'prone_mod': 1,
#           'pickaninny_mod': 1}),
#  'Cross': Counter(),
#  'Sally': Counter(),
#  'Ralph': Counter({'died_agent': 2,
#           'wearing_agent': 1,
#           'buried_patient': 1,
#           'nuts_mod': 1}),
#  'Tin Lizzie': Counter({'rolled_agent': 2, 'calling_patient': 1}),
#  'Daddy': Counter({'answered_agent': 1}),
#  'William S. Hart': Counter(),
#  'L&N': Counter(),
#  'Mrs. Follet': Counter({'threw_agent': 1,
#           'sustain_patient': 1,
#           'touching_patient': 1,
#           'whispering_patient': 1}),
#  'Kate': Counter({'standing_agent': 1}),
#  'Oliver': Counter(),
#  'Charlie': Counter({'squeeze_agent': 1,
#           'guessed_agent': 1,
#           'tasted_agent': 1,
#           'needed_agent': 7,
#           'brushed_agent': 1,
#           'figured_agent': 1,
#           'burned_agent': 2,
#           'discovered_agent': 1,
#           'taught_agent': 1,
#           'memorizing_agent': 1,
#           'sleep_agent': 1,
#           'named_agent': 1,
#           'rub_agent': 1,
#           'vomit_agent': 2,
#           'expected_agent': 3,
#           'passed_agent': 1,
#           'noticed_agent': 1,
#           'entertaining_agent': 1,
#           'stepped_agent': 2,
#           'pushed_agent': 2,
#           'congratulated_agent': 1,
#           'stick_agent': 1,
#           'dialed_agent': 4,
#           'grew_agent': 1,
#           'Is_agent': 1,
#           'showed_agent': 1,
#           'lying_agent': 4,
#           'processing_agent': 1,
#           'sit_agent': 4,
#           'sounded_agent': 1,
#           'hung_agent': 2,
#           'rolled_agent': 4,
#           'feed_agent': 1,
#           'owned_agent': 1,
#           'funneled_agent': 1,
#           'bought_agent': 4,
#           'spelled_agent': 1,
#           'grinned_agent': 1,
#           'threw_agent': 1,
#           'laid_agent': 1,
#           'swept_agent': 1,
#           'worried_agent': 4,
#           'rubbed_agent': 1,
#           'folded_agent': 1,
#           'saying_agent': 3,
#           "'d_agent": 1,
#           'imagined_agent': 4,
#           'join_agent': 1,
#           'leave_agent': 1,
#           'questioned_agent': 1,
#           'phrased_agent': 1,
#           'shaking_agent': 2,
#           'kissed_agent': 2,
#           'break_agent': 1,
#           'admired_agent': 1,
#           'absorbed_agent': 1,
#           'believed_agent': 1,
#           'joining_agent': 1,
#           'sworn_agent': 1,
#           'poured_agent': 1,
#           'stabbed_agent': 1,
#           'laughing_agent': 2,
#           'insist_agent': 1,
#           'patted_agent': 1,
#           'missed_agent': 2,
#           'hated_agent': 4,
#           'outgrew_agent': 1,
#           'imagine_agent': 4,
#           'grabbed_agent': 1,
#           'drafting_agent': 1,
#           'snatched_agent': 1,
#           'twisted_agent': 1,
#           'busied_agent': 1,
#           'understood_agent': 1,
#           'prided_agent': 1,
#           'mouthed_agent': 1,
#           'seeing_agent': 1,
#           'rest_agent': 1,
#           'learned_agent': 1,
#           'run_agent': 3,
#           'pop_agent': 1,
#           'sign_agent': 1,
#           'drinking_agent': 2,
#           'gotten_agent': 2,
#           'bit_agent': 2,
#           'help_agent': 2,
#           'find_agent': 3,
#           'deal_agent': 2,
#           'drummed_agent': 1,
#           'need_agent': 3,
#           'keep_agent': 1,
#           'paid_agent': 1,
#           'live_agent': 2,
#           'balk_agent': 1,
#           'floating_agent': 1,
#           'joked_agent': 1,
#           'spotted_agent': 1,
#           'rescue_agent': 1,
#           'looks_agent': 1,
#           'headed_agent': 2,
#           'remember_agent': 3,
#           'talking_agent': 1,
#           'burst_agent': 1,
#           'notice_agent': 1,
#           'wonder_agent': 1,
#           'holding_agent': 1,
#           'buried_agent': 1,
#           'resented_agent': 1,
#           'stewing_agent': 1,
#           'collapsed_agent': 1,
#           'changed_agent': 2,
#           'interrogate_agent': 1,
#           'neglecting_agent': 1,
#           'won_agent': 1,
#           'eat_agent': 4,
#           'dropped_agent': 1,
#           'stuck_agent': 2,
#           'vanished_agent': 1,
#           'listened_agent': 1,
#           'explained_agent': 1,
#           'married_agent': 1,
#           'appraising_agent': 1,
#           'chosen_agent': 1,
#           'switch_agent': 1,
#           'propose_agent': 1,
#           'arranged_agent': 1,
#           'planning_agent': 1,
#           'broke_agent': 2,
#           'dialing_agent': 1,
#           'handed_agent': 1,
#           'considered_agent': 1,
#           'call_agent': 3,
#           'chase_agent': 1,
#           'begin_agent': 1,
#           'show_agent': 1,
#           'chastising_agent': 1,
#           'Walking_agent': 1,
#           'using_agent': 1,
#           'shuddered_agent': 1,
#           'snorted_agent': 1,
#           'jerked_agent': 1,
#           'fell_agent': 1,
#           'throwing_agent': 2,
#           'working_agent': 2,
#           'joined_agent': 1,
#           'stop_agent': 1,
#           'buttoned_agent': 1,
#           'yelling_agent': 2,
#           'promise_agent': 1,
#           'looking_agent': 1,
#           'assumed_agent': 2,
#           'responded_agent': 1,
#           'wanting_agent': 3,
#           'visit_agent': 1,
#           'bring_agent': 1,
#           'coming_agent': 1,
#           'appear_agent': 1,
#           'having_agent': 1,
#           'crying_agent': 2,
#           'broken_agent': 2,
#           'tested_agent': 3,
#           'kicked_agent': 3,
#           'care_agent': 2,
#           'dying_agent': 1,
#           'sank_agent': 1,
#           'wandered_agent': 1,
#           'pounding_agent': 1,
#           'walking_agent': 2,
#           'wait_agent': 2,
#           'manage_agent': 1,
#           'cheated_agent': 2,
#           'happened_agent': 1,
#           'climbed_agent': 1,
#           'killed_agent': 1,
#           'impose_agent': 1,
#           'reminded_agent': 1,
#           'woke_agent': 2,
#           'convince_agent': 1,
#           'work_agent': 1,
#           'send_agent': 1,
#           'hoped_agent': 2,
#           'driving_agent': 1,
#           'spent_agent': 3,
#           'developing_agent': 1,
#           'hate_agent': 1,
#           'publishes_agent': 1,
#           'suffer_agent': 1,
#           'worry_agent': 1,
#           'does_agent': 1,
#           'calmed_agent': 1,
#           'played_agent': 1,
#           'scrubbed_agent': 1,
#           'stiffened_agent': 1,
#           'dropping_agent': 1,
#           'hurried_agent': 1,
#           'shut_agent': 1,
#           'trying_agent': 2,
#           'died_agent': 2,
#           'flung_agent': 1,
#           'closed_agent': 1,
#           'apologize_agent': 1,
#           'sorting_agent': 1,
#           'living_agent': 1,
#           'wearing_agent': 1,
#           'padded_agent': 1,
#           'rinsing_agent': 1,
#           'fix_agent': 2,
#           'wear_agent': 1,
#           'uttered_agent': 1,
#           'toured_agent': 1,
#           'buy_agent': 1,
#           'believe_agent': 2,
#           'arrived_agent': 1,
#           'blowing_agent': 1,
#           'staring_agent': 1,
#           'remembering_agent': 1,
#           'shouting_agent': 1,
#           'waiting_agent': 1,
#           'coerce_agent': 1,
#           'infected_agent': 1,
#           'eaten_agent': 1,
#           'die_agent': 1,
#           'yelled_agent': 1,
#           'end_agent': 1,
#           'met_agent': 2,
#           'dance_agent': 2,
#           'offered_agent': 1,
#           'inherited_agent': 2,
#           'treating_agent': 1,
#           'caused_agent': 1,
#           'loves_agent': 1,
#           'organized_agent': 1,
#           'introduced_agent': 1,
#           'worn_agent': 1,
#           'appreciated_agent': 1,
#           'use_agent': 1,
#           'pointed_agent': 1,
#           'getting_agent': 1,
#           'snap_agent': 1,
#           'doing_agent': 1,
#           'stayed_agent': 2,
#           'picking_agent': 1,
#           'protecting_agent': 1,
#           'exposing_agent': 1,
#           'slept_agent': 1,
#           'shoved_agent': 1,
#           'cursed_agent': 1,
#           'outlive_agent': 1,
#           'drowning_agent': 1,
#           'standing_agent': 1,
#           'expecting_agent': 1,
#           'fly_agent': 1,
#           'tackled_agent': 1,
#           'meant_agent': 1,
#           'skulking_agent': 1,
#           'accused_agent': 1,
#           'throw_agent': 1,
#           'smoothed_agent': 1,
#           'receiving_agent': 1,
#           'proposed_agent': 1,
#           'apologized_agent': 1,
#           'ate_agent': 1,
#           'keeping_agent': 1,
#           'spared_agent': 1,
#           'seem_agent': 1,
#           'caught_agent': 1,
#           'written_agent': 1,
#           'sweated_agent': 1,
#           'visited_agent': 1,
#           'grasped_agent': 1,
#           'talk_agent': 1,
#           'explain_agent': 1,
#           'check_agent': 1,
#           'forgave_agent': 1,
#           'hold_agent': 1,
#           'fed_agent': 1,
#           'replaced_agent': 1,
#           'give_agent': 1,
#           'unpack_agent': 1,
#           'redecorated_agent': 1,
#           'assured_agent': 1,
#           'promised_agent': 1,
#           'return_agent': 1,
#           'complaining_agent': 1,
#           'goes_agent': 1,
#           'coked_agent': 1,
#           'rubbing_agent': 1,
#           'pushing_patient': 1,
#           'wake_patient': 1,
#           'reassuring_patient': 1,
#           'spot_patient': 1,
#           'crossed_patient': 1,
#           'filled_patient': 2,
#           'curled_patient': 1,
#           'involved_patient': 1,
#           'worked_patient': 1,
#           'shout_patient': 1,
#           'questioned_patient': 1,
#           'exhausted_patient': 1,
#           'agitated_patient': 1,
#           'pitying_patient': 1,
#           'laughed_patient': 1,
#           'misdialed_patient': 1,
#           'gotten_patient': 1,
#           'reassured_patient': 1,
#           'broke_patient': 1,
#           'warm_patient': 1,
#           'thrilled_patient': 2,
#           'congratulate_patient': 1,
#           'parroting_patient': 1,
#           'save_patient': 1,
#           'trusting_patient': 1,
#           'scared_patient': 1,
#           'hurting_patient': 1,
#           'interrogate_patient': 1,
#           'teased_patient': 1,
#           'swung_patient': 1,
#           'contradicting_patient': 1,
#           'beat_patient': 1,
#           'chastising_patient': 1,
#           'lead_patient': 1,
#           'exposed_patient': 2,
#           'screamed_patient': 1,
#           'punched_patient': 1,
#           'convinced_patient': 1,
#           'hating_patient': 1,
#           'missing_patient': 1,
#           'absorbed_patient': 1,
#           'believe_patient': 1,
#           'chase_patient': 1,
#           'missed_patient': 3,
#           'meeting_patient': 1,
#           'trailed_patient': 1,
#           'tested_patient': 1,
#           'coerce_patient': 1,
#           'infected_patient': 2,
#           'prepared_patient': 1,
#           'fascinated_patient': 1,
#           'terrified_patient': 1,
#           'hate_patient': 1,
#           'inherited_patient': 1,
#           'treating_patient': 1,
#           'face_patient': 1,
#           'introduced_patient': 1,
#           'helping_patient': 1,
#           'escaped_patient': 1,
#           'protected_patient': 1,
#           'exposing_patient': 1,
#           'presented_patient': 1,
#           'outlive_patient': 1,
#           'follow_patient': 1,
#           'concerned_patient': 1,
#           'unhinged_patient': 1,
#           'avoid_patient': 1,
#           'tackled_patient': 1,
#           'sold_patient': 1,
#           'surprise_patient': 1,
#           'written_patient': 1,
#           'softened_patient': 1,
#           'hugged_patient': 1,
#           'forgave_patient': 1,
#           'showed_patient': 1,
#           'pick_patient': 1,
#           'fucking_patient': 1,
#           'hub_mod': 1,
#           'taller_mod': 1,
#           'allergic_mod': 1,
#           'genius_mod': 1,
#           'soft_mod': 1,
#           'hands-off_mod': 1,
#           'hard_mod': 1,
#           'available_mod': 1,
#           'wet_mod': 1,
#           'busier_mod': 1,
#           'uninterested_mod': 1,
#           'due_mod': 1,
#           'partner_mod': 1,
#           'outside_mod': 1,
#           'weepy_mod': 1,
#           'cook_mod': 1,
#           'fantastic_mod': 1,
#           'hypocrite_mod': 1,
#           'louse_mod': 1,
#           'calming_mod': 1,
#           'high_mod': 1,
#           'infected_mod': 1,
#           'last_mod': 1,
#           'cheating_mod': 2,
#           'pillar_mod': 1,
#           'chickenshit_mod': 1,
#           'okay_mod': 1,
#           'alien_mod': 1,
#           'lucid_mod': 1,
#           'new_mod': 1}),
#  'Sugar Babe': Counter({'ai_patient': 1, 'blow_patient': 1}),
#  'Colm Larkin': Counter({'played_agent': 1,
#           'stayed_agent': 1,
#           'identify_agent': 1,
#           'lost_agent': 1,
#           'weeping_agent': 1,
#           'sleep_agent': 1,
#           'fall_agent': 1,
#           'wounded_agent': 1,
#           'walk_agent': 2,
#           'pointed_agent': 1,
#           'remember_agent': 1,
#           'pierced_patient': 1,
#           'cheerful_mod': 1}),
#  'William Murray': Counter({'write_agent': 1,
#           'enrolled_agent': 1,
#           'showed_agent': 1,
#           'described_agent': 1,
#           'cured_agent': 1}),
#  'Dr. Kopeckny': Counter({'arrived_agent': 1,
#           'invited_agent': 1,
#           'replied_agent': 1,
#           'showed_agent': 1,
#           'ask_agent': 1,
#           'tested_agent': 1,
#           'test_agent': 1}),
#  'Michaels': Counter(),
#  'Helen': Counter({'volunteered_agent': 1,
#           'searched_agent': 1,
#           'rested_agent': 1,
#           'touched_agent': 1,
#           'written_agent': 1,
#           'offend_patient': 1,
#           'placed_patient': 1}),
#  'Virgil': Counter({'broke_agent': 1,
#           'jumped_agent': 2,
#           'gestured_agent': 1,
#           'wander_agent': 1,
#           'leap_agent': 1,
#           'snap_agent': 1,
#           'talk_agent': 1,
#           'discussed_agent': 1,
#           'intended_agent': 1,
#           'mastered_agent': 1,
#           'sent_agent': 2,
#           'trotting_agent': 1,
#           'grunted_agent': 1,
#           'spent_agent': 1,
#           'lookin_agent': 1,
#           'needed_agent': 1,
#           'paused_agent': 1,
#           'jes_agent': 1,
#           'worried_agent': 1,
#           'urged_agent': 1,
#           'speak_agent': 1,
#           'planting_agent': 1,
#           'run_agent': 1,
#           'expressed_agent': 1,
#           'rocking_patient': 1,
#           'retrieve_patient': 1,
#           'putting_patient': 1,
#           'assigned_patient': 1,
#           'patting_patient': 1,
#           'sen_patient': 1,
#           'confuse_patient': 1,
#           'train_patient': 1,
#           'talked_patient': 1,
#           'said_patient': 1,
#           'excepting_patient': 1,
#           'shouted_patient': 1,
#           'tryin_mod': 1,
#           'easy_mod': 1,
#           'mo_mod': 1}),
#  'Liwie': Counter({'filling_agent': 1, 'pass_agent': 1, 'pouring_agent': 1}),
#  'Leo': Counter({'developed_agent': 1,
#           'moaned_agent': 1,
#           'trying_agent': 1,
#           'calls_agent': 1,
#           'eats_agent': 1,
#           'worn_agent': 1,
#           'giggled_agent': 1,
#           'clapped_agent': 1,
#           'touched_agent': 1,
#           'commanded_agent': 1,
#           'gotten_agent': 2,
#           'wound_agent': 1,
#           'wheezed_agent': 1,
#           'exchanged_agent': 1,
#           'helped_agent': 1,
#           'handled_agent': 1,
#           'join_agent': 1,
#           'working_agent': 1,
#           'showed_agent': 1,
#           'rolled_agent': 1,
#           'hissed_agent': 1,
#           'snoring_agent': 1,
#           'mumbled_agent': 1,
#           'mention_agent': 1,
#           'standing_agent': 1,
#           'swung_agent': 1,
#           'loves_agent': 1,
#           'lifted_agent': 1,
#           'was_patient': 1,
#           'determined_patient': 1,
#           'exhausted_patient': 1,
#           'torn_patient': 1,
#           'spotted_patient': 1,
#           'rousted_patient': 1,
#           'released_patient': 1}),
#  'Nora': Counter({'listed_agent': 2,
#           'bore_agent': 1,
#           'covered_agent': 1,
#           'touched_agent': 1,
#           'beamed_agent': 1,
#           'rescued_agent': 1,
#           'coughed_agent': 2,
#           'blinked_agent': 2,
#           'leaned_agent': 3,
#           'blushed_agent': 1,
#           'pointed_agent': 2,
#           'predict_agent': 1,
#           'repeat_agent': 1,
#           'love_agent': 1,
#           'promised_agent': 1,
#           'try_agent': 1,
#           'dies_agent': 1,
#           'suggested_agent': 2,
#           'keep_agent': 1,
#           'understand_agent': 1,
#           'talk_agent': 1,
#           'claimed_agent': 1,
#           'pay_agent': 1,
#           'endow_agent': 1,
#           'seem_agent': 2,
#           'doing_agent': 1,
#           'died_agent': 2,
#           'vanished_agent': 1,
#           'talking_agent': 3,
#           'lives_agent': 1,
#           'donate_agent': 1,
#           'needed_agent': 3,
#           'piped_agent': 1,
#           'wheeled_agent': 2,
#           'invited_agent': 1,
#           'die_agent': 2,
#           'managed_agent': 1,
#           'showed_agent': 1,
#           'means_agent': 1,
#           'raised_agent': 1,
#           'passing_agent': 1,
#           'tapped_agent': 1,
#           'donating_agent': 1,
#           'willed_agent': 1,
#           'written_agent': 2,
#           'imagined_agent': 1,
#           'ordered_agent': 1,
#           'remember_agent': 1,
#           'holding_agent': 1,
#           'meant_agent': 4,
#           'passed_agent': 2,
#           'telling_agent': 1,
#           'drowning_agent': 1,
#           'coughing_agent': 1,
#           'taking_agent': 1,
#           'belonged_agent': 1,
#           'object_agent': 1,
#           'burned_agent': 1,
#           'sit_agent': 1,
#           'fixed_agent': 1,
#           'squeezing_agent': 1,
#           'accepted_agent': 1,
#           'contacted_agent': 1,
#           'chosen_agent': 1,
#           'looking_agent': 1,
#           'insisted_agent': 1,
#           'prepare_agent': 1,
#           'squinted_agent': 1,
#           'ask_agent': 1,
#           'zoomed_agent': 1,
#           'given_agent': 1,
#           'trusted_agent': 1,
#           'tended_agent': 1,
#           'show_agent': 1,
#           'getting_agent': 1,
#           'mugged_patient': 1,
#           'built_patient': 1,
#           'agitated_patient': 1,
#           'spoiled_patient': 1,
#           'grill_patient': 1,
#           'counseling_patient': 1,
#           'humoring_patient': 1,
#           'bother_patient': 1,
#           'lock_patient': 1,
#           'remind_patient': 1,
#           'harass_patient': 1,
#           'wrote_patient': 1,
#           'reach_patient': 1,
#           'sat_patient': 1,
#           'entertained_patient': 1,
#           'shopped_patient': 1,
#           'thrilled_patient': 1,
#           'roll_patient': 1,
#           'pushing_patient': 1,
#           'impish_mod': 1,
#           'front_mod': 1,
#           'victim_mod': 1,
#           'adamant_mod': 1,
#           'artist_mod': 1,
#           'sharp_mod': 1,
#           'amenable_mod': 1,
#           'lovely_mod': 1,
#           'great_mod': 1}),
#  'Dr. Chouteau': Counter({'learned_agent': 1,
#           'hides_agent': 1,
#           'strolls_agent': 1,
#           'resembles_agent': 1,
#           'continued_agent': 1,
#           'resembling_patient': 1}),
#  'Lawrence': Counter({'grinned_agent': 1,
#           'goin_agent': 1,
#           'carrying_agent': 1,
#           'died_agent': 2,
#           'understand_agent': 1}),
#  'Jane': Counter({'pretended_agent': 1, 'scarce-hipped_mod': 1}),
#  'Lauren': Counter({'lives_agent': 1,
#           'forbade_agent': 1,
#           'constructed_agent': 1,
#           'sank_agent': 1,
#           'admitted_agent': 1,
#           'avoided_agent': 1,
#           'attended_agent': 1,
#           'forgiven_agent': 1,
#           'objected_agent': 1,
#           'bear_agent': 1,
#           'presented_agent': 1,
#           'twitched_agent': 1,
#           'tossed_agent': 1,
#           'continued_agent': 1,
#           'manufactured_agent': 1,
#           'chosen_agent': 2,
#           'ransacked_agent': 1,
#           'owned_agent': 1,
#           'marrying_patient': 1,
#           'awaited_patient': 1}),
#  'Dr. Fuller': Counter({'sniffed_agent': 1, 'thrust_agent': 1}),
#  'Copernicus': Counter({'spoken_agent': 1,
#           'pull_agent': 1,
#           'find_agent': 1,
#           'painted_agent': 1,
#           'head_agent': 1,
#           'led_agent': 1,
#           'drawn_patient': 1,
#           'stayed_patient': 1}),
#  'Theo': Counter({'looks_agent': 1,
#           'enjoy_agent': 1,
#           'speak_agent': 1,
#           'stay_agent': 1,
#           'ok_agent': 1,
#           'ask_agent': 1,
#           'moving_agent': 1,
#           'repeated_agent': 1,
#           'stepped_agent': 1,
#           'trying_agent': 2,
#           'marvel_agent': 1,
#           'slipped_agent': 1,
#           'committed_agent': 1,
#           'pushed_agent': 1,
#           'meant_agent': 1,
#           "'m_patient": 1,
#           'hey_patient': 1,
#           'remember_patient': 1,
#           'adorable_mod': 1,
#           'darling_mod': 1,
#           'addict_mod': 1}),
#  'Agnes': Counter({'emerged_agent': 2,
#           'accepted_agent': 2,
#           'slid_agent': 1,
#           'dropped_agent': 1,
#           'poured_agent': 2,
#           'carried_agent': 1,
#           'raised_agent': 3,
#           'ask_agent': 2,
#           'disappeared_agent': 1,
#           'bought_agent': 1,
#           'wave_agent': 1,
#           'placed_agent': 3,
#           'warm_agent': 1,
#           'chosen_agent': 2,
#           'studied_agent': 1,
#           'designed_agent': 1,
#           'selected_agent': 1,
#           'claimed_agent': 1,
#           'forgotten_agent': 1,
#           'concluded_agent': 1,
#           'approve_agent': 1,
#           'given_agent': 1,
#           'discussed_agent': 1,
#           'offered_agent': 1,
#           'paused_agent': 2,
#           'died_agent': 1,
#           'lifted_agent': 1,
#           'looking_agent': 1,
#           'learned_agent': 1,
#           'stand_agent': 1,
#           'snub_agent': 1,
#           'begun_agent': 1,
#           'froze_agent': 1,
#           'waiting_agent': 1,
#           'crossed_agent': 1,
#           'mentioned_agent': 1,
#           'spent_agent': 1,
#           'promised_agent': 1,
#           'closed_agent': 1,
#           'touching_agent': 1,
#           'played_agent': 1,
#           'proceed_agent': 1,
#           'approached_agent': 1,
#           'saying_agent': 1,
#           'waited_patient': 1,
#           'studied_patient': 1,
#           'forgiven_patient': 1,
#           'waking_patient': 1,
#           'convince_patient': 1,
#           'seated_patient': 1,
#           'bride_mod': 1,
#           'thin_mod': 1,
#           'freshman_mod': 1}),
#  'Bancroft': Counter({'disappeared_agent': 1, 'chilling_patient': 1}),
#  'Cassandra': Counter({'raised_agent': 1,
#           'libs_agent': 1,
#           'ejaculated_agent': 1,
#           'considered_agent': 1,
#           'name_agent': 1,
#           'clicked_agent': 1,
#           'defended_agent': 1,
#           'taught_agent': 1,
#           'thinking_agent': 1,
#           'perturbed_agent': 1,
#           'agreed_agent': 1,
#           'getting_agent': 1,
#           'care_agent': 1,
#           'educated_agent': 1,
#           'doing_agent': 1,
#           'been_patient': 1,
#           'nigger_mod': 1}),
#  'Martin': Counter({'remember_patient': 1, 'Charlie_mod': 1}),
#  'Winifred': Counter(),
#  'Bessie': Counter({'spent_agent': 1,
#           'packed_agent': 1,
#           'signed_agent': 1,
#           'strolled_agent': 1,
#           'failed_agent': 1,
#           'hustled_agent': 1,
#           'passed_agent': 1,
#           'crossed_agent': 1,
#           'searched_agent': 1,
#           'arrived_agent': 2,
#           'greeted_agent': 1,
#           'sleeping_agent': 1,
#           'switch_agent': 1,
#           'bought_agent': 1,
#           'smoothed_agent': 1,
#           'bunched_agent': 1,
#           'allowed_agent': 1,
#           'mopped_agent': 1,
#           'listened_agent': 1,
#           'benefited_agent': 1,
#           'admired_agent': 1,
#           'survived_agent': 1,
#           'prepared_agent': 1,
#           'imagined_agent': 1,
#           'sprinted_agent': 1,
#           'delivered_agent': 1,
#           'waited_agent': 1,
#           'chortled_agent': 1,
#           'suggested_agent': 1,
#           'invited_agent': 1,
#           'recruited_agent': 1,
#           'reported_agent': 1,
#           'elevated_agent': 1,
#           'sold_agent': 2,
#           'snarled_agent': 1,
#           'handed_agent': 1,
#           'relinquished_agent': 1,
#           'thanked_patient': 1,
#           'chased_patient': 1,
#           'recognized_patient': 1,
#           'thrilled_patient': 1,
#           'purchased_patient': 1,
#           'write_patient': 1,
#           'threw_patient': 1,
#           'named_patient': 1,
#           'patient_mod': 1}),
#  'Lesueur': Counter({'pouted_agent': 1, 'continued_agent': 1}),
#  'Montgomerie': Counter(),
#  'Denis': Counter({'doan_agent': 2,
#           'showed_agent': 1,
#           'answered_agent': 1,
#           'remarked_agent': 1,
#           'inquired_agent': 2,
#           'led_agent': 1,
#           'dropped_agent': 1,
#           'raised_agent': 1,
#           'give_agent': 1,
#           'lies_agent': 1,
#           'works_agent': 1,
#           'appear_agent': 1,
#           'pointed_agent': 1,
#           'call_agent': 1,
#           'swished_agent': 1,
#           'run_agent': 1,
#           'join_patient': 1,
#           'correct_mod': 1}),
#  'James': Counter({'eat_agent': 1,
#           'refused_agent': 2,
#           'led_agent': 1,
#           'stop_agent': 3,
#           'pick_agent': 1,
#           'failed_agent': 1,
#           'wandered_agent': 1,
#           'looking_agent': 1,
#           'wept_agent': 1,
#           'placed_agent': 1,
#           'pointed_agent': 1,
#           'tapped_agent': 1,
#           'grabbed_agent': 1,
#           'notice_agent': 1,
#           'interrupted_agent': 1,
#           'trusted_agent': 1,
#           'worked_agent': 2,
#           'spat_agent': 1,
#           'dug_agent': 1,
#           'disappeared_agent': 1,
#           'becoming_agent': 1,
#           'lost_agent': 1,
#           'scurried_agent': 1,
#           'stayed_agent': 1,
#           'replaced_agent': 1,
#           'keep_agent': 1,
#           'packed_agent': 1,
#           'requested_agent': 1,
#           'patted_agent': 1,
#           'grunted_agent': 1,
#           'swept_agent': 1,
#           'produced_agent': 1,
#           'fetched_agent': 1,
#           'ignored_agent': 1,
#           'pushed_agent': 1,
#           'ordered_agent': 1,
#           'asking_agent': 1,
#           'gestured_agent': 1,
#           'paled_agent': 1,
#           'concluded_agent': 1,
#           'attempted_agent': 1,
#           'repeated_agent': 1,
#           'glanced_agent': 1,
#           'hid_agent': 1,
#           'roved_agent': 1,
#           'locate_agent': 1,
#           'reach_agent': 1,
#           'find_agent': 1,
#           'nursing_patient': 1,
#           'concerned_patient': 1,
#           'follow_patient': 1,
#           'alerted_patient': 1,
#           'address_patient': 1,
#           'digging_mod': 1,
#           'brief_mod': 1}),
#  'Harry': Counter({'showed_agent': 1,
#           'pointed_agent': 1,
#           'planning_agent': 1,
#           'invited_agent': 1,
#           'created_agent': 1,
#           'concocted_agent': 1,
#           'daubed_agent': 1,
#           'unleash_agent': 1,
#           'written_agent': 1}),
#  'Lavinia': Counter(),
#  'Caleb': Counter({'ordered_agent': 1,
#           'dismounted_agent': 1,
#           'managed_agent': 2,
#           'pass_agent': 1,
#           'changed_agent': 1}),
#  'Erasmus': Counter({'given_agent': 1,
#           'recorded_agent': 1,
#           'owned_agent': 1,
#           'sold_agent': 1,
#           'coming_agent': 1,
#           'shore_patient': 1}),
#  'Eudora': Counter({'meet_agent': 1}),
#  'Scheuchzer': Counter(),
#  'Dr. Boerhaave': Counter(),
#  'Grace': Counter({'showed_agent': 1,
#           'led_agent': 1,
#           'falls_agent': 1,
#           'lays_agent': 1,
#           'predicted_agent': 1,
#           'worked_agent': 1,
#           'lying_agent': 1,
#           'lifted_agent': 1,
#           'eased_agent': 1,
#           'broke_agent': 1,
#           'stepped_agent': 1,
#           'busied_agent': 1,
#           'working_agent': 1,
#           'shattered_agent': 1,
#           'sewn_agent': 1,
#           'promised_agent': 1,
#           'smoothed_agent': 1,
#           'saved_agent': 1,
#           'struggled_agent': 1,
#           'sought_agent': 1,
#           'given_agent': 1,
#           'expected_agent': 1,
#           'pressed_agent': 1,
#           'breathed_agent': 1,
#           'glimpsed_patient': 1,
#           'disturb_patient': 1,
#           'shifted_patient': 1}),
#  'Mr. Wright': Counter({'presented_patient': 1, 'did_patient': 1}),
#  'George': Counter({'dropped_agent': 1, 'waited_agent': 1}),
#  'Dehra Dun': Counter(),
#  'Hermione': Counter({'send_agent': 1, 'grown_agent': 1}),
#  'Mr. Woodruff': Counter({'spent_agent': 1,
#           'gained_agent': 1,
#           'rowed_patient': 1}),
#  'Academy': Counter(),
#  'Godfrey Vigne': Counter({'managed_agent': 1,
#           'described_agent': 1,
#           'triangulated_agent': 1}),
#  'Samuel': Counter({'preaches_agent': 1,
#           'visit_agent': 2,
#           'perked_agent': 1,
#           'dreamed_agent': 2,
#           'thinks_agent': 1,
#           'talks_agent': 1,
#           'met_agent': 3,
#           'swear_agent': 1,
#           'urged_agent': 1,
#           'run_agent': 1,
#           'finished_agent': 1,
#           'telling_agent': 1,
#           'holding_agent': 1,
#           'speaking_agent': 1,
#           'hesitated_agent': 1,
#           'tells_agent': 1,
#           'loves_agent': 1,
#           'accompanied_agent': 1,
#           'continued_agent': 1,
#           'struck_agent': 1,
#           'reassure_agent': 1,
#           'sends_agent': 1,
#           'discussing_agent': 1,
#           'feels_agent': 1,
#           'married_agent': 1,
#           'reading_patient': 1,
#           'browbeat_patient': 1,
#           'worries_patient': 1,
#           'teach_patient': 1,
#           'invite_patient': 1,
#           'confused_patient': 1,
#           'reached_patient': 1,
#           'respected_patient': 1,
#           'reassure_patient': 1,
#           'swaying_patient': 1,
#           'father_mod': 1}),
#  'Kalm': Counter({'visited_agent': 1}),
#  'Suky': Counter({'reminded_agent': 1,
#           'directed_agent': 1,
#           'bought_agent': 1,
#           'consulted_agent': 1,
#           'disappeared_agent': 1,
#           'breathed_agent': 1,
#           'basked_agent': 1,
#           'given_agent': 1,
#           'occupied_patient': 1,
#           'holding_patient': 1}),
#  'Dr. Davis': Counter({'admits_agent': 1,
#           'scorn_agent': 1,
#           'thinks_agent': 2,
#           'displays_agent': 1,
#           'does_agent': 1,
#           'likes_agent': 1,
#           'gathers_agent': 1,
#           'placed_patient': 1,
#           'upset_patient': 1}),
#  'East India Company': Counter({'tells_agent': 1,
#           'appears_agent': 1,
#           'reveals_agent': 1,
#           'resembles_agent': 1,
#           'claims_agent': 2}),
#  'Conrad': Counter({'risen_agent': 1,
#           'hoisted_agent': 1,
#           'folded_agent': 1,
#           'fell_agent': 1,
#           'choose_agent': 1,
#           'pulling_agent': 1,
#           'murmur_agent': 1,
#           'guessed_agent': 1,
#           'send_agent': 1,
#           'jumped_agent': 1,
#           'coming_agent': 2,
#           'stay_agent': 1,
#           'leaned_agent': 1,
#           'excited_patient': 1,
#           'absolved_patient': 1,
#           'reassured_patient': 1,
#           'upset_patient': 1,
#           'imagine_patient': 1,
#           'competent_mod': 1}),
#  'Mr. Bartram': Counter({'listened_agent': 1,
#           'waved_agent': 1,
#           'train_agent': 1,
#           'pulls_agent': 1,
#           'gestured_agent': 1,
#           'explained_agent': 1,
#           'gaze_agent': 1,
#           'betrayed_agent': 1,
#           'continued_agent': 1,
#           'written_agent': 1,
#           'complimented_patient': 1}),
#  'Stuart': Counter({'rode_agent': 1,
#           'moving_agent': 1,
#           'doing_agent': 1,
#           'joyriding_agent': 2,
#           'sent_agent': 1,
#           'fool_agent': 1,
#           'leave_agent': 1,
#           'gets_agent': 1,
#           'having_agent': 1,
#           'comes_agent': 4,
#           'thanked_agent': 1,
#           'woke_agent': 1,
#           'developed_agent': 1,
#           'appeared_agent': 1,
#           'pressed_agent': 1,
#           'wished_agent': 1,
#           'swung_agent': 1,
#           'grinning_agent': 1,
#           'grinned_agent': 1,
#           'drawled_agent': 1,
#           'froze_agent': 1,
# ...
#           'shrugged_agent': 1,
#           'grown_agent': 1,
#           'pursed_agent': 1,
#           'knocked_agent': 1,
#           'tells_agent': 1,
#           'sprang_agent': 1,
#           'tossed_agent': 1,
#           'tries_agent': 1}),
#  'Murphy': Counter(),
#  'Headquarters Squadron': Counter({'activate_patient': 1}),
#  'Miss Jelliffe': Counter({'advanced_agent': 1,
#           'typed_agent': 1,
#           'laid_agent': 1,
#           'hesitated_agent': 1,
#           'shrugged_agent': 1,
#           'closed_agent': 1,
#           'entered_agent': 1,
#           'remember_agent': 1,
#           'allowed_patient': 1,
#           'day_mod': 1}),
#  'Signal Corps': Counter({'sent_agent': 1}),
#  'Lester': Counter(),
#  'De Luca': Counter(),
#  'Sal': Counter(),
#  'Wiley': Counter({'sticking_agent': 1,
#           'find_agent': 1,
#           'attended_agent': 1,
#           'leaned_agent': 1,
#           'demand_agent': 1,
#           'reads_agent': 1,
#           'calls_agent': 1,
#           'tanned_agent': 1,
#           'promises_agent': 1,
#           'looking_agent': 1,
#           'kissed_agent': 1,
#           'reassuring_agent': 1,
#           'slammed_agent': 1,
#           'drive_agent': 1,
#           'offered_agent': 1,
#           'taking_agent': 1,
#           'driven_agent': 1,
#           'share_agent': 1,
#           'pry_patient': 1,
#           'return_patient': 1,
#           'drawing_patient': 1,
#           'disappointed_patient': 1,
#           'stationed_patient': 1,
#           'cut_patient': 1,
#           'important_mod': 1,
#           'cheerful_mod': 1}),
#  'Transit Company': Counter({'causing_patient': 1}),
#  'Anderson': Counter({'listened_agent': 1, 'Mormon_mod': 1}),
#  'Malcolm': Counter({'bought_agent': 1,
#           'answered_agent': 1,
#           'been_patient': 1}),
#  'Tyler': Counter({'waiting_agent': 1,
#           'judge_agent': 1,
#           'sobered_agent': 1,
#           'reason_patient': 1}),
#  'Negro': Counter(),
#  'Edsell': Counter({'refuse_agent': 1,
#           'lives_agent': 1,
#           'thinks_agent': 2,
#           'understands_agent': 1,
#           'hung_agent': 2,
#           'glanced_agent': 2,
#           'rein_agent': 1,
#           'doing_agent': 4,
#           'persecuted_agent': 1,
#           'mean_agent': 1,
#           'means_agent': 2,
#           'sees_agent': 1,
#           'write_agent': 1,
#           'appeared_agent': 1,
#           'showed_agent': 2,
#           'getting_agent': 1,
#           'arose_agent': 1,
#           'run_agent': 1,
#           'try_agent': 1,
#           'forgotten_agent': 1,
#           'noticed_agent': 1,
#           'sent_agent': 1,
#           'figured_agent': 1,
#           'believe_agent': 1,
#           'lets_agent': 1,
#           'looking_agent': 2,
#           'stepped_agent': 1,
#           'talking_agent': 1,
#           'improved_agent': 1,
#           'pretend_agent': 1,
#           'asking_agent': 1,
#           'lean_agent': 1,
#           'displayed_agent': 1,
#           'acted_agent': 1,
#           'met_agent': 1,
#           'refused_agent': 1,
#           'questioned_agent': 1,
#           'behaved_agent': 1,
#           'proceed_agent': 1,
#           'planned_agent': 1,
#           'yielded_agent': 1,
#           'seem_agent': 1,
#           'disregarded_agent': 1,
#           'running_agent': 1,
#           'attempted_agent': 1,
#           'observed_agent': 1,
#           'coming_agent': 2,
#           'hit_agent': 1,
#           'shrugged_agent': 1,
#           'gets_agent': 2,
#           'push_agent': 1,
#           'owe_agent': 1,
#           'allowed_agent': 1,
#           'owes_agent': 2,
#           'give_agent': 1,
#           'jumped_agent': 1,
#           'brooded_agent': 1,
#           'acknowledged_agent': 1,
#           'suffered_agent': 1,
#           'roused_agent': 1,
#           'makes_agent': 1,
#           'approached_agent': 1,
#           'considered_agent': 1,
#           'answered_agent': 1,
#           'help_agent': 1,
#           'reached_patient': 1,
#           'push_patient': 1,
#           'needed_patient': 1,
#           'publish_patient': 1,
#           'pay_patient': 1,
#           'bringing_patient': 1,
#           'favoring_patient': 1,
#           'dedicated_patient': 1,
#           'drag_patient': 1,
#           'involved_patient': 1,
#           'wearing_patient': 1,
#           'understand_patient': 1,
#           'touching_patient': 1,
#           'arrest_patient': 2,
#           'restrain_patient': 1,
#           'scared_patient': 1,
#           'blame_patient': 1,
#           'was_patient': 1,
#           'officer_mod': 1,
#           'writer_mod': 3,
#           'drinker_mod': 1,
#           'jerk_mod': 1,
#           'goddamn_mod': 1,
#           'way_mod': 1,
#           'incompetent_mod': 1,
#           'marvelous_mod': 1,
#           'player_mod': 1}),
#  'Shakespeare': Counter({'lectured_agent': 2,
#           'counting_patient': 1,
#           'reciting_patient': 1,
#           'course_mod': 1}),
#  'Operations': Counter({'directed_patient': 1, 'run_patient': 1}),
#  'Jim Crow': Counter({'ai_agent': 1, 'defined_agent': 1}),
#  'Pettie': Counter({'passed_agent': 1,
#           'breathed_agent': 1,
#           'regretting_agent': 1,
#           'managed_agent': 1,
#           'catches_agent': 1,
#           'arisen_agent': 1,
#           'blushed_agent': 1,
#           'showed_patient': 1,
#           'overwhelmed_mod': 1}),
#  'Mr. DeWilton': Counter(),
#  'Richardson': Counter(),
#  'Miami Herald': Counter({'remarked_agent': 1, 'estimated_agent': 1}),
#  'Washington Star': Counter({'proposed_agent': 1, 'pointed_agent': 1}),
#  'Mr. Hines': Counter({'time_mod': 1}),
#  'Herbert Gelman': Counter({'remembers_agent': 1,
#           'please_agent': 1,
#           'are_agent': 1,
#           'remarked_agent': 1,
#           'looking_agent': 2,
#           'wishes_agent': 1,
#           'shifted_agent': 1,
#           'replied_agent': 1,
#           'repeated_agent': 1,
#           'promised_agent': 1,
#           'interrupted_agent': 2,
#           'permit_agent': 1,
#           'demanded_agent': 1,
#           'blowing_agent': 1,
#           'leaned_agent': 1,
#           'offer_agent': 1,
#           'telling_agent': 1,
#           'remember_patient': 2,
#           'solved_patient': 1,
#           'forgiven_patient': 1,
#           'regarding_patient': 1,
#           'elbowed_patient': 1,
#           'bothering_patient': 1,
#           'Secretary_mod': 1,
#           'citizen_mod': 1,
#           'case_mod': 1}),
#  'Newark News': Counter(),
#  'Mimi': Counter({'cracking_agent': 1, 'wrap_patient': 1}),
#  'Mr. Witness': Counter({'intend_agent': 1, 'observed_agent': 2}),
#  'Interior': Counter(),
#  'Mr. Abbott': Counter(),
#  'Navy Band': Counter({'playing_agent': 1}),
#  'Henry Lytle': Counter({'tells_agent': 1, 'prints_agent': 1}),
#  'Billy Knox': Counter({'occupied_agent': 1,
#           'beginning_agent': 2,
#           'spent_agent': 1}),
#  'Victor Ennis': Counter({'nods_agent': 1,
#           'observed_agent': 1,
#           'echoed_agent': 1,
#           'refused_agent': 1,
#           'murmured_agent': 1,
#           'perfected_agent': 1}),
#  'Mr. LefBngwell': Counter({'win_agent': 1, 'treated_patient': 1}),
#  'Pooh': Counter({'included_agent': 1,
#           'find_agent': 1,
#           'wandered_agent': 1,
#           'looking_agent': 1,
#           'given_agent': 1,
#           'failed_agent': 1}),
#  'Rob Cunningham': Counter({'leaned_agent': 1, 'murmured_agent': 1}),
#  'Henry Wilson': Counter({'sent_agent': 1, 'doing_agent': 1}),
#  'AP': Counter(),
#  'National Committee': Counter(),
#  'Robert A. Leffingwell': Counter({'repeat_agent': 1,
#           'opposed_agent': 1,
#           'paused_agent': 2,
#           'betray_agent': 1,
#           'drained_agent': 1,
#           'laid_agent': 1,
#           'finished_agent': 1,
#           'making_agent': 1,
#           'applying_agent': 1,
#           'keep_agent': 1,
#           'studied_agent': 1,
#           'hung_agent': 1,
#           'reconcile_agent': 1,
#           'needed_agent': 1,
#           'feeling_agent': 1,
#           'slept_agent': 1,
#           'stay_agent': 1,
#           'supposed_agent': 1,
#           'wished_agent': 1,
#           'waved_agent': 1,
#           'submitted_agent': 1,
#           'justify_agent': 1,
#           'opposed_patient': 2,
#           'abominate_patient': 1,
#           'defy_patient': 1,
#           'came_patient': 1,
#           'considered_patient': 1,
#           'placing_patient': 1,
#           'greeted_patient': 1,
#           'scare_patient': 1,
#           'dragging_patient': 1,
#           'informed_patient': 1,
#           'defeating_patient': 1,
#           'confirm_patient': 1,
#           'wish_patient': 1,
#           'appoint_patient': 1,
#           'use_patient': 2,
#           'supported_patient': 1,
#           'high_mod': 1,
#           'honest_mod': 1,
#           'dismayed_mod': 1,
#           'tireder_mod': 1}),
#  'Mrs. Adams': Counter({'slipped_agent': 1}),
#  'Hank': Counter({'grown_agent': 2}),
#  'Ray Smith': Counter({'thinks_agent': 2}),
#  'Murfee Andrews': Counter({'loaded_agent': 1,
#           'cast_agent': 1,
#           'emerged_agent': 1,
#           'joined_agent': 1,
#           'hesitated_agent': 1,
#           'provoke_patient': 1}),
#  'Stanley Danta': Counter({'sent_agent': 1,
#           'practicing_agent': 1,
#           'played_agent': 1,
#           'observed_agent': 2,
#           'explained_agent': 1,
#           'suspects_agent': 1,
#           'gestured_agent': 1,
#           'comes_agent': 1,
#           'chuckled_agent': 1,
#           'means_agent': 1,
#           'prevent_agent': 1,
#           'remarked_agent': 3,
#           'watching_agent': 1,
#           'thinking_agent': 1,
#           'suggested_agent': 6,
#           'gested_agent': 1,
#           'agreed_agent': 1,
#           'reflected_agent': 1,
#           'conceded_agent': 1,
#           'rates_agent': 1,
#           'understands_agent': 1,
#           'valued_agent': 1,
#           'rally_agent': 1,
#           'volunteered_agent': 1,
#           'contacted_agent': 1,
#           'talk_agent': 1,
#           'repeated_agent': 1,
#           'are_agent': 1,
#           'carried_agent': 1,
#           'piloting_agent': 1,
#           'offended_patient': 1,
#           'reserved_patient': 1,
#           'determined_patient': 1,
#           'fool_patient': 1,
#           'welcome_patient': 1,
#           'understand_patient': 1,
#           'judge_patient': 1,
#           'Ask_patient': 1,
#           'curious_mod': 1,
#           'moment_mod': 1,
#           'politician_mod': 1}),
#  'Raoul Barre': Counter({'order_agent': 1,
#           'suggested_agent': 3,
#           'inquired_agent': 1,
#           'observed_agent': 1,
#           'overwhelms_agent': 1,
#           'finished_agent': 1,
#           'murmured_agent': 1,
#           'decide_agent': 1,
#           'relapsed_agent': 1,
#           'need_patient': 1,
#           'quote_patient': 1,
#           'picking_patient': 1,
#           'informed_patient': 1}),
#  'Dave Grant': Counter({'busied_agent': 1}),
#  'Cashton': Counter(),
#  'Abe': Counter({'died_agent': 1,
#           'refused_agent': 1,
#           'believed_agent': 1,
#           'freed_patient': 1,
#           'bitter_mod': 1,
#           'happier_mod': 1}),
#  'Royce Blair': Counter({'selected_agent': 1,
#           'enunciates_agent': 1,
#           'snapped_agent': 1}),
#  'Kitty': Counter({'ended_agent': 1,
#           'insists_agent': 1,
#           'ordered_agent': 1,
#           'stepped_agent': 2,
#           'grinned_agent': 1,
#           'interrupted_agent': 1,
#           'spoken_agent': 1,
#           'demurred_agent': 1,
#           'headed_agent': 1,
#           'undergone_agent': 1,
#           'washed_agent': 1,
#           'exhaled_agent': 1,
#           'humming_agent': 1,
#           'wearing_agent': 2,
#           'turn_agent': 1,
#           'experienced_agent': 1,
#           'poured_agent': 1,
#           'pressed_agent': 1,
#           'adored_agent': 1,
#           'leaned_agent': 1,
#           'stop_agent': 1,
#           'flung_agent': 1,
#           'died_agent': 1,
#           'smiling_agent': 1,
#           'played_agent': 1,
#           'smiles_agent': 1,
#           'starts_agent': 1,
#           'belongs_agent': 1,
#           'recognize_agent': 1,
#           'asks_agent': 1,
#           'turns_agent': 1,
#           'eats_agent': 1,
#           'ignores_agent': 1,
#           'requested_agent': 1,
#           'touch_agent': 1,
#           'dipped_agent': 1,
#           'falls_agent': 1,
#           'tilts_agent': 1,
#           'shrinks_agent': 1,
#           'erect_agent': 1,
#           'leads_agent': 1,
#           'reach_agent': 1,
#           'resumed_agent': 1,
#           'looks_agent': 1,
#           'writhing_agent': 1,
#           'open_agent': 1,
#           'avails_agent': 1,
#           'manages_agent': 1,
#           'running_agent': 1,
#           'sent_agent': 1,
#           'assaulting_patient': 1,
#           'interviewing_patient': 1,
#           'enshrined_patient': 1,
#           'hire_patient': 1,
#           'hiding_patient': 1,
#           'forced_patient': 1,
#           'went_patient': 1,
#           'hustled_patient': 1,
#           'recognize_patient': 3,
#           'carrying_patient': 1,
#           'nuzzling_patient': 1,
#           'sees_patient': 1,
#           'terrified_patient': 1,
#           'disappointed_patient': 1,
#           'pinions_patient': 1,
#           'break_patient': 1,
#           'fuck_patient': 1,
#           'killing_patient': 1,
#           'fucking_patient': 1,
#           'pinning_patient': 1,
#           'hard_mod': 1,
#           'Jackson_mod': 1,
#           'starlet_mod': 1,
#           'restless_mod': 1,
#           'exception_mod': 1,
#           'minute_mod': 1}),
#  'Federal Reserve': Counter(),
#  'Mr. Anderson': Counter({'worked_agent': 1, 'received_agent': 1}),
#  'Ben': Counter({'sends_agent': 1,
#           'sees_agent': 1,
#           'tires_agent': 1,
#           'fell_patient': 1,
#           'bedridden_mod': 1}),
#  'Bob Lefifingwell': Counter({'braced_agent': 1}),
#  'Ellabelle Proctor': Counter({'denied_agent': 1, 'father_mod': 1}),
#  'Allen Whiteside': Counter({'showed_agent': 1,
#           'hurried_agent': 1,
#           'jumped_agent': 1}),
#  'Houston Press': Counter(),
#  'Boche': Counter({'stick_agent': 1, 'beat_patient': 1}),
#  'Washington Daily News': Counter({'lay_patient': 1}),
#  'Walker': Counter({'joined_agent': 1,
#           'owed_agent': 2,
#           'agreed_agent': 1,
#           'killed_agent': 1,
#           'bought_agent': 1,
#           'turn_patient': 1,
#           'murdered_patient': 1,
#           'debt-free_mod': 1,
#           'suicidal_mod': 1}),
#  'Nelson Lloyd': Counter({'listening_agent': 1}),
#  'Lloyd B. Cavanaugh': Counter({'rushed_agent': 1, 'rode_agent': 1}),
#  'Treasury': Counter({'mixed_agent': 1}),
#  'Claude Maudulayne': Counter({'find_agent': 1,
#           'murmured_agent': 1,
#           'observed_agent': 1,
#           'protested_agent': 1,
#           'conferred_agent': 1,
#           'suggested_agent': 1,
#           'shrugged_agent': 1,
#           'provoked_patient': 1,
#           'curious_mod': 1}),
#  'Harl': Counter(),
#  'John Baker': Counter({'manages_agent': 1, 'joined_agent': 1}),
#  'Raymond Robert Smith': Counter(),
#  'Mr. Chairman': Counter({'finished_agent': 1,
#           'plan_agent': 1,
#           'give_agent': 1,
#           'succeeding_agent': 1,
#           'promised_agent': 2,
#           'seems_agent': 1,
#           'forgotten_agent': 1,
#           'apologize_agent': 1,
#           'leaned_agent': 1,
#           'ask_agent': 1,
#           'making_agent': 1,
#           "'m_patient": 1,
#           'bother_patient': 1,
#           'evasive_mod': 1}),
#  'FPC': Counter(),
#  'Elizabeth Henry': Counter(),
#  'Herald Tribune': Counter(),
#  'Appropriations Committee': Counter(),
#  'Post-Dispatch': Counter({'remarked_agent': 1,
#           'exclaimed_agent': 2,
#           'inquired_agent': 1,
#           'observed_agent': 1,
#           'agreed_agent': 1,
#           'sounds_agent': 1}),
#  'Finance Committee': Counter({'waiting_agent': 1}),
#  'Joint Chiefs of Staff': Counter(),
#  'Irving Steinman': Counter({'clapping_patient': 1}),
#  'Fred Cahill': Counter({'struggling_agent': 1, 'waved_agent': 1}),
#  'Associated Press': Counter(),
#  'Roselands': Counter({'sold_agent': 1}),
#  'Mr. Knox': Counter({'observed_agent': 1}),
#  'Mr. Lefflngwell': Counter({'perform_agent': 1,
#           'examine_patient': 1,
#           'nominee_mod': 1,
#           'tricky_mod': 1}),
#  'Los Angeles Times': Counter(),
#  ...}

# %%
charTexts
# Out:
# [['wore',
#   'had',
#   'carried',
#   'seemed',
#   'said',
#   'said',
#   'said',
#   'realized',
#   'gave'],
#  ['were'],
#  ['got',
#   'recognize',
#   'died',
#   'knew',
#   'laid',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'had',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'began',
#   'thought',
#   'nodded',
#   'say',
#   'spoke',
#   'turned',
#   'knows',
#   'knows',
#   'advising',
#   'talk',
#   'loses',
#   'does',
#   'crying'],
#  ['left',
#   'forgotten',
#   'asked',
#   'asked',
#   'strode',
#   'held',
#   'changed',
#   'looked',
#   'looked',
#   'looked',
#   'frowning',
#   'smiled',
#   'smiled',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'broke',
#   'leaned',
#   'speaking',
#   'addressed',
#   'praying',
#   'spoke',
#   'spoke',
#   'closed',
#   'took',
#   'helped',
#   'think',
#   'wished',
#   'wished',
#   'hated',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hate',
#   'hate',
#   'hate',
#   'hate',
#   'thought',
#   'thought',
#   'thought',
#   'remember',
#   'shown',
#   'was',
#   'was',
#   'been',
#   'loves',
#   'loves',
#   'loves',
#   'loves',
#   'talked',
#   'like',
#   "'s",
#   "'s",
#   "'s",
#   'likes',
#   'likes',
#   'acts',
#   'feels',
#   'told',
#   'told',
#   'told',
#   'told',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'wanted',
#   'wanted',
#   'wanted',
#   'does',
#   'does',
#   'want',
#   'want',
#   'want',
#   'want',
#   'Want',
#   'knows',
#   'love',
#   'ask',
#   'ask',
#   'ask'],
#  ['get'],
#  ['notice',
#   'kept',
#   'wants',
#   'told',
#   'be',
#   'said',
#   'said',
#   'lowered',
#   'took',
#   'whispered',
#   'straightened'],
#  ['hated', 'got'],
#  ['got'],
#  ['were',
#   'were',
#   'felt',
#   'bear',
#   'went',
#   'went',
#   'hear',
#   'knew',
#   'want',
#   'hurried',
#   'hurried',
#   'hurried',
#   'looked',
#   'crying'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'turned',
#   'accusing',
#   'coming',
#   'trailed',
#   'promised',
#   'promised',
#   'says'],
#  ['felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'made',
#   'made',
#   'made',
#   'laughed',
#   'kill',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'fight',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'lifted',
#   'brag',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'done',
#   'done',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'noticed',
#   'put',
#   'put',
#   'imitated',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'pressed',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'sat',
#   'sat',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'eat',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'been',
#   'been',
#   'believe',
#   'believe',
#   'insisted',
#   'play',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'wants',
#   'is',
#   'is',
#   'is',
#   'is',
#   'hurt',
#   'hurt',
#   'suspected',
#   'suspected',
#   'planned',
#   'make',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'has',
#   'likes',
#   'arrived',
#   'found',
#   'found',
#   'found',
#   'found',
#   'found',
#   'wash',
#   'hurried',
#   'warned',
#   'meant',
#   'followed',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'shrilled',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'paid',
#   'paid',
#   'stared',
#   'stared',
#   'stared',
#   'suffered',
#   'enjoyed',
#   'exclaimed',
#   'speak',
#   'speak',
#   'speak',
#   'imagine',
#   'imagine',
#   'imagine',
#   'say',
#   'say',
#   'say',
#   'say',
#   'think',
#   'hearing',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'pointed',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'realize',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'remembuh',
#   'remember',
#   'hadflung',
#   'give',
#   'give',
#   'go',
#   'loved',
#   'loved',
#   'grow',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'wandered',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'look',
#   'look',
#   'beginning',
#   'told',
#   'told',
#   'told',
#   'told',
#   'understand',
#   'understand',
#   'answered',
#   'answered',
#   'sing',
#   'sing',
#   'danced',
#   'danced',
#   'sang',
#   'sang',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'finished',
#   'suspect',
#   'do',
#   'do',
#   'do',
#   'do',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'doing',
#   'doing',
#   'doing',
#   'doing',
#   'refused',
#   'struct',
#   'fought',
#   'lie',
#   'lie',
#   'need',
#   'stayed',
#   'stayed',
#   'seemed',
#   'seemed',
#   'seemed',
#   'failing',
#   'comprehend',
#   'comprehend',
#   'jumped',
#   'called',
#   'leaned',
#   'leaned',
#   'walked',
#   'walked',
#   'walked',
#   'walked',
#   'couldfeel',
#   'held',
#   'be',
#   'be',
#   'joined',
#   'slapped',
#   'listened',
#   'listened',
#   'listened',
#   'listened',
#   'listened',
#   'move',
#   'move',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'understood',
#   'kissed',
#   'going',
#   'going',
#   'did',
#   'did',
#   'did',
#   'got',
#   'added',
#   'fixed',
#   'buttoned',
#   'died',
#   'died',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'spank',
#   'find',
#   'find',
#   'opened',
#   'sees',
#   'have',
#   'have',
#   'have',
#   'have',
#   'let',
#   'let',
#   'coming',
#   'coming',
#   'took',
#   'took',
#   'met',
#   'meeting',
#   'turned',
#   'turned',
#   'replied',
#   'replied',
#   'replied',
#   'speaking',
#   'lay',
#   'lay',
#   'tell',
#   'tell',
#   'hurrying',
#   'steer',
#   'try',
#   'lying',
#   'lying',
#   'get',
#   'puzzled',
#   'were',
#   'spoken',
#   'stopped',
#   'stopped',
#   'informed',
#   'claimed',
#   'considered',
#   'volunteer',
#   'decided',
#   'decided',
#   'strode',
#   'reflected',
#   'known',
#   'known',
#   'wore',
#   'sit',
#   'intended',
#   'intended',
#   'reprimand',
#   'saying',
#   'smiled',
#   'waited',
#   'concealing',
#   'gave',
#   'glanced',
#   'glanced',
#   'shaved',
#   'continued',
#   'gazed',
#   'slid',
#   'touched',
#   'lowering',
#   'wished',
#   'touch',
#   'bring',
#   'moved',
#   'moved',
#   'moved',
#   'flung',
#   'stuck',
#   'experienced',
#   'understands',
#   'believed',
#   'looking',
#   'looking',
#   'frowning',
#   'smelled',
#   'thinking',
#   'stirred',
#   'flew',
#   'flew',
#   'worked',
#   'sprang',
#   'disliked',
#   'read',
#   'answer',
#   'trying',
#   'talking'],
#  ['tried',
#   'tried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'went',
#   'went',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'began',
#   'began',
#   'began',
#   'touched',
#   'explained',
#   'knew',
#   'knew',
#   'knew',
#   'watched',
#   'watched',
#   'decided',
#   'decided',
#   'need',
#   'pushed',
#   'heard',
#   'heard',
#   'known',
#   'sat',
#   'taste',
#   'braced',
#   'felt',
#   'felt',
#   'getting',
#   'wanted',
#   'wanted',
#   'wished',
#   'wished',
#   'think',
#   'think',
#   'feels',
#   'says',
#   'say',
#   'mean',
#   'understands',
#   'took',
#   'nodded',
#   'nodded',
#   'asked',
#   'asked',
#   'gotten',
#   'gave',
#   'tell',
#   'realized',
#   'growled',
#   'saying',
#   'exclaimed',
#   'did',
#   'did',
#   'please',
#   'know',
#   'spoke',
#   'wondered',
#   'pat',
#   'stood'],
#  ['had',
#   'whispered',
#   'leaned',
#   'leaned',
#   'leaned',
#   'lifted',
#   'smoothed',
#   'looked',
#   'thought',
#   'saw',
#   'stood'],
#  ['cried',
#   'held',
#   'shook',
#   'shook',
#   'embraced',
#   'smelled',
#   'allow',
#   'took',
#   'took',
#   'took',
#   'bathed',
#   'going',
#   'come',
#   'Bless',
#   'told',
#   'looked',
#   'looked',
#   'asked',
#   'answer',
#   'answer',
#   'said',
#   'said',
#   'said',
#   'look',
#   'seemed',
#   'seem',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'squeezed',
#   'stopped',
#   'put',
#   'had',
#   'waved'],
#  ['was'],
#  ['sitting', 'thought', 'leaning'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'know',
#   'know',
#   'did',
#   'did',
#   'did',
#   'did',
#   'did',
#   'swung',
#   'hurried',
#   'hurried',
#   'hurried',
#   'tried',
#   'tried',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'cut',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'started',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'listened',
#   'listened',
#   'began',
#   'understood',
#   'changed',
#   'leave',
#   'suspected',
#   'speakin',
#   'hit',
#   'thank',
#   'is',
#   'is',
#   'is',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'talk',
#   'help',
#   'sat',
#   'sat',
#   'doing',
#   'fastened',
#   'liked',
#   'liked',
#   'liked',
#   'watched',
#   'watched',
#   'watched',
#   'reflected',
#   'reflected',
#   'reflected',
#   'meant',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'hear',
#   'saw',
#   'saw',
#   'unbuttoned',
#   'tucked',
#   'feel',
#   'feel',
#   'feel',
#   'set',
#   'caught',
#   'caught',
#   'kissed',
#   'kissed',
#   'kissed',
#   'answered',
#   'answered',
#   'answered',
#   'noticed',
#   'doubtless',
#   'ate',
#   'drink',
#   'frowned',
#   'frowned',
#   'took',
#   'took',
#   'took',
#   'took',
#   'finished',
#   'pressed',
#   'brought',
#   'plastered',
#   'chewed',
#   'prevent',
#   'eat',
#   'glanced',
#   'asked',
#   'asked',
#   'joked',
#   'guessed',
#   'went',
#   'went',
#   'went',
#   'snapped',
#   'stood',
#   'gotten',
#   'gotten',
#   'knew',
#   'knew',
#   'buttoned',
#   'backed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'pulled',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'look',
#   'cared',
#   'showed',
#   'stroked',
#   'continued',
#   'walking',
#   'lifted',
#   'disappeared',
#   'try',
#   'try',
#   'try',
#   'braked',
#   'shut',
#   'quit',
#   'turned',
#   'nodded',
#   'nodded',
#   'passed',
#   'forgive',
#   'filled',
#   'waited',
#   'lighted',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'say',
#   'say',
#   'say',
#   'disliked',
#   'made',
#   'made',
#   'been',
#   'been',
#   'came',
#   'came',
#   'came',
#   'stand',
#   'found',
#   'found',
#   'found',
#   'done',
#   'imagine',
#   'imagine',
#   'be',
#   'mind',
#   'hollered',
#   'fret',
#   "'s",
#   "'s",
#   'told',
#   'told',
#   'told',
#   'told',
#   'sees',
#   'm-make',
#   'understand',
#   'met',
#   'wants',
#   'wants',
#   'driving',
#   'driving',
#   'goes',
#   'warning',
#   'thinks',
#   'were',
#   'come',
#   'hurrying',
#   'trying',
#   'trying',
#   'speak',
#   'speak',
#   'lying',
#   'lying',
#   'managed',
#   'knows',
#   'does',
#   'understands',
#   'died',
#   'blame',
#   'fixed',
#   'assented',
#   'gathered',
#   'covered',
#   'seen',
#   'seen',
#   'remembered',
#   'known',
#   'take',
#   'shook',
#   'shook',
#   'working',
#   'looking',
#   'see'],
#  ['hurried', 'told', 'passed', 'passed', 'feel', 'setting'],
#  [],
#  ['told', 'told', 'missed', 'missed', 'expecting', 'came', 'looked', 'saw'],
#  ['were'],
#  ['had',
#   'make',
#   'liked',
#   'laughed',
#   'bought',
#   'spent',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shaking',
#   'see',
#   'whistling',
#   'asked',
#   'looked',
#   'looked',
#   'mean',
#   'meant',
#   'trusted',
#   'likes',
#   'believe',
#   'smiled',
#   'smiled'],
#  ['called',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'bite',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'replied',
#   'replied',
#   'replied',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'seemed',
#   'ask',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'came',
#   'came',
#   'came',
#   'came',
#   'know',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'wanted',
#   'wanted',
#   'wanted',
#   'going',
#   'going',
#   'hurt',
#   'hurt',
#   'say',
#   'say',
#   'say',
#   'say',
#   'say',
#   'says',
#   'says',
#   'says',
#   'says',
#   'says',
#   'says',
#   'has',
#   'talks',
#   'be',
#   'stayed',
#   'stayed',
#   'accusing',
#   'saying',
#   'left',
#   'left',
#   "'s",
#   "'s",
#   "'s",
#   'getting',
#   'have',
#   'have',
#   'have',
#   'phoned',
#   'phoned',
#   'scared',
#   'meant',
#   'hoping',
#   'do',
#   'do',
#   'do',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'did',
#   'did',
#   'did',
#   'did',
#   'did',
#   'doing',
#   'bother',
#   'hesitate',
#   'put',
#   'put',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'speak',
#   'speak',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'holding',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'set',
#   'expected',
#   'kissed',
#   'kissed',
#   'sobbed',
#   'stared',
#   'twist',
#   'brought',
#   'brought',
#   'brought',
#   'bringing',
#   'sat',
#   'surprised',
#   'broke',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'poured',
#   'prepared',
#   'want',
#   'want',
#   'speaking',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'dropped',
#   'got',
#   'got',
#   'got',
#   'got',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'led',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'shook',
#   'shook',
#   'walked',
#   'wishes',
#   'wishes',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'nursing',
#   'squatted',
#   'stood',
#   'stood',
#   'drew',
#   'thinks',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'stand',
#   'locked',
#   'showed',
#   'guided',
#   'thrown',
#   'thrown',
#   'grabbed',
#   'reached',
#   'returned',
#   'spoke',
#   'groaned',
#   'groaned',
#   'grimace',
#   'spoken',
#   'hear',
#   'hear',
#   'hear',
#   'think',
#   'began',
#   'began',
#   'began',
#   'shouted',
#   'shouted',
#   'explained',
#   'mimic',
#   'cried',
#   'tried',
#   'tried',
#   'admit',
#   'tightened',
#   'pointed',
#   'died',
#   'died',
#   'lived',
#   'remembered',
#   'remembered',
#   'lay',
#   'loved',
#   'look',
#   'assured',
#   'shut',
#   'talking',
#   'take',
#   'take',
#   'laughed',
#   'lie',
#   'question',
#   'asking',
#   'wants',
#   'feel',
#   'intended',
#   'get',
#   'glanced',
#   'glanced',
#   'met',
#   'watching',
#   'corrected',
#   'answer',
#   'embraced',
#   'realized',
#   'realized',
#   'helped',
#   'helped',
#   'walking',
#   'found',
#   'found',
#   'reflected',
#   'mind',
#   'cared',
#   'cared',
#   'made',
#   'overheard',
#   'rushed',
#   'leaning',
#   'invited',
#   'tell',
#   'stopped',
#   'hit',
#   'insists',
#   'glared',
#   'caricatured',
#   'snarled'],
#  ['was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'folded',
#   'folded',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'respected',
#   'try',
#   'try',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'bring',
#   'bring',
#   'be',
#   'be',
#   'be',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'waiting',
#   'waiting',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'intended',
#   'intended',
#   'made',
#   'made',
#   'made',
#   'made',
#   'made',
#   'made',
#   'held',
#   'held',
#   'held',
#   'smiled',
#   'smiled',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'followed',
#   'muttered',
#   'leaned',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'steered',
#   'prepared',
#   'dressed',
#   'doing',
#   'doing',
#   'loved',
#   'examine',
#   'had',
#   'had',
#   'had',
#   'had',
#   'shopped',
#   'bought',
#   'turned',
#   'smelled',
#   'saw',
#   'saw',
#   'saw',
#   'doubted',
#   'doubted',
#   'speak',
#   'speak',
#   'meant',
#   'meant',
#   'meant',
#   'meant',
#   'reflected',
#   'reflected',
#   'indicated',
#   'paid',
#   'is',
#   'went',
#   'went',
#   'went',
#   'went',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hurried',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'hustled',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'talk',
#   'sat',
#   'found',
#   'found',
#   'found',
#   'found',
#   'watching',
#   'watching',
#   'focused',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'help',
#   'help',
#   'waited',
#   'waited',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'decided',
#   'think',
#   'think',
#   'think',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   "'s",
#   'wave',
#   'wave',
#   'stopped',
#   'stood',
#   'stood',
#   'continued',
#   'continued',
#   'continued',
#   'continued',
#   'rapped',
#   'come',
#   'bit',
#   'blurted',
#   'struck',
#   'subdued',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'know',
#   'know',
#   'reached',
#   'squeezed',
#   'realized',
#   'realized',
#   'realized',
#   'wished',
#   'wished',
#   'wished',
#   'lean',
#   'sighed',
#   'sighed',
#   'sighed',
#   'beginning',
#   'live',
#   'look',
#   'die',
#   'die',
#   'set',
#   'bear',
#   'learn',
#   'learn',
#   'watched',
#   'watched',
#   'watched',
#   'kneel',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'suspected',
#   'trailed',
#   'rid',
#   'repeated',
#   'left',
#   'left',
#   'indulged',
#   'been',
#   'done',
#   'resist',
#   'managed',
#   'nodding',
#   'blink',
#   'resume',
#   'seem',
#   'prefers',
#   'helped',
#   'helped',
#   'helped',
#   'gets',
#   'do',
#   'saying',
#   'saying',
#   'saying',
#   'saying',
#   'saying',
#   'doubting',
#   'put',
#   'drank',
#   'drank',
#   'stared',
#   'drew',
#   'clucked',
#   'asked',
#   'asked',
#   'asked',
#   'gotten',
#   'sobbed',
#   'moved',
#   'explained',
#   'explained',
#   'suggested',
#   'closed',
#   'closed',
#   'hear',
#   'hear',
#   'hear',
#   'stifled',
#   'cried',
#   'feel',
#   'kept',
#   'kept',
#   'tell',
#   'thinks',
#   'has',
#   'say',
#   'say',
#   'say',
#   'please',
#   'stay',
#   'stay',
#   'added',
#   'were',
#   'were',
#   'see',
#   'see',
#   'touched',
#   'touched',
#   'touched',
#   'want',
#   'take',
#   'take',
#   'threading',
#   'exclaimed',
#   'called',
#   'called',
#   'remembered',
#   'loaded',
#   'lay',
#   'lay',
#   'stooped',
#   'go',
#   'snapped',
#   'struggled',
#   'let',
#   'have',
#   'did',
#   'did',
#   'did',
#   'sliced',
#   'gave',
#   'glanced',
#   'talking',
#   'sipped',
#   'hurt',
#   'swallowed',
#   'watch',
#   'spoke',
#   'spoke',
#   'tried',
#   'paused',
#   'paused',
#   'pressed',
#   'accusing',
#   'jerked',
#   'demonstrated',
#   'wore',
#   'wore',
#   'carrying',
#   'wheeled',
#   'says',
#   'walked',
#   'messing',
#   'started',
#   'started',
#   'sputtered',
#   'talked',
#   'washed',
#   'get',
#   'cleaned',
#   'thank',
#   'going',
#   'seemed',
#   'murmured',
#   'understand',
#   'caught',
#   'ceased',
#   'got',
#   'got',
#   'appear',
#   'speaking',
#   'crying',
#   'gasped'],
#  ['were', 'came', 'wearing', 'carried', 'walked', 'looked'],
#  [],
#  ['phoned', 'says', 'wanted', 'loves'],
#  ['had', 'get'],
#  [],
#  ['said',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'suffered',
#   'think',
#   'looked'],
#  ['say', 'said', 'said'],
#  ['were'],
#  [],
#  ['come', 'stood', 'were'],
#  ['came', 'stopped', 'turned', 'saw', 'took', 'wondered', 'kept'],
#  [],
#  ['take',
#   'come',
#   'stayed',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'came',
#   'came',
#   'came',
#   'patted',
#   'drives',
#   'tell',
#   'hurt',
#   'living',
#   'bringing',
#   'put',
#   'go',
#   'want',
#   'thought',
#   'shook',
#   'shut',
#   'say',
#   'stood',
#   'stood',
#   'have',
#   'glanced',
#   'drying',
#   'passed',
#   'went',
#   'know',
#   'nodded'],
#  ['singing', 'turned', 'turned', 'whispered', 'walked'],
#  ['wore',
#   'wore',
#   'carried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'had',
#   'tease',
#   'decided',
#   'trust',
#   'thought',
#   'seemed',
#   'understood',
#   'started',
#   'teasing',
#   'smiled',
#   'quieted',
#   'got',
#   'got',
#   'noticed',
#   'saw',
#   'take',
#   'told',
#   'bring',
#   'turned',
#   'drove',
#   'shut',
#   'began',
#   'twisted',
#   'brought',
#   'stopped',
#   'moved',
#   'move',
#   'look',
#   'looked'],
#  [],
#  ['realized',
#   'wanted',
#   'restrained',
#   'felt',
#   'went',
#   'swing',
#   'bear',
#   'lay',
#   'lay'],
#  ['got'],
#  ['got',
#   'do',
#   'reckoned',
#   'get',
#   'get',
#   'know',
#   'knew',
#   'heard',
#   'watched',
#   'climb',
#   'thought',
#   'seen'],
#  ['thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'readjusted',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'getting',
#   'cried',
#   'cried',
#   'cried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'glared',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'use',
#   'bought',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'trying',
#   'trying',
#   'trying',
#   'turned',
#   'turned',
#   'winced',
#   'relaxed',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'imagine',
#   'decided',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'facing',
#   'needs',
#   'gazed',
#   'patted',
#   'patted',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'waited',
#   'waited',
#   'waited',
#   'let',
#   'gave',
#   'inquired',
#   'know',
#   'know',
#   'know',
#   'sleeping',
#   'scowling',
#   'standing',
#   'settled',
#   'got',
#   'got',
#   'began',
#   'began',
#   'began',
#   'yelled',
#   'yelled',
#   'bawled',
#   'recovered',
#   'peered',
#   'put',
#   'put',
#   'put',
#   'caught',
#   'stared',
#   'speak',
#   'tucked',
#   'cry',
#   'sniffled',
#   'sniffled',
#   'look',
#   'look',
#   'repeated',
#   'continued',
#   'mean',
#   'groaned',
#   'loosened',
#   'dressed',
#   'came',
#   'came',
#   'try',
#   'did',
#   'say',
#   'say',
#   'say',
#   'feel',
#   'feel',
#   'feel',
#   'ate',
#   'ate',
#   'tried',
#   'tried',
#   'tried',
#   'make',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'knew',
#   'knew',
#   'coming',
#   'coming',
#   'coming',
#   'come',
#   'come',
#   'remember',
#   'think',
#   'looking',
#   'looking',
#   'drew',
#   'ask',
#   'snapped',
#   'expected',
#   'flinched',
#   'stopped',
#   'stopped',
#   'squeezed',
#   'kept',
#   'seem',
#   'exclaimed',
#   'working',
#   'made',
#   'bore',
#   'crying',
#   'crying',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'helped',
#   'gather',
#   'passed',
#   'have',
#   'brought',
#   'helping',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'ran',
#   'held',
#   'held',
#   'held',
#   'held',
#   'stroked',
#   'seemed',
#   'seemed',
#   'seemed',
#   'swallowed',
#   'told',
#   'hissed',
#   'raised',
#   'hesitated',
#   'hesitated',
#   'answered',
#   'had',
#   'had',
#   'watched',
#   'watched',
#   'watched',
#   'added',
#   'hastened',
#   'noticed',
#   'wetting',
#   'hated',
#   'remembered',
#   'remembered',
#   'understand',
#   'understood',
#   'realized',
#   'realized',
#   'realized',
#   'blushed',
#   'smiled',
#   'waiting',
#   'feared',
#   'goes',
#   'pulled',
#   'pulled',
#   'thinks',
#   'whispered',
#   'stayed',
#   'rock',
#   'moved',
#   'moved',
#   'straightened',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'wearing',
#   'reassured',
#   'opened',
#   'plays',
#   'played',
#   'hearing',
#   'seen',
#   'stole',
#   'shook',
#   'run'],
#  ['asked',
#   'was',
#   'was',
#   'frighten',
#   'wanted',
#   'help',
#   'spoke',
#   'nodded',
#   'sucked',
#   'coming',
#   'eating',
#   'walk'],
#  ["'s"],
#  [],
#  [],
#  [],
#  ["'s", 'leave', 'were'],
#  ['understand',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'disappear',
#   'meant',
#   'meant',
#   'meant',
#   'meant',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'making',
#   'spoke',
#   'spoke',
#   'spoke',
#   'spoke',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'covered',
#   'peppered',
#   'done',
#   'made',
#   'made',
#   'made',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'supposed',
#   'make',
#   'stand',
#   'stand',
#   'stand',
#   'watch',
#   'smiled',
#   'smiled',
#   'smiled',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'been',
#   'opened',
#   'opened',
#   'shook',
#   'shook',
#   'squeezed',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'hoped',
#   'doze',
#   'crossed',
#   'bring',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'blame',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'look',
#   'feared',
#   'feared',
#   'like',
#   'like',
#   'cared',
#   'wondered',
#   'wondered',
#   'wondered',
#   'liked',
#   'disliked',
#   'assured',
#   'assured',
#   'resented',
#   'begun',
#   'replied',
#   'replied',
#   'come',
#   'come',
#   'inquired',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'have',
#   'have',
#   'going',
#   'manage',
#   'manage',
#   'decided',
#   'decided',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'drew',
#   'drew',
#   'drew',
#   'extended',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'coaxing',
#   'murmured',
#   'murmured',
#   'murmured',
#   'murmured',
#   'drawing',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'waved',
#   'twisted',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'looking',
#   'looking',
#   'spoken',
#   'spoken',
#   'seen',
#   'seen',
#   'seen',
#   'lifted',
#   'lifted',
#   'lifted',
#   'glanced',
#   'glanced',
#   'glanced',
#   'cried',
#   'cried',
#   'cried',
#   'cried',
#   'drank',
#   'drank',
#   'drank',
#   'noticed',
#   'noticed',
#   'continued',
#   'continued',
#   'continued',
#   'continued',
#   'has',
#   'found',
#   'found',
#   'bear',
#   'interrupted',
#   'took',
#   'took',
#   'took',
#   'took',
#   'retorted',
#   'waited',
#   'waited',
#   'subdued',
#   'laughed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'speak',
#   'gazing',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'speaking',
#   'speaking',
#   'remember',
#   'remember',
#   'remember',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'joined',
#   'joined',
#   'talked',
#   'talked',
#   'Excuse',
#   'stared',
#   'returned',
#   'seemed',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'remembered',
#   'remembered',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'find',
#   'leaning',
#   'catching',
#   'losing',
#   'squeezing',
#   'were',
#   'were',
#   'walked',
#   'walked',
#   'needs',
#   'poured',
#   'poured',
#   'croaked',
#   'sipped',
#   'added',
#   'added',
#   'tasted',
#   'nodding',
#   'finished',
#   'prepared',
#   'means',
#   'was',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'groaned',
#   'groaned',
#   'groaned',
#   'saying',
#   'risen',
#   'moaned',
#   'feel',
#   'feel',
#   'embraced',
#   'screamed',
#   'asks',
#   'tries',
#   'met',
#   'pressing',
#   'died',
#   'called',
#   'called',
#   'wished',
#   'wished',
#   'leaned',
#   'leaned',
#   'leaned',
#   'lied',
#   'says',
#   'says',
#   'lingering',
#   'does',
#   'cutting',
#   'gave',
#   'did',
#   'broke',
#   'dying',
#   'trailed',
#   'thinks',
#   'fell',
#   'growled',
#   'caught',
#   'caught',
#   'ease',
#   'pressed',
#   'pressed',
#   "'s",
#   "'s",
#   'mean',
#   'watching',
#   'smells',
#   'wants',
#   'straightened',
#   'switched',
#   'switched',
#   'closed',
#   'gathering',
#   'disappeared',
#   'gathered',
#   'knelt',
#   'bother',
#   'lay',
#   'lay',
#   'falling',
#   'tole',
#   'slapped',
#   'stopped',
#   'cut',
#   'cornered',
#   'humbled',
#   'loved',
#   'gained',
#   'grown',
#   'shared',
#   'refused',
#   'know',
#   'experienced',
#   'left',
#   'rocked',
#   'rocked',
#   'swayed',
#   'tried'],
#  [],
#  ['Is', 'Let', 'forgive', 'go', 'finished', 'doing', 'came', 'knows'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'begin',
#   'help',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'ai',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'driving',
#   'was',
#   'was',
#   'was',
#   'hit',
#   'cut',
#   'hold',
#   'hold',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'warmed',
#   'get',
#   'get',
#   'been',
#   'hesitated',
#   'want',
#   'want',
#   'says',
#   'says',
#   'says',
#   'has',
#   'tell',
#   'gets',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'added',
#   'done',
#   'drove',
#   'goes',
#   'got',
#   'got',
#   'got',
#   'stood',
#   'stood',
#   'stood',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'sighed',
#   'remember',
#   'remember',
#   'known',
#   'left',
#   'meant',
#   'meant',
#   'lost',
#   'lost',
#   'needed',
#   'needed',
#   'think',
#   'understood',
#   'understood',
#   'understood',
#   'understood',
#   'asked',
#   'called',
#   'put',
#   'sped',
#   'sped',
#   'rammed',
#   'suffered',
#   'suffered',
#   'suffered',
#   'rushed',
#   'showed',
#   'see',
#   'came',
#   'came',
#   'making',
#   'beseeching',
#   'began',
#   'began',
#   'began',
#   'began',
#   'bringing',
#   'feared',
#   'redoubled',
#   'tried',
#   'saw',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'swung',
#   'burn',
#   'have',
#   'have',
#   'have',
#   'care',
#   'went',
#   'take',
#   'learned',
#   'braced',
#   'despised',
#   'looked',
#   'nodded',
#   'died',
#   'covered',
#   'whispered',
#   'thrust',
#   'announced',
#   'announced',
#   'wants',
#   'come',
#   'chose',
#   'did',
#   'navigate',
#   'succeeded',
#   'told',
#   'reckoned',
#   'concurred',
#   'beginning',
#   'swear',
#   'recognized',
#   'is',
#   'shook',
#   'explained',
#   'climb',
#   'stepped'],
#  ['rolled', 'rolled', 'done'],
#  ['kill'],
#  ['was'],
#  [],
#  ['said', 'said', 'threw', 'whispered', 'took', 'is'],
#  ['came',
#   'had',
#   'miss',
#   'took',
#   'took',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'looked',
#   'wake',
#   'shaking'],
#  ['went', 'wake', 'woke', 'did'],
#  ['was',
#   'stole',
#   'looked',
#   'remembered',
#   'laughed',
#   'got',
#   'reached',
#   'peered',
#   'whipped',
#   'killed',
#   'insulted',
#   'have',
#   'asked'],
#  [],
#  ['made',
#   'had',
#   'had',
#   'played',
#   'stayed',
#   'come',
#   'been',
#   'identify',
#   'known',
#   'wrote',
#   'wrote',
#   'wrote',
#   'wrote',
#   'wrote',
#   'was',
#   'lost',
#   'weeping',
#   'sleep',
#   'going',
#   'fall',
#   'wounded',
#   'walk',
#   'walk',
#   'pointed',
#   'remember',
#   'tell'],
#  ['is', 'write', 'enrolled', 'wrote', 'showed', 'described', 'cured'],
#  ['arrived',
#   'invited',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'replied',
#   'showed',
#   'ask',
#   'tested',
#   'test'],
#  ['persists',
#   'asks',
#   'use',
#   'appears',
#   'takes',
#   'made',
#   'thinks',
#   'said',
#   'meant',
#   'is',
#   'hides',
#   'told',
#   'bought',
#   'denied',
#   'resist',
#   'knows',
#   'think',
#   'longs',
#   'dreams',
#   'sees',
#   'encouraged',
#   'called',
#   'had',
#   'ignored',
#   'write',
#   'write',
#   'keep',
#   'makes',
#   'does',
#   'remember',
#   'make',
#   'say',
#   'do'],
#  [],
#  ['perched',
#   'said',
#   'rose',
#   'deepened',
#   'flew',
#   'tossed',
#   'tossed',
#   'staring',
#   'tired',
#   'seek',
#   'named',
#   'worked',
#   'worked',
#   'dwarfed',
#   'joined'],
#  ['filling', 'pass', 'pouring'],
#  ['made', 'asked', 'died', 'entertained', 'paid', 'noticed', 'gave'],
#  ['learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'imagine',
#   'imagine',
#   'imagine',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'despised',
#   'let',
#   'let',
#   'let',
#   'brought',
#   'brought',
#   'made',
#   'made',
#   'aired',
#   'borrowed',
#   'showed',
#   'lost',
#   'told',
#   'told',
#   'told',
#   'kept',
#   'kept',
#   'kept',
#   'feels',
#   'have',
#   'hears',
#   'saying',
#   'backs',
#   'find',
#   'find',
#   'appeared',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'led',
#   'called',
#   'called',
#   'reached',
#   'shared',
#   'found',
#   'found',
#   'found',
#   'paused',
#   'stood',
#   'stood',
#   'stood',
#   'stepping',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'purchased',
#   'extracted',
#   'walk',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'chosen',
#   'offered',
#   'bear',
#   'left',
#   'left',
#   'left',
#   'left',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'taken',
#   'taken',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'lying',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'rented',
#   'paying',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'gave',
#   'gave',
#   'gave',
#   'moved',
#   'moved',
#   'was',
#   'returned',
#   'returned',
#   'miss',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'helped',
#   'helped',
#   'helped',
#   'carrying',
#   'spread',
#   'gathered',
#   'gathered',
#   'gathered',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'imagined',
#   'love',
#   'helping',
#   'carried',
#   'wrote',
#   'got',
#   'got',
#   'waited',
#   'waited',
#   'work',
#   'lived',
#   'live',
#   'signed',
#   'nursed',
#   'nursed',
#   'cared',
#   'read',
#   'read',
#   'read',
#   'read',
#   'read',
#   'taught',
#   'tormented',
#   'started',
#   'end',
#   'know',
#   'know',
#   'think',
#   'think',
#   'think',
#   'stopped',
#   'stopped',
#   'stopped',
#   'given',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'hear',
#   'hear',
#   'wish',
#   'wish',
#   'forgave',
#   'opened',
#   'opened',
#   'painted',
#   'leave',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'bundled',
#   'pressed',
#   'wiped',
#   'packed',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'learn',
#   'learn',
#   'included',
#   'recognized',
#   'see',
#   'see',
#   'see',
#   'whispered',
#   'puzzle',
#   'grown',
#   'grown',
#   'vanished',
#   'stand',
#   'crossing',
#   'dug',
#   'replied',
#   'took',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'knowing',
#   'described',
#   'described',
#   'keep',
#   'keep',
#   'rubbed',
#   'crawled',
#   'settled',
#   'recollect',
#   'missed',
#   'missed',
#   'tended',
#   'meant',
#   'identify',
#   'known',
#   'nearing',
#   'realized',
#   'do',
#   'bought',
#   'wished',
#   'caught',
#   'caught',
#   'caught',
#   'asks',
#   'knows',
#   'says',
#   'says',
#   'says',
#   'nods',
#   "'s",
#   'chided',
#   'persist',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'appear',
#   'worried',
#   'remember',
#   'spent',
#   'circulated',
#   'remembered',
#   'interrupted',
#   'prepared',
#   'visited',
#   'visited',
#   'blamed',
#   'put',
#   'closed',
#   'covered',
#   'touched',
#   'shook',
#   'turned',
#   'turned',
#   'picked',
#   'seemed',
#   'rise',
#   'concocting',
#   'did',
#   'did',
#   'did',
#   'explained',
#   'devised',
#   'passed',
#   'began',
#   'began',
#   'stared',
#   'stared',
#   'held',
#   'ate',
#   'eat',
#   'talk',
#   'talk',
#   'goes',
#   'order',
#   'flirting',
#   'begged',
#   'stanched',
#   'seized',
#   'sickened',
#   'chose',
#   'feel',
#   'conceals',
#   'pays',
#   "'d",
#   'decided',
#   'sleeping',
#   'grew',
#   'aged',
#   'growing',
#   'approached',
#   'moves'],
#  ['talked',
#   'learned',
#   'said',
#   'said',
#   'said',
#   'said',
#   'made',
#   'saw',
#   'hides',
#   'strolls',
#   'laughed',
#   'resembles',
#   'is',
#   'continued'],
#  ['had'],
#  ['has',
#   'says',
#   'takes',
#   'gets',
#   'rises',
#   'said',
#   'kept',
#   'moaned',
#   'was',
#   'longed',
#   'slept',
#   'permit'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'wanted',
#   'lives',
#   'thought',
#   'thought',
#   'forbade',
#   'constructed',
#   'sank',
#   'felt',
#   'admitted',
#   'avoided',
#   'called',
#   'called',
#   'had',
#   'had',
#   'attended',
#   'forgiven',
#   'objected',
#   'bear',
#   'spoke',
#   'took',
#   'presented',
#   'twitched',
#   'held',
#   'tossed',
#   'went',
#   'went',
#   'returned',
#   'continued',
#   'found',
#   'found',
#   'found',
#   'turned',
#   'manufactured',
#   'kept',
#   'chosen',
#   'chosen',
#   'ransacked',
#   'owned',
#   'left',
#   'left'],
#  ['sniffed', 'thrust', 'said', 'said', 'turned'],
#  ['was',
#   'spoken',
#   'said',
#   'moved',
#   'pull',
#   'find',
#   'set',
#   'painted',
#   'head',
#   'went',
#   'led',
#   'had'],
#  ['had',
#   'met',
#   'thinking',
#   'thinking',
#   'turned',
#   'saw',
#   'see',
#   'name',
#   'stuck',
#   'heard',
#   'said'],
#  ['shook', 'said'],
#  ['disappeared'],
#  ['has', 'entered', 'left'],
#  ['dying',
#   'dying',
#   'arrived',
#   'coughing',
#   'coughing',
#   'needs',
#   'needs',
#   'needs',
#   'weighs',
#   'swallowed',
#   'raised',
#   'told',
#   'had',
#   'had',
#   'had',
#   'said',
#   'said',
#   'felt',
#   'felt',
#   'suspected',
#   'was',
#   'swooped',
#   'lifted',
#   'set',
#   'loses',
#   'sweats',
#   'cough',
#   'cough',
#   'cough',
#   'go',
#   'have',
#   'have',
#   'goes',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'take',
#   'cast',
#   'barks',
#   'has',
#   'has',
#   'passes',
#   'prints',
#   'leave',
#   'begins',
#   'begins',
#   'decided',
#   'write',
#   'write',
#   'write',
#   'liked',
#   'coughed',
#   'writes',
#   'be',
#   'be',
#   'say',
#   'start',
#   'hear',
#   'hear',
#   'spreads',
#   'eat',
#   'come',
#   'lose',
#   'came',
#   'knew',
#   'explain',
#   'recovered',
#   'blame',
#   'describe',
#   'fished',
#   'fix',
#   'do',
#   'bounds',
#   'waiting',
#   'waiting',
#   'fret'],
#  ['watched'],
#  ['agreed', 'made', 'took', 'heard', 'asked', 'said', 'said', 'said'],
#  ['pouted', 'continued'],
#  [],
#  ['lowered',
#   'thought',
#   'saw',
#   'loved',
#   'opened',
#   'held',
#   'said',
#   'is',
#   'knew',
#   'fell',
#   'brought'],
#  ['nearing',
#   'has',
#   'comes',
#   'goes',
#   'nods',
#   'nods',
#   'pick',
#   'lifted',
#   'lifted',
#   'lifted',
#   'passing',
#   'see',
#   'arrived',
#   'arrived',
#   'convey',
#   'knows',
#   'marking',
#   'came',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'pointed',
#   'brought',
#   'knelt',
#   'laid',
#   'pressed',
#   'picked',
#   'left',
#   'feels',
#   'murmured',
#   'smelled',
#   'nodded',
#   'refuse',
#   'drank',
#   'passed',
#   'stepped',
#   'asked',
#   'raised',
#   'knew',
#   'started',
#   'belongs',
#   'passes',
#   'slept',
#   'holds'],
#  ['feel',
#   'read',
#   'help',
#   'lost',
#   'dreamed',
#   'saw',
#   'saw',
#   'grown',
#   'said',
#   'said',
#   'manage'],
#  ['helps', 'separated', 'learned', 'twisted', 'died', 'thought', 'returned'],
#  ['used',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'shared',
#   'shared',
#   'tells',
#   'writing',
#   'writing',
#   'saying',
#   'promises',
#   'explained',
#   'tell',
#   'corralled',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'moved',
#   'moved',
#   'stayed',
#   'was',
#   'was',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'bore',
#   'heard',
#   'heard',
#   'heard',
# ...
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'concluded',
#   'concluded',
#   'reassure',
#   'slide',
#   'jump',
#   'strolled',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'saying',
#   'saying',
#   'pushed',
#   'pushed',
#   'added',
#   'breathed',
#   'breathed',
#   'like',
#   'like',
#   'like',
#   'steeled',
#   'started',
#   'started',
#   'started',
#   'tried',
#   'tried',
#   'slipped',
#   'lowered',
#   'undid',
#   'followed',
#   'followed',
#   'headed',
#   'murmured',
#   'murmured',
#   'stared',
#   'stared',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'caught',
#   'caught',
#   'caught',
#   'certified',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'belonged',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'try',
#   'draw',
#   'take',
#   'take',
#   'take',
#   'come',
#   'come',
#   'come',
#   'venture',
#   'venture',
#   'opened',
#   'opened',
#   'opened',
#   'opened',
#   'cut',
#   'decided',
#   'mind',
#   'gives',
#   'goggling',
#   'stopped',
#   'stopped',
#   'stopped',
#   'stopped',
#   'let',
#   'let',
#   'let',
#   'let',
#   'let',
#   'swung',
#   'ran',
#   'ran',
#   'hoped',
#   'hoped',
#   'removed',
#   'open',
#   'showed',
#   'showed',
#   'grasp',
#   'makes',
#   'regards',
#   'consider',
#   'tells',
#   'tells',
#   'admired',
#   'lit',
#   'lit',
#   'intended',
#   'comes',
#   'comes',
#   'announced',
#   'thinks',
#   'thinks',
#   'thinks',
#   'talked',
#   'wants',
#   'wants',
#   'wants',
#   'wants',
#   'wants',
#   'tapped',
#   'rising',
#   'writes',
#   'answer',
#   'shook',
#   'handed',
#   'lost',
#   'remember',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'send',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'believe',
#   'does',
#   'recognized',
#   'recognized',
#   'recognized',
#   'debated',
#   'continued',
#   'continued',
#   'continued',
#   'supposed',
#   'supposed',
#   'supposed',
#   'supposed',
#   'stepped',
#   'overtook',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'drove',
#   'reflected',
#   'reflected',
#   'flicked',
#   'enjoy',
#   'lift',
#   'loved',
#   'say',
#   'say',
#   'say',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'signaled',
#   'use',
#   'knows',
#   'knows',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'doing',
#   'doing',
#   'cared',
#   'pinch',
#   'behave',
#   'give',
#   'broke',
#   'arose',
#   'arose',
#   'guessed',
#   'guessed',
#   'lifted',
#   'lifted',
#   'forming',
#   'moved',
#   'moved',
#   'moved',
#   'listen',
#   "'s",
#   "'s",
#   "'s",
#   "'s",
#   "'s",
#   'mixing',
#   'coming',
#   'coming',
#   'balanced',
#   'waved',
#   'waved',
#   'add',
#   'nodded',
#   'nodded',
#   'considered',
#   'considered',
#   'seemed',
#   'acted',
#   'imagine',
#   'believed',
#   'agree',
#   'been',
#   'talking',
#   'talking',
#   'stay',
#   'observed',
#   'meant',
#   ...],
#  [],
#  ['kept',
#   'recognized',
#   'going',
#   'going',
#   'come',
#   'was',
#   'was',
#   'was',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'gave',
#   'does',
#   'drops',
#   'says',
#   'picked',
#   'lost',
#   'got',
#   'had',
#   'had',
#   'looked',
#   'hoped',
#   'told',
#   'showing',
#   'groped',
#   'let',
#   'frowned',
#   'is',
#   'intends',
#   'flew',
#   'flew',
#   'leaving',
#   'knew',
#   'laughed',
#   'are',
#   'showed',
#   'tagged',
#   'did',
#   'cleared',
#   'act',
#   'believe',
#   'were',
#   'make'],
#  ['calling',
#   'flying',
#   'do',
#   'seen',
#   'was',
#   'was',
#   'going',
#   'took',
#   'wants',
#   'take',
#   'did',
#   'afford'],
#  ['lay',
#   'waited',
#   'stretched',
#   'caught',
#   'bulked',
#   'said',
#   'said',
#   'said',
#   'gave',
#   'started',
#   'bumped'],
#  ['stared',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shook',
#   'briefed',
#   'doing',
#   'pinned',
#   'gave',
#   'waited',
#   'arose',
#   'whispered',
#   'raised',
#   'moistened',
#   'mentioned',
#   'has',
#   'got',
#   'showed',
#   'do',
#   'was',
#   'was',
#   'made'],
#  ['understand',
#   'got',
#   'shrugged',
#   'told',
#   'dare',
#   'wanted',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'gathered',
#   'opened',
#   'opened',
#   'held',
#   'held',
#   'put',
#   'put',
#   'looked',
#   'regard',
#   'had',
#   'be'],
#  ['found', 'countenances', 'countenance'],
#  ['said', 'showed', 'got'],
#  ['crouched',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'left',
#   'put',
#   'has',
#   'sat',
#   'began'],
#  ['handed'],
#  [],
#  [],
#  ['had', 'have', 'has', 'assigned', 'do', 'mind'],
#  ['know'],
#  ['bother',
#   'got',
#   'noticed',
#   'knew',
#   'show',
#   'see',
#   'talk',
#   'reported',
#   'speak',
#   'speak',
#   'says',
#   'gives',
#   'picking',
#   'has',
#   'criticizes',
#   'warns',
#   'thinks'],
#  ['said', 'said', 'put'],
#  ['told', 'told'],
#  ['doing', 'using', 'uses', 'have'],
#  [],
#  ['says',
#   'says',
#   'says',
#   'had',
#   'had',
#   'consider',
#   'read',
#   'took',
#   'arranged',
#   'ambled',
#   'got',
#   'got',
#   'got',
#   'cared',
#   'wants',
#   'wants',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'doubt',
#   'like',
#   'was',
#   'was',
#   'make',
#   'did',
#   'did',
#   'emitted',
#   'shown',
#   'looked',
#   'went',
#   'seemed',
#   'asked',
#   'defended',
#   'knew',
#   'worked',
#   'used',
#   'seems',
#   'decided',
#   'say',
#   'say',
#   'mean',
#   'ran',
#   'runs',
#   'is',
#   'drives',
#   'seem',
#   'gave',
#   'gave',
#   'get',
#   'get',
#   'has',
#   'have',
#   'muttering',
#   'called',
#   'expressed',
#   'figures',
#   'sitting',
#   'hesitating',
#   'threw',
#   'handed',
#   'lifted',
#   'opened',
#   'turned',
#   'gaped',
#   'seen',
#   'found',
#   'swallowed',
#   'told',
#   'stayed'],
#  ['was'],
#  ['said', 'said', 'said', 'said', 'said'],
#  ['called',
#   'knew',
#   'drawn',
#   'hear',
#   'make',
#   'hung',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shook',
#   'shook',
#   'resolve',
#   'responded',
#   'colored',
#   'led',
#   'married',
#   'reddened',
#   'looked',
#   'looked',
#   'take',
#   'take',
#   'perform',
#   'broke',
#   'broke',
#   'whistled',
#   'went',
#   'went',
#   'stood',
#   'marked',
#   'done',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'proved',
#   'showed',
#   'expecting',
#   'is',
#   'is',
#   'seen',
#   'was',
#   'was',
#   'was',
#   'turned',
#   'turned',
#   'drew',
#   'feel',
#   'offered',
#   'passed',
#   'smile',
#   'managed',
#   'holding',
#   'got',
#   'got',
#   'got',
#   'got',
#   'sat',
#   'sat',
#   'acknowledged',
#   'decided',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'have',
#   'interrupted',
#   'stopped',
#   'getting',
#   'think',
#   'mean',
#   'see',
#   'see',
#   'wilted',
#   'been',
#   'want',
#   "'s",
#   'took',
#   'tells',
#   'believed',
#   'started',
#   'guessed',
#   'opened',
#   'put',
#   'put',
#   'know',
#   'be',
#   'taking',
#   'knows'],
#  ['produced',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'cleared',
#   'mentioned',
#   'stopped',
#   'thought',
#   'sat',
#   'grew',
#   'hearing',
#   'understand',
#   'seeing',
#   'liked',
#   'arose',
#   'wanted',
#   'says'],
#  ['unfolded'],
#  ['came', 'said', 'said', 'said', 'released'],
#  ['said', 'fly'],
#  ['took',
#   'took',
#   'took',
#   'has',
#   'asked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'mumbled',
#   'said',
#   'said',
#   'going',
#   'is',
#   'is',
#   'is',
#   'says',
#   'indicate',
#   'say',
#   'jumping',
#   'was',
#   'was',
#   'thinks',
#   'left',
#   'did',
#   'got',
#   'told',
#   'sense',
#   "'s",
#   'be',
#   'went',
#   'went',
#   'stay'],
#  ['heard'],
#  ['broke', 'said', 'observed'],
#  ['set', 'set', 'said', 'turned', 'meant'],
#  ['letting', 'went', 'went', 'ate', 'said', "'s", 'got', 'turned'],
#  ['look',
#   'looked',
#   'lost',
#   'lost',
#   'began',
#   'paused',
#   'leaving',
#   'realize',
#   'going',
#   'going',
#   'bit',
#   'said',
#   'turned',
#   'go',
#   'tell'],
#  ['has',
#   'went',
#   'got',
#   'going',
#   'want',
#   'fretting',
#   'left',
#   'is',
#   'is',
#   'gave',
#   'thought',
#   'did',
#   'recognized',
#   'seeing',
#   'be',
#   'stay',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'came',
#   'came',
#   'lifting',
#   'saw',
#   'was',
#   'were',
#   'recovered',
#   'portrayed'],
#  ['learn',
#   'had',
#   'had',
#   'had',
#   'get',
#   'gave',
#   'like',
#   'went',
#   'went',
#   'went',
#   'apologized',
#   'going',
#   'taken',
#   'kept',
#   'said',
#   'said',
#   'seemed',
#   'understood',
#   'compose',
#   'made',
#   'explain',
#   'got',
#   'thinks',
#   'thinks',
#   'needs',
#   'watched',
#   'want',
#   'was',
#   'was',
#   'look',
#   'killed'],
#  [],
#  ['is'],
#  ['called',
#   'repeat',
#   'is',
#   'is',
#   'has',
#   'has',
#   'doing',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'retired',
#   'told',
#   'told',
#   'thought',
#   'come',
#   'wanted',
#   'make',
#   'began',
#   'taken',
#   'crying',
#   'faced',
#   'knows',
#   'spoke',
#   'arisen',
#   'came',
#   'snapped',
#   'moved',
#   'pushed',
#   'coming',
#   'let',
#   'looked',
#   'looked',
#   'smiled',
#   'gave',
#   'sent',
#   'slicing',
#   'reached',
#   'sat',
#   'dislike',
#   'happens',
#   'calling',
#   'throwing',
#   'made',
#   'take',
#   'say',
#   'took',
#   'says',
#   'says',
#   'drank',
#   'drank',
#   'drank',
#   'saw',
#   'do',
#   'found',
#   'find',
#   'like',
#   'liked',
#   'pulled'],
#  ['got', 'go', 'do', 'made', 'saying', 'says', 'says', 'says', 'thought'],
#  [],
#  ['told',
#   'told',
#   'had',
#   'had',
#   'had',
#   'answered',
#   'doubted',
#   'washed',
#   'washed',
#   'rated',
#   'give',
#   'gave',
#   'said',
#   'squawked',
#   'crossed',
#   'did',
#   'know',
#   'have',
#   'knows',
#   'show',
#   'do',
#   'added'],
#  ['take', 'rang', 'said'],
#  ['offering',
#   'admitted',
#   'have',
#   'have',
#   'have',
#   'feel',
#   'regarded',
#   'knew',
#   'saw',
#   'saw',
#   'explained',
#   'needed',
#   'wanted',
#   'wanted',
#   'stoop',
#   'intended',
#   'come',
#   'swallowed',
#   'decided'],
#  [],
#  [],
#  ['said', 'dragged', 'read'],
#  ['like', 'kidding', 'kidding', 'know', 'having'],
#  [],
#  ['appeared', 'saying'],
#  ['come',
#   'was',
#   'was',
#   'had',
#   'missed',
#   'forgot',
#   'spot',
#   'rescued',
#   'restated',
#   'made',
#   'halt',
#   'proved',
#   'refused',
#   'said',
#   'weighed',
#   'got',
#   'hope',
#   'let',
#   'have',
#   'feel',
#   'thought',
#   'found',
#   'agree'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'see',
#   'makes',
#   'do',
#   'got',
#   'talked',
#   'approve',
#   'thinks',
#   'thinks',
#   'told',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'expect',
#   'want',
#   'escorted',
#   'has'],
#  ['having', 'showed', 'was'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'scratched',
#   'began',
#   'made',
#   'shrugged',
#   'grown',
#   'pursed',
#   'knocked',
#   'tells',
#   'going',
#   'sprang',
#   'opened',
#   "'s",
#   'tossed',
#   'tries'],
#  ['said',
#   'said',
#   'said',
#   'raised',
#   'raised',
#   'looked',
#   'turned',
#   'brought',
#   'taken',
#   'gave'],
#  [],
#  ['had',
#   'took',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'knew',
#   'advanced',
#   'typed',
#   'went',
#   'laid',
#   'hesitated',
#   'asked',
#   'opened',
#   'shrugged',
#   'closed',
#   'cried',
#   'entered',
#   'called',
#   'remember',
#   'remembered',
#   'take'],
#  ['was', 'sent'],
#  ['explain', 'goes', 'think', 'have'],
#  ['said'],
#  ['was',
#   'was',
#   'was',
#   'knew',
#   'knew',
#   'had',
#   'meant',
#   'going',
#   'going',
#   'going',
#   'rechristened',
#   'sat',
#   'sat',
#   'controlled',
#   'send',
#   'meeting',
#   'know',
#   'lied',
#   'aggravated',
#   'says',
#   'enlisting',
#   'feels',
#   'do',
#   'said',
#   'said',
#   'said',
#   'said',
#   'found',
#   'repeated',
#   'repeated',
#   'repeated',
#   'listening',
#   'went',
#   'unlocked',
#   'please',
#   'drive',
#   'driven',
#   'checking',
#   'stood',
#   'pressed',
#   'showed',
#   'looked',
#   'admit'],
#  ['faced',
#   'began',
#   'putting',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'says',
#   'says',
#   'says',
#   'get',
#   'get',
#   'managed',
#   'let',
#   'doubled',
#   'thinks',
#   'happened',
#   'comes',
#   'say',
#   'shoot',
#   'thought',
#   'do',
#   'calls',
#   'puts',
#   'puts',
#   'have',
#   'show',
#   'see',
#   'was',
#   'has',
#   'went',
#   'met',
#   'know',
#   'is',
#   'knows',
#   'sat',
#   'threw',
#   'remember'],
#  ['diagrams',
#   'be',
#   'be',
#   'comes',
#   'told',
#   'told',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'was',
#   'was',
#   'was',
#   'flying',
#   'erected',
#   'lifted',
#   'lifted',
#   'stood',
#   'stood',
#   'stood',
#   'looked',
#   'looked',
#   'looked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'showed',
#   'felt',
#   'felt',
#   'put',
#   'put',
#   'proved',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'extracted',
#   'got',
#   'got',
#   'narrowed',
#   'narrowed',
#   'regarded',
#   'regarded',
#   'make',
#   'send',
#   'let',
#   'let',
#   'let',
#   'found',
#   'found',
#   'tossed',
#   'dropped',
#   'dropped',
#   'brought',
#   'set',
#   'poised',
#   'smack',
#   'began',
#   'began',
#   'flew',
#   'killed',
#   'forgot',
#   'emptied',
#   'poured',
#   'poured',
#   'frowned',
#   'rested',
#   'gaze',
#   'considered',
#   'accept',
#   'get',
#   'get',
#   'help',
#   'waiting',
#   'studied',
#   'pulled',
#   'wheeled',
#   'moved',
#   'moved',
#   'swung',
#   'is',
#   'is',
#   'happen',
#   'came',
#   'came',
#   'dug',
#   'watched',
#   'shook',
#   'shook',
#   'smiled',
#   'has',
#   'has',
#   'has',
#   'getting',
#   'use',
#   'opened',
#   'been',
#   'try',
#   'laughed',
#   'went',
#   'slouched',
#   'gave',
#   'slapped',
#   'gazed',
#   'attempt',
#   'say',
#   'knew',
#   'knew',
#   'acknowledged',
#   'straightened',
#   'depressed',
#   'named',
#   'remarks',
#   'stared',
#   'glanced',
#   'were',
#   'rising',
#   'crouched',
#   'made',
#   'made',
#   'made',
#   'scooped',
#   'weighed',
#   'lie',
#   'have',
#   'drawn',
#   'cut',
#   'flipped',
#   'held',
#   'remembered',
#   'speaking',
#   'agreed',
#   'seemed',
#   'feel',
#   'lost',
#   'doing',
#   'missing',
#   'wanted',
#   'laid'],
#  [],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'caught',
#   'see',
#   'see',
#   'looks',
#   'handed',
#   'shot',
#   'consulted',
#   'stood',
#   'looked',
#   'looked',
#   'has',
#   'was',
#   'regarded',
#   'dealt',
#   'lifted',
#   'had',
#   'turned',
#   'joined',
#   'glanced',
#   'saw',
#   'wait',
#   'called',
#   'roared',
#   'hooked',
#   'came',
#   'thought',
#   'seeing',
#   'put',
#   'listen',
#   'did',
#   'twisted',
#   'took'],
#  ['want', 'came', 'know'],
#  ['stepped'],
#  ['was',
#   'was',
#   'picked',
#   'waiting',
#   'want',
#   'judge',
#   'take',
#   'sobered',
#   'been'],
#  ['saw', 'said', 'earn', 'earns', 'moistened', 'sit', 'had'],
#  ...]

# %%
charNames
# Out:
# ['Dr. Whittaker',
#  'Mrs. Gunn',
#  'Sadie',
#  'Jackson',
#  'Lynch',
#  'Mother',
#  'Jessie',
#  'Ettie Lou',
#  'Mrs. Dekalb',
#  'Mama',
#  'Rufus',
#  'Joel',
#  'Amelia',
#  'Victoria',
#  'Abraham Lincoln',
#  'George Bailey',
#  'Jay',
#  'Thomas',
#  'Google',
#  'Bell',
#  'Miss Amy Field',
#  'Ted',
#  'Andrew',
#  'Hannah',
#  'Gordon Dekalb',
#  'Roberts',
#  'Uncle Ralph',
#  'Grampa',
#  'LaFollette',
#  'Jesus',
#  'Powell',
#  'Miss Nettie Field',
#  'Granmaw',
#  'Dr. Dekalb',
#  'Arthur',
#  'Rhoda',
#  'Walter',
#  'John Henry',
#  'Mr. Starr',
#  'Carrie',
#  'Mr. Ralph',
#  'Jim-Wilson',
#  'Tom',
#  'Catherine',
#  'Granma',
#  'Jackie',
#  'Morris',
#  'Ann',
#  'Brannick',
#  'Celia Gunn',
#  'Mary',
#  'Cross',
#  'Sally',
#  'Ralph',
#  'Tin Lizzie',
#  'Daddy',
#  'William S. Hart',
#  'L&N',
#  'Mrs. Follet',
#  'Kate',
#  'Oliver',
#  'Charlie',
#  'Sugar Babe',
#  'Colm Larkin',
#  'William Murray',
#  'Dr. Kopeckny',
#  'Michaels',
#  'Helen',
#  'Virgil',
#  'Liwie',
#  'Leo',
#  'Nora',
#  'Dr. Chouteau',
#  'Lawrence',
#  'Jane',
#  'Lauren',
#  'Dr. Fuller',
#  'Copernicus',
#  'Theo',
#  'Agnes',
#  'Bancroft',
#  'Cassandra',
#  'Martin',
#  'Winifred',
#  'Bessie',
#  'Lesueur',
#  'Montgomerie',
#  'Denis',
#  'James',
#  'Harry',
#  'Lavinia',
#  'Caleb',
#  'Erasmus',
#  'Eudora',
#  'Scheuchzer',
#  'Dr. Boerhaave',
#  'Grace',
#  'Mr. Wright',
#  'George',
#  'Dehra Dun',
#  'Hermione',
#  'Mr. Woodruff',
#  'Academy',
#  'Godfrey Vigne',
#  'Samuel',
#  'Kalm',
#  'Suky',
#  'Dr. Davis',
#  'East India Company',
#  'Conrad',
#  'Mr. Bartram',
#  'Kate',
#  'Stuart',
#  'Peter',
#  'Rose',
#  'Darwin',
#  'Dr. Grant',
#  'Ned',
#  'Roger',
#  'Fannie',
#  'Ladakhis',
#  'Dorrie',
#  'Horace',
#  'Elias',
#  'Dr. Mason',
#  'Margaret',
#  'Alvah',
#  'Noah',
#  'Rosina',
#  'Daphne',
#  'Northview Inn',
#  'Phoebe',
#  'Max',
#  'Emeline',
#  'Mrs. MacDonald',
#  'Arnold',
#  'Bianca',
#  'Andrew',
#  'Fabre',
#  'Mr. Wells',
#  'Harriet',
#  'Baltis',
#  'Vivek',
#  'Wyatt',
#  'Gideon',
#  'Joseph',
#  'Miriam',
#  'Laurence',
#  'Gillian',
#  'Mrs. Dietrich',
#  'Corinne',
#  'Signe',
#  'Meg',
#  'Zoe',
#  'Mr. Darwin',
#  'Diego',
#  'Jocelyn',
#  'Mr. Rapp',
#  'Herb',
#  'Mr. Cameron',
#  'Rosellen',
#  'Elizabeth',
#  'Clara',
#  'Constance',
#  'Michael',
#  'Dima',
#  'Francis',
#  'Mrs. Bernhard',
#  'Duncan',
#  'Sophie',
#  'Krzysztof',
#  'Dr. Hooker',
#  'Tom',
#  'Saks',
#  'Joan',
#  'Thackeray',
#  'Marguerite',
#  'Warburtons',
#  'Percy',
#  'Renee',
#  'Army',
#  'Sherill',
#  'Maple Dell',
#  'DeVarennes',
#  'Vic',
#  'Mrs. Woodruff',
#  'Brutto',
#  'Emma',
#  'Augustus',
#  'Mr. Tennyson',
#  'Mrs. Dunston',
#  'Fiat',
#  'Mr. Hurlow',
#  'Mrs. Farquarson',
#  'Adele',
#  'Mozart',
#  'Sidney',
#  'Molly',
#  'Toby',
#  'Antonio',
#  'Townsend',
#  'Bill',
#  'Mayakovsky',
#  'Christopher Columbus',
#  'Mr. Seridan',
#  'Buckingham Palace',
#  'Edith',
#  'Fraulein',
#  'Lord Byron',
#  'Theresa',
#  'Ryans',
#  'Wallace',
#  'Mr. DePaul',
#  'Delaney',
#  'Tifty',
#  'Mrs. Doubleday',
#  'Doc Mullens',
#  'Mrs. Chidchester',
#  'Mr. Selfredge',
#  'Brooks Brothers',
#  'Serafino',
#  'Wilma',
#  'Stephen',
#  'Peter',
#  'Willy',
#  'Sweeneys',
#  'Agnes',
#  'Ozamanides',
#  'Mackenzies',
#  'Madonna',
#  'Tom Maitland',
#  'Lears',
#  'Gibson',
#  'Mr. Hatherly',
#  'Henry Bulstrode',
#  'Susan Hewitt',
#  'Townsends',
#  'Mrs. Walton',
#  'Jeremy',
#  'Matisse',
#  'Gil',
#  'Ingrid',
#  'Russell',
#  'Ralphie',
#  'Bessie Black',
#  'Bibber',
#  'Mrs. Howells',
#  'Malloys',
#  'Franz',
#  'Ford',
#  'Joany',
#  'Mr. Estabrook',
#  'Gary',
#  'Marge',
#  'Mrs. Negus',
#  'Margaret',
#  'Ren',
#  'American Airlines',
#  'Richard',
#  'Ralph',
#  'Protestant Cemetery',
#  'Roma',
#  'Mr. Nixon',
#  'Mildred',
#  'Miss James',
#  'Mr. Coolidge',
#  'Nerissa',
#  'Emily',
#  'Alice',
#  'Charlie',
#  'Penumbra',
#  'Jenny Lind',
#  'Rosemary',
#  'Wentworth',
#  'Mrs. Ditmar',
#  'Beardens',
#  'Grampa',
#  'Altman',
#  'Donna Carla',
#  'Mr. Whittemore',
#  'Buick',
#  'Julia',
#  'Francis',
#  'Winifred-Mae',
#  'Venus',
#  'Cecil Smith',
#  'Mrs. Compton',
#  'Marie',
#  'Amos Cabot',
#  'Kate',
#  'Mrs. Pastern',
#  'Thomas',
#  'Mrs. Cavis',
#  'Artemis',
#  'Mrs. Talbot',
#  'Clementina',
#  'Chekhov',
#  'Mr. Marston',
#  'Roosevelt',
#  'Mrs. Wryson',
#  'Mr. Flannagan',
#  'Mr. Osborn',
#  'Natasha',
#  'Simmons',
#  'Stella',
#  'Mrs. Brownlee',
#  'Autostrada',
#  'Beethoven',
#  'Mrs. Emerson',
#  'Genoa',
#  'Mother',
#  'Victor',
#  'Harry',
#  'Mrs. Aboleen',
#  'Farquarsons',
#  'Bitsey',
#  'Doris',
#  'Bob',
#  'Mr. Flanagan',
#  'Mrs. Sheridan',
#  'Priscilla',
#  'Mr. Leavitt',
#  'Tavola-Calda',
#  'Times',
#  'Carol',
#  'Nora',
#  'Hester',
#  'Millicent',
#  'Olney Pratt',
#  'Randall',
#  'Williams',
#  'Mrs. Ryan',
#  'Chesneys',
#  'Florrie',
#  'Hauser Agency',
#  'Victoria',
#  'Hall',
#  'Sam Farley',
#  'Mrs. Vuiton',
#  'Greta',
#  'Mario',
#  'Mrs. Whiteside',
#  'Mrs. Gadshill',
#  'Larry',
#  'Marcie',
#  'Lucinda',
#  'Streeter',
#  'Mr. Brownlee',
#  'Jesus',
#  'Zimba',
#  "Macy 's",
#  'Miss Armstrong',
#  'Frank',
#  'Langston',
#  'Mr. Hadaam',
#  'Mr. Hubber',
#  'Mr. Pastern',
#  'Tibi',
#  'Mr. Bucklin',
#  'Moses',
#  'Robert',
#  'Luncharvsky',
#  'Vassar',
#  'Com Exchange Bank',
#  'Paul Hadaam',
#  'Katie',
#  'Mr. Hartley',
#  'Mrs. Bachman',
#  'Gee-Gee',
#  'Mrs. Dobree',
#  'Blake',
#  'Pete',
#  'Mrs. Nudd',
#  'Mr. Bruce',
#  'Mr. Kovacs',
#  'McGowen',
#  'Grace Harris',
#  'Mrs. Coolidge',
#  'Mr. Weston',
#  'Shirley Adams',
#  'Uncle Abbott',
#  'Louisa',
#  'Mrs. Bestwick',
#  'Bertha',
#  'Mr. Brown',
#  'Minnie',
#  'Duke',
#  'Chucky Ewing',
#  'Mrs. Bronson',
#  'Flora',
#  'Mildred-Rose',
#  'Mrs. Weston',
#  'Ned',
#  'Metropolitan Club',
#  'Mrs. DePaul',
#  'Mrs. Harley',
#  'Hermes',
#  'Baxter',
#  'Cipriani',
#  'Lermontov',
#  'Blevins',
#  'Whittemores',
#  'Mr. Bestwick',
#  'Mrs. Haney',
#  'Odette',
#  'Tony',
#  'Mrs. Tennyson',
#  'Clayton',
#  'John',
#  'Pietro',
#  'Kellner',
#  'Harvard',
#  'Paul',
#  'Martha',
#  'Miss Coolidge',
#  'Lin Yutang',
#  'Mrs. Zagreb',
#  'Nils',
#  'Mrs. Bearden',
#  'Amy',
#  'Mrs. Hirshman',
#  'Ellen',
#  'Laura',
#  'Mallory',
#  'Eva',
#  'Carlotta',
#  'Mitch Kababian',
#  'Mr. Negus',
#  'Mrs. Fuller',
#  'Levi',
#  'Clarissa Ryan',
#  'Imperial Rome',
#  'Lydia',
#  'Carla Giusti',
#  'Murchisons',
#  'Fullers',
#  'Aeroflot',
#  'Mr. Cabot',
#  'Binxey',
#  'Jessica',
#  'Grace Biswanger',
#  'Madge Beatty',
#  'Prescott',
#  'Mr. Fuller',
#  'Baseomb',
#  'Beefeater Gibsons',
#  'Nero',
#  'Mummy',
#  'Marcia Lawton',
#  'Mr. Fellows',
#  'Cavour',
#  'Boobee',
#  'Lee',
#  'Littletons',
#  'Lindleys',
#  'Bates',
#  "O'Brien",
#  'Milltonium',
#  'Mathilde',
#  'Maggie',
#  'Lawrence',
#  'Hartleys',
#  'Tivoli',
#  'Bearden',
#  'Mrs. Halloran',
#  'Zena',
#  'Felici',
#  'Betman',
#  'Gertrude',
#  'Mitchell',
#  'Beaufort',
#  'Prince',
#  'Mr. Watkins',
#  'Lord & Taylor',
#  'Kennedy',
#  'Sebastiano',
#  'Verna',
#  'Rente',
#  'Eddie',
#  'Ronnie',
#  'Timmons',
#  'Louise',
#  'Clancy',
#  'Cardin',
#  'Mrs. Lasser',
#  'Roncari',
#  'Jack',
#  'Berenson',
#  'Elixircol',
#  'Ernest',
#  'Pierce',
#  'Mr. Lothard',
#  'Katherine',
#  'Mrs. Peranger',
#  'Miss Deming',
#  'Lytle',
#  'Cadillac',
#  'Abraham',
#  'Monte Carbone',
#  'Mrs. Kosiev',
#  'Rachel',
#  'Chopin',
#  'Mr. Rowantree',
#  'Rolls-Royce',
#  'Juney',
#  'Randy',
#  'Mr. Rowan-tree',
#  'Grahams',
#  'Jove',
#  'St. James',
#  'Mrs. Cabot',
#  'Philip',
#  'Anna',
#  'Mackham',
#  'Jim',
#  'Mrs. Estabrook',
#  'Dr. Trencher',
#  'Tiffany',
#  'Diana',
#  'Boysen',
#  'Monte Giordano',
#  'Phyllis',
#  'Titian',
#  'Eric',
#  'Beatrice',
#  'Bridget',
#  'Jocelin',
#  'Rogerses',
#  'Bobbie',
#  'Mrs. Leary',
#  'Ferarri',
#  'Mrs. Hatherly',
#  'Mrs. Deckker',
#  'Yale',
#  'Khrushchev',
#  'Cezanne',
#  'Assunta',
#  'Mr. Nudd',
#  'Herbert McGrath',
#  'Mrs. Wardsworth',
#  'Mrs. Bucknam',
#  'Ritz',
#  'Sheila',
#  'Luigi',
#  'Jill',
#  'Timmy',
#  'Mrs. Hartley',
#  'Abbott',
#  'George',
#  'Mrs. Selfredge',
#  'Pamela',
#  'Mr. Ashmead',
#  'Mark',
#  'State Department',
#  'Mr. Sheridan',
#  'Mrs. Bruce',
#  'Mrs. Wrightson',
#  'Debussy',
#  'Orpheo',
#  'Mrs. Holinshed',
#  'Dr. Parminter',
#  'Mr. Talbot',
#  'Mr. Farquarson',
#  'Lovell',
#  'Village Council',
#  'Donald Goslin',
#  'Lois',
#  'Mrs. Garrison',
#  'Parlapiano',
#  'Nascosta',
#  'Justina',
#  'Helen',
#  'Mr. Sauer',
#  'Dr. Herzog',
#  'Marchand',
#  'Anthony',
#  'Biff',
#  'Pat Levy',
#  'Perley',
#  'Reno',
#  'Dynaflex',
#  'Mrs. Mackenzie',
#  'Internal Revenue Service',
#  'Burt',
#  'Mrs. Filler',
#  'Charles',
#  'Chaddy',
#  'Bonwit',
#  'Mrs. Madison',
#  'Mr. Murchison',
#  'Bradish',
#  'Baronessa',
#  'Cash',
#  "Women 's Club",
#  'Mrs. Trencher',
#  'Murchison',
#  'Don Camillo',
#  'Isaac',
#  'Deborah',
#  'Amelia',
#  'Mrs. Pentason',
#  'Chester',
#  'Junior',
#  'Mrs. Osborn',
#  'Esther',
#  'Holy Virgin',
#  'Evarts',
#  'Dolly',
#  'Henry James',
#  'Finelli',
#  'Magda',
#  'Mrs. Willoughby',
#  'Betty',
#  'Brimmer',
#  'Mrs. Henlein',
#  'Olga',
#  'Martini',
#  'Seton',
#  'Mrs. Flannagan',
#  'Walsers',
#  'Lawtons',
#  'Mrs. Marston',
#  'Chinese Temple Incense',
#  'Neddy',
#  'Christ',
#  'Skye',
#  'Alfreda',
#  'Clarissa',
#  'Pete Parsons',
#  'Mrs. Sauer',
#  'Coca-Cola',
#  'Mr. Weed',
#  'Bendel',
#  'Santa Claus',
#  'Uncle George',
#  'Mrs. Hewing',
#  'Cook',
#  'Mrs. Walpole',
#  'Lyle Smythe',
#  'Miss Brownlee',
#  'Sally',
#  'Nellie',
#  'Vivaldi',
#  'Mrs. Hardey',
#  'Bronco',
#  'Newsomes',
#  'Red Cross',
#  'Howie Brown',
#  'Kasiak',
#  'Mr. Pruitt',
#  'Promessi Sposi',
#  'Helen Bulstrode',
#  'Troyan',
#  'Mr. Livermore',
#  'Mary-Lee',
#  'Maria',
#  'Navy',
#  'Westons',
#  'Piazza',
#  'Dennis Port',
#  'Donne',
#  'Tennysons',
#  'Mr. Greenwood',
#  'Salvini',
#  'Pinky',
#  'Mr. Lawton',
#  'Antonini',
#  'Nils Jugstrum',
#  'Mr. Wallow',
#  'American Kennel Club',
#  'MacPherson',
#  'Cosimo',
#  'Woolworth',
#  'Parma',
#  'Mathilda',
#  'Georgie',
#  'Chardin Club',
#  'Moss',
#  'Bestwicks',
#  'Cora',
#  'Mr. Hardey',
#  'Shady Hill',
#  'Embassy',
#  'Belinsky',
#  'Anne',
#  'Mrs. Armstrong',
#  'Joe',
#  'Irene',
#  'Ruth',
#  'Donald',
#  'Marlon Brando',
#  'Thompsons',
#  'Miss Rainey',
#  'Christina',
#  'Levys',
#  'Rosita',
#  'Will',
#  'Jack Thompson',
#  'Ethel',
#  'Mary Toms',
#  'Carl',
#  'Dolores',
#  'Mrs. Butterick',
#  'Daddy',
#  'Henry',
#  'Stowe',
#  'Chamber Music Club',
#  'Gogh',
#  'Chet',
#  'Cooper',
#  'Stanley',
#  'Watkinses',
#  'Timothy',
#  'Bascomb',
#  'Dow Chemical',
#  'Dick',
#  'Nixon',
#  'Iris',
#  'Dierdre',
#  'Congress',
#  'Juan',
#  'Anne',
#  'Alice',
#  'Casa Mare',
#  'Helen',
#  'Carol',
#  'Jen',
#  'William',
#  'Mr. Minski',
#  'FBI',
#  'Lorraine',
#  'Evan',
#  'Jesus',
#  'Bob',
#  'UCLA',
#  'Alan',
#  'Joanne',
#  'Peter Pan',
#  'McCloud',
#  'Polly',
#  'Jenny',
#  'James Shimada',
#  'Jim',
#  'Robbie',
#  'Tom',
#  'Dolly',
#  'Walter Cronkite',
#  'Sears',
#  'Joe Smith',
#  'Mr. Morton',
#  'Wildmoor',
#  'Pauhne',
#  'Mike',
#  'Mrs. Fowler',
#  'Thomas',
#  'Elson',
#  'Dana',
#  'Lena',
#  'Yvonne',
#  'Margot',
#  'Christ',
#  'Coke',
#  'Buell',
#  'Mr. Jones',
#  'Roebuck',
#  'Michael',
#  'Frazer',
#  'Mrs. McNulty',
#  'Berkeley',
#  'Newsweek',
#  'Sandra',
#  'Stockton',
#  'Sandy',
#  'Times',
#  'Pauline',
#  'Time',
#  'Graham Jobson',
#  'Nichols',
#  'Beal',
#  'Johnson',
#  'Bombardment Analysis',
#  'Helen',
#  'RAF',
#  'McCabe',
#  'Milt',
#  'Whitney',
#  'Pentagon',
#  'Mcllmoyle',
#  'Haight',
#  'Miss Crittenden',
#  'Bill',
#  'Sellers Field',
#  'Air Force',
#  'Dyer',
#  'Personnel Analysis',
#  'Tactical Air Force',
#  'Jones',
#  'Powell',
#  'Public Relations Office',
#  'Nicodemus',
#  'Table of Organization',
#  'Association',
#  'Miller',
#  'Pop',
#  'Oswald',
#  'Mr. Prouty',
#  'Sybil',
#  'Ross',
#  'Raimondi',
#  'Ira',
#  'Phillips',
#  'Christ',
#  'Major Post',
#  'Mr. Lovewell',
#  'Norma',
#  'CO',
#  'Maxwell',
#  'Gordon',
#  'Bud',
#  'War Department',
#  'Sears',
#  'Katherine',
#  'Turck',
#  'Miss Candee',
#  'Air Staff',
#  'Kashkin',
#  'Smith',
#  'CoUins',
#  'Manny',
#  'Miss Lang',
#  'Rogers',
#  'Benny Car-ricker',
#  'Young Ross',
#  'Claude',
#  'Adler',
#  'Rockwell',
#  'Stanley',
#  'Beaudry',
#  'T/5 McIntyre',
#  'AAF Board',
#  'Benny',
#  'Arnold',
#  'Mrs. Spann',
#  'Zinnia',
#  'Evan',
#  'Danny',
#  'Hermann',
#  'Training Command',
#  'Mrs. Pellerino',
#  'Vaughan',
#  'Werthauer',
#  'Brereton',
#  'Pound',
#  'Luke',
#  'Gonzales',
#  'Mr. Bot-winick',
#  'Wierum',
#  'Hitler',
#  'Eileen',
#  'Trade School',
#  'WAC',
#  'National Guard',
#  'Fighter Squadron',
#  'Mr. Botwinick',
#  'Lardsy',
#  'Potter',
#  'Ehret',
#  'Keller',
#  'Johnny',
#  'Lake Lalage',
#  'General Beal',
#  'Coke',
#  'Mr. Churchill',
#  'James',
#  'Jo-Jo',
#  'Marines',
#  'Clark',
#  'Yount',
#  'Milton',
#  'Tietam',
#  'Fifth Air Force',
#  'Howden',
#  'Donald Andrews',
#  'Michaels',
#  'Mr. Bullen',
#  'Pete',
#  'Orion',
#  'Collins',
#  'Botty',
#  'Air Forces Group',
#  'Wilbur Wright',
#  'OCS',
#  'Pve',
#  'Jane',
#  'Nat',
#  'Gene',
#  'Dobie',
#  'Vera',
#  'Aviation Engineers',
#  'Woolsey',
#  'Bell',
#  'Junior',
#  'Mowbray',
#  'Solomon',
#  'Jesus',
#  'Army Service Forces',
#  'Duchemin',
#  'Lippa',
#  'Carl',
#  'Woodman',
#  'Saint Paul',
#  'Eighth Air Force',
#  'Medical Corps',
#  'Jimmy',
#  'McIntyre',
#  'Mandy',
#  'Provost Marshal',
#  'Uline',
#  'Katherine Andrews',
#  'Nick',
#  'Nauroze',
#  'Mai',
#  'Willis',
#  'Coca-Cola',
#  'Pellerino',
#  'Nate',
#  'Steve',
#  'Olmstead',
#  'Engineer Corps',
#  'Hyde',
#  'Blake',
#  'Nathaniel Hicks',
#  "Women 's Army Corps",
#  'Baxter',
#  'Army',
#  'Oleander Towers Hotel',
#  'Jobson',
#  'Brooks',
#  'Army Air Forces',
#  'Hildebrand',
#  'La Barre',
#  'Red Cross',
#  'Command Post',
#  'Wilco',
#  'AAF',
#  'Regular Army',
#  'Hogan',
#  'Dick',
#  'Prissy',
#  'Navy',
#  'State House',
#  'Coulthard',
#  'Officers Club',
#  'Roger',
#  'Andrews',
#  'Burton',
#  'Ocanara Morning Sun',
#  "O'Mara",
#  'Air Corps',
#  'McCreery',
#  'Art Bullen',
#  'Worthington',
#  'Caroline',
#  'Colonel Ross',
#  'Van Pelt',
#  'Don',
#  'Woody',
#  'Military Academy',
#  'Wister',
#  'Mrs. Ross',
#  'Carter',
#  'Directorate Centers',
#  'Folsom',
#  'Bob',
#  'Mr. McCormack',
#  'AFORAD',
#  'Harvard',
#  'Royal Air Force',
#  'Joe',
#  'Mike',
#  'Mrs. Eliot',
#  'Schlichter',
#  'Norm',
#  'Emily',
#  'Levy',
#  'Murphy',
#  'Headquarters Squadron',
#  'Miss Jelliffe',
#  'Signal Corps',
#  'Lester',
#  'De Luca',
#  'Cora',
#  'Sal',
#  'Wiley',
#  'Transit Company',
#  'Anderson',
#  'Malcolm',
#  'Jack',
#  'Tyler',
#  'Negro',
#  ...]

# %%
dictionary = corpora.Dictionary(charTexts)
corpus = [dictionary.doc2bow(text) for text in charTexts]
num_topics = 10
lda_model = gensim.models.LdaModel(corpus, id2word=dictionary, 
                                   num_topics=num_topics, passes=3, alpha='auto')

# %%
for i in range(num_topics):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	remember_patient invited_agent reading_patient accustomed_patient playing_patient purchased_agent whined_agent aged_agent departed_agent married_agent
# topic 1:	read_patient artist_mod shouts_agent join_patient jes_agent divorced_patient giving_patient haunted_patient lose_patient play_patient
# topic 2:	worked_agent spent_agent managed_agent stayed_agent followed_agent replied_agent leaned_agent pointed_agent wished_agent saying_agent
# topic 3:	needed_agent looking_agent stepped_agent trying_agent coming_agent find_agent waited_agent died_agent fell_agent raised_agent
# topic 4:	ast_agent say_patient sing_agent crouched_agent grab_agent pull_patient helped_agent counted_agent marry_agent Get_patient
# topic 5:	met_agent arrived_agent imagined_agent remember_agent learned_agent noticed_agent glanced_agent understood_agent thinking_agent understand_agent
# topic 6:	thinks_agent looks_agent goes_agent feels_agent tells_agent takes_agent comes_agent sees_agent does_agent asks_agent
# topic 7:	spotted_patient pleaded_agent smiles_agent making_agent sent_agent named_patient run_agent keep_agent love_agent invisible_mod
# topic 8:	died_agent replied_agent agreed_agent explained_agent pointed_agent grinned_agent suggested_agent remarked_agent shrugged_agent offered_agent
# topic 9:	tested_agent taught_agent dog_mod husband_mod trotted_agent reached_patient friendly_mod signaled_agent turning_agent available_mod

# %%
topic_model=lda_model 

topic_docs=[]
for i in range(num_topics):
    topic_docs.append({})
for doc_id in range(len(corpus)):
    doc_topics=topic_model.get_document_topics(corpus[doc_id])
    for topic_num, topic_prob in doc_topics:
        topic_docs[topic_num][doc_id]=topic_prob

for i in range(num_topics):
    print("%s\n" % ' '.join([term for term, freq in topic_model.show_topic(i, topn=10)]))
    sorted_x = sorted(topic_docs[i].items(), key=operator.itemgetter(1), reverse=True)
    for k, v in sorted_x[:5]:
        print("%s\t%.3f\t%s" % (i,v, charNames[k]))
    print()
# Out:
# remember_patient invited_agent reading_patient accustomed_patient playing_patient purchased_agent whined_agent aged_agent departed_agent married_agent
#
# 0	0.812	Mr. Treete
# 0	0.781	Jesus
# 0	0.777	Red Cross
# 0	0.741	Scotty
# 0	0.732	Billie Martin
#
# read_patient artist_mod shouts_agent join_patient jes_agent divorced_patient giving_patient haunted_patient lose_patient play_patient
#
# 1	0.810	Bertie
# 1	0.791	Emil
# 1	0.783	Frances FitzGerald
# 1	0.781	Tilda
# 1	0.778	Winfiel
#
# worked_agent spent_agent managed_agent stayed_agent followed_agent replied_agent leaned_agent pointed_agent wished_agent saying_agent
#
# 2	0.986	Ralph
# 2	0.980	Roy
# 2	0.973	Savage
# 2	0.970	Lois
# 2	0.970	Mother
#
# needed_agent looking_agent stepped_agent trying_agent coming_agent find_agent waited_agent died_agent fell_agent raised_agent
#
# 3	0.979	Genaro
# 3	0.977	Neddy
# 3	0.976	Irene
# 3	0.976	Catherine
# 3	0.970	Clancy
#
# ast_agent say_patient sing_agent crouched_agent grab_agent pull_patient helped_agent counted_agent marry_agent Get_patient
#
# 4	0.844	Ephraim Lipmann
# 4	0.812	Mrs. Negus
# 4	0.811	Mommy
# 4	0.803	Stanley
# 4	0.784	Louisa
#
# met_agent arrived_agent imagined_agent remember_agent learned_agent noticed_agent glanced_agent understood_agent thinking_agent understand_agent
#
# 5	0.971	Sondelius
# 5	0.953	Renee
# 5	0.947	Hurd
# 5	0.942	Alice
# 5	0.938	Schlichter
#
# thinks_agent looks_agent goes_agent feels_agent tells_agent takes_agent comes_agent sees_agent does_agent asks_agent
#
# 6	0.949	Lorraine
# 6	0.900	Norm
# 6	0.878	Christina Roby
# 6	0.869	Steven Bennett
# 6	0.867	Schnorp
#
# spotted_patient pleaded_agent smiles_agent making_agent sent_agent named_patient run_agent keep_agent love_agent invisible_mod
#
# 7	0.876	Mr. Fitzroy
# 7	0.861	Ossie
# 7	0.842	Bureau
# 7	0.841	Dan
# 7	0.817	Angus Duers
#
# died_agent replied_agent agreed_agent explained_agent pointed_agent grinned_agent suggested_agent remarked_agent shrugged_agent offered_agent
#
# 8	0.956	Times
# 8	0.934	AP
# 8	0.929	Fowles
# 8	0.923	Herald Tribune
# 8	0.923	Mr. Pillsbury
#
# tested_agent taught_agent dog_mod husband_mod trotted_agent reached_patient friendly_mod signaled_agent turning_agent available_mod
#
# 9	0.876	Horace Carp
# 9	0.840	Joanie
# 9	0.798	Cooper
# 9	0.758	Pugh
# 9	0.740	Walter Calloway

# %%
# {"agent":[{"w":"wore","i":104276},
#           {"w":"had","i":104283},
#           {"w":"carried","i":104297},
#           {"w":"seemed","i":104306},
#           {"w":"said","i":104318},
#           {"w":"said","i":104358},
#           {"w":"said","i":107106},
#           {"w":"realized","i":107110},
#           {"w":"gave","i":107125}],
#  "NNPcount":3,
#  "names":[{"c":3,"n":"Dr. Whittaker"}],
#  "mod":[],
#  "speaking":[{"w":"`` Oh , good morning , '' ","i":104321},
#              {"w":"`` Of course , '' ","i":104353}],
#  "patient":[],
#  "g":2,
#  "id":0,
#  "poss":[{"w":"words","i":107127}]}
