# %%
import operator
from collections import Counter
import math
from os import path
import json
import gensim
from gensim import corpora

# %%
def read_book_nlp_metadata(filename):
    metadata={}
    with open(filename) as file:
        for line in file:
            cols=line.rstrip().split("\t")
            idd=cols[0]
            date=int(cols[1])
            author=cols[2]
            title=cols[3]
            author_gender=cols[4]
            metadata[idd]=(date, author, title, author_gender)
    return metadata

def read_book_nlp_data(data_folder):
    data={}

    for idd in metadata:
        filename=path.join(data_folder, "%s.book" % idd)
        if path.exists(filename):
            with open(filename) as file:
                data[idd]=json.load(file)

    print(f"Read {len(data)} books")
    return data

# %%
def get_character_actions(alldata):
    
    charactersAgentsDict = {}
    charactersAgentsList = []
    
    for idd in alldata:
        data=alldata[idd]
        for character in data["characters"]:
            if len(character["names"]) > 0:
                char_name = character["names"][0]['n']
                charactersAgentsDict[char_name] = Counter()
                charactersAgentsList.append([])
                agent_terms=[term["w"] for term in character["agent"]] 

                for verb in agent_terms:
                    charactersAgentsDict[char_name][verb]+=1
                    
                for verb, count in charactersAgentsDict[char_name].items():
                    charactersAgentsList[-1]+=[verb]*count
                    
                    
    return charactersAgentsDict, charactersAgentsList

# %%
metadata=read_book_nlp_metadata("../../../Code/comphumF20/data/pulitzer_metadata.txt")
data=read_book_nlp_data("../../../Code/comphumF20/data/pulitzer_booknlp")
# Out:
# Read 94 books

# %%
charAgents, charTexts = get_character_actions(data)

# %%
charAgents
# Out:
# {'Dr. Whittaker': Counter({'wore': 1,
#           'had': 1,
#           'carried': 1,
#           'seemed': 1,
#           'said': 3,
#           'realized': 1,
#           'gave': 1}),
#  'Mrs. Gunn': Counter({'were': 1}),
#  'Sadie': Counter({'see': 1,
#           'plowing': 1,
#           'meant': 1,
#           'took': 4,
#           'going': 1,
#           'was': 14,
#           'got': 3,
#           'answer': 2,
#           'breathing': 1,
#           'managed': 1,
#           'had': 10,
#           'draw': 1,
#           'said': 72,
#           'snapped': 2,
#           'felt': 1,
#           'cut': 2,
#           'have': 4,
#           'say': 1,
#           'slapped': 1,
#           'landed': 1,
#           'saying': 2,
#           'stopped': 3,
#           'elaborated': 1,
#           'popping': 1,
#           'spoke': 1,
#           'cleared': 1,
#           'wore': 1,
#           'made': 4,
#           'taken': 1,
#           'put': 2,
#           'been': 3,
#           'learned': 2,
#           'came': 5,
#           'sat': 3,
#           'inspected': 1,
#           'whispered': 1,
#           'demanded': 6,
#           'admitted': 1,
#           'spewed': 1,
#           'spotted': 1,
#           'knocked': 1,
#           'tell': 4,
#           'did': 3,
#           'reached': 1,
#           'saw': 1,
#           'knew': 5,
#           'led': 2,
#           'know': 2,
#           'flashed': 1,
#           'sent': 1,
#           'fudge': 1,
#           'cook': 1,
#           'turned': 3,
#           'looked': 4,
#           'blazed': 1,
#           'set': 1,
#           'paused': 1,
#           'waited': 2,
#           'twisted': 1,
#           'laughed': 3,
#           'exclaimed': 1,
#           'swung': 2,
#           'announced': 2,
#           'notice': 1,
#           'leaned': 1,
#           'turn': 1,
#           'defining': 1,
#           'sitting': 3,
#           'added': 2,
#           'expelled': 1,
#           'come': 2,
#           'played': 1,
#           'mean': 1,
#           'talked': 1,
#           'went': 1,
#           'beat': 1,
#           'gone': 2,
#           'asked': 4,
#           'gave': 1,
#           'looking': 2,
#           'stood': 2,
#           'settled': 1,
#           'kept': 1,
#           'commanded': 1,
#           'hung': 1,
#           'smack': 1,
#           'God-damn': 1,
#           'sprang': 1,
#           'strangle': 1,
#           'popped': 1,
#           'stuck': 1,
#           'running': 1,
#           'snatched': 1,
#           'caught': 1,
#           'iterated': 1,
#           'repeated': 2,
#           'shook': 3,
#           'lifted': 2,
#           'face': 1,
#           'showing': 1,
#           'asserted': 1,
#           'fumes': 1,
#           'found': 2,
#           'exploded': 1,
#           'seen': 3,
#           'condoning': 1,
#           'seemed': 3,
#           'jabbed': 2,
#           'told': 3,
#           'ask': 1,
#           'grown': 1,
#           'keep': 1,
#           'hack': 1,
#           'get': 1,
#           'treat': 1,
#           'stand': 1,
#           'suffered': 1,
#           'bit': 1,
#           'crying': 1,
#           'eyed': 1,
#           'commented': 1,
#           'fished': 1,
#           'whipped': 1,
#           'swept': 1,
#           'affirmed': 1,
#           'started': 1,
#           'ordered': 1,
#           'understood': 1,
#           'hanging': 1,
#           'respond': 1,
#           'continued': 1,
#           'help': 1,
#           'be': 2,
#           'is': 2,
#           'lying': 1,
#           'studied': 1,
#           'reckon': 1,
#           'interrupted': 1,
#           'sank': 1,
#           'seem': 1,
#           'watching': 1,
#           'throwing': 1,
#           'practicing': 1,
#           'killed': 1,
#           'done': 1,
#           'make': 1,
#           'putting': 1,
#           'rose': 1,
#           'plunged': 1,
#           'shrugged': 1,
#           "'s": 2,
#           'care': 1,
#           'given': 1,
#           'called': 1,
#           'known': 1,
#           'read': 2,
#           'live': 1}),
#  'Jackson': Counter(),
#  'Lynch': Counter({'get': 1}),
#  'Mother': Counter({'died': 1, 'call': 1}),
#  'Jessie': Counter({'explained': 1,
#           'said': 16,
#           'added': 1,
#           'took': 1,
#           'is': 1,
#           'smiled': 1,
#           'spoke': 1,
#           'led': 1,
#           'asked': 1,
#           'sighed': 2,
#           'clicked': 1,
#           'confessed': 1,
#           'advanced': 2,
#           'demanded': 1,
#           'defended': 1,
#           'turned': 3,
#           'raged': 1,
#           'ordered': 1,
#           'got': 2,
#           'ai': 1,
#           'nodded': 1}),
#  'Ettie Lou': Counter({'got': 1}),
#  'Mrs. Dekalb': Counter({'were': 2,
#           'felt': 1,
#           'bear': 1,
#           'went': 2,
#           'hear': 1,
#           'knew': 1,
#           'want': 1,
#           'hurried': 3,
#           'looked': 1,
#           'crying': 1}),
#  'Mama': Counter({'said': 5,
#           'turned': 1,
#           'accusing': 1,
#           'coming': 1,
#           'trailed': 1,
#           'promised': 2,
#           'says': 1}),
#  'Rufus': Counter({'grabbed': 1,
#           'heard': 1,
#           'dropped': 1,
#           'nodded': 1,
#           'said': 1,
#           'asked': 1}),
#  'Joel': Counter({'comes': 1, 'clobbers': 1}),
#  'Amelia': Counter({'warned': 1,
#           'decided': 2,
#           'prefer': 1,
#           'helped': 1,
#           'spread': 1,
#           'looked': 1}),
#  'Victoria': Counter(),
#  'Abraham Lincoln': Counter({'was': 1}),
#  'George Bailey': Counter({'sitting': 1, 'thought': 1, 'leaning': 1}),
#  'Jay': Counter({'ran': 2,
#           'lumbered': 1,
#           'had': 1,
#           'was': 1,
#           'said': 1,
#           'come': 1}),
#  'Thomas': Counter(),
#  'Google': Counter(),
#  'Bell': Counter({'dressed': 1,
#           'got': 2,
#           'bring': 1,
#           'knew': 1,
#           'wound': 1,
#           'headed': 1,
#           'crept': 1,
#           'take': 1,
#           'hid': 1,
#           'caressed': 1,
#           'soothe': 1}),
#  'Miss Amy Field': Counter({'were': 1}),
#  'Ted': Counter({'experienced': 2,
#           'said': 11,
#           'look': 2,
#           'went': 1,
#           'brought': 1,
#           'speak': 1,
#           'felt': 18,
#           'taken': 1,
#           'had': 6,
#           'glimpsed': 2,
#           'folded': 1,
#           'slip': 1,
#           'supposed': 1,
#           'began': 4,
#           'feel': 2,
#           'braced': 1,
#           'asked': 3,
#           'spoke': 1,
#           'refused': 1,
#           'sensed': 6,
#           'appeared': 1,
#           'drank': 1,
#           'thinking': 1,
#           'taught': 1,
#           'needed': 1,
#           'installed': 1,
#           'thought': 6,
#           'found': 7,
#           'point': 1,
#           'sit': 1,
#           'tell': 1,
#           'think': 1,
#           'strolled': 1,
#           'shrank': 1,
#           'witnessed': 1,
#           'saw': 3,
#           'steered': 1,
#           'wanted': 1,
#           'rose': 2,
#           'drifted': 1,
#           'faced': 1,
#           'stepped': 1,
#           'walked': 2,
#           'stared': 1,
#           'left': 2,
#           'spent': 2,
#           'visited': 1,
#           'passed': 1,
#           'imagined': 2,
#           'recognized': 2,
#           'dreading': 1,
#           'slowed': 1,
#           'followed': 4,
#           'sliding': 1,
#           'cried': 1,
#           'rejoined': 1,
#           'hugged': 1,
#           'doing': 1,
#           'kept': 1,
#           'pushed': 2,
#           'wondered': 1,
#           'lived': 1,
#           'given': 1,
#           'take': 2,
#           'took': 2,
#           'gave': 1,
#           'hiding': 1,
#           'allow': 1,
#           'carried': 1,
#           'turn': 1,
#           'tried': 3,
#           'hurting': 1,
#           'longed': 1,
#           'trusted': 1,
#           'do': 1,
#           'loaded': 1,
#           'set': 1,
#           'knew': 2,
#           'exhausted': 1,
#           'parked': 1,
#           'hoped': 1,
#           'made': 1,
#           'seen': 1,
#           'paid': 1,
#           'pictured': 1,
#           'assured': 1,
#           'write': 1,
#           'corrected': 1,
#           'waved': 1,
#           'shoved': 1,
#           'escape': 1,
#           'reached': 2,
#           'wrested': 1,
#           'noticed': 3,
#           'come': 1,
#           'watched': 1,
#           'hovered': 1,
#           'lingered': 1,
#           'circled': 1,
#           'ordered': 1,
#           'realize': 1,
#           'gone': 1,
#           'been': 1,
#           'met': 1,
#           'thrown': 1,
#           'showered': 1,
#           'deliberated': 1,
#           'caught': 1,
#           'tripped': 1,
#           'did': 1,
#           'lecturing': 1,
#           'notice': 1,
#           'smelled': 1,
#           'need': 1,
#           'moved': 1,
#           'bring': 1,
#           'stood': 1,
#           'rubbed': 1,
#           'sleep': 1,
#           'opened': 1,
#           'sat': 3,
#           'forgotten': 1,
#           'heard': 1,
#           'begun': 1,
#           'held': 1,
#           'let': 2,
#           'looked': 2,
#           'hauled': 1,
#           'divorced': 1}),
#  'Andrew': Counter({'left': 1, 'knew': 1}),
#  'Hannah': Counter({'saw': 1,
#           'stay': 1,
#           'dressed': 1,
#           'lamented': 1,
#           'let': 1,
#           'sang': 1,
#           'had': 2,
#           'laughed': 1,
#           'handed': 1,
#           'confirmed': 1,
#           'see': 1,
#           'said': 2,
#           'prepared': 1,
#           'needed': 1,
#           'says': 1,
#           'wiping': 1,
#           'inclined': 1,
#           'interrupted': 1,
#           'getting': 1,
#           'beamed': 1,
#           "'d": 1,
#           'went': 1,
#           'told': 1,
#           'thought': 1}),
#  'Gordon Dekalb': Counter({'were': 1,
#           'came': 1,
#           'wearing': 1,
#           'carried': 1,
#           'walked': 1,
#           'looked': 1}),
#  'Roberts': Counter(),
#  'Uncle Ralph': Counter({'phoned': 1, 'says': 1, 'wanted': 1, 'loves': 1}),
#  'Grampa': Counter({'says': 1,
#           'come': 1,
#           'took': 2,
#           'killed': 1,
#           'got': 2,
#           'get': 3,
#           'throwed': 1,
#           'yells': 1,
#           'is': 1,
#           'said': 11,
#           'was': 2,
#           'raced': 1,
#           'demanded': 1,
#           'stopped': 1,
#           'walked': 1,
#           'choked': 1,
#           'focused': 1,
#           'bowed': 1,
#           'go': 1,
#           'emerging': 1,
#           'held': 1,
#           'brought': 1,
#           'came': 1,
#           'waved': 1,
#           "'s": 1,
#           'began': 2,
#           'went': 1,
#           'carried': 1,
#           'struggling': 1,
#           'cried': 1,
#           'slept': 1,
#           'grunted': 1,
#           'sticking': 1,
#           'lay': 1,
#           'seemed': 1,
#           'buried': 1,
#           'died': 3,
#           'lies': 1}),
#  'LaFollette': Counter(),
#  'Jesus': Counter({'carry': 1,
#           'go': 1,
#           'know': 1,
#           'moved': 1,
#           'looked': 2,
#           'stayed': 1,
#           'planned': 1,
#           'intended': 1,
#           "'s": 1,
#           'wanted': 1,
#           'knew': 1,
#           'hold': 1,
#           'thought': 1}),
#  'Powell': Counter({'began': 1,
#           'inaugurating': 1,
#           'has': 2,
#           'hiring': 1,
#           'understood': 1,
#           'kill': 1,
#           'said': 1,
#           'is': 1}),
#  'Miss Nettie Field': Counter({'were': 1}),
#  'Granmaw': Counter(),
#  'Dr. Dekalb': Counter({'come': 1, 'stood': 1, 'were': 1}),
#  'Arthur': Counter({'moved': 1, 'done': 1}),
#  'Rhoda': Counter(),
#  'Walter': Counter({'blew': 1,
#           'go': 1,
#           'lived': 1,
#           'came': 1,
#           'brought': 1,
#           'handed': 1,
#           'stretched': 1,
#           'said': 2,
#           'smiled': 1,
#           'sat': 1,
#           'come': 1,
#           'leaving': 1,
#           'smiling': 1,
#           'raised': 1}),
#  'John Henry': Counter({"'s": 1, 'indicated': 1}),
#  'Mr. Starr': Counter({'wore': 2,
#           'carried': 1,
#           'said': 8,
#           'put': 1,
#           'had': 1,
#           'tease': 1,
#           'decided': 1,
#           'trust': 1,
#           'thought': 1,
#           'seemed': 1,
#           'understood': 1,
#           'started': 1,
#           'teasing': 1,
#           'smiled': 1,
#           'quieted': 1,
#           'got': 2,
#           'noticed': 1,
#           'saw': 1,
#           'take': 1,
#           'told': 1,
#           'bring': 1,
#           'turned': 1,
#           'drove': 1,
#           'shut': 1,
#           'began': 1,
#           'twisted': 1,
#           'brought': 1,
#           'stopped': 1,
#           'moved': 1,
#           'move': 1,
#           'look': 1,
#           'looked': 1}),
#  'Carrie': Counter({'say': 2, 'start': 1, 'going': 1, 'got': 1, 'wearing': 1}),
#  'Mr. Ralph': Counter({'realized': 1,
#           'wanted': 1,
#           'restrained': 1,
#           'felt': 1,
#           'went': 1,
#           'swing': 1,
#           'bear': 1,
#           'lay': 2}),
#  'Jim-Wilson': Counter({'got': 1}),
#  'Tom': Counter({'flipped': 1,
#           'walking': 1,
#           'vent': 1,
#           'got': 1,
#           'claimed': 1,
#           'wept': 1,
#           'was': 3,
#           'been': 1}),
#  'Catherine': Counter({'has': 1, 'accompanied': 1}),
#  'Granma': Counter({'says': 2,
#           'got': 2,
#           'read': 1,
#           'heard': 1,
#           'said': 14,
#           'moved': 2,
#           'shook': 1,
#           'ai': 1,
#           'coughed': 1,
#           'smiled': 1,
#           'raised': 1,
#           'wants': 2,
#           'thought': 1,
#           'spoken': 1,
#           'bowed': 1,
#           'give': 1,
#           'set': 1,
#           'slept': 4,
#           'do': 1,
#           'drew': 2,
#           'looked': 3,
#           'yawned': 1,
#           'grinned': 1,
#           'settled': 1,
#           'answered': 1,
#           'let': 1,
#           'sulkin': 1,
#           'gon': 2,
#           'have': 1,
#           'pray': 1,
#           'hopped': 1,
#           'cried': 2,
#           'shouted': 1,
#           'was': 2,
#           'sat': 1,
#           'whimpered': 1,
#           'spoke': 1,
#           'had': 1,
#           'feels': 1,
#           'speeded': 2,
#           'retarded': 1,
#           'needs': 1,
#           'wore': 1,
#           'forget': 1,
#           'dozed': 1,
#           'called': 1,
#           'come': 1,
#           'bleated': 1,
#           'swung': 1,
#           'kicked': 1,
#           'whined': 1,
#           'sighed': 1,
#           'thinkin': 1,
#           'gets': 1,
#           'sniffed': 1,
#           'saw': 1,
#           'died': 1}),
#  'Jackie': Counter({'started': 2,
#           'wrote': 1,
#           'knowing': 1,
#           'went': 1,
#           'was': 1,
#           'grown': 1,
#           'discovered': 1,
#           'had': 4,
#           'see': 1,
#           'woke': 1,
#           'disappointed': 1,
#           'made': 1,
#           'killed': 1,
#           'lived': 1,
#           'live': 1,
#           'passed': 1,
#           'pulled': 1,
#           'failed': 1,
#           'got': 2,
#           'do': 1,
#           'knew': 1,
#           'reached': 1,
#           'leaked': 1}),
#  'Morris': Counter({'said': 5,
#           'cleared': 1,
#           'raised': 1,
#           'has': 1,
#           'took': 1,
#           'clicked': 1}),
#  'Ann': Counter({'hoping': 1,
#           'been': 1,
#           'said': 32,
#           'thought': 1,
#           'got': 3,
#           'called': 1,
#           'gotten': 1,
#           'held': 1,
#           'saying': 1,
#           'nodded': 1,
#           'lay': 1,
#           'banged': 1,
#           'holding': 2,
#           'sat': 2,
#           'dropped': 1,
#           'looked': 2,
#           'patted': 1,
#           'scratching': 1,
#           'added': 1,
#           'shrugged': 1,
#           'look': 1,
#           'hoisted': 1,
#           'picked': 2,
#           'respond': 1,
#           'had': 9,
#           'stood': 1,
#           'appeared': 3,
#           'was': 5,
#           'go': 2,
#           'washed': 1,
#           'stepped': 1,
#           'gave': 1,
#           'do': 1,
#           'noticed': 1,
#           'asked': 3,
#           'see': 1,
#           'answered': 1,
#           'stand': 1,
#           'put': 1,
#           'left': 3,
#           'swatted': 1,
#           'tired': 1,
#           'retired': 1,
#           'have': 2,
#           'remembered': 2,
#           'felt': 2,
#           'returned': 1,
#           'trying': 1,
#           'smiled': 1,
#           'rubbed': 1,
#           'feeding': 1,
#           'speaking': 1,
#           'swallowed': 1,
#           'carried': 1,
#           'ordered': 1,
#           'talked': 1,
#           'pushed': 1,
#           'went': 1,
#           'flicked': 1,
#           'say': 1,
#           'slept': 1,
#           'going': 1,
#           'sit': 1,
#           'wanted': 1,
#           'mopping': 1,
#           'has': 1,
#           'cried': 1,
#           'told': 1,
#           'call': 1}),
#  'Brannick': Counter(),
#  'Celia Gunn': Counter({"'s": 1, 'leave': 1, 'were': 1}),
#  'Mary': Counter({'was': 1,
#           'feuded': 1,
#           'suffered': 1,
#           'woke': 1,
#           'moved': 1,
#           'dragged': 1,
#           'worked': 1,
#           'ministered': 1,
#           'stayed': 1,
#           'endured': 1,
#           'do': 1,
#           'appeared': 1,
#           'said': 3,
#           'had': 1,
#           'maintained': 1,
#           'descended': 1,
#           'let': 1,
#           'wondered': 1,
#           'judged': 1,
#           'figure': 1}),
#  'Cross': Counter(),
#  'Sally': Counter(),
#  'Ralph': Counter({'died': 2, "'s": 1, 'wearing': 1}),
#  'Tin Lizzie': Counter({'rolled': 2, 'done': 1}),
#  'Daddy': Counter({'says': 1, 'answered': 1}),
#  'William S. Hart': Counter({'was': 1}),
#  'L&N': Counter(),
#  'Mrs. Follet': Counter({'said': 2,
#           'threw': 1,
#           'whispered': 1,
#           'took': 1,
#           'is': 1}),
#  'Kate': Counter({'knows': 1, 'standing': 1, 'said': 1}),
#  'Oliver': Counter({'said': 1}),
#  'Charlie': Counter({'said': 98,
#           'whispered': 7,
#           'squeeze': 1,
#           'guessed': 1,
#           'tasted': 1,
#           'needed': 7,
#           'look': 4,
#           'brushed': 1,
#           'feel': 7,
#           'picked': 6,
#           'heard': 6,
#           'had': 35,
#           'felt': 12,
#           'figured': 1,
#           'opened': 3,
#           'burned': 2,
#           'saw': 7,
#           'discovered': 1,
#           'got': 8,
#           'taught': 1,
#           'memorizing': 1,
#           'did': 17,
#           'sleep': 1,
#           'named': 1,
#           'gone': 6,
#           'knew': 8,
#           'rub': 1,
#           'hear': 3,
#           'looked': 15,
#           'came': 6,
#           'vomit': 2,
#           'turned': 6,
#           'let': 3,
#           'expected': 3,
#           'been': 11,
#           'walked': 8,
#           'passed': 1,
#           'noticed': 1,
#           'entertaining': 1,
#           'stepped': 2,
#           'wanted': 23,
#           'pushed': 2,
#           'wrote': 3,
#           'left': 2,
#           'come': 2,
#           'congratulated': 1,
#           'made': 11,
#           'lived': 1,
#           'stick': 1,
#           'dialed': 4,
#           'called': 6,
#           'grew': 1,
#           'Is': 1,
#           "'s": 2,
#           'sat': 4,
#           'moved': 3,
#           'showed': 1,
#           'lying': 4,
#           'processing': 1,
#           'sit': 4,
#           'sounded': 1,
#           'hung': 2,
#           'rolled': 4,
#           'watched': 4,
#           'want': 9,
#           'was': 21,
#           'feed': 1,
#           'owned': 1,
#           'funneled': 1,
#           'bought': 4,
#           'went': 9,
#           'spelled': 1,
#           'grinned': 1,
#           'have': 10,
#           'threw': 1,
#           'laid': 1,
#           'swept': 1,
#           'worried': 4,
#           'rubbed': 1,
#           'took': 4,
#           'seen': 7,
#           'brought': 2,
#           'folded': 1,
#           'used': 7,
#           'saying': 3,
#           'taken': 3,
#           "'d": 1,
#           'say': 11,
#           'imagined': 4,
#           'started': 3,
#           'realized': 1,
#           'join': 1,
#           'leave': 1,
#           'questioned': 1,
#           'phrased': 1,
#           'spoke': 1,
#           'get': 5,
#           'shaking': 2,
#           'kissed': 2,
#           'take': 4,
#           'break': 1,
#           'admired': 1,
#           'absorbed': 1,
#           'believed': 1,
#           'know': 6,
#           'joining': 1,
#           'sworn': 1,
#           'poured': 1,
#           'stabbed': 1,
#           'laughing': 2,
#           'insist': 1,
#           'patted': 1,
#           'told': 9,
#           'missed': 2,
#           'hated': 4,
#           'outgrew': 1,
#           'imagine': 4,
#           'grabbed': 1,
#           'drafting': 1,
#           'snatched': 1,
#           'nodded': 1,
#           'twisted': 1,
#           'busied': 1,
#           'understood': 1,
#           'prided': 1,
#           'kept': 7,
#           'mouthed': 1,
#           'seeing': 1,
#           'go': 4,
#           'rest': 1,
#           'learned': 1,
#           'run': 3,
#           'pop': 1,
#           'sign': 1,
#           'drinking': 2,
#           'gotten': 2,
#           'were': 4,
#           'set': 2,
#           'bit': 2,
#           'held': 1,
#           'help': 2,
#           'tried': 5,
#           'find': 3,
#           'sitting': 2,
#           'asked': 3,
#           'deal': 2,
#           'pulled': 2,
#           'drummed': 1,
#           'done': 4,
#           'need': 3,
#           'keep': 1,
#           'paid': 1,
#           'live': 2,
#           'balk': 1,
#           'floating': 1,
#           'joked': 1,
#           'going': 6,
#           'spotted': 1,
#           'thought': 10,
#           'rescue': 1,
#           'gave': 2,
#           'looks': 1,
#           'headed': 2,
#           'remember': 3,
#           'talking': 1,
#           'has': 4,
#           'burst': 1,
#           'put': 8,
#           'notice': 1,
#           'wonder': 1,
#           'holding': 1,
#           'buried': 1,
#           'do': 4,
#           'resented': 1,
#           'stewing': 1,
#           'collapsed': 1,
#           'changed': 2,
#           'interrogate': 1,
#           'neglecting': 1,
#           'won': 1,
#           'eat': 4,
#           'dropped': 1,
#           'stopped': 2,
#           'stuck': 2,
#           'vanished': 1,
#           'listened': 1,
#           'explained': 1,
#           'married': 1,
#           'appraising': 1,
#           'chosen': 1,
#           'smiled': 1,
#           'switch': 1,
#           'propose': 1,
#           'arranged': 1,
#           'planning': 1,
#           'broke': 2,
#           'shook': 1,
#           'dialing': 1,
#           'handed': 1,
#           'considered': 1,
#           'call': 3,
#           'chase': 1,
#           'begin': 1,
#           'found': 2,
#           'show': 1,
#           'chastising': 1,
#           'Walking': 1,
#           'using': 1,
#           'shuddered': 1,
#           'snorted': 1,
#           'jerked': 1,
#           'stood': 2,
#           'cried': 1,
#           'fell': 1,
#           'throwing': 2,
#           'working': 2,
#           'joined': 1,
#           'talked': 2,
#           'stop': 1,
#           'buttoned': 1,
#           'wants': 2,
#           'yelling': 2,
#           'promise': 1,
#           'looking': 1,
#           'assumed': 2,
#           'responded': 1,
#           'wanting': 3,
#           'visit': 1,
#           'bring': 1,
#           'coming': 1,
#           'appear': 1,
#           'having': 1,
#           'crying': 2,
#           'tell': 4,
#           'knows': 1,
#           'broken': 2,
#           'think': 2,
#           'tested': 3,
#           'kicked': 3,
#           'care': 2,
#           'dying': 1,
#           'sank': 1,
#           'wandered': 1,
#           'pounding': 1,
#           'walking': 2,
#           'wait': 2,
#           'manage': 1,
#           'cheated': 2,
#           'happened': 1,
#           'climbed': 1,
#           'killed': 1,
#           'decided': 1,
#           'impose': 1,
#           'reminded': 1,
#           'woke': 2,
#           'convince': 1,
#           'work': 1,
#           'send': 1,
#           'hoped': 2,
#           'be': 4,
#           'driving': 1,
#           'spent': 3,
#           'lay': 2,
#           'developing': 1,
#           'hate': 1,
#           'publishes': 1,
#           'suffer': 1,
#           'worry': 1,
#           'does': 1,
#           'known': 1,
#           'calmed': 1,
#           'played': 1,
#           'scrubbed': 1,
#           'stiffened': 1,
#           'dropping': 1,
#           'hurried': 1,
#           'shut': 1,
#           'trying': 2,
#           'died': 2,
#           'flung': 1,
#           'stared': 1,
#           'closed': 1,
#           'apologize': 1,
#           'sorting': 1,
#           'living': 1,
#           'wearing': 1,
#           'padded': 1,
#           'rinsing': 1,
#           'fix': 2,
#           'wear': 1,
#           'uttered': 1,
#           'toured': 1,
#           'buy': 1,
#           'believe': 2,
#           'arrived': 1,
#           'blowing': 1,
#           'staring': 1,
#           'remembering': 1,
#           'seemed': 1,
#           'shouting': 1,
#           'waiting': 1,
#           'coerce': 1,
#           'infected': 1,
#           'eaten': 1,
#           'die': 1,
#           'yelled': 1,
#           'end': 1,
#           'met': 2,
#           'dance': 2,
#           'offered': 1,
#           'loved': 1,
#           'inherited': 2,
#           'treating': 1,
#           'caused': 1,
#           'loves': 1,
#           'organized': 1,
#           'introduced': 1,
#           'worn': 1,
#           'appreciated': 1,
#           'use': 1,
#           'pointed': 1,
#           'getting': 1,
#           'snap': 1,
#           'doing': 1,
#           'stayed': 2,
#           'picking': 1,
#           'protecting': 1,
#           'exposing': 1,
#           'slept': 1,
#           'shoved': 1,
#           'cursed': 1,
#           'outlive': 1,
#           'drowning': 1,
#           'standing': 1,
#           'expecting': 1,
#           'fly': 1,
#           'ran': 3,
#           'tackled': 1,
#           'meant': 1,
#           'skulking': 1,
#           'accused': 1,
#           'throw': 1,
#           'smoothed': 1,
#           'receiving': 1,
#           'proposed': 1,
#           'apologized': 1,
#           'ate': 1,
#           'keeping': 1,
#           'spared': 1,
#           'seem': 1,
#           'caught': 1,
#           'written': 1,
#           'sweated': 1,
#           'see': 1,
#           'visited': 1,
#           'grasped': 1,
#           'talk': 1,
#           'explain': 1,
#           'check': 1,
#           'forgave': 1,
#           'hold': 1,
#           'fed': 1,
#           'replaced': 1,
#           'give': 1,
#           'wondered': 1,
#           'unpack': 1,
#           'redecorated': 1,
#           'assured': 1,
#           'promised': 1,
#           'return': 1,
#           'complaining': 1,
#           'goes': 1,
#           'coked': 1,
#           'rubbing': 1}),
#  'Sugar Babe': Counter(),
#  'Colm Larkin': Counter({'made': 1,
#           'had': 2,
#           'played': 1,
#           'stayed': 1,
#           'come': 1,
#           'been': 1,
#           'identify': 1,
#           'known': 1,
#           'wrote': 5,
#           'was': 1,
#           'lost': 1,
#           'weeping': 1,
#           'sleep': 1,
#           'going': 1,
#           'fall': 1,
#           'wounded': 1,
#           'walk': 2,
#           'pointed': 1,
#           'remember': 1,
#           'tell': 1}),
#  'William Murray': Counter({'is': 1,
#           'write': 1,
#           'enrolled': 1,
#           'wrote': 1,
#           'showed': 1,
#           'described': 1,
#           'cured': 1}),
#  'Dr. Kopeckny': Counter({'arrived': 1,
#           'invited': 1,
#           'said': 6,
#           'replied': 1,
#           'showed': 1,
#           'ask': 1,
#           'tested': 1,
#           'test': 1}),
#  'Michaels': Counter({'was': 1}),
#  'Helen': Counter({'volunteered': 1,
#           'laughed': 1,
#           'searched': 1,
#           'wrote': 1,
#           'put': 1,
#           'rested': 1,
#           'came': 1,
#           'looked': 1,
#           'were': 1,
#           'touched': 1,
#           'written': 1}),
#  'Virgil': Counter({'say': 2,
#           'spoke': 2,
#           'came': 1,
#           'seen': 1,
#           'began': 1,
#           'did': 3,
#           'go': 1,
#           'broke': 1,
#           'went': 3,
#           'done': 1,
#           'jumped': 2,
#           'brought': 1,
#           'tried': 1,
#           'want': 1,
#           'be': 1,
#           'gestured': 1,
#           'wander': 1,
#           'leap': 1,
#           'do': 1,
#           'snap': 1,
#           'talk': 1,
#           'decided': 1,
#           'discussed': 1,
#           'intended': 1,
#           'mastered': 1,
#           'sent': 2,
#           'trotting': 1,
#           'grunted': 1,
#           'been': 1,
#           'told': 1,
#           'spent': 1,
#           'said': 6,
#           'lookin': 1,
#           'needed': 1,
#           'paused': 1,
#           'added': 1,
#           'jes': 1,
#           'worried': 1,
#           'make': 1,
#           'urged': 1,
#           'saw': 1,
#           'speak': 1,
#           'planting': 1,
#           'run': 1,
#           'expressed': 1,
#           'turned': 1}),
#  'Liwie': Counter({'filling': 1, 'pass': 1, 'pouring': 1}),
#  'Leo': Counter({'developed': 1,
#           'moaned': 1,
#           'trying': 1,
#           'calls': 1,
#           'eats': 1,
#           'stood': 2,
#           'worn': 1,
#           'giggled': 1,
#           'clapped': 1,
#           'tell': 2,
#           'know': 1,
#           'touched': 1,
#           'ran': 1,
#           'had': 3,
#           'called': 1,
#           'commanded': 1,
#           'set': 1,
#           'have': 1,
#           'gotten': 2,
#           'wound': 1,
#           'wheezed': 1,
#           'said': 3,
#           'exchanged': 1,
#           'helped': 1,
#           'handled': 1,
#           'join': 1,
#           'working': 1,
#           'showed': 1,
#           'rolled': 1,
#           'made': 1,
#           'hissed': 1,
#           'snoring': 1,
#           'mumbled': 1,
#           'mention': 1,
#           'standing': 1,
#           'swung': 1,
#           'loves': 1,
#           'saw': 2,
#           'let': 1,
#           'kept': 1,
#           'lifted': 1}),
#  'Nora': Counter({'listed': 2,
#           'loved': 2,
#           'bore': 1,
#           'covered': 1,
#           'wore': 2,
#           'look': 3,
#           'was': 2,
#           'touched': 1,
#           'beamed': 1,
#           'said': 59,
#           'rescued': 1,
#           'coughed': 2,
#           'held': 2,
#           'shook': 1,
#           'blinked': 2,
#           'looked': 4,
#           'leaned': 3,
#           'has': 1,
#           'have': 1,
#           'blushed': 1,
#           'gave': 2,
#           'had': 3,
#           'pointed': 2,
#           'taken': 1,
#           'predict': 1,
#           'take': 1,
#           'repeat': 1,
#           'known': 2,
#           'called': 2,
#           'liked': 1,
#           'love': 1,
#           'promised': 1,
#           'try': 1,
#           'stopped': 1,
#           'dies': 1,
#           'suggested': 2,
#           'keep': 1,
#           'understand': 1,
#           'talk': 1,
#           'claimed': 1,
#           'pay': 1,
#           'endow': 1,
#           'seem': 2,
#           'doing': 1,
#           'died': 2,
#           'vanished': 1,
#           'wanted': 5,
#           'talking': 3,
#           'knows': 1,
#           'lives': 1,
#           'wants': 3,
#           'donate': 1,
#           'sat': 2,
#           'needed': 3,
#           'piped': 1,
#           'laughed': 4,
#           'turned': 1,
#           'wheeled': 2,
#           'invited': 1,
#           'die': 2,
#           'seen': 2,
#           'managed': 1,
#           'opened': 2,
#           'showed': 1,
#           'means': 1,
#           'raised': 1,
#           'passing': 1,
#           'let': 1,
#           'tapped': 1,
#           'donating': 1,
#           'willed': 1,
#           'told': 4,
#           'written': 2,
#           'used': 1,
#           'imagined': 1,
#           'like': 1,
#           'ordered': 1,
#           'remember': 1,
#           'sitting': 1,
#           'holding': 1,
#           'meant': 4,
#           'spoke': 1,
#           'passed': 2,
#           'telling': 1,
#           'come': 1,
#           'drowning': 1,
#           'coughing': 1,
#           'taking': 1,
#           'belonged': 1,
#           'object': 1,
#           'remembered': 1,
#           'returned': 1,
#           'burned': 1,
#           'lived': 1,
#           'sit': 1,
#           'fixed': 1,
#           'squeezing': 1,
#           'stood': 2,
#           'accepted': 1,
#           'contacted': 1,
#           'chosen': 1,
#           'thought': 1,
#           'looking': 1,
#           'insisted': 1,
#           'prepare': 1,
#           'began': 1,
#           'moved': 1,
#           'squinted': 1,
#           'ran': 1,
#           'ask': 1,
#           'put': 1,
#           'zoomed': 1,
#           'talked': 1,
#           'given': 1,
#           'trusted': 1,
#           'see': 2,
#           'tended': 1,
#           'took': 2,
#           'tell': 2,
#           'show': 1,
#           'think': 1,
#           'getting': 1,
#           'say': 1}),
#  'Dr. Chouteau': Counter({'talked': 1,
#           'learned': 1,
#           'said': 4,
#           'made': 1,
#           'saw': 1,
#           'hides': 1,
#           'strolls': 1,
#           'laughed': 1,
#           'resembles': 1,
#           'is': 1,
#           'continued': 1}),
#  'Lawrence': Counter({'stopped': 1,
#           'grinned': 1,
#           'goin': 1,
#           'went': 2,
#           'carrying': 1,
#           'said': 1,
#           'want': 2,
#           'got': 1,
#           'going': 1,
#           'been': 1,
#           'died': 2,
#           'understand': 1}),
#  'Jane': Counter({'took': 1,
#           'left': 1,
#           'ran': 1,
#           'turned': 1,
#           'pretended': 1}),
#  'Lauren': Counter({'said': 5,
#           'wanted': 1,
#           'lives': 1,
#           'thought': 2,
#           'forbade': 1,
#           'constructed': 1,
#           'sank': 1,
#           'felt': 1,
#           'admitted': 1,
#           'avoided': 1,
#           'called': 2,
#           'had': 2,
#           'attended': 1,
#           'forgiven': 1,
#           'objected': 1,
#           'bear': 1,
#           'spoke': 1,
#           'took': 1,
#           'presented': 1,
#           'twitched': 1,
#           'held': 1,
#           'tossed': 1,
#           'went': 2,
#           'returned': 1,
#           'continued': 1,
#           'found': 3,
#           'turned': 1,
#           'manufactured': 1,
#           'kept': 1,
#           'chosen': 2,
#           'ransacked': 1,
#           'owned': 1,
#           'left': 2}),
#  'Dr. Fuller': Counter({'sniffed': 1, 'thrust': 1, 'said': 2, 'turned': 1}),
#  'Copernicus': Counter({'was': 1,
#           'spoken': 1,
#           'said': 1,
#           'moved': 1,
#           'pull': 1,
#           'find': 1,
#           'set': 1,
#           'painted': 1,
#           'head': 1,
#           'went': 1,
#           'led': 1,
#           'had': 1}),
#  'Theo': Counter({'knows': 2,
#           'said': 24,
#           'looks': 1,
#           'enjoy': 1,
#           'speak': 1,
#           'stay': 1,
#           'ok': 1,
#           'stared': 1,
#           'ask': 1,
#           'asked': 1,
#           'gave': 1,
#           'know': 2,
#           'looked': 1,
#           'be': 2,
#           'stopped': 1,
#           'moving': 1,
#           'repeated': 1,
#           'let': 1,
#           'stepped': 1,
#           'trying': 2,
#           'reached': 1,
#           'says': 1,
#           'heard': 1,
#           'marvel': 1,
#           'go': 1,
#           'slipped': 1,
#           'committed': 1,
#           'had': 1,
#           'pushed': 1,
#           'did': 1,
#           'meant': 1}),
#  'Agnes': Counter({'emerged': 2,
#           'accepted': 2,
#           'slid': 1,
#           'dropped': 1,
#           'poured': 2,
#           'lived': 1,
#           'carried': 1,
#           'raised': 3,
#           'seen': 1,
#           'ask': 2,
#           'say': 4,
#           'disappeared': 1,
#           'bought': 1,
#           'wave': 1,
#           'placed': 3,
#           'told': 2,
#           'warm': 1,
#           'said': 11,
#           'found': 3,
#           'was': 2,
#           'wore': 2,
#           'knew': 6,
#           'chosen': 2,
#           'made': 1,
#           'thought': 1,
#           'looked': 1,
#           'studied': 1,
#           'asked': 3,
#           'returned': 2,
#           'designed': 1,
#           'selected': 1,
#           'claimed': 1,
#           'taken': 1,
#           'called': 2,
#           'forgotten': 1,
#           'concluded': 1,
#           'approve': 1,
#           'brought': 1,
#           'given': 1,
#           'discussed': 1,
#           'offered': 1,
#           'paused': 2,
#           'put': 1,
#           'left': 1,
#           'died': 1,
#           'heard': 1,
#           'lifted': 1,
#           'looking': 1,
#           'learned': 1,
#           'stand': 1,
#           'snub': 1,
#           'begun': 1,
#           'froze': 1,
#           'waiting': 1,
#           'came': 2,
#           'crossed': 1,
#           'mentioned': 1,
#           'spent': 1,
#           'promised': 1,
#           'knows': 1,
#           'wants': 1,
#           'closed': 1,
#           'smiled': 1,
#           'held': 1,
#           'turned': 3,
#           'nodded': 1,
#           'touching': 1,
#           'began': 1,
#           'played': 1,
#           'been': 1,
#           'proceed': 1,
#           'approached': 1,
#           'saying': 1,
#           'added': 1}),
#  'Bancroft': Counter({'disappeared': 1}),
#  'Cassandra': Counter({'raised': 1,
#           'picked': 1,
#           'lived': 1,
#           'let': 1,
#           'libs': 1,
#           'ejaculated': 1,
#           'smiled': 1,
#           'thought': 3,
#           'considered': 1,
#           'knew': 1,
#           'got': 1,
#           'said': 4,
#           'name': 1,
#           'went': 1,
#           'clicked': 1,
#           'read': 2,
#           'defended': 1,
#           'taught': 1,
#           'added': 1,
#           'thinking': 1,
#           'gave': 1,
#           'perturbed': 1,
#           'put': 1,
#           'agreed': 1,
#           'getting': 1,
#           'care': 1,
#           'educated': 1,
#           'doing': 1}),
#  'Martin': Counter({'wondered': 1}),
#  'Winifred': Counter({'watched': 1}),
#  'Bessie': Counter({'spent': 1,
#           'make': 1,
#           'packed': 1,
#           'picked': 2,
#           'had': 4,
#           'put': 1,
#           'signed': 1,
#           'liked': 2,
#           'strolled': 1,
#           'made': 1,
#           'took': 1,
#           'failed': 1,
#           'wondered': 1,
#           'was': 1,
#           'hustled': 1,
#           'passed': 1,
#           'walked': 2,
#           'crossed': 1,
#           'stopped': 2,
#           'searched': 1,
#           'arrived': 2,
#           'greeted': 1,
#           'reached': 1,
#           'said': 5,
#           'sleeping': 1,
#           'switch': 1,
#           'turned': 2,
#           'see': 2,
#           'opened': 1,
#           'bought': 1,
#           'smoothed': 1,
#           'bunched': 1,
#           'allowed': 1,
#           'mopped': 1,
#           'listened': 1,
#           'thought': 1,
#           'brought': 1,
#           'benefited': 1,
#           'admired': 1,
#           'gave': 1,
#           'survived': 1,
#           'prepared': 1,
#           'take': 1,
#           'sat': 1,
#           'knew': 1,
#           'imagined': 1,
#           'sprinted': 1,
#           'delivered': 1,
#           'waited': 1,
#           'chortled': 1,
#           'suggested': 1,
#           'invited': 1,
#           'recruited': 1,
#           'reported': 1,
#           'elevated': 1,
#           'sold': 2,
#           'snarled': 1,
#           'handed': 1,
#           'relinquished': 1}),
#  'Lesueur': Counter({'pouted': 1, 'continued': 1}),
#  'Montgomerie': Counter(),
#  'Denis': Counter({'doan': 2,
#           'opened': 1,
#           'said': 3,
#           'showed': 1,
#           'spoke': 1,
#           'let': 1,
#           'is': 1,
#           'answered': 1,
#           'remarked': 1,
#           'inquired': 2,
#           'pulled': 1,
#           'led': 1,
#           'dropped': 1,
#           'raised': 1,
#           'give': 1,
#           'lies': 1,
#           'works': 1,
#           'appear': 1,
#           'laughed': 3,
#           'saw': 1,
#           'asked': 1,
#           'pointed': 1,
#           'call': 1,
#           'swished': 1,
#           'say': 1,
#           'whispered': 1,
#           'run': 1}),
#  'James': Counter({'eat': 1,
#           'refused': 2,
#           'led': 1,
#           'stop': 3,
#           'pick': 1,
#           'failed': 1,
#           'came': 1,
#           'seemed': 1,
#           'wandered': 1,
#           'stared': 2,
#           'looking': 1,
#           'wept': 1,
#           'had': 4,
#           'placed': 1,
#           'started': 3,
#           'stopped': 1,
#           'went': 3,
#           'found': 2,
#           'pointed': 1,
#           'tapped': 1,
#           'grabbed': 1,
#           'notice': 1,
#           'interrupted': 1,
#           'want': 1,
#           'trusted': 1,
#           'worked': 2,
#           'spat': 1,
#           'dug': 1,
#           'disappeared': 1,
#           'taken': 1,
#           'becoming': 1,
#           'lost': 1,
#           'scurried': 1,
#           'stayed': 1,
#           'replaced': 1,
#           'keep': 1,
#           'decided': 1,
#           'gave': 1,
#           'packed': 1,
#           'took': 2,
#           'walked': 3,
#           'nodded': 2,
#           'requested': 1,
#           'looked': 5,
#           'put': 1,
#           'patted': 1,
#           'grunted': 1,
#           'swept': 1,
#           'was': 1,
#           'produced': 1,
#           'made': 1,
#           'fetched': 1,
#           'ignored': 1,
#           'pushed': 1,
#           'stood': 1,
#           'kept': 1,
#           'ordered': 1,
#           'turned': 1,
#           'asking': 1,
#           'come': 1,
#           'gestured': 1,
#           'paled': 1,
#           'concluded': 1,
#           'attempted': 1,
#           'repeated': 1,
#           'glanced': 1,
#           'hid': 1,
#           'roved': 1,
#           'locate': 1,
#           'reach': 1,
#           'find': 1}),
#  'Harry': Counter({'showed': 1,
#           'pointed': 1,
#           'said': 2,
#           'had': 1,
#           'planning': 1,
#           'invited': 1,
#           'laughed': 1,
#           'created': 1,
#           'concocted': 1,
#           'daubed': 1,
#           'unleash': 1,
#           'written': 1}),
#  'Lavinia': Counter(),
#  'Caleb': Counter({'ordered': 1,
#           'was': 1,
#           'asked': 1,
#           'dismounted': 1,
#           'managed': 2,
#           'pass': 1,
#           'changed': 1,
#           'seemed': 1,
#           'stared': 1,
#           'looked': 1}),
#  'Erasmus': Counter({'came': 1,
#           'given': 1,
#           'recorded': 1,
#           'owned': 1,
#           'sold': 1,
#           'coming': 1}),
#  'Eudora': Counter({'meet': 1, 'says': 1}),
#  'Scheuchzer': Counter(),
#  'Dr. Boerhaave': Counter(),
#  'Grace': Counter({'showed': 1,
#           'returned': 1,
#           'said': 6,
#           'led': 1,
#           'know': 1,
#           'turned': 2,
#           'came': 1,
#           'falls': 1,
#           'lays': 1,
#           'was': 3,
#           'predicted': 1,
#           'worked': 1,
#           'called': 1,
#           'lying': 1,
#           'lifted': 1,
#           'eased': 1,
#           'broke': 1,
#           'stepped': 1,
#           'busied': 1,
#           'be': 1,
#           'working': 1,
#           'left': 1,
#           'felt': 1,
#           'come': 1,
#           'stood': 1,
#           'shattered': 1,
#           'seemed': 1,
#           'went': 2,
#           'sewn': 1,
#           'looked': 1,
#           'promised': 1,
#           'done': 1,
#           'smoothed': 1,
#           'saved': 1,
#           'struggled': 1,
#           'asked': 1,
#           'sought': 1,
#           'given': 1,
#           'reached': 1,
#           'nodded': 1,
#           'expected': 1,
#           'took': 1,
#           'let': 1,
#           'held': 1,
#           'pressed': 1,
#           'breathed': 1,
#           'gave': 1}),
#  'Mr. Wright': Counter({'pulled': 1, 'added': 1}),
#  'George': Counter({'picked': 1, 'dropped': 1, 'waited': 1}),
#  'Dehra Dun': Counter(),
#  'Hermione': Counter({'send': 1, 'grown': 1}),
#  'Mr. Woodruff': Counter({'spent': 1,
#           'felt': 1,
#           'had': 1,
#           'decided': 1,
#           'asked': 1,
#           'sat': 1,
#           'gained': 1}),
#  'Academy': Counter(),
#  'Godfrey Vigne': Counter({'thought': 1,
#           'managed': 1,
#           'described': 1,
#           'triangulated': 1,
#           'said': 2}),
#  'Samuel': Counter({'preaches': 1,
#           'visit': 2,
#           'talked': 1,
#           'thought': 4,
#           'told': 3,
#           'asked': 3,
#           'have': 3,
#           'looked': 3,
#           'perked': 1,
#           'said': 17,
#           'says': 2,
#           'felt': 1,
#           'dreamed': 2,
#           'thinks': 1,
#           'talks': 1,
#           'met': 3,
#           'swear': 1,
#           'left': 2,
#           'urged': 1,
#           'is': 2,
#           'run': 1,
#           'found': 1,
#           'finished': 1,
#           'telling': 1,
#           'holding': 1,
#           'did': 2,
#           'speaking': 1,
#           'gave': 1,
#           'gone': 1,
#           'hesitated': 1,
#           'tells': 1,
#           'loves': 1,
#           'accompanied': 1,
#           'continued': 1,
#           'struck': 1,
#           'started': 1,
#           'reassure': 1,
#           'sends': 1,
#           'discussing': 1,
#           'feels': 1,
#           'married': 1}),
#  'Kalm': Counter({'wrote': 1, 'visited': 1}),
#  'Suky': Counter({'used': 1,
#           'said': 6,
#           'reminded': 1,
#           'directed': 1,
#           'sat': 1,
#           'bought': 1,
#           'found': 1,
#           'consulted': 1,
#           'saw': 1,
#           'disappeared': 1,
#           'breathed': 1,
#           'basked': 1,
#           'given': 1}),
#  'Dr. Davis': Counter({'admits': 1,
#           'scorn': 1,
#           'thinks': 2,
#           'displays': 1,
#           'think': 1,
#           'does': 1,
#           'likes': 1,
#           'gathers': 1,
#           'says': 2}),
#  'East India Company': Counter({'lived': 1,
#           'says': 2,
#           'tells': 1,
#           'appears': 1,
#           'reveals': 1,
#           'resembles': 1,
#           'claims': 2,
#           'knows': 1}),
#  'Conrad': Counter({'found': 1,
#           'wrote': 1,
#           'was': 1,
#           'risen': 1,
#           'said': 6,
#           'hoisted': 1,
#           'folded': 1,
#           'fell': 1,
#           'did': 1,
#           'turned': 1,
#           'had': 2,
#           'choose': 1,
#           'pulling': 1,
#           'done': 1,
#           'take': 1,
#           'came': 1,
#           'murmur': 1,
#           'guessed': 1,
#           'go': 1,
#           'send': 1,
#           'wanted': 1,
#           'jumped': 1,
#           'asked': 1,
#           'coming': 2,
#           'stay': 1,
#           'leaned': 1,
#           'think': 1,
#           'told': 1,
#           'called': 1,
#           'brought': 2}),
#  'Mr. Bartram': Counter({'see': 1,
#           'listened': 1,
#           'said': 8,
#           'waved': 1,
#           'walked': 1,
#           'train': 1,
#           'saw': 1,
#           'watched': 1,
#           'came': 1,
#           'pulls': 1,
#           'nodded': 1,
#           'gestured': 1,
#           'explained': 1,
#           'made': 1,
#           'found': 2,
#           'gaze': 1,
#           'known': 1,
#           'knows': 1,
#           'betrayed': 1,
#           'say': 1,
#           'continued': 1,
#           'used': 1,
#           'asked': 1,
#           'returned': 1,
#           'written': 1}),
#  'Stuart': Counter({'rode': 1,
#           'had': 2,
#           'moving': 1,
#           'doing': 1,
#           'joyriding': 2,
#           'sent': 1,
#           'fool': 1,
#           'left': 1,
#           'leave': 1,
#           'gets': 1,
#           'having': 1,
#           'returned': 1,
#           'let': 2,
#           'come': 4,
#           'said': 5,
#           'thought': 2,
#           'heard': 1,
#           'go': 1,
#           'comes': 4,
#           'read': 1,
#           'been': 1,
#           'thanked': 1,
#           'saw': 1,
#           'woke': 1,
#           'developed': 1,
#           'knew': 1,
#           'appeared': 1,
#           'pressed': 1,
#           'wished': 1,
#           'swung': 1,
#           'is': 1,
#           'came': 2,
#           'grinning': 1,
#           'know': 1,
#           'grinned': 1,
#           'drawled': 1,
#           'froze': 1,
#           'shook': 1,
#           'struggling': 1,
#           'stood': 5,
#           'paused': 1,
#           'was': 1,
#           'felt': 1,
#           'wanted': 1,
#           'help': 1,
#           'reached': 1,
#           'saying': 1,
#           'held': 1,
#           'complete': 1,
#           'gone': 1}),
#  'Peter': Counter({'have': 1, 'asked': 1}),
#  'Rose': Counter(),
#  'Darwin': Counter({'pushed': 1, 'struck': 1}),
#  'Dr. Grant': Counter({'thought': 1,
#           'had': 1,
#           'saved': 1,
#           'returned': 1,
#           'been': 1}),
#  'Ned': Counter({'belonged': 2,
#           'were': 2,
#           'happened': 1,
#           'died': 1,
#           'changed': 1,
#           'let': 2,
#           'win': 1,
#           'mislaid': 1,
#           'was': 16,
#           'said': 328,
#           'look': 3,
#           'went': 4,
#           'rode': 1,
#           'realised': 2,
#           'speak': 1,
#           'wash': 1,
#           'used': 3,
#           'knew': 5,
#           'refused': 2,
#           'had': 38,
#           'loved': 1,
#           'scorn': 1,
#           'left': 3,
#           'come': 5,
#           'blinked': 3,
#           'see': 12,
#           'doing': 4,
#           'carrying': 1,
#           'loading': 1,
# ...
#           'closed': 1,
#           'cried': 1,
#           'entered': 1,
#           'called': 1,
#           'remember': 1,
#           'remembered': 1,
#           'take': 1}),
#  'Signal Corps': Counter({'was': 1, 'sent': 1}),
#  'Lester': Counter(),
#  'De Luca': Counter({'said': 1}),
#  'Sal': Counter({'smiled': 1}),
#  'Wiley': Counter({'sticking': 1,
#           'find': 1,
#           'attended': 1,
#           'said': 5,
#           'looked': 2,
#           'leaned': 1,
#           'sat': 1,
#           'demand': 1,
#           'reads': 1,
#           'calls': 1,
#           'set': 1,
#           'tanned': 1,
#           'promises': 1,
#           'looking': 1,
#           'came': 1,
#           'left': 1,
#           'kissed': 1,
#           'reassuring': 1,
#           'made': 1,
#           'slammed': 1,
#           'drive': 1,
#           'were': 1,
#           'offered': 1,
#           'taking': 1,
#           'took': 1,
#           'driven': 1,
#           'was': 2,
#           'share': 1,
#           'moved': 1,
#           'be': 1}),
#  'Transit Company': Counter(),
#  'Anderson': Counter({'listened': 1, 'turned': 1}),
#  'Malcolm': Counter({'loved': 1,
#           'did': 1,
#           'was': 1,
#           'said': 4,
#           'bought': 1,
#           'stopped': 1,
#           'answered': 1,
#           'feel': 1}),
#  'Tyler': Counter({'was': 2,
#           'picked': 1,
#           'waiting': 1,
#           'want': 1,
#           'judge': 1,
#           'take': 1,
#           'sobered': 1,
#           'been': 1}),
#  'Negro': Counter({'going': 1, 'sat': 1, 'had': 1}),
#  'Edsell': Counter({'said': 62,
#           'had': 5,
#           'refuse': 1,
#           'lives': 1,
#           'thinks': 2,
#           'says': 4,
#           'understands': 1,
#           'do': 4,
#           'left': 1,
#           'hung': 2,
#           'glanced': 2,
#           'rein': 1,
#           'going': 5,
#           'doing': 4,
#           'did': 1,
#           'told': 2,
#           'thought': 2,
#           'persecuted': 1,
#           'wrote': 2,
#           'stopped': 3,
#           'done': 1,
#           'mean': 1,
#           'means': 2,
#           'sees': 1,
#           'write': 1,
#           'appeared': 1,
#           'showed': 2,
#           'getting': 1,
#           'arose': 1,
#           'see': 1,
#           'brought': 1,
#           'turned': 3,
#           'stared': 2,
#           'took': 5,
#           'run': 1,
#           'asked': 1,
#           'try': 1,
#           'forgotten': 1,
#           'taken': 1,
#           'noticed': 1,
#           'wants': 1,
#           'get': 3,
#           'looked': 3,
#           'sent': 1,
#           'figured': 1,
#           'believe': 1,
#           'walked': 1,
#           'lets': 1,
#           'have': 2,
#           'put': 2,
#           'smiled': 1,
#           'looking': 2,
#           'knows': 1,
#           'picked': 1,
#           'be': 2,
#           'wanted': 2,
#           'stepped': 1,
#           'is': 3,
#           'held': 2,
#           'knew': 3,
#           'seen': 1,
#           'talking': 1,
#           'improved': 1,
#           'pretend': 1,
#           'spoke': 1,
#           'got': 2,
#           'asking': 1,
#           'lean': 1,
#           'go': 1,
#           'displayed': 1,
#           'went': 1,
#           'acted': 1,
#           'met': 1,
#           'refused': 1,
#           'questioned': 1,
#           'behaved': 1,
#           'feel': 1,
#           'let': 1,
#           'proceed': 1,
#           'planned': 1,
#           'made': 6,
#           'yielded': 1,
#           'seem': 1,
#           'disregarded': 1,
#           'running': 1,
#           'attempted': 1,
#           'felt': 1,
#           'observed': 1,
#           'gave': 2,
#           'coming': 2,
#           'hit': 1,
#           'shrugged': 1,
#           'come': 1,
#           'was': 1,
#           'think': 1,
#           'stood': 2,
#           'gets': 2,
#           'push': 1,
#           'owe': 1,
#           'allowed': 1,
#           'owes': 2,
#           'give': 1,
#           'pulled': 1,
#           'jumped': 1,
#           'brooded': 1,
#           'acknowledged': 1,
#           'suffered': 1,
#           'roused': 1,
#           'want': 2,
#           'say': 1,
#           'makes': 1,
#           'approached': 1,
#           'considered': 1,
#           'laughed': 1,
#           'answered': 1,
#           'help': 1}),
#  'Shakespeare': Counter({'lectured': 2, 'were': 1}),
#  'Operations': Counter(),
#  'Jim Crow': Counter({'ai': 1, 'defined': 1}),
#  'Pettie': Counter({'said': 10,
#           'passed': 1,
#           'breathed': 1,
#           'regretting': 1,
#           'managed': 1,
#           'know': 1,
#           'going': 1,
#           'got': 1,
#           'catches': 1,
#           'smiled': 1,
#           'had': 1,
#           'arisen': 1,
#           'turned': 1,
#           'blushed': 1}),
#  'Mr. DeWilton': Counter(),
#  'Richardson': Counter(),
#  'Miami Herald': Counter({'asked': 1,
#           'remarked': 1,
#           'said': 4,
#           'estimated': 1}),
#  'Washington Star': Counter({'said': 5,
#           'asked': 4,
#           'proposed': 1,
#           'sitting': 1,
#           'pointed': 1,
#           'whispered': 1}),
#  'Mr. Hines': Counter({'says': 2}),
#  'Herbert Gelman': Counter({'says': 2,
#           'remembers': 1,
#           'please': 1,
#           'come': 1,
#           'said': 72,
#           'know': 1,
#           'asked': 5,
#           'are': 1,
#           'knew': 1,
#           'gave': 1,
#           'remarked': 1,
#           'added': 2,
#           'looking': 2,
#           'did': 2,
#           'seen': 1,
#           'wishes': 1,
#           'shifted': 1,
#           'nodded': 1,
#           'replied': 1,
#           'repeated': 1,
#           'spoke': 1,
#           'promised': 1,
#           'interrupted': 2,
#           'told': 1,
#           'permit': 1,
#           'had': 1,
#           'demanded': 1,
#           'blowing': 1,
#           'leaned': 1,
#           'offer': 1,
#           'made': 1,
#           'be': 1,
#           'done': 1,
#           'telling': 1}),
#  'Newark News': Counter({'let': 1, 'had': 1}),
#  'Mimi': Counter({'cracking': 1, 'said': 2}),
#  'Mr. Witness': Counter({'did': 1,
#           'asked': 2,
#           'intend': 1,
#           'observed': 2,
#           'said': 3,
#           'was': 1}),
#  'Interior': Counter(),
#  'Mr. Abbott': Counter(),
#  'Navy Band': Counter({'playing': 1}),
#  'Henry Lytle': Counter({'sitting': 1,
#           'got': 1,
#           'tells': 1,
#           'prints': 1,
#           'loved': 2,
#           'thought': 1}),
#  'Billy Knox': Counter({'known': 1,
#           'occupied': 1,
#           'beginning': 2,
#           'spent': 1,
#           'began': 1}),
#  'Victor Ennis': Counter({'nods': 1,
#           'says': 2,
#           'said': 3,
#           'observed': 1,
#           'came': 1,
#           'thought': 1,
#           'echoed': 1,
#           'refused': 1,
#           'murmured': 1,
#           'perfected': 1}),
#  'Mr. LefBngwell': Counter({'has': 1,
#           'added': 1,
#           'asked': 1,
#           'did': 1,
#           'says': 1,
#           'know': 1,
#           'win': 1}),
#  'Pooh': Counter({'included': 1,
#           'find': 1,
#           'had': 2,
#           'wandered': 1,
#           'found': 1,
#           'looking': 1,
#           'took': 1,
#           'made': 1,
#           'held': 1,
#           'given': 1,
#           'realized': 1,
#           'failed': 1}),
#  'Rob Cunningham': Counter({'says': 2,
#           'leaned': 1,
#           'stood': 1,
#           'murmured': 1,
#           'going': 1}),
#  'Henry Wilson': Counter({'sent': 1, 'got': 1, 'doing': 1}),
#  'AP': Counter({'says': 1}),
#  'National Committee': Counter({'been': 1}),
#  'Robert A. Leffingwell': Counter({'knew': 2,
#           'repeat': 1,
#           'said': 4,
#           'opposed': 1,
#           'paused': 2,
#           'betray': 1,
#           'found': 3,
#           'drained': 1,
#           'read': 1,
#           'laid': 1,
#           'finished': 1,
#           'had': 5,
#           'sat': 1,
#           'thought': 3,
#           'have': 3,
#           'making': 1,
#           'applying': 1,
#           'keep': 1,
#           'felt': 3,
#           'studied': 1,
#           'began': 1,
#           'hung': 1,
#           'realized': 2,
#           'going': 1,
#           'was': 2,
#           'wanted': 1,
#           'hear': 1,
#           'reconcile': 1,
#           'needed': 1,
#           'took': 1,
#           'feeling': 1,
#           'been': 1,
#           'slept': 1,
#           'wondered': 1,
#           'tried': 1,
#           'stay': 1,
#           'say': 1,
#           'supposed': 1,
#           'wished': 1,
#           'waved': 1,
#           'knows': 1,
#           'decided': 1,
#           'went': 1,
#           'be': 1,
#           'submitted': 1,
#           'do': 1,
#           'justify': 1,
#           'added': 1}),
#  'Mrs. Adams': Counter({'kept': 1, 'got': 1, 'slipped': 1}),
#  'Hank': Counter({'grown': 2}),
#  'Ray Smith': Counter({'thinks': 2, 'got': 1, 'be': 1, 'went': 1}),
#  'Murfee Andrews': Counter({'loaded': 1,
#           'cast': 1,
#           'got': 1,
#           'see': 1,
#           'emerged': 1,
#           'joined': 1,
#           'hesitated': 1}),
#  'Stanley Danta': Counter({'said': 51,
#           'did': 1,
#           'sent': 1,
#           'practicing': 1,
#           'played': 1,
#           'observed': 2,
#           'explained': 1,
#           'suspects': 1,
#           'knows': 4,
#           'smiled': 5,
#           'see': 1,
#           'gestured': 1,
#           'comes': 1,
#           'chuckled': 1,
#           'told': 2,
#           'going': 1,
#           'means': 1,
#           'were': 1,
#           'added': 2,
#           'reached': 2,
#           'prevent': 1,
#           'remarked': 3,
#           'watching': 1,
#           'thinking': 1,
#           'suggested': 6,
#           'gested': 1,
#           'made': 1,
#           'agreed': 1,
#           'reflected': 1,
#           'conceded': 1,
#           'started': 1,
#           'laughed': 1,
#           'left': 3,
#           'rates': 1,
#           'understands': 1,
#           'was': 2,
#           'valued': 1,
#           'realized': 1,
#           'found': 1,
#           'known': 1,
#           'gone': 1,
#           'rally': 1,
#           'get': 1,
#           'volunteered': 1,
#           'looked': 1,
#           'thought': 1,
#           'go': 1,
#           'contacted': 1,
#           'came': 1,
#           'talk': 1,
#           'nodded': 1,
#           'want': 1,
#           'repeated': 1,
#           'are': 1,
#           'know': 1,
#           'carried': 1,
#           'make': 1,
#           'feel': 1,
#           'piloting': 1}),
#  'Raoul Barre': Counter({'order': 1,
#           'said': 24,
#           'suggested': 3,
#           'inquired': 1,
#           'observed': 1,
#           'overwhelms': 1,
#           'looked': 1,
#           'asked': 3,
#           'finished': 1,
#           'began': 1,
#           'know': 1,
#           'took': 1,
#           'murmured': 1,
#           'made': 1,
#           'seemed': 1,
#           'like': 1,
#           'called': 1,
#           'decide': 1,
#           'relapsed': 1,
#           'come': 1,
#           'came': 1}),
#  'Dave Grant': Counter({'busied': 1}),
#  'Cashton': Counter({'said': 1, 'looked': 1}),
#  'Abe': Counter({'died': 1,
#           'refused': 1,
#           'be': 1,
#           'was': 1,
#           'thought': 1,
#           'go': 1,
#           'went': 2,
#           'believed': 1}),
#  'Royce Blair': Counter({'selected': 1,
#           'wants': 1,
#           'like': 1,
#           'tried': 1,
#           'tell': 1,
#           'enunciates': 1,
#           'be': 1,
#           'snapped': 1,
#           'been': 1}),
#  'Kitty': Counter({'ended': 1,
#           'insists': 1,
#           'heard': 1,
#           'said': 21,
#           'nodded': 1,
#           'going': 1,
#           'ordered': 1,
#           'sat': 1,
#           'stepped': 2,
#           'wore': 2,
#           'gave': 2,
#           'grinned': 1,
#           'looked': 4,
#           'reached': 2,
#           'say': 2,
#           'interrupted': 1,
#           'spoken': 1,
#           'demurred': 1,
#           'headed': 1,
#           'turned': 1,
#           'undergone': 1,
#           'washed': 1,
#           'began': 1,
#           'wanted': 2,
#           'asked': 3,
#           'laughed': 1,
#           'exhaled': 1,
#           'opened': 1,
#           'humming': 1,
#           'wearing': 2,
#           'had': 2,
#           'turn': 1,
#           'watched': 1,
#           'came': 1,
#           'moved': 1,
#           'experienced': 1,
#           'poured': 1,
#           'pressed': 1,
#           'stood': 1,
#           'pulled': 1,
#           'adored': 1,
#           'leaned': 1,
#           'stop': 1,
#           'flung': 1,
#           'were': 1,
#           'taken': 1,
#           'died': 1,
#           'smiling': 1,
#           'played': 1,
#           'be': 1,
#           'smiles': 1,
#           "'s": 1,
#           'starts': 1,
#           'belongs': 1,
#           'recognize': 1,
#           'says': 8,
#           'has': 3,
#           'asks': 1,
#           'turns': 1,
#           'eats': 1,
#           'ignores': 1,
#           'requested': 1,
#           'touch': 1,
#           'dipped': 1,
#           'go': 1,
#           'do': 1,
#           'falls': 1,
#           'tilts': 1,
#           'shrinks': 1,
#           'erect': 1,
#           'leads': 1,
#           'reach': 1,
#           'resumed': 1,
#           'is': 1,
#           'looks': 1,
#           'writhing': 1,
#           'open': 1,
#           'avails': 1,
#           'manages': 1,
#           'running': 1,
#           'sent': 1,
#           'wrote': 1}),
#  'Federal Reserve': Counter(),
#  'Mr. Anderson': Counter({'worked': 1, 'received': 1, 'added': 1}),
#  'Ben': Counter({'sends': 1, 'sees': 1, 'have': 1, 'tires': 1}),
#  'Bob Lefifingwell': Counter({'braced': 1, 'said': 3, 'made': 1}),
#  'Ellabelle Proctor': Counter({'got': 1, 'knew': 1, 'denied': 1}),
#  'Allen Whiteside': Counter({'cried': 1,
#           'spoke': 1,
#           'gave': 1,
#           'said': 1,
#           'showed': 1,
#           'hurried': 1,
#           'jumped': 1,
#           'been': 1}),
#  'Houston Press': Counter({'shook': 1, 'said': 1}),
#  'Boche': Counter({'stick': 1}),
#  'Washington Daily News': Counter(),
#  'Walker': Counter({'smiled': 1,
#           'felt': 1,
#           'asked': 1,
#           'joined': 1,
#           'did': 1,
#           'said': 2,
#           'owed': 2,
#           'agreed': 1,
#           'told': 1,
#           'going': 1,
#           'killed': 1,
#           'gave': 1,
#           'get': 1,
#           'has': 1,
#           'do': 1,
#           'was': 1,
#           'bought': 1}),
#  'Nelson Lloyd': Counter({'listening': 1, 'went': 1}),
#  'Lloyd B. Cavanaugh': Counter({'sitting': 1,
#           'rushed': 1,
#           'said': 1,
#           'rode': 1}),
#  'Treasury': Counter({'mixed': 1}),
#  'Claude Maudulayne': Counter({'said': 17,
#           'find': 1,
#           'has': 1,
#           'murmured': 1,
#           'observed': 1,
#           'protested': 1,
#           'conferred': 1,
#           'knew': 2,
#           'suggested': 1,
#           'made': 1,
#           'like': 1,
#           'come': 1,
#           'asked': 1,
#           'shrugged': 1,
#           'say': 1}),
#  'Harl': Counter({'stopped': 1, 'said': 1}),
#  'John Baker': Counter({'manages': 1, 'joined': 1, 'said': 1}),
#  'Raymond Robert Smith': Counter({'said': 1, 'made': 1, 'was': 1}),
#  'Mr. Chairman': Counter({'said': 19,
#           'asked': 3,
#           'added': 1,
#           'finished': 1,
#           'tell': 1,
#           'plan': 1,
#           'give': 1,
#           'succeeding': 1,
#           'promised': 2,
#           'seems': 1,
#           'forgotten': 1,
#           'apologize': 1,
#           'leaned': 1,
#           'do': 1,
#           'ask': 1,
#           'making': 1}),
#  'FPC': Counter(),
#  'Elizabeth Henry': Counter({'decided': 1, 'thought': 1}),
#  'Herald Tribune': Counter({'had': 1}),
#  'Appropriations Committee': Counter(),
#  'Post-Dispatch': Counter({'remarked': 1,
#           'said': 2,
#           'exclaimed': 2,
#           'inquired': 1,
#           'observed': 1,
#           'agreed': 1,
#           'whispered': 1,
#           'sounds': 1}),
#  'Finance Committee': Counter({'waiting': 1, 'wants': 1}),
#  'Joint Chiefs of Staff': Counter({'had': 1}),
#  'Irving Steinman': Counter({'sitting': 1, 'said': 2, 'found': 1, 'came': 1}),
#  'Fred Cahill': Counter({'struggling': 1, 'waved': 1, 'felt': 1}),
#  'Associated Press': Counter({'stopped': 1}),
#  'Roselands': Counter({'come': 1, 'sold': 1}),
#  'Mr. Knox': Counter({'observed': 1, 'like': 1, 'said': 1, 'had': 1}),
#  'Mr. Lefflngwell': Counter({'said': 2, 'perform': 1, 'been': 1}),
#  'Los Angeles Times': Counter(),
#  ...}

# %%
charTexts
# Out:
# [['wore',
#   'had',
#   'carried',
#   'seemed',
#   'said',
#   'said',
#   'said',
#   'realized',
#   'gave'],
#  ['were'],
#  ['got',
#   'recognize',
#   'died',
#   'knew',
#   'laid',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'had',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'began',
#   'thought',
#   'nodded',
#   'say',
#   'spoke',
#   'turned',
#   'knows',
#   'knows',
#   'advising',
#   'talk',
#   'loses',
#   'does',
#   'crying'],
#  ['left',
#   'forgotten',
#   'asked',
#   'asked',
#   'strode',
#   'held',
#   'changed',
#   'looked',
#   'looked',
#   'looked',
#   'frowning',
#   'smiled',
#   'smiled',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'broke',
#   'leaned',
#   'speaking',
#   'addressed',
#   'praying',
#   'spoke',
#   'spoke',
#   'closed',
#   'took',
#   'helped',
#   'think',
#   'wished',
#   'wished',
#   'hated',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hates',
#   'hate',
#   'hate',
#   'hate',
#   'hate',
#   'thought',
#   'thought',
#   'thought',
#   'remember',
#   'shown',
#   'was',
#   'was',
#   'been',
#   'loves',
#   'loves',
#   'loves',
#   'loves',
#   'talked',
#   'like',
#   "'s",
#   "'s",
#   "'s",
#   'likes',
#   'likes',
#   'acts',
#   'feels',
#   'told',
#   'told',
#   'told',
#   'told',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'wanted',
#   'wanted',
#   'wanted',
#   'does',
#   'does',
#   'want',
#   'want',
#   'want',
#   'want',
#   'Want',
#   'knows',
#   'love',
#   'ask',
#   'ask',
#   'ask'],
#  ['get'],
#  ['notice',
#   'kept',
#   'wants',
#   'told',
#   'be',
#   'said',
#   'said',
#   'lowered',
#   'took',
#   'whispered',
#   'straightened'],
#  ['hated', 'got'],
#  ['got'],
#  ['were',
#   'were',
#   'felt',
#   'bear',
#   'went',
#   'went',
#   'hear',
#   'knew',
#   'want',
#   'hurried',
#   'hurried',
#   'hurried',
#   'looked',
#   'crying'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'turned',
#   'accusing',
#   'coming',
#   'trailed',
#   'promised',
#   'promised',
#   'says'],
#  ['felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'made',
#   'made',
#   'made',
#   'laughed',
#   'kill',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'fight',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'lifted',
#   'brag',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'done',
#   'done',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'liked',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'come',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'noticed',
#   'put',
#   'put',
#   'imitated',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'pressed',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'feel',
#   'sat',
#   'sat',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'eat',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'been',
#   'been',
#   'believe',
#   'believe',
#   'insisted',
#   'play',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'wants',
#   'is',
#   'is',
#   'is',
#   'is',
#   'hurt',
#   'hurt',
#   'suspected',
#   'suspected',
#   'planned',
#   'make',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'has',
#   'likes',
#   'arrived',
#   'found',
#   'found',
#   'found',
#   'found',
#   'found',
#   'wash',
#   'hurried',
#   'warned',
#   'meant',
#   'followed',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'shrilled',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'paid',
#   'paid',
#   'stared',
#   'stared',
#   'stared',
#   'suffered',
#   'enjoyed',
#   'exclaimed',
#   'speak',
#   'speak',
#   'speak',
#   'imagine',
#   'imagine',
#   'imagine',
#   'say',
#   'say',
#   'say',
#   'say',
#   'think',
#   'hearing',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'pointed',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'drew',
#   'realize',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'remembuh',
#   'remember',
#   'hadflung',
#   'give',
#   'give',
#   'go',
#   'loved',
#   'loved',
#   'grow',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'wandered',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'look',
#   'look',
#   'beginning',
#   'told',
#   'told',
#   'told',
#   'told',
#   'understand',
#   'understand',
#   'answered',
#   'answered',
#   'sing',
#   'sing',
#   'danced',
#   'danced',
#   'sang',
#   'sang',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'finished',
#   'suspect',
#   'do',
#   'do',
#   'do',
#   'do',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'doing',
#   'doing',
#   'doing',
#   'doing',
#   'refused',
#   'struct',
#   'fought',
#   'lie',
#   'lie',
#   'need',
#   'stayed',
#   'stayed',
#   'seemed',
#   'seemed',
#   'seemed',
#   'failing',
#   'comprehend',
#   'comprehend',
#   'jumped',
#   'called',
#   'leaned',
#   'leaned',
#   'walked',
#   'walked',
#   'walked',
#   'walked',
#   'couldfeel',
#   'held',
#   'be',
#   'be',
#   'joined',
#   'slapped',
#   'listened',
#   'listened',
#   'listened',
#   'listened',
#   'listened',
#   'move',
#   'move',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'understood',
#   'kissed',
#   'going',
#   'going',
#   'did',
#   'did',
#   'did',
#   'got',
#   'added',
#   'fixed',
#   'buttoned',
#   'died',
#   'died',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'spank',
#   'find',
#   'find',
#   'opened',
#   'sees',
#   'have',
#   'have',
#   'have',
#   'have',
#   'let',
#   'let',
#   'coming',
#   'coming',
#   'took',
#   'took',
#   'met',
#   'meeting',
#   'turned',
#   'turned',
#   'replied',
#   'replied',
#   'replied',
#   'speaking',
#   'lay',
#   'lay',
#   'tell',
#   'tell',
#   'hurrying',
#   'steer',
#   'try',
#   'lying',
#   'lying',
#   'get',
#   'puzzled',
#   'were',
#   'spoken',
#   'stopped',
#   'stopped',
#   'informed',
#   'claimed',
#   'considered',
#   'volunteer',
#   'decided',
#   'decided',
#   'strode',
#   'reflected',
#   'known',
#   'known',
#   'wore',
#   'sit',
#   'intended',
#   'intended',
#   'reprimand',
#   'saying',
#   'smiled',
#   'waited',
#   'concealing',
#   'gave',
#   'glanced',
#   'glanced',
#   'shaved',
#   'continued',
#   'gazed',
#   'slid',
#   'touched',
#   'lowering',
#   'wished',
#   'touch',
#   'bring',
#   'moved',
#   'moved',
#   'moved',
#   'flung',
#   'stuck',
#   'experienced',
#   'understands',
#   'believed',
#   'looking',
#   'looking',
#   'frowning',
#   'smelled',
#   'thinking',
#   'stirred',
#   'flew',
#   'flew',
#   'worked',
#   'sprang',
#   'disliked',
#   'read',
#   'answer',
#   'trying',
#   'talking'],
#  ['tried',
#   'tried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'leaned',
#   'went',
#   'went',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'began',
#   'began',
#   'began',
#   'touched',
#   'explained',
#   'knew',
#   'knew',
#   'knew',
#   'watched',
#   'watched',
#   'decided',
#   'decided',
#   'need',
#   'pushed',
#   'heard',
#   'heard',
#   'known',
#   'sat',
#   'taste',
#   'braced',
#   'felt',
#   'felt',
#   'getting',
#   'wanted',
#   'wanted',
#   'wished',
#   'wished',
#   'think',
#   'think',
#   'feels',
#   'says',
#   'say',
#   'mean',
#   'understands',
#   'took',
#   'nodded',
#   'nodded',
#   'asked',
#   'asked',
#   'gotten',
#   'gave',
#   'tell',
#   'realized',
#   'growled',
#   'saying',
#   'exclaimed',
#   'did',
#   'did',
#   'please',
#   'know',
#   'spoke',
#   'wondered',
#   'pat',
#   'stood'],
#  ['had',
#   'whispered',
#   'leaned',
#   'leaned',
#   'leaned',
#   'lifted',
#   'smoothed',
#   'looked',
#   'thought',
#   'saw',
#   'stood'],
#  ['cried',
#   'held',
#   'shook',
#   'shook',
#   'embraced',
#   'smelled',
#   'allow',
#   'took',
#   'took',
#   'took',
#   'bathed',
#   'going',
#   'come',
#   'Bless',
#   'told',
#   'looked',
#   'looked',
#   'asked',
#   'answer',
#   'answer',
#   'said',
#   'said',
#   'said',
#   'look',
#   'seemed',
#   'seem',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'knows',
#   'squeezed',
#   'stopped',
#   'put',
#   'had',
#   'waved'],
#  ['was'],
#  ['sitting', 'thought', 'leaning'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'know',
#   'know',
#   'did',
#   'did',
#   'did',
#   'did',
#   'did',
#   'swung',
#   'hurried',
#   'hurried',
#   'hurried',
#   'tried',
#   'tried',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'cut',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'started',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'listened',
#   'listened',
#   'began',
#   'understood',
#   'changed',
#   'leave',
#   'suspected',
#   'speakin',
#   'hit',
#   'thank',
#   'is',
#   'is',
#   'is',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'talk',
#   'help',
#   'sat',
#   'sat',
#   'doing',
#   'fastened',
#   'liked',
#   'liked',
#   'liked',
#   'watched',
#   'watched',
#   'watched',
#   'reflected',
#   'reflected',
#   'reflected',
#   'meant',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'hear',
#   'saw',
#   'saw',
#   'unbuttoned',
#   'tucked',
#   'feel',
#   'feel',
#   'feel',
#   'set',
#   'caught',
#   'caught',
#   'kissed',
#   'kissed',
#   'kissed',
#   'answered',
#   'answered',
#   'answered',
#   'noticed',
#   'doubtless',
#   'ate',
#   'drink',
#   'frowned',
#   'frowned',
#   'took',
#   'took',
#   'took',
#   'took',
#   'finished',
#   'pressed',
#   'brought',
#   'plastered',
#   'chewed',
#   'prevent',
#   'eat',
#   'glanced',
#   'asked',
#   'asked',
#   'joked',
#   'guessed',
#   'went',
#   'went',
#   'went',
#   'snapped',
#   'stood',
#   'gotten',
#   'gotten',
#   'knew',
#   'knew',
#   'buttoned',
#   'backed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'pulled',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'look',
#   'cared',
#   'showed',
#   'stroked',
#   'continued',
#   'walking',
#   'lifted',
#   'disappeared',
#   'try',
#   'try',
#   'try',
#   'braked',
#   'shut',
#   'quit',
#   'turned',
#   'nodded',
#   'nodded',
#   'passed',
#   'forgive',
#   'filled',
#   'waited',
#   'lighted',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'say',
#   'say',
#   'say',
#   'disliked',
#   'made',
#   'made',
#   'been',
#   'been',
#   'came',
#   'came',
#   'came',
#   'stand',
#   'found',
#   'found',
#   'found',
#   'done',
#   'imagine',
#   'imagine',
#   'be',
#   'mind',
#   'hollered',
#   'fret',
#   "'s",
#   "'s",
#   'told',
#   'told',
#   'told',
#   'told',
#   'sees',
#   'm-make',
#   'understand',
#   'met',
#   'wants',
#   'wants',
#   'driving',
#   'driving',
#   'goes',
#   'warning',
#   'thinks',
#   'were',
#   'come',
#   'hurrying',
#   'trying',
#   'trying',
#   'speak',
#   'speak',
#   'lying',
#   'lying',
#   'managed',
#   'knows',
#   'does',
#   'understands',
#   'died',
#   'blame',
#   'fixed',
#   'assented',
#   'gathered',
#   'covered',
#   'seen',
#   'seen',
#   'remembered',
#   'known',
#   'take',
#   'shook',
#   'shook',
#   'working',
#   'looking',
#   'see'],
#  ['hurried', 'told', 'passed', 'passed', 'feel', 'setting'],
#  [],
#  ['told', 'told', 'missed', 'missed', 'expecting', 'came', 'looked', 'saw'],
#  ['were'],
#  ['had',
#   'make',
#   'liked',
#   'laughed',
#   'bought',
#   'spent',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shaking',
#   'see',
#   'whistling',
#   'asked',
#   'looked',
#   'looked',
#   'mean',
#   'meant',
#   'trusted',
#   'likes',
#   'believe',
#   'smiled',
#   'smiled'],
#  ['called',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'bite',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'replied',
#   'replied',
#   'replied',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'seemed',
#   'ask',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'came',
#   'came',
#   'came',
#   'came',
#   'know',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'wanted',
#   'wanted',
#   'wanted',
#   'going',
#   'going',
#   'hurt',
#   'hurt',
#   'say',
#   'say',
#   'say',
#   'say',
#   'say',
#   'says',
#   'says',
#   'says',
#   'says',
#   'says',
#   'says',
#   'has',
#   'talks',
#   'be',
#   'stayed',
#   'stayed',
#   'accusing',
#   'saying',
#   'left',
#   'left',
#   "'s",
#   "'s",
#   "'s",
#   'getting',
#   'have',
#   'have',
#   'have',
#   'phoned',
#   'phoned',
#   'scared',
#   'meant',
#   'hoping',
#   'do',
#   'do',
#   'do',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'did',
#   'did',
#   'did',
#   'did',
#   'did',
#   'doing',
#   'bother',
#   'hesitate',
#   'put',
#   'put',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'speak',
#   'speak',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'holding',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'set',
#   'expected',
#   'kissed',
#   'kissed',
#   'sobbed',
#   'stared',
#   'twist',
#   'brought',
#   'brought',
#   'brought',
#   'bringing',
#   'sat',
#   'surprised',
#   'broke',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'poured',
#   'prepared',
#   'want',
#   'want',
#   'speaking',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'dropped',
#   'got',
#   'got',
#   'got',
#   'got',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'led',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'shook',
#   'shook',
#   'walked',
#   'wishes',
#   'wishes',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'nursing',
#   'squatted',
#   'stood',
#   'stood',
#   'drew',
#   'thinks',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'stand',
#   'locked',
#   'showed',
#   'guided',
#   'thrown',
#   'thrown',
#   'grabbed',
#   'reached',
#   'returned',
#   'spoke',
#   'groaned',
#   'groaned',
#   'grimace',
#   'spoken',
#   'hear',
#   'hear',
#   'hear',
#   'think',
#   'began',
#   'began',
#   'began',
#   'shouted',
#   'shouted',
#   'explained',
#   'mimic',
#   'cried',
#   'tried',
#   'tried',
#   'admit',
#   'tightened',
#   'pointed',
#   'died',
#   'died',
#   'lived',
#   'remembered',
#   'remembered',
#   'lay',
#   'loved',
#   'look',
#   'assured',
#   'shut',
#   'talking',
#   'take',
#   'take',
#   'laughed',
#   'lie',
#   'question',
#   'asking',
#   'wants',
#   'feel',
#   'intended',
#   'get',
#   'glanced',
#   'glanced',
#   'met',
#   'watching',
#   'corrected',
#   'answer',
#   'embraced',
#   'realized',
#   'realized',
#   'helped',
#   'helped',
#   'walking',
#   'found',
#   'found',
#   'reflected',
#   'mind',
#   'cared',
#   'cared',
#   'made',
#   'overheard',
#   'rushed',
#   'leaning',
#   'invited',
#   'tell',
#   'stopped',
#   'hit',
#   'insists',
#   'glared',
#   'caricatured',
#   'snarled'],
#  ['was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'folded',
#   'folded',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'respected',
#   'try',
#   'try',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'bring',
#   'bring',
#   'be',
#   'be',
#   'be',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'waiting',
#   'waiting',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'intended',
#   'intended',
#   'made',
#   'made',
#   'made',
#   'made',
#   'made',
#   'made',
#   'held',
#   'held',
#   'held',
#   'smiled',
#   'smiled',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'followed',
#   'muttered',
#   'leaned',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'steered',
#   'prepared',
#   'dressed',
#   'doing',
#   'doing',
#   'loved',
#   'examine',
#   'had',
#   'had',
#   'had',
#   'had',
#   'shopped',
#   'bought',
#   'turned',
#   'smelled',
#   'saw',
#   'saw',
#   'saw',
#   'doubted',
#   'doubted',
#   'speak',
#   'speak',
#   'meant',
#   'meant',
#   'meant',
#   'meant',
#   'reflected',
#   'reflected',
#   'indicated',
#   'paid',
#   'is',
#   'went',
#   'went',
#   'went',
#   'went',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hurried',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'hustled',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'talk',
#   'sat',
#   'found',
#   'found',
#   'found',
#   'found',
#   'watching',
#   'watching',
#   'focused',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'help',
#   'help',
#   'waited',
#   'waited',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'decided',
#   'think',
#   'think',
#   'think',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   "'s",
#   'wave',
#   'wave',
#   'stopped',
#   'stood',
#   'stood',
#   'continued',
#   'continued',
#   'continued',
#   'continued',
#   'rapped',
#   'come',
#   'bit',
#   'blurted',
#   'struck',
#   'subdued',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'know',
#   'know',
#   'reached',
#   'squeezed',
#   'realized',
#   'realized',
#   'realized',
#   'wished',
#   'wished',
#   'wished',
#   'lean',
#   'sighed',
#   'sighed',
#   'sighed',
#   'beginning',
#   'live',
#   'look',
#   'die',
#   'die',
#   'set',
#   'bear',
#   'learn',
#   'learn',
#   'watched',
#   'watched',
#   'watched',
#   'kneel',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'suspected',
#   'trailed',
#   'rid',
#   'repeated',
#   'left',
#   'left',
#   'indulged',
#   'been',
#   'done',
#   'resist',
#   'managed',
#   'nodding',
#   'blink',
#   'resume',
#   'seem',
#   'prefers',
#   'helped',
#   'helped',
#   'helped',
#   'gets',
#   'do',
#   'saying',
#   'saying',
#   'saying',
#   'saying',
#   'saying',
#   'doubting',
#   'put',
#   'drank',
#   'drank',
#   'stared',
#   'drew',
#   'clucked',
#   'asked',
#   'asked',
#   'asked',
#   'gotten',
#   'sobbed',
#   'moved',
#   'explained',
#   'explained',
#   'suggested',
#   'closed',
#   'closed',
#   'hear',
#   'hear',
#   'hear',
#   'stifled',
#   'cried',
#   'feel',
#   'kept',
#   'kept',
#   'tell',
#   'thinks',
#   'has',
#   'say',
#   'say',
#   'say',
#   'please',
#   'stay',
#   'stay',
#   'added',
#   'were',
#   'were',
#   'see',
#   'see',
#   'touched',
#   'touched',
#   'touched',
#   'want',
#   'take',
#   'take',
#   'threading',
#   'exclaimed',
#   'called',
#   'called',
#   'remembered',
#   'loaded',
#   'lay',
#   'lay',
#   'stooped',
#   'go',
#   'snapped',
#   'struggled',
#   'let',
#   'have',
#   'did',
#   'did',
#   'did',
#   'sliced',
#   'gave',
#   'glanced',
#   'talking',
#   'sipped',
#   'hurt',
#   'swallowed',
#   'watch',
#   'spoke',
#   'spoke',
#   'tried',
#   'paused',
#   'paused',
#   'pressed',
#   'accusing',
#   'jerked',
#   'demonstrated',
#   'wore',
#   'wore',
#   'carrying',
#   'wheeled',
#   'says',
#   'walked',
#   'messing',
#   'started',
#   'started',
#   'sputtered',
#   'talked',
#   'washed',
#   'get',
#   'cleaned',
#   'thank',
#   'going',
#   'seemed',
#   'murmured',
#   'understand',
#   'caught',
#   'ceased',
#   'got',
#   'got',
#   'appear',
#   'speaking',
#   'crying',
#   'gasped'],
#  ['were', 'came', 'wearing', 'carried', 'walked', 'looked'],
#  [],
#  ['phoned', 'says', 'wanted', 'loves'],
#  ['had', 'get'],
#  [],
#  ['said',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'suffered',
#   'think',
#   'looked'],
#  ['say', 'said', 'said'],
#  ['were'],
#  [],
#  ['come', 'stood', 'were'],
#  ['came', 'stopped', 'turned', 'saw', 'took', 'wondered', 'kept'],
#  [],
#  ['take',
#   'come',
#   'stayed',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'came',
#   'came',
#   'came',
#   'patted',
#   'drives',
#   'tell',
#   'hurt',
#   'living',
#   'bringing',
#   'put',
#   'go',
#   'want',
#   'thought',
#   'shook',
#   'shut',
#   'say',
#   'stood',
#   'stood',
#   'have',
#   'glanced',
#   'drying',
#   'passed',
#   'went',
#   'know',
#   'nodded'],
#  ['singing', 'turned', 'turned', 'whispered', 'walked'],
#  ['wore',
#   'wore',
#   'carried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'had',
#   'tease',
#   'decided',
#   'trust',
#   'thought',
#   'seemed',
#   'understood',
#   'started',
#   'teasing',
#   'smiled',
#   'quieted',
#   'got',
#   'got',
#   'noticed',
#   'saw',
#   'take',
#   'told',
#   'bring',
#   'turned',
#   'drove',
#   'shut',
#   'began',
#   'twisted',
#   'brought',
#   'stopped',
#   'moved',
#   'move',
#   'look',
#   'looked'],
#  [],
#  ['realized',
#   'wanted',
#   'restrained',
#   'felt',
#   'went',
#   'swing',
#   'bear',
#   'lay',
#   'lay'],
#  ['got'],
#  ['got',
#   'do',
#   'reckoned',
#   'get',
#   'get',
#   'know',
#   'knew',
#   'heard',
#   'watched',
#   'climb',
#   'thought',
#   'seen'],
#  ['thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'readjusted',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'getting',
#   'cried',
#   'cried',
#   'cried',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'glared',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'use',
#   'bought',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'trying',
#   'trying',
#   'trying',
#   'turned',
#   'turned',
#   'winced',
#   'relaxed',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'imagine',
#   'decided',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'took',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'facing',
#   'needs',
#   'gazed',
#   'patted',
#   'patted',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'replied',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'waited',
#   'waited',
#   'waited',
#   'let',
#   'gave',
#   'inquired',
#   'know',
#   'know',
#   'know',
#   'sleeping',
#   'scowling',
#   'standing',
#   'settled',
#   'got',
#   'got',
#   'began',
#   'began',
#   'began',
#   'yelled',
#   'yelled',
#   'bawled',
#   'recovered',
#   'peered',
#   'put',
#   'put',
#   'put',
#   'caught',
#   'stared',
#   'speak',
#   'tucked',
#   'cry',
#   'sniffled',
#   'sniffled',
#   'look',
#   'look',
#   'repeated',
#   'continued',
#   'mean',
#   'groaned',
#   'loosened',
#   'dressed',
#   'came',
#   'came',
#   'try',
#   'did',
#   'say',
#   'say',
#   'say',
#   'feel',
#   'feel',
#   'feel',
#   'ate',
#   'ate',
#   'tried',
#   'tried',
#   'tried',
#   'make',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'knew',
#   'knew',
#   'coming',
#   'coming',
#   'coming',
#   'come',
#   'come',
#   'remember',
#   'think',
#   'looking',
#   'looking',
#   'drew',
#   'ask',
#   'snapped',
#   'expected',
#   'flinched',
#   'stopped',
#   'stopped',
#   'squeezed',
#   'kept',
#   'seem',
#   'exclaimed',
#   'working',
#   'made',
#   'bore',
#   'crying',
#   'crying',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'helped',
#   'gather',
#   'passed',
#   'have',
#   'brought',
#   'helping',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'ran',
#   'held',
#   'held',
#   'held',
#   'held',
#   'stroked',
#   'seemed',
#   'seemed',
#   'seemed',
#   'swallowed',
#   'told',
#   'hissed',
#   'raised',
#   'hesitated',
#   'hesitated',
#   'answered',
#   'had',
#   'had',
#   'watched',
#   'watched',
#   'watched',
#   'added',
#   'hastened',
#   'noticed',
#   'wetting',
#   'hated',
#   'remembered',
#   'remembered',
#   'understand',
#   'understood',
#   'realized',
#   'realized',
#   'realized',
#   'blushed',
#   'smiled',
#   'waiting',
#   'feared',
#   'goes',
#   'pulled',
#   'pulled',
#   'thinks',
#   'whispered',
#   'stayed',
#   'rock',
#   'moved',
#   'moved',
#   'straightened',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'wearing',
#   'reassured',
#   'opened',
#   'plays',
#   'played',
#   'hearing',
#   'seen',
#   'stole',
#   'shook',
#   'run'],
#  ['asked',
#   'was',
#   'was',
#   'frighten',
#   'wanted',
#   'help',
#   'spoke',
#   'nodded',
#   'sucked',
#   'coming',
#   'eating',
#   'walk'],
#  ["'s"],
#  [],
#  [],
#  [],
#  ["'s", 'leave', 'were'],
#  ['understand',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'put',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'got',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'disappear',
#   'meant',
#   'meant',
#   'meant',
#   'meant',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'came',
#   'came',
#   'came',
#   'came',
#   'came',
#   'making',
#   'spoke',
#   'spoke',
#   'spoke',
#   'spoke',
#   'stood',
#   'stood',
#   'stood',
#   'stood',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'covered',
#   'peppered',
#   'done',
#   'made',
#   'made',
#   'made',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'supposed',
#   'make',
#   'stand',
#   'stand',
#   'stand',
#   'watch',
#   'smiled',
#   'smiled',
#   'smiled',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'whispered',
#   'been',
#   'opened',
#   'opened',
#   'shook',
#   'shook',
#   'squeezed',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'hoped',
#   'doze',
#   'crossed',
#   'bring',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'blame',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'look',
#   'feared',
#   'feared',
#   'like',
#   'like',
#   'cared',
#   'wondered',
#   'wondered',
#   'wondered',
#   'liked',
#   'disliked',
#   'assured',
#   'assured',
#   'resented',
#   'begun',
#   'replied',
#   'replied',
#   'come',
#   'come',
#   'inquired',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'exclaimed',
#   'have',
#   'have',
#   'going',
#   'manage',
#   'manage',
#   'decided',
#   'decided',
#   'hurried',
#   'hurried',
#   'hurried',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'drew',
#   'drew',
#   'drew',
#   'extended',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'see',
#   'coaxing',
#   'murmured',
#   'murmured',
#   'murmured',
#   'murmured',
#   'drawing',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'sat',
#   'waved',
#   'twisted',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'looking',
#   'looking',
#   'spoken',
#   'spoken',
#   'seen',
#   'seen',
#   'seen',
#   'lifted',
#   'lifted',
#   'lifted',
#   'glanced',
#   'glanced',
#   'glanced',
#   'cried',
#   'cried',
#   'cried',
#   'cried',
#   'drank',
#   'drank',
#   'drank',
#   'noticed',
#   'noticed',
#   'continued',
#   'continued',
#   'continued',
#   'continued',
#   'has',
#   'found',
#   'found',
#   'bear',
#   'interrupted',
#   'took',
#   'took',
#   'took',
#   'took',
#   'retorted',
#   'waited',
#   'waited',
#   'subdued',
#   'laughed',
#   'laughed',
#   'laughed',
#   'laughed',
#   'speak',
#   'gazing',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'speaking',
#   'speaking',
#   'remember',
#   'remember',
#   'remember',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'joined',
#   'joined',
#   'talked',
#   'talked',
#   'Excuse',
#   'stared',
#   'returned',
#   'seemed',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'remembered',
#   'remembered',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'find',
#   'leaning',
#   'catching',
#   'losing',
#   'squeezing',
#   'were',
#   'were',
#   'walked',
#   'walked',
#   'needs',
#   'poured',
#   'poured',
#   'croaked',
#   'sipped',
#   'added',
#   'added',
#   'tasted',
#   'nodding',
#   'finished',
#   'prepared',
#   'means',
#   'was',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'nodded',
#   'groaned',
#   'groaned',
#   'groaned',
#   'saying',
#   'risen',
#   'moaned',
#   'feel',
#   'feel',
#   'embraced',
#   'screamed',
#   'asks',
#   'tries',
#   'met',
#   'pressing',
#   'died',
#   'called',
#   'called',
#   'wished',
#   'wished',
#   'leaned',
#   'leaned',
#   'leaned',
#   'lied',
#   'says',
#   'says',
#   'lingering',
#   'does',
#   'cutting',
#   'gave',
#   'did',
#   'broke',
#   'dying',
#   'trailed',
#   'thinks',
#   'fell',
#   'growled',
#   'caught',
#   'caught',
#   'ease',
#   'pressed',
#   'pressed',
#   "'s",
#   "'s",
#   'mean',
#   'watching',
#   'smells',
#   'wants',
#   'straightened',
#   'switched',
#   'switched',
#   'closed',
#   'gathering',
#   'disappeared',
#   'gathered',
#   'knelt',
#   'bother',
#   'lay',
#   'lay',
#   'falling',
#   'tole',
#   'slapped',
#   'stopped',
#   'cut',
#   'cornered',
#   'humbled',
#   'loved',
#   'gained',
#   'grown',
#   'shared',
#   'refused',
#   'know',
#   'experienced',
#   'left',
#   'rocked',
#   'rocked',
#   'swayed',
#   'tried'],
#  [],
#  ['Is', 'Let', 'forgive', 'go', 'finished', 'doing', 'came', 'knows'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'begin',
#   'help',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'ai',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'driving',
#   'was',
#   'was',
#   'was',
#   'hit',
#   'cut',
#   'hold',
#   'hold',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'warmed',
#   'get',
#   'get',
#   'been',
#   'hesitated',
#   'want',
#   'want',
#   'says',
#   'says',
#   'says',
#   'has',
#   'tell',
#   'gets',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'added',
#   'done',
#   'drove',
#   'goes',
#   'got',
#   'got',
#   'got',
#   'stood',
#   'stood',
#   'stood',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'sighed',
#   'remember',
#   'remember',
#   'known',
#   'left',
#   'meant',
#   'meant',
#   'lost',
#   'lost',
#   'needed',
#   'needed',
#   'think',
#   'understood',
#   'understood',
#   'understood',
#   'understood',
#   'asked',
#   'called',
#   'put',
#   'sped',
#   'sped',
#   'rammed',
#   'suffered',
#   'suffered',
#   'suffered',
#   'rushed',
#   'showed',
#   'see',
#   'came',
#   'came',
#   'making',
#   'beseeching',
#   'began',
#   'began',
#   'began',
#   'began',
#   'bringing',
#   'feared',
#   'redoubled',
#   'tried',
#   'saw',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'swung',
#   'burn',
#   'have',
#   'have',
#   'have',
#   'care',
#   'went',
#   'take',
#   'learned',
#   'braced',
#   'despised',
#   'looked',
#   'nodded',
#   'died',
#   'covered',
#   'whispered',
#   'thrust',
#   'announced',
#   'announced',
#   'wants',
#   'come',
#   'chose',
#   'did',
#   'navigate',
#   'succeeded',
#   'told',
#   'reckoned',
#   'concurred',
#   'beginning',
#   'swear',
#   'recognized',
#   'is',
#   'shook',
#   'explained',
#   'climb',
#   'stepped'],
#  ['rolled', 'rolled', 'done'],
#  ['kill'],
#  ['was'],
#  [],
#  ['said', 'said', 'threw', 'whispered', 'took', 'is'],
#  ['came',
#   'had',
#   'miss',
#   'took',
#   'took',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'looked',
#   'wake',
#   'shaking'],
#  ['went', 'wake', 'woke', 'did'],
#  ['was',
#   'stole',
#   'looked',
#   'remembered',
#   'laughed',
#   'got',
#   'reached',
#   'peered',
#   'whipped',
#   'killed',
#   'insulted',
#   'have',
#   'asked'],
#  [],
#  ['made',
#   'had',
#   'had',
#   'played',
#   'stayed',
#   'come',
#   'been',
#   'identify',
#   'known',
#   'wrote',
#   'wrote',
#   'wrote',
#   'wrote',
#   'wrote',
#   'was',
#   'lost',
#   'weeping',
#   'sleep',
#   'going',
#   'fall',
#   'wounded',
#   'walk',
#   'walk',
#   'pointed',
#   'remember',
#   'tell'],
#  ['is', 'write', 'enrolled', 'wrote', 'showed', 'described', 'cured'],
#  ['arrived',
#   'invited',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'replied',
#   'showed',
#   'ask',
#   'tested',
#   'test'],
#  ['persists',
#   'asks',
#   'use',
#   'appears',
#   'takes',
#   'made',
#   'thinks',
#   'said',
#   'meant',
#   'is',
#   'hides',
#   'told',
#   'bought',
#   'denied',
#   'resist',
#   'knows',
#   'think',
#   'longs',
#   'dreams',
#   'sees',
#   'encouraged',
#   'called',
#   'had',
#   'ignored',
#   'write',
#   'write',
#   'keep',
#   'makes',
#   'does',
#   'remember',
#   'make',
#   'say',
#   'do'],
#  [],
#  ['perched',
#   'said',
#   'rose',
#   'deepened',
#   'flew',
#   'tossed',
#   'tossed',
#   'staring',
#   'tired',
#   'seek',
#   'named',
#   'worked',
#   'worked',
#   'dwarfed',
#   'joined'],
#  ['filling', 'pass', 'pouring'],
#  ['made', 'asked', 'died', 'entertained', 'paid', 'noticed', 'gave'],
#  ['learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'learned',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'imagine',
#   'imagine',
#   'imagine',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'seen',
#   'despised',
#   'let',
#   'let',
#   'let',
#   'brought',
#   'brought',
#   'made',
#   'made',
#   'aired',
#   'borrowed',
#   'showed',
#   'lost',
#   'told',
#   'told',
#   'told',
#   'kept',
#   'kept',
#   'kept',
#   'feels',
#   'have',
#   'hears',
#   'saying',
#   'backs',
#   'find',
#   'find',
#   'appeared',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'led',
#   'called',
#   'called',
#   'reached',
#   'shared',
#   'found',
#   'found',
#   'found',
#   'paused',
#   'stood',
#   'stood',
#   'stood',
#   'stepping',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'purchased',
#   'extracted',
#   'walk',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'asked',
#   'chosen',
#   'offered',
#   'bear',
#   'left',
#   'left',
#   'left',
#   'left',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'thought',
#   'taken',
#   'taken',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'felt',
#   'lying',
#   'ask',
#   'ask',
#   'ask',
#   'ask',
#   'rented',
#   'paying',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'looked',
#   'went',
#   'went',
#   'went',
#   'went',
#   'went',
#   'gave',
#   'gave',
#   'gave',
#   'moved',
#   'moved',
#   'was',
#   'returned',
#   'returned',
#   'miss',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'helped',
#   'helped',
#   'helped',
#   'carrying',
#   'spread',
#   'gathered',
#   'gathered',
#   'gathered',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'imagined',
#   'love',
#   'helping',
#   'carried',
#   'wrote',
#   'got',
#   'got',
#   'waited',
#   'waited',
#   'work',
#   'lived',
#   'live',
#   'signed',
#   'nursed',
#   'nursed',
#   'cared',
#   'read',
#   'read',
#   'read',
#   'read',
#   'read',
#   'taught',
#   'tormented',
#   'started',
#   'end',
#   'know',
#   'know',
#   'think',
#   'think',
#   'think',
#   'stopped',
#   'stopped',
#   'stopped',
#   'given',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'hear',
#   'hear',
#   'wish',
#   'wish',
#   'forgave',
#   'opened',
#   'opened',
#   'painted',
#   'leave',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'bundled',
#   'pressed',
#   'wiped',
#   'packed',
#   'tried',
#   'tried',
#   'tried',
#   'tried',
#   'learn',
#   'learn',
#   'included',
#   'recognized',
#   'see',
#   'see',
#   'see',
#   'whispered',
#   'puzzle',
#   'grown',
#   'grown',
#   'vanished',
#   'stand',
#   'crossing',
#   'dug',
#   'replied',
#   'took',
#   'watched',
#   'watched',
#   'watched',
#   'watched',
#   'knowing',
#   'described',
#   'described',
#   'keep',
#   'keep',
#   'rubbed',
#   'crawled',
#   'settled',
#   'recollect',
#   'missed',
#   'missed',
#   'tended',
#   'meant',
#   'identify',
#   'known',
#   'nearing',
#   'realized',
#   'do',
#   'bought',
#   'wished',
#   'caught',
#   'caught',
#   'caught',
#   'asks',
#   'knows',
#   'says',
#   'says',
#   'says',
#   'nods',
#   "'s",
#   'chided',
#   'persist',
#   'wondered',
#   'wondered',
#   'wondered',
#   'wondered',
#   'appear',
#   'worried',
#   'remember',
#   'spent',
#   'circulated',
#   'remembered',
#   'interrupted',
#   'prepared',
#   'visited',
#   'visited',
#   'blamed',
#   'put',
#   'closed',
#   'covered',
#   'touched',
#   'shook',
#   'turned',
#   'turned',
#   'picked',
#   'seemed',
#   'rise',
#   'concocting',
#   'did',
#   'did',
#   'did',
#   'explained',
#   'devised',
#   'passed',
#   'began',
#   'began',
#   'stared',
#   'stared',
#   'held',
#   'ate',
#   'eat',
#   'talk',
#   'talk',
#   'goes',
#   'order',
#   'flirting',
#   'begged',
#   'stanched',
#   'seized',
#   'sickened',
#   'chose',
#   'feel',
#   'conceals',
#   'pays',
#   "'d",
#   'decided',
#   'sleeping',
#   'grew',
#   'aged',
#   'growing',
#   'approached',
#   'moves'],
#  ['talked',
#   'learned',
#   'said',
#   'said',
#   'said',
#   'said',
#   'made',
#   'saw',
#   'hides',
#   'strolls',
#   'laughed',
#   'resembles',
#   'is',
#   'continued'],
#  ['had'],
#  ['has',
#   'says',
#   'takes',
#   'gets',
#   'rises',
#   'said',
#   'kept',
#   'moaned',
#   'was',
#   'longed',
#   'slept',
#   'permit'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'wanted',
#   'lives',
#   'thought',
#   'thought',
#   'forbade',
#   'constructed',
#   'sank',
#   'felt',
#   'admitted',
#   'avoided',
#   'called',
#   'called',
#   'had',
#   'had',
#   'attended',
#   'forgiven',
#   'objected',
#   'bear',
#   'spoke',
#   'took',
#   'presented',
#   'twitched',
#   'held',
#   'tossed',
#   'went',
#   'went',
#   'returned',
#   'continued',
#   'found',
#   'found',
#   'found',
#   'turned',
#   'manufactured',
#   'kept',
#   'chosen',
#   'chosen',
#   'ransacked',
#   'owned',
#   'left',
#   'left'],
#  ['sniffed', 'thrust', 'said', 'said', 'turned'],
#  ['was',
#   'spoken',
#   'said',
#   'moved',
#   'pull',
#   'find',
#   'set',
#   'painted',
#   'head',
#   'went',
#   'led',
#   'had'],
#  ['had',
#   'met',
#   'thinking',
#   'thinking',
#   'turned',
#   'saw',
#   'see',
#   'name',
#   'stuck',
#   'heard',
#   'said'],
#  ['shook', 'said'],
#  ['disappeared'],
#  ['has', 'entered', 'left'],
#  ['dying',
#   'dying',
#   'arrived',
#   'coughing',
#   'coughing',
#   'needs',
#   'needs',
#   'needs',
#   'weighs',
#   'swallowed',
#   'raised',
#   'told',
#   'had',
#   'had',
#   'had',
#   'said',
#   'said',
#   'felt',
#   'felt',
#   'suspected',
#   'was',
#   'swooped',
#   'lifted',
#   'set',
#   'loses',
#   'sweats',
#   'cough',
#   'cough',
#   'cough',
#   'go',
#   'have',
#   'have',
#   'goes',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'thinks',
#   'take',
#   'cast',
#   'barks',
#   'has',
#   'has',
#   'passes',
#   'prints',
#   'leave',
#   'begins',
#   'begins',
#   'decided',
#   'write',
#   'write',
#   'write',
#   'liked',
#   'coughed',
#   'writes',
#   'be',
#   'be',
#   'say',
#   'start',
#   'hear',
#   'hear',
#   'spreads',
#   'eat',
#   'come',
#   'lose',
#   'came',
#   'knew',
#   'explain',
#   'recovered',
#   'blame',
#   'describe',
#   'fished',
#   'fix',
#   'do',
#   'bounds',
#   'waiting',
#   'waiting',
#   'fret'],
#  ['watched'],
#  ['agreed', 'made', 'took', 'heard', 'asked', 'said', 'said', 'said'],
#  ['pouted', 'continued'],
#  [],
#  ['lowered',
#   'thought',
#   'saw',
#   'loved',
#   'opened',
#   'held',
#   'said',
#   'is',
#   'knew',
#   'fell',
#   'brought'],
#  ['nearing',
#   'has',
#   'comes',
#   'goes',
#   'nods',
#   'nods',
#   'pick',
#   'lifted',
#   'lifted',
#   'lifted',
#   'passing',
#   'see',
#   'arrived',
#   'arrived',
#   'convey',
#   'knows',
#   'marking',
#   'came',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'pointed',
#   'brought',
#   'knelt',
#   'laid',
#   'pressed',
#   'picked',
#   'left',
#   'feels',
#   'murmured',
#   'smelled',
#   'nodded',
#   'refuse',
#   'drank',
#   'passed',
#   'stepped',
#   'asked',
#   'raised',
#   'knew',
#   'started',
#   'belongs',
#   'passes',
#   'slept',
#   'holds'],
#  ['feel',
#   'read',
#   'help',
#   'lost',
#   'dreamed',
#   'saw',
#   'saw',
#   'grown',
#   'said',
#   'said',
#   'manage'],
#  ['helps', 'separated', 'learned', 'twisted', 'died', 'thought', 'returned'],
#  ['used',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'shared',
#   'shared',
#   'tells',
#   'writing',
#   'writing',
#   'saying',
#   'promises',
#   'explained',
#   'tell',
#   'corralled',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'told',
#   'moved',
#   'moved',
#   'stayed',
#   'was',
#   'was',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'bore',
#   'heard',
#   'heard',
#   'heard',
# ...
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'turned',
#   'concluded',
#   'concluded',
#   'reassure',
#   'slide',
#   'jump',
#   'strolled',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'saying',
#   'saying',
#   'pushed',
#   'pushed',
#   'added',
#   'breathed',
#   'breathed',
#   'like',
#   'like',
#   'like',
#   'steeled',
#   'started',
#   'started',
#   'started',
#   'tried',
#   'tried',
#   'slipped',
#   'lowered',
#   'undid',
#   'followed',
#   'followed',
#   'headed',
#   'murmured',
#   'murmured',
#   'stared',
#   'stared',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'heard',
#   'caught',
#   'caught',
#   'caught',
#   'certified',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'wanted',
#   'belonged',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'try',
#   'draw',
#   'take',
#   'take',
#   'take',
#   'come',
#   'come',
#   'come',
#   'venture',
#   'venture',
#   'opened',
#   'opened',
#   'opened',
#   'opened',
#   'cut',
#   'decided',
#   'mind',
#   'gives',
#   'goggling',
#   'stopped',
#   'stopped',
#   'stopped',
#   'stopped',
#   'let',
#   'let',
#   'let',
#   'let',
#   'let',
#   'swung',
#   'ran',
#   'ran',
#   'hoped',
#   'hoped',
#   'removed',
#   'open',
#   'showed',
#   'showed',
#   'grasp',
#   'makes',
#   'regards',
#   'consider',
#   'tells',
#   'tells',
#   'admired',
#   'lit',
#   'lit',
#   'intended',
#   'comes',
#   'comes',
#   'announced',
#   'thinks',
#   'thinks',
#   'thinks',
#   'talked',
#   'wants',
#   'wants',
#   'wants',
#   'wants',
#   'wants',
#   'tapped',
#   'rising',
#   'writes',
#   'answer',
#   'shook',
#   'handed',
#   'lost',
#   'remember',
#   'want',
#   'want',
#   'want',
#   'want',
#   'want',
#   'send',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'remembered',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'knew',
#   'believe',
#   'does',
#   'recognized',
#   'recognized',
#   'recognized',
#   'debated',
#   'continued',
#   'continued',
#   'continued',
#   'supposed',
#   'supposed',
#   'supposed',
#   'supposed',
#   'stepped',
#   'overtook',
#   'began',
#   'began',
#   'began',
#   'began',
#   'began',
#   'drove',
#   'reflected',
#   'reflected',
#   'flicked',
#   'enjoy',
#   'lift',
#   'loved',
#   'say',
#   'say',
#   'say',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'realized',
#   'signaled',
#   'use',
#   'knows',
#   'knows',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'tell',
#   'doing',
#   'doing',
#   'cared',
#   'pinch',
#   'behave',
#   'give',
#   'broke',
#   'arose',
#   'arose',
#   'guessed',
#   'guessed',
#   'lifted',
#   'lifted',
#   'forming',
#   'moved',
#   'moved',
#   'moved',
#   'listen',
#   "'s",
#   "'s",
#   "'s",
#   "'s",
#   "'s",
#   'mixing',
#   'coming',
#   'coming',
#   'balanced',
#   'waved',
#   'waved',
#   'add',
#   'nodded',
#   'nodded',
#   'considered',
#   'considered',
#   'seemed',
#   'acted',
#   'imagine',
#   'believed',
#   'agree',
#   'been',
#   'talking',
#   'talking',
#   'stay',
#   'observed',
#   'meant',
#   ...],
#  [],
#  ['kept',
#   'recognized',
#   'going',
#   'going',
#   'come',
#   'was',
#   'was',
#   'was',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'gave',
#   'does',
#   'drops',
#   'says',
#   'picked',
#   'lost',
#   'got',
#   'had',
#   'had',
#   'looked',
#   'hoped',
#   'told',
#   'showing',
#   'groped',
#   'let',
#   'frowned',
#   'is',
#   'intends',
#   'flew',
#   'flew',
#   'leaving',
#   'knew',
#   'laughed',
#   'are',
#   'showed',
#   'tagged',
#   'did',
#   'cleared',
#   'act',
#   'believe',
#   'were',
#   'make'],
#  ['calling',
#   'flying',
#   'do',
#   'seen',
#   'was',
#   'was',
#   'going',
#   'took',
#   'wants',
#   'take',
#   'did',
#   'afford'],
#  ['lay',
#   'waited',
#   'stretched',
#   'caught',
#   'bulked',
#   'said',
#   'said',
#   'said',
#   'gave',
#   'started',
#   'bumped'],
#  ['stared',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shook',
#   'briefed',
#   'doing',
#   'pinned',
#   'gave',
#   'waited',
#   'arose',
#   'whispered',
#   'raised',
#   'moistened',
#   'mentioned',
#   'has',
#   'got',
#   'showed',
#   'do',
#   'was',
#   'was',
#   'made'],
#  ['understand',
#   'got',
#   'shrugged',
#   'told',
#   'dare',
#   'wanted',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'gathered',
#   'opened',
#   'opened',
#   'held',
#   'held',
#   'put',
#   'put',
#   'looked',
#   'regard',
#   'had',
#   'be'],
#  ['found', 'countenances', 'countenance'],
#  ['said', 'showed', 'got'],
#  ['crouched',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'left',
#   'put',
#   'has',
#   'sat',
#   'began'],
#  ['handed'],
#  [],
#  [],
#  ['had', 'have', 'has', 'assigned', 'do', 'mind'],
#  ['know'],
#  ['bother',
#   'got',
#   'noticed',
#   'knew',
#   'show',
#   'see',
#   'talk',
#   'reported',
#   'speak',
#   'speak',
#   'says',
#   'gives',
#   'picking',
#   'has',
#   'criticizes',
#   'warns',
#   'thinks'],
#  ['said', 'said', 'put'],
#  ['told', 'told'],
#  ['doing', 'using', 'uses', 'have'],
#  [],
#  ['says',
#   'says',
#   'says',
#   'had',
#   'had',
#   'consider',
#   'read',
#   'took',
#   'arranged',
#   'ambled',
#   'got',
#   'got',
#   'got',
#   'cared',
#   'wants',
#   'wants',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'doubt',
#   'like',
#   'was',
#   'was',
#   'make',
#   'did',
#   'did',
#   'emitted',
#   'shown',
#   'looked',
#   'went',
#   'seemed',
#   'asked',
#   'defended',
#   'knew',
#   'worked',
#   'used',
#   'seems',
#   'decided',
#   'say',
#   'say',
#   'mean',
#   'ran',
#   'runs',
#   'is',
#   'drives',
#   'seem',
#   'gave',
#   'gave',
#   'get',
#   'get',
#   'has',
#   'have',
#   'muttering',
#   'called',
#   'expressed',
#   'figures',
#   'sitting',
#   'hesitating',
#   'threw',
#   'handed',
#   'lifted',
#   'opened',
#   'turned',
#   'gaped',
#   'seen',
#   'found',
#   'swallowed',
#   'told',
#   'stayed'],
#  ['was'],
#  ['said', 'said', 'said', 'said', 'said'],
#  ['called',
#   'knew',
#   'drawn',
#   'hear',
#   'make',
#   'hung',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'shook',
#   'shook',
#   'resolve',
#   'responded',
#   'colored',
#   'led',
#   'married',
#   'reddened',
#   'looked',
#   'looked',
#   'take',
#   'take',
#   'perform',
#   'broke',
#   'broke',
#   'whistled',
#   'went',
#   'went',
#   'stood',
#   'marked',
#   'done',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'proved',
#   'showed',
#   'expecting',
#   'is',
#   'is',
#   'seen',
#   'was',
#   'was',
#   'was',
#   'turned',
#   'turned',
#   'drew',
#   'feel',
#   'offered',
#   'passed',
#   'smile',
#   'managed',
#   'holding',
#   'got',
#   'got',
#   'got',
#   'got',
#   'sat',
#   'sat',
#   'acknowledged',
#   'decided',
#   'has',
#   'has',
#   'has',
#   'has',
#   'has',
#   'have',
#   'interrupted',
#   'stopped',
#   'getting',
#   'think',
#   'mean',
#   'see',
#   'see',
#   'wilted',
#   'been',
#   'want',
#   "'s",
#   'took',
#   'tells',
#   'believed',
#   'started',
#   'guessed',
#   'opened',
#   'put',
#   'put',
#   'know',
#   'be',
#   'taking',
#   'knows'],
#  ['produced',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'cleared',
#   'mentioned',
#   'stopped',
#   'thought',
#   'sat',
#   'grew',
#   'hearing',
#   'understand',
#   'seeing',
#   'liked',
#   'arose',
#   'wanted',
#   'says'],
#  ['unfolded'],
#  ['came', 'said', 'said', 'said', 'released'],
#  ['said', 'fly'],
#  ['took',
#   'took',
#   'took',
#   'has',
#   'asked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'mumbled',
#   'said',
#   'said',
#   'going',
#   'is',
#   'is',
#   'is',
#   'says',
#   'indicate',
#   'say',
#   'jumping',
#   'was',
#   'was',
#   'thinks',
#   'left',
#   'did',
#   'got',
#   'told',
#   'sense',
#   "'s",
#   'be',
#   'went',
#   'went',
#   'stay'],
#  ['heard'],
#  ['broke', 'said', 'observed'],
#  ['set', 'set', 'said', 'turned', 'meant'],
#  ['letting', 'went', 'went', 'ate', 'said', "'s", 'got', 'turned'],
#  ['look',
#   'looked',
#   'lost',
#   'lost',
#   'began',
#   'paused',
#   'leaving',
#   'realize',
#   'going',
#   'going',
#   'bit',
#   'said',
#   'turned',
#   'go',
#   'tell'],
#  ['has',
#   'went',
#   'got',
#   'going',
#   'want',
#   'fretting',
#   'left',
#   'is',
#   'is',
#   'gave',
#   'thought',
#   'did',
#   'recognized',
#   'seeing',
#   'be',
#   'stay',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'came',
#   'came',
#   'lifting',
#   'saw',
#   'was',
#   'were',
#   'recovered',
#   'portrayed'],
#  ['learn',
#   'had',
#   'had',
#   'had',
#   'get',
#   'gave',
#   'like',
#   'went',
#   'went',
#   'went',
#   'apologized',
#   'going',
#   'taken',
#   'kept',
#   'said',
#   'said',
#   'seemed',
#   'understood',
#   'compose',
#   'made',
#   'explain',
#   'got',
#   'thinks',
#   'thinks',
#   'needs',
#   'watched',
#   'want',
#   'was',
#   'was',
#   'look',
#   'killed'],
#  [],
#  ['is'],
#  ['called',
#   'repeat',
#   'is',
#   'is',
#   'has',
#   'has',
#   'doing',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'retired',
#   'told',
#   'told',
#   'thought',
#   'come',
#   'wanted',
#   'make',
#   'began',
#   'taken',
#   'crying',
#   'faced',
#   'knows',
#   'spoke',
#   'arisen',
#   'came',
#   'snapped',
#   'moved',
#   'pushed',
#   'coming',
#   'let',
#   'looked',
#   'looked',
#   'smiled',
#   'gave',
#   'sent',
#   'slicing',
#   'reached',
#   'sat',
#   'dislike',
#   'happens',
#   'calling',
#   'throwing',
#   'made',
#   'take',
#   'say',
#   'took',
#   'says',
#   'says',
#   'drank',
#   'drank',
#   'drank',
#   'saw',
#   'do',
#   'found',
#   'find',
#   'like',
#   'liked',
#   'pulled'],
#  ['got', 'go', 'do', 'made', 'saying', 'says', 'says', 'says', 'thought'],
#  [],
#  ['told',
#   'told',
#   'had',
#   'had',
#   'had',
#   'answered',
#   'doubted',
#   'washed',
#   'washed',
#   'rated',
#   'give',
#   'gave',
#   'said',
#   'squawked',
#   'crossed',
#   'did',
#   'know',
#   'have',
#   'knows',
#   'show',
#   'do',
#   'added'],
#  ['take', 'rang', 'said'],
#  ['offering',
#   'admitted',
#   'have',
#   'have',
#   'have',
#   'feel',
#   'regarded',
#   'knew',
#   'saw',
#   'saw',
#   'explained',
#   'needed',
#   'wanted',
#   'wanted',
#   'stoop',
#   'intended',
#   'come',
#   'swallowed',
#   'decided'],
#  [],
#  [],
#  ['said', 'dragged', 'read'],
#  ['like', 'kidding', 'kidding', 'know', 'having'],
#  [],
#  ['appeared', 'saying'],
#  ['come',
#   'was',
#   'was',
#   'had',
#   'missed',
#   'forgot',
#   'spot',
#   'rescued',
#   'restated',
#   'made',
#   'halt',
#   'proved',
#   'refused',
#   'said',
#   'weighed',
#   'got',
#   'hope',
#   'let',
#   'have',
#   'feel',
#   'thought',
#   'found',
#   'agree'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'see',
#   'makes',
#   'do',
#   'got',
#   'talked',
#   'approve',
#   'thinks',
#   'thinks',
#   'told',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'expect',
#   'want',
#   'escorted',
#   'has'],
#  ['having', 'showed', 'was'],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'scratched',
#   'began',
#   'made',
#   'shrugged',
#   'grown',
#   'pursed',
#   'knocked',
#   'tells',
#   'going',
#   'sprang',
#   'opened',
#   "'s",
#   'tossed',
#   'tries'],
#  ['said',
#   'said',
#   'said',
#   'raised',
#   'raised',
#   'looked',
#   'turned',
#   'brought',
#   'taken',
#   'gave'],
#  [],
#  ['had',
#   'took',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'knew',
#   'advanced',
#   'typed',
#   'went',
#   'laid',
#   'hesitated',
#   'asked',
#   'opened',
#   'shrugged',
#   'closed',
#   'cried',
#   'entered',
#   'called',
#   'remember',
#   'remembered',
#   'take'],
#  ['was', 'sent'],
#  ['explain', 'goes', 'think', 'have'],
#  ['said'],
#  ['was',
#   'was',
#   'was',
#   'knew',
#   'knew',
#   'had',
#   'meant',
#   'going',
#   'going',
#   'going',
#   'rechristened',
#   'sat',
#   'sat',
#   'controlled',
#   'send',
#   'meeting',
#   'know',
#   'lied',
#   'aggravated',
#   'says',
#   'enlisting',
#   'feels',
#   'do',
#   'said',
#   'said',
#   'said',
#   'said',
#   'found',
#   'repeated',
#   'repeated',
#   'repeated',
#   'listening',
#   'went',
#   'unlocked',
#   'please',
#   'drive',
#   'driven',
#   'checking',
#   'stood',
#   'pressed',
#   'showed',
#   'looked',
#   'admit'],
#  ['faced',
#   'began',
#   'putting',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'says',
#   'says',
#   'says',
#   'get',
#   'get',
#   'managed',
#   'let',
#   'doubled',
#   'thinks',
#   'happened',
#   'comes',
#   'say',
#   'shoot',
#   'thought',
#   'do',
#   'calls',
#   'puts',
#   'puts',
#   'have',
#   'show',
#   'see',
#   'was',
#   'has',
#   'went',
#   'met',
#   'know',
#   'is',
#   'knows',
#   'sat',
#   'threw',
#   'remember'],
#  ['diagrams',
#   'be',
#   'be',
#   'comes',
#   'told',
#   'told',
#   'saw',
#   'saw',
#   'saw',
#   'saw',
#   'was',
#   'was',
#   'was',
#   'flying',
#   'erected',
#   'lifted',
#   'lifted',
#   'stood',
#   'stood',
#   'stood',
#   'looked',
#   'looked',
#   'looked',
#   'had',
#   'had',
#   'had',
#   'had',
#   'had',
#   'showed',
#   'felt',
#   'felt',
#   'put',
#   'put',
#   'proved',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'extracted',
#   'got',
#   'got',
#   'narrowed',
#   'narrowed',
#   'regarded',
#   'regarded',
#   'make',
#   'send',
#   'let',
#   'let',
#   'let',
#   'found',
#   'found',
#   'tossed',
#   'dropped',
#   'dropped',
#   'brought',
#   'set',
#   'poised',
#   'smack',
#   'began',
#   'began',
#   'flew',
#   'killed',
#   'forgot',
#   'emptied',
#   'poured',
#   'poured',
#   'frowned',
#   'rested',
#   'gaze',
#   'considered',
#   'accept',
#   'get',
#   'get',
#   'help',
#   'waiting',
#   'studied',
#   'pulled',
#   'wheeled',
#   'moved',
#   'moved',
#   'swung',
#   'is',
#   'is',
#   'happen',
#   'came',
#   'came',
#   'dug',
#   'watched',
#   'shook',
#   'shook',
#   'smiled',
#   'has',
#   'has',
#   'has',
#   'getting',
#   'use',
#   'opened',
#   'been',
#   'try',
#   'laughed',
#   'went',
#   'slouched',
#   'gave',
#   'slapped',
#   'gazed',
#   'attempt',
#   'say',
#   'knew',
#   'knew',
#   'acknowledged',
#   'straightened',
#   'depressed',
#   'named',
#   'remarks',
#   'stared',
#   'glanced',
#   'were',
#   'rising',
#   'crouched',
#   'made',
#   'made',
#   'made',
#   'scooped',
#   'weighed',
#   'lie',
#   'have',
#   'drawn',
#   'cut',
#   'flipped',
#   'held',
#   'remembered',
#   'speaking',
#   'agreed',
#   'seemed',
#   'feel',
#   'lost',
#   'doing',
#   'missing',
#   'wanted',
#   'laid'],
#  [],
#  ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'caught',
#   'see',
#   'see',
#   'looks',
#   'handed',
#   'shot',
#   'consulted',
#   'stood',
#   'looked',
#   'looked',
#   'has',
#   'was',
#   'regarded',
#   'dealt',
#   'lifted',
#   'had',
#   'turned',
#   'joined',
#   'glanced',
#   'saw',
#   'wait',
#   'called',
#   'roared',
#   'hooked',
#   'came',
#   'thought',
#   'seeing',
#   'put',
#   'listen',
#   'did',
#   'twisted',
#   'took'],
#  ['want', 'came', 'know'],
#  ['stepped'],
#  ['was',
#   'was',
#   'picked',
#   'waiting',
#   'want',
#   'judge',
#   'take',
#   'sobered',
#   'been'],
#  ['saw', 'said', 'earn', 'earns', 'moistened', 'sit', 'had'],
#  ...]

# %%
dictionary = corpora.Dictionary(charTexts)
corpus = [dictionary.doc2bow(text) for text in charTexts]
num_topics = 10
lda_model = gensim.models.LdaModel(corpus, id2word=dictionary, 
                                   num_topics=num_topics, passes=3, alpha='auto')

# %%
for i in range(num_topics):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	said thought had felt saw knew heard looked asked was
# topic 1:	was had got went made came took come looked knew
# topic 2:	put know left please shouted swore cries provided shouts included
# topic 3:	said came smiled laughed seemed sitting standing paused raised looked
# topic 4:	told had wanted said have was say knew did be
# topic 5:	said asked looked told had was turned took came put
# topic 6:	say says has is knows thinks look 's wants looks
# topic 7:	going said wrote nudged smiles take talking has call are
# topic 8:	died were pleaded taught grab lost retrieved build married reconciled
# topic 9:	had was said came gave made began wore spoke found

# %%
# {"agent":[{"w":"wore","i":104276},
#           {"w":"had","i":104283},
#           {"w":"carried","i":104297},
#           {"w":"seemed","i":104306},
#           {"w":"said","i":104318},
#           {"w":"said","i":104358},
#           {"w":"said","i":107106},
#           {"w":"realized","i":107110},
#           {"w":"gave","i":107125}],
#  "NNPcount":3,
#  "names":[{"c":3,"n":"Dr. Whittaker"}],
#  "mod":[],
#  "speaking":[{"w":"`` Oh , good morning , '' ","i":104321},
#              {"w":"`` Of course , '' ","i":104353}],
#  "patient":[],
#  "g":2,
#  "id":0,
#  "poss":[{"w":"words","i":107127}]}
